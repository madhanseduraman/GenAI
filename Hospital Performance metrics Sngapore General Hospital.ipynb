# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=1.6.1 in /opt/anaconda3/lib/python3.12/site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in /opt/anaconda3/lib/python3.12/site-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.12/site-packages (from wordcloud) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->wordcloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.4-cp312-cp312-macosx_11_0_arm64.whl (168 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.4

# %%
# !pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.19.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: nltk>=3.9 in /opt/anaconda3/lib/python3.12/site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.12/site-packages (from nltk>=3.9->textblob) (8.1.7)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.12/site-packages (from nltk>=3.9->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/lib/python3.12/site-packages (from nltk>=3.9->textblob) (2024.9.11)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.12/site-packages (from nltk>=3.9->textblob) (4.66.5)
# Downloading textblob-0.19.0-py3-none-any.whl (624 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 624.3/624.3 kB 10.8 MB/s eta 0:00:00
# Installing collected packages: textblob
# Successfully installed textblob-0.19.0

# %%
# ==============================
# 1. Setup & Load Data
# ==============================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from textblob import TextBlob

# Load dataset
df = pd.read_excel("Singapore General Hospital.xlsx")

# Display basic info
print(df.shape)
df.head()
# Out:
# (614, 35)
#                                    query                        name  \
# 0  0x31da196f954c6cd5:0x5c6009b161544a96  Singapore General Hospital
# 1  0x31da196f954c6cd5:0x5c6009b161544a96  Singapore General Hospital
# 2  0x31da196f954c6cd5:0x5c6009b161544a96  Singapore General Hospital
# 3  0x31da196f954c6cd5:0x5c6009b161544a96  Singapore General Hospital
# 4  0x31da196f954c6cd5:0x5c6009b161544a96  Singapore General Hospital
#
#                                google_id                     place_id  \
# 0  0x31da196f954c6cd5:0x5c6009b161544a96  ChIJ1WxMlW8Z2jERlkpUYbEJYFw
# 1  0x31da196f954c6cd5:0x5c6009b161544a96  ChIJ1WxMlW8Z2jERlkpUYbEJYFw
# 2  0x31da196f954c6cd5:0x5c6009b161544a96  ChIJ1WxMlW8Z2jERlkpUYbEJYFw
# 3  0x31da196f954c6cd5:0x5c6009b161544a96  ChIJ1WxMlW8Z2jERlkpUYbEJYFw
# 4  0x31da196f954c6cd5:0x5c6009b161544a96  ChIJ1WxMlW8Z2jERlkpUYbEJYFw
#
#                                        location_link  \
# 0  https://www.google.com/maps/place/Singapore+Ge...
# 1  https://www.google.com/maps/place/Singapore+Ge...
# 2  https://www.google.com/maps/place/Singapore+Ge...
# 3  https://www.google.com/maps/place/Singapore+Ge...
# 4  https://www.google.com/maps/place/Singapore+Ge...
#
#                                         reviews_link  reviews  rating  \
# 0  https://search.google.com/local/reviews?placei...      624     3.4
# 1  https://search.google.com/local/reviews?placei...      624     3.4
# 2  https://search.google.com/local/reviews?placei...      624     3.4
# 3  https://search.google.com/local/reviews?placei...      624     3.4
# 4  https://search.google.com/local/reviews?placei...      624     3.4
#
#                                            review_id  \
# 0  Ci9DQUlRQUNvZENodHljRjlvT21kSmNHVjViMDlmZUhkd1...
# 1  Ci9DQUlRQUNvZENodHljRjlvT2t4Zk1ISldMVnB3WlRkTW...
# 2  Ci9DQUlRQUNvZENodHljRjlvT201NGRFeENVR0owVkVwUG...
# 3  Ci9DQUlRQUNvZENodHljRjlvT25aS2VIUlFjMjFQVTJoWF...
# 4  Ci9DQUlRQUNvZENodHljRjlvT21wQ2FIQjZPRXhvVVVGV1...
#
#                                 review_pagination_id  ... review_rating  \
# 0  CAESYENBRVFBUnBDUTJrNFNVRlNTVzVEWjI5QlVEY3lSMk...  ...             1
# 1  CAESY0NBRVFBaHBFUTJwRlNVRlNTWEJEWjI5QlVEY3lSMl...  ...             1
# 2  CAESY0NBRVFBeHBFUTJwRlNVRlNTWEJEWjI5QlVEY3lSMl...  ...             3
# 3  CAESY0NBRVFCQnBFUTJwRlNVRlNTWEJEWjI5QlVEY3lSMl...  ...             1
# 4  CAESY0NBRVFCUnBFUTJwRlNVRlNTWEJEWjI5QlVEY3lSMl...  ...             5
#
#   review_timestamp  review_datetime_utc review_likes           reviews_id  \
# 0       1756212144  08/26/2025 12:42:24          NaN  6656330906700368534
# 1       1754935232  08/11/2025 18:00:32          NaN  6656330906700368534
# 2       1753671107  07/28/2025 02:51:47          NaN  6656330906700368534
# 3       1753357154  07/24/2025 11:39:14          NaN  6656330906700368534
# 4       1753243774  07/23/2025 04:09:34          NaN  6656330906700368534
#
#    reviews_per_score_1 reviews_per_score_2 reviews_per_score_3  \
# 0                  177                  30                  57
# 1                  177                  30                  57
# 2                  177                  30                  57
# 3                  177                  30                  57
# 4                  177                  30                  57
#
#   reviews_per_score_4  reviews_per_score_5
# 0                  90                  270
# 1                  90                  270
# 2                  90                  270
# 3                  90                  270
# 4                  90                  270
#
# [5 rows x 35 columns]

# %%
df.columns
# Out:
# Index(['query', 'name', 'google_id', 'place_id', 'location_link',
#        'reviews_link', 'reviews', 'rating', 'review_id',
#        'review_pagination_id', 'author_link', 'author_title', 'author_id',
#        'author_image', 'author_reviews_count', 'author_ratings_count',
#        'review_text', 'review_img_urls', 'review_img_url', 'review_questions',
#        'review_photo_ids', 'owner_answer', 'owner_answer_timestamp',
#        'owner_answer_timestamp_datetime_utc', 'review_link', 'review_rating',
#        'review_timestamp', 'review_datetime_utc', 'review_likes', 'reviews_id',
#        'reviews_per_score_1', 'reviews_per_score_2', 'reviews_per_score_3',
#        'reviews_per_score_4', 'reviews_per_score_5'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 35 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   query                                614 non-null    object
#  1   name                                 614 non-null    object
#  2   google_id                            614 non-null    object
#  3   place_id                             614 non-null    object
#  4   location_link                        614 non-null    object
#  5   reviews_link                         614 non-null    object
#  6   reviews                              614 non-null    int64
#  7   rating                               614 non-null    float64
#  8   review_id                            614 non-null    object
#  9   review_pagination_id                 613 non-null    object
#  10  author_link                          614 non-null    object
#  11  author_title                         614 non-null    object
#  12  author_id                            614 non-null    object
#  13  author_image                         614 non-null    object
#  14  author_reviews_count                 614 non-null    int64
#  15  author_ratings_count                 614 non-null    int64
#  16  review_text                          356 non-null    object
#  17  review_img_urls                      29 non-null     object
#  18  review_img_url                       29 non-null     object
#  19  review_questions                     0 non-null      float64
#  20  review_photo_ids                     29 non-null     object
#  21  owner_answer                         5 non-null      object
#  22  owner_answer_timestamp               5 non-null      float64
#  23  owner_answer_timestamp_datetime_utc  5 non-null      object
#  24  review_link                          614 non-null    object
#  25  review_rating                        614 non-null    int64
#  26  review_timestamp                     614 non-null    int64
#  27  review_datetime_utc                  614 non-null    object
#  28  review_likes                         0 non-null      float64
#  29  reviews_id                           614 non-null    int64
#  30  reviews_per_score_1                  614 non-null    int64
#  31  reviews_per_score_2                  614 non-null    int64
#  32  reviews_per_score_3                  614 non-null    int64
#  33  reviews_per_score_4                  614 non-null    int64
#  34  reviews_per_score_5                  614 non-null    int64
# dtypes: float64(4), int64(11), object(20)
# memory usage: 168.0+ KB

# %%
# ==============================
# 2. Data Cleaning
# ==============================
# Remove duplicates
df = df.drop_duplicates()

# Convert datetime column
df['review_datetime_utc'] = pd.to_datetime(df['review_datetime_utc'], errors='coerce')

# Add review text length
df['review_length'] = df['review_text'].astype(str).apply(len)

# Check missing values
print(df.isna().sum())
# Out:
# query                                    0
# name                                     0
# google_id                                0
# place_id                                 0
# location_link                            0
# reviews_link                             0
# reviews                                  0
# rating                                   0
# review_id                                0
# review_pagination_id                     1
# author_link                              0
# author_title                             0
# author_id                                0
# author_image                             0
# author_reviews_count                     0
# author_ratings_count                     0
# review_text                            258
# review_img_urls                        585
# review_img_url                         585
# review_questions                       614
# review_photo_ids                       585
# owner_answer                           609
# owner_answer_timestamp                 609
# owner_answer_timestamp_datetime_utc    609
# review_link                              0
# review_rating                            0
# review_timestamp                         0
# review_datetime_utc                      0
# review_likes                           614
# reviews_id                               0
# reviews_per_score_1                      0
# reviews_per_score_2                      0
# reviews_per_score_3                      0
# reviews_per_score_4                      0
# reviews_per_score_5                      0
# review_length                            0
# dtype: int64

# %%
# ==============================
# 3. Descriptive Statistics
# ==============================
print(df['review_rating'].describe())
print(df['review_length'].describe())

print("Reviewer reviews count stats:")
print(df['author_reviews_count'].describe())

print("Reviewer ratings count stats:")
print(df['author_ratings_count'].describe())

print("Owner response rate:", df['owner_answer'].notna().mean())
# Out:
# count    614.000000
# mean       3.390879
# std        1.704130
# min        1.000000
# 25%        1.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000
# Name: review_rating, dtype: float64
# count     614.000000
# mean      186.965798
# std       425.632826
# min         1.000000
# 25%         3.000000
# 50%        26.000000
# 75%       194.000000
# max      4082.000000
# Name: review_length, dtype: float64
# Reviewer reviews count stats:
# count     614.000000
# mean       83.877850
# std       228.047088
# min         0.000000
# 25%         2.000000
# 50%         8.000000
# 75%        55.000000
# max      2717.000000
# Name: author_reviews_count, dtype: float64
# Reviewer ratings count stats:
# count     614.000000
# mean       44.070033
# std       169.490716
# min         0.000000
# 25%         1.000000
# 50%         3.000000
# 75%        17.000000
# max      2356.000000
# Name: author_ratings_count, dtype: float64
# Owner response rate: 0.008143322475570033

# %%
# ==============================
# 4. Univariate Analysis
# ==============================
sns.countplot(x='review_rating', data=df)
plt.title("Ratings Distribution")
plt.show()

sns.histplot(df['review_length'], bins=30, kde=True)
plt.title("Review Length Distribution")
plt.show()

sns.histplot(df['author_reviews_count'], bins=30)
plt.title("Reviewer Review Count Distribution")
plt.show()

# %%
# ==============================
# 5. Bivariate Analysis
# ==============================
sns.boxplot(x='review_rating', y='review_length', data=df)
plt.title("Review Length vs Rating")
plt.show()

sns.heatmap(df[['review_rating','review_likes','author_reviews_count','review_length']].corr(),
            annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

sns.barplot(x='review_rating', y=df['owner_answer'].notna(), data=df, estimator=np.mean)
plt.title("Owner Response Rate by Rating")
plt.show()

# %%
# ==============================
# 6. Time-based Analysis
# ==============================
df['month'] = df['review_datetime_utc'].dt.to_period("M")

monthly = df.groupby('month').agg(
    avg_rating=('review_rating','mean'),
    review_count=('review_rating','count')
)

monthly.plot(y=['avg_rating','review_count'], subplots=True, figsize=(10,6),
             title=["Average Rating Over Time","Review Count Over Time"])
plt.show()

# %%
# ==============================
# 7. Text Analysis (WordCloud + Sentiment)
# ==============================
# Positive reviews wordcloud
positive_text = " ".join(df[df['review_rating'] >= 4]['review_text'].dropna())
wordcloud_pos = WordCloud(width=800, height=400, background_color='white').generate(positive_text)
plt.imshow(wordcloud_pos, interpolation='bilinear')
plt.axis("off")
plt.title("Positive Reviews WordCloud")
plt.show()

# Negative reviews wordcloud
negative_text = " ".join(df[df['review_rating'] <= 2]['review_text'].dropna())
wordcloud_neg = WordCloud(width=800, height=400, background_color='black').generate(negative_text)
plt.imshow(wordcloud_neg, interpolation='bilinear')
plt.axis("off")
plt.title("Negative Reviews WordCloud")
plt.show()

# Sentiment polarity
df['sentiment'] = df['review_text'].astype(str).apply(lambda x: TextBlob(x).sentiment.polarity)
sns.histplot(df['sentiment'], bins=30, kde=True)
plt.title("Sentiment Distribution")
plt.show()

# %%
# ==============================
# 8. Reviewer Insights
# ==============================
top_reviewers = df.groupby('author_title').size().sort_values(ascending=False).head(10)
print("Top Reviewers:")
print(top_reviewers)

df['is_frequent'] = df['author_reviews_count'] > 5
sns.countplot(x='is_frequent', hue='review_rating', data=df)
plt.title("Frequent vs One-time Reviewers by Rating")
plt.show()
# Out:
# Top Reviewers:
# author_title
# D C                           2
# Jeremy Lim                    2
# * j-hope just logged out *    1
# Shine Flame                   1
# Shah Osman                    1
# Sheng Lee                     1
# Sherril Ewing                 1
# Shervin Ooi                   1
# Shifa Naa                     1
# Shiming Zeng                  1
# dtype: int64

# %%
# ==============================
# 9. Owner Response Analysis
# ==============================
neg = df[df['review_rating'] <= 2]
pos = df[df['review_rating'] >= 4]

print("Response rate for negative reviews:", neg['owner_answer'].notna().mean())
print("Response rate for positive reviews:", pos['owner_answer'].notna().mean())
# Out:
# Response rate for negative reviews: 0.024509803921568627
# Response rate for positive reviews: 0.0

# %%
# ==============================
# 10. Aggregate Check
# ==============================
agg_counts = {
    "1_star": df['reviews_per_score_1'].iloc[0],
    "2_star": df['reviews_per_score_2'].iloc[0],
    "3_star": df['reviews_per_score_3'].iloc[0],
    "4_star": df['reviews_per_score_4'].iloc[0],
    "5_star": df['reviews_per_score_5'].iloc[0],
}
print("Aggregated counts from metadata:", agg_counts)

actual_counts = df['review_rating'].value_counts()
print("Actual counts from reviews:", actual_counts)
# Out:
# Aggregated counts from metadata: {'1_star': 177, '2_star': 30, '3_star': 57, '4_star': 90, '5_star': 270}
# Actual counts from reviews: review_rating
# 5    265
# 1    174
# 4     88
# 3     57
# 2     30
# Name: count, dtype: int64

# %% [markdown]
# #### 🏥 Google Reviews EDA + NLP Extension

# %%
# ==============================
# 11. Keyword Extraction (TF-IDF)
# ==============================
from sklearn.feature_extraction.text import TfidfVectorizer

# Use only non-null review text
texts = df['review_text'].dropna().astype(str)

# Vectorize reviews
tfidf = TfidfVectorizer(stop_words='english', max_features=20, ngram_range=(1,2))
tfidf_matrix = tfidf.fit_transform(texts)

# Top keywords
keywords = pd.DataFrame({
    "keyword": tfidf.get_feature_names_out(),
    "score": tfidf_matrix.sum(axis=0).A1
}).sort_values(by="score", ascending=False)

print("Top Keywords (TF-IDF):")
print(keywords.head(20))
# Out:
# Top Keywords (TF-IDF):
#         keyword      score
# 5      hospital  45.656962
# 4          good  33.266766
# 13          sgh  32.568441
# 15        staff  28.681175
# 16         time  24.860313
# 2        doctor  22.761699
# 10      patient  22.707786
# 3       doctors  21.971036
# 7       medical  20.994797
# 12      service  20.939511
# 17         wait  20.404886
# 6         hours  20.099241
# 9        nurses  18.736551
# 18      waiting  18.422172
# 1          care  18.218613
# 14    singapore  16.490532
# 11     patients  16.344440
# 19         ward  14.915315
# 0   appointment  14.659320
# 8         nurse  14.569807

# %%
# ==============================
# 12. Topic Modeling (LDA)
# ==============================
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer

# Count vectorizer for LDA
cv = CountVectorizer(stop_words='english', max_df=0.9, min_df=5)
cv_matrix = cv.fit_transform(texts)

# Fit LDA model
lda = LatentDirichletAllocation(n_components=5, random_state=42)
lda.fit(cv_matrix)

# Display top words for each topic
def display_topics(model, feature_names, no_top_words=10):
    for idx, topic in enumerate(model.components_):
        print(f"Topic {idx+1}:")
        print(" | ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))
        print("\n")

display_topics(lda, cv.get_feature_names_out())
# Out:
# Topic 1:
# good | people | care | place | ray | friendly | staff | private | sgh | help
#
#
# Topic 2:
# hospital | singapore | service | best | general | good | mother | waiting | ward | care
#
#
# Topic 3:
# sgh | wait | medical | time | appointment | don | long | doctor | department | hospital
#
#
# Topic 4:
# patient | nurse | doctor | sgh | time | asked | waiting | hospital | staff | ward
#
#
# Topic 5:
# nurses | staff | care | dr | doctors | doctor | good | thank | hospital | sgh

# %%
# ==============================
# 13. Topic Distribution per Review
# ==============================
topic_values = lda.transform(cv_matrix)

# Create a new DataFrame with the same index as cv_matrix to ensure alignment
# This assumes cv_matrix was created from a subset of df
df_subset = df.iloc[cv_matrix.index] if hasattr(cv_matrix, 'index') else df.head(len(topic_values))

# Add dominant topic to this subset
df_subset['dominant_topic'] = topic_values.argmax(axis=1)

# Plot with the correctly aligned data
sns.countplot(x='dominant_topic', data=df_subset)
plt.title("Most Common Topics in Reviews")
plt.show()

# Alternatively, if you need to keep the original df intact:
# Create a temporary DataFrame for plotting
# temp_df = pd.DataFrame({'dominant_topic': topic_values.argmax(axis=1)})
# sns.countplot(x='dominant_topic', data=temp_df)
# Out:
# /var/folders/st/zkgc24pn5qlfxb9k9y3j07d40000gn/T/ipykernel_2133/1274790882.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['dominant_topic'] = topic_values.argmax(axis=1)

# %% [markdown]
# # Assistant
# This error occurs because the length of the `topic_values` array (146) doesn't match the length of your DataFrame `df` (185). This mismatch happens when you try to assign the `dominant_topic` column to your DataFrame.
#
# The most likely cause is that your `cv_matrix` (CountVectorizer or TF-IDF matrix) was created using a subset of your data, or some rows were filtered out during preprocessing (perhaps due to empty reviews after text cleaning).
#
# Would you like me to provide the corrected code?

# %% [markdown]
# # KPI Metrics

# %%
import pandas as pd
import numpy as np
from textblob import TextBlob

# Ensure datetime and review length are present
df['review_datetime_utc'] = pd.to_datetime(df['review_datetime_utc'], errors='coerce')
df['review_length'] = df['review_text'].astype(str).apply(len)
df['sentiment'] = df['review_text'].astype(str).apply(lambda x: TextBlob(x).sentiment.polarity)

# %% [markdown]
# # ⭐ 1. Ratings-Based Metrics

# %%
# Average rating
avg_rating = df['review_rating'].mean()
median_rating = df['review_rating'].median()
rating_distribution = df['review_rating'].value_counts(normalize=True) * 100

print("Average Rating:", avg_rating)
print("Median Rating:", median_rating)
print("Rating Distribution (%):\n", rating_distribution)

# Trend over time (monthly)
df['month'] = df['review_datetime_utc'].dt.to_period("M")
rating_trend = df.groupby('month')['review_rating'].mean()
print("Monthly Rating Trend:\n", rating_trend.tail())
# Out:
# Average Rating: 3.3908794788273617
# Median Rating: 4.0
# Rating Distribution (%):
#  review_rating
# 5    43.159609
# 1    28.338762
# 4    14.332248
# 3     9.283388
# 2     4.885993
# Name: proportion, dtype: float64
# Monthly Rating Trend:
#  month
# 2025-04    3.250000
# 2025-05    3.636364
# 2025-06    1.800000
# 2025-07    3.000000
# 2025-08    1.000000
# Freq: M, Name: review_rating, dtype: float64

# %% [markdown]
# # 💬 2. Sentiment Metrics

# %%
avg_sentiment = df['sentiment'].mean()
sentiment_distribution = pd.cut(df['sentiment'], bins=[-1,-0.05,0.05,1], labels=["Negative","Neutral","Positive"]).value_counts(normalize=True) * 100

print("Average Sentiment Score:", avg_sentiment)
print("Sentiment Distribution (%):\n", sentiment_distribution)

# Correlation with rating
corr_sentiment_rating = df[['review_rating','sentiment']].corr().iloc[0,1]
print("Correlation between Sentiment & Rating:", corr_sentiment_rating)
# Out:
# Average Sentiment Score: 0.08201741917502264
# Sentiment Distribution (%):
#  sentiment
# Neutral     60.457516
# Positive    28.267974
# Negative    11.274510
# Name: proportion, dtype: float64
# Correlation between Sentiment & Rating: 0.3248610294052266

# %% [markdown]
# # ✍️ 3. Review Quality & Engagement

# %%
avg_review_length = df['review_length'].mean()
avg_likes = df['review_likes'].mean(skipna=True)

print("Average Review Length:", avg_review_length)
print("Average Likes per Review:", avg_likes)

# Length vs rating
length_by_rating = df.groupby('review_rating')['review_length'].mean()
print("Review Length by Rating:\n", length_by_rating)
# Out:
# Average Review Length: 186.9657980456026
# Average Likes per Review: nan
# Review Length by Rating:
#  review_rating
# 1    333.442529
# 2    234.400000
# 3    173.964912
# 4     49.625000
# 5    133.822642
# Name: review_length, dtype: float64

# %% [markdown]
# # 👥 4. Reviewer Behavior

# %%
# One-time vs frequent
one_time_reviewers = (df['author_reviews_count'] == 1).mean() * 100
frequent_reviewers = (df['author_reviews_count'] > 5).mean() * 100

print("One-time Reviewers (%):", one_time_reviewers)
print("Frequent Reviewers (%):", frequent_reviewers)

# Reviewer bias (avg rating by reviewer type)
df['is_frequent'] = df['author_reviews_count'] > 5
bias = df.groupby('is_frequent')['review_rating'].mean()
print("Avg Rating by Reviewer Type:\n", bias)
# Out:
# One-time Reviewers (%): 10.097719869706841
# Frequent Reviewers (%): 57.65472312703584
# Avg Rating by Reviewer Type:
#  is_frequent
# False    3.465385
# True     3.336158
# Name: review_rating, dtype: float64

# %% [markdown]
# # 🔁 5. Owner Response Metrics

# %%
# Overall response rate
response_rate = df['owner_answer'].notna().mean() * 100

# Response rate by rating
response_by_rating = df.groupby('review_rating')['owner_answer'].apply(lambda x: x.notna().mean()*100)

# Response by sentiment
df['sentiment_group'] = pd.cut(df['sentiment'], bins=[-1,-0.05,0.05,1], labels=["Negative","Neutral","Positive"])
response_by_sentiment = df.groupby('sentiment_group')['owner_answer'].apply(lambda x: x.notna().mean()*100)

print("Overall Response Rate (%):", response_rate)
print("Response Rate by Rating (%):\n", response_by_rating)
print("Response Rate by Sentiment (%):\n", response_by_sentiment)
# Out:
# Overall Response Rate (%): 0.8143322475570033
# Response Rate by Rating (%):
#  review_rating
# 1    2.873563
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# Name: owner_answer, dtype: float64
# Response Rate by Sentiment (%):
#  sentiment_group
# Negative    5.797101
# Neutral     0.270270
# Positive    0.000000
# Name: owner_answer, dtype: float64
# /var/folders/st/zkgc24pn5qlfxb9k9y3j07d40000gn/T/ipykernel_2133/4059787264.py:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   response_by_sentiment = df.groupby('sentiment_group')['owner_answer'].apply(lambda x: x.notna().mean()*100)

# %% [markdown]
# # 🔁 5. Owner Response Metrics

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# Create a copy of the dataframe with only non-NA reviews
# This ensures we work with the same subset throughout the code
df_clean = df.dropna(subset=['review_text']).copy()
texts = df_clean['review_text'].astype(str)

# ---- TF-IDF ----
tfidf = TfidfVectorizer(stop_words='english', max_features=20, ngram_range=(1,2))
tfidf_matrix = tfidf.fit_transform(texts)
keywords = pd.DataFrame({
    "keyword": tfidf.get_feature_names_out(),
    "score": tfidf_matrix.sum(axis=0).A1
}).sort_values(by="score", ascending=False)
print("Top TF-IDF Keywords:\n", keywords)

# ---- LDA Topic Modeling ----
cv = CountVectorizer(stop_words='english', max_df=0.9, min_df=5)
cv_matrix = cv.fit_transform(texts)

lda = LatentDirichletAllocation(n_components=5, random_state=42)
lda.fit(cv_matrix)

def display_topics(model, feature_names, no_top_words=10):
    topics = {}
    for idx, topic in enumerate(model.components_):
        topics[f"Topic {idx+1}"] = [feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]
    return topics

topics = display_topics(lda, cv.get_feature_names_out())
print("LDA Topics:\n", topics)

# Assign dominant topic per review
# Now we're using df_clean which has the same length as texts
topic_values = lda.transform(cv_matrix)
df_clean['dominant_topic'] = topic_values.argmax(axis=1) + 1

topic_distribution = df_clean['dominant_topic'].value_counts(normalize=True) * 100
print("Topic Distribution (%):\n", topic_distribution)
# Out:
# Top TF-IDF Keywords:
#          keyword      score
# 5      hospital  45.656962
# 4          good  33.266766
# 13          sgh  32.568441
# 15        staff  28.681175
# 16         time  24.860313
# 2        doctor  22.761699
# 10      patient  22.707786
# 3       doctors  21.971036
# 7       medical  20.994797
# 12      service  20.939511
# 17         wait  20.404886
# 6         hours  20.099241
# 9        nurses  18.736551
# 18      waiting  18.422172
# 1          care  18.218613
# 14    singapore  16.490532
# 11     patients  16.344440
# 19         ward  14.915315
# 0   appointment  14.659320
# 8         nurse  14.569807
# LDA Topics:
#  {'Topic 1': ['good', 'people', 'care', 'place', 'ray', 'friendly', 'staff', 'private', 'sgh', 'help'], 'Topic 2': ['hospital', 'singapore', 'service', 'best', 'general', 'good', 'mother', 'waiting', 'ward', 'care'], 'Topic 3': ['sgh', 'wait', 'medical', 'time', 'appointment', 'don', 'long', 'doctor', 'department', 'hospital'], 'Topic 4': ['patient', 'nurse', 'doctor', 'sgh', 'time', 'asked', 'waiting', 'hospital', 'staff', 'ward'], 'Topic 5': ['nurses', 'staff', 'care', 'dr', 'doctors', 'doctor', 'good', 'thank', 'hospital', 'sgh']}
# Topic Distribution (%):
#  dominant_topic
# 5    23.314607
# 1    21.067416
# 4    19.943820
# 3    17.977528
# 2    17.696629
# Name: proportion, dtype: float64

# %% [markdown]
# # 🗝 6. Thematic Insights (TF-IDF & LDA)

# %%
agg_counts = {
    "1_star": df['reviews_per_score_1'].iloc[0],
    "2_star": df['reviews_per_score_2'].iloc[0],
    "3_star": df['reviews_per_score_3'].iloc[0],
    "4_star": df['reviews_per_score_4'].iloc[0],
    "5_star": df['reviews_per_score_5'].iloc[0],
}
actual_counts = df['review_rating'].value_counts()

print("Google Metadata Counts:", agg_counts)
print("Actual Extracted Counts:\n", actual_counts)
# Out:
# Google Metadata Counts: {'1_star': 177, '2_star': 30, '3_star': 57, '4_star': 90, '5_star': 270}
# Actual Extracted Counts:
#  review_rating
# 5    265
# 1    174
# 4     88
# 3     57
# 2     30
# Name: count, dtype: int64

# %%
# =============================
# 1. Setup
# =============================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from textblob import TextBlob
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

sns.set(style="whitegrid", palette="muted", font_scale=1.1)

# Load dataset
df = pd.read_excel("Outscraper-20250823032119xs76.xlsx")
df['review_datetime_utc'] = pd.to_datetime(df['review_datetime_utc'], errors='coerce')
df['review_length'] = df['review_text'].astype(str).apply(len)
df['sentiment'] = df['review_text'].astype(str).apply(lambda x: TextBlob(x).sentiment.polarity)

# %% [markdown]
# # ⭐ 2. Ratings Overview

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="review_rating", data=df, palette="viridis")
plt.title("Ratings Distribution")
plt.show()

df.groupby(df['review_datetime_utc'].dt.to_period("M"))['review_rating'].mean().plot(figsize=(10,5), marker="o")
plt.title("Average Rating Over Time")
plt.ylabel("Avg Rating")
plt.show()
# Out:
# /var/folders/st/zkgc24pn5qlfxb9k9y3j07d40000gn/T/ipykernel_2133/998790571.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="review_rating", data=df, palette="viridis")

# %% [markdown]
# # 💬 3. Sentiment Analysis

# %%
df['sentiment_group'] = pd.cut(df['sentiment'], bins=[-1,-0.05,0.05,1], labels=["Negative","Neutral","Positive"])

plt.figure(figsize=(6,4))
sns.countplot(x="sentiment_group", data=df, order=["Negative","Neutral","Positive"], palette="coolwarm")
plt.title("Sentiment Distribution")
plt.show()

sns.scatterplot(x="sentiment", y="review_rating", data=df, alpha=0.5)
plt.title("Sentiment vs Rating")
plt.show()
# Out:
# /var/folders/st/zkgc24pn5qlfxb9k9y3j07d40000gn/T/ipykernel_2133/3429959399.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="sentiment_group", data=df, order=["Negative","Neutral","Positive"], palette="coolwarm")

# %% [markdown]
# # ✍️ 4. Review Length & Engagement

# %%
sns.histplot(df['review_length'], bins=50, kde=True)
plt.title("Review Length Distribution")
plt.show()

sns.boxplot(x="review_rating", y="review_length", data=df, palette="magma")
plt.title("Review Length by Rating")
plt.show()
# Out:
# /var/folders/st/zkgc24pn5qlfxb9k9y3j07d40000gn/T/ipykernel_2133/2932125478.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="review_rating", y="review_length", data=df, palette="magma")

# %% [markdown]
# # 👥 5. Reviewer Behavior

# %%
sns.histplot(df['author_reviews_count'], bins=30, log_scale=True)
plt.title("Distribution of Reviewer Activity (# Reviews by Author)")
plt.show()

df['is_frequent'] = df['author_reviews_count'] > 5
sns.boxplot(x="is_frequent", y="review_rating", data=df, palette="Set2")
plt.title("Frequent vs One-Time Reviewers (Rating Bias)")
plt.xticks([0,1], ["One-time","Frequent"])
plt.show()
# Out:
# /var/folders/st/zkgc24pn5qlfxb9k9y3j07d40000gn/T/ipykernel_2133/3163081248.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="is_frequent", y="review_rating", data=df, palette="Set2")

# %% [markdown]
# # 🔁 6. Owner Response Behavior

# %%
sns.barplot(x="review_rating", y=df['owner_answer'].notna(), data=df, estimator=np.mean, palette="crest")
plt.title("Response Rate by Rating")
plt.ylabel("Response Rate")
plt.show()

sns.barplot(x="sentiment_group", y=df['owner_answer'].notna(), data=df, estimator=np.mean, palette="rocket")
plt.title("Response Rate by Sentiment")
plt.ylabel("Response Rate")
plt.show()
# Out:
# /var/folders/st/zkgc24pn5qlfxb9k9y3j07d40000gn/T/ipykernel_2133/3810842962.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="review_rating", y=df['owner_answer'].notna(), data=df, estimator=np.mean, palette="crest")
# /var/folders/st/zkgc24pn5qlfxb9k9y3j07d40000gn/T/ipykernel_2133/3810842962.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="sentiment_group", y=df['owner_answer'].notna(), data=df, estimator=np.mean, palette="rocket")

# %% [markdown]
# # ☁️ 7. Word Cloud & Keywords

# %%
text = " ".join(df['review_text'].dropna().astype(str).values)

wc = WordCloud(width=800, height=400, background_color="white", colormap="viridis").generate(text)
plt.figure(figsize=(12,6))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.title("Most Frequent Words in Reviews")
plt.show()

# TF-IDF Keywords
tfidf = TfidfVectorizer(stop_words='english', max_features=20, ngram_range=(1,2))
tfidf_matrix = tfidf.fit_transform(df['review_text'].dropna().astype(str))
keywords = pd.DataFrame({
    "keyword": tfidf.get_feature_names_out(),
    "score": tfidf_matrix.sum(axis=0).A1
}).sort_values(by="score", ascending=False)

print("Top Keywords:\n", keywords)
# Out:
# Top Keywords:
#         keyword      score
# 14         sgh  18.752765
# 11     patient  15.967290
# 5     hospital  15.915407
# 10      nurses  14.227536
# 1       doctor  13.272173
# 19        ward  13.141293
# 15       staff  12.941786
# 9        nurse  11.370480
# 18        wait  11.115516
# 2      doctors  10.630487
# 0         care  10.208913
# 13     service   9.785278
# 4   experience   9.044751
# 17        time   8.983837
# 7         just   8.751689
# 8         like   8.606570
# 12    patients   8.023438
# 6        hours   7.964858
# 3           dr   6.805263
# 16     surgery   5.013204

# %% [markdown]
# # 🗝 8. Topic Modeling (LDA)

# %%
cv = CountVectorizer(stop_words='english', max_df=0.9, min_df=5)
cv_matrix = cv.fit_transform(df['review_text'].dropna().astype(str))

lda = LatentDirichletAllocation(n_components=5, random_state=42)
lda.fit(cv_matrix)

def display_topics(model, feature_names, no_top_words=8):
    for idx, topic in enumerate(model.components_):
        print(f"Topic {idx+1}: ", [feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]])

display_topics(lda, cv.get_feature_names_out())
# Out:
# Topic 1:  ['patient', 'doctor', 'sgh', 'dr', 'hospital', 'surgery', 'care', 'days']
# Topic 2:  ['hours', 'bad', 'just', 'went', 'surgery', 'hospital', 'doctor', 'tan']
# Topic 3:  ['block', 'patient', 'just', 'sgh', 'procedure', 'staff', 'clinic', 'make']
# Topic 4:  ['sgh', 'ward', 'nurses', 'patient', 'nurse', 'hospital', 'patients', 'doctors']
# Topic 5:  ['wait', 'thanks', 'hospital', 'pain', 'singapore', 'doctor', 'work', 'care']

# %% [markdown]
# # 📌 9. KPI Summary (Text Output)

# %%
summary = {
    "Average Rating": round(df['review_rating'].mean(),2),
    "Average Sentiment": round(df['sentiment'].mean(),2),
    "Response Rate (%)": round(df['owner_answer'].notna().mean()*100,2),
    "One-time Reviewer %": round((df['author_reviews_count'] == 1).mean()*100,2),
    "Frequent Reviewer %": round((df['author_reviews_count'] > 5).mean()*100,2),
    "Avg Review Length": round(df['review_length'].mean(),2),
    "Avg Likes": round(df['review_likes'].mean(skipna=True),2)
}
print("📊 KPI Dashboard:\n")
for k,v in summary.items():
    print(f"{k}: {v}")
# Out:
# 📊 KPI Dashboard:
#
# Average Rating: 2.71
# Average Sentiment: 0.04
# Response Rate (%): 0.54
# One-time Reviewer %: 8.11
# Frequent Reviewer %: 71.89
# Avg Review Length: 340.74
# Avg Likes: nan

# %%
# =============================
# 📌 9. Enhanced KPI Summary
# =============================

summary = {
    "Average Rating": round(df['review_rating'].mean(),2),
    "Average Sentiment": round(df['sentiment'].mean(),2),
    "Response Rate (%)": round(df['owner_answer'].notna().mean()*100,2),
    "One-time Reviewer %": round((df['author_reviews_count'] == 1).mean()*100,2),
    "Frequent Reviewer %": round((df['author_reviews_count'] > 5).mean()*100,2),
    "Avg Review Length": round(df['review_length'].mean(),2),
    "Avg Likes": round(df['review_likes'].mean(skipna=True),2)
}

# % Rating distribution
rating_dist = df['review_rating'].value_counts(normalize=True).sort_index() * 100
for rating, pct in rating_dist.items():
    summary[f"Rating {rating} %"] = round(pct,2)

# % Sentiment distribution
sentiment_dist = df['sentiment_group'].value_counts(normalize=True) * 100
for sentiment, pct in sentiment_dist.items():
    summary[f"{sentiment} Sentiment %"] = round(pct,2)

print("📊 KPI Dashboard:\n")
for k,v in summary.items():
    print(f"{k}: {v}")
# Out:
# 📊 KPI Dashboard:
#
# Average Rating: 2.71
# Average Sentiment: 0.04
# Response Rate (%): 0.54
# One-time Reviewer %: 8.11
# Frequent Reviewer %: 71.89
# Avg Review Length: 340.74
# Avg Likes: nan
# Rating 1 %: 49.73
# Rating 2 %: 4.32
# Rating 3 %: 4.32
# Rating 4 %: 8.65
# Rating 5 %: 32.97
# Neutral Sentiment %: 44.57
# Positive Sentiment %: 29.35
# Negative Sentiment %: 26.09

# %%
import matplotlib.pyplot as plt

# =============================
# 📊 10. KPI Visualizations
# =============================

# --- Ratings Distribution ---
rating_dist = df['review_rating'].value_counts(normalize=True).sort_index() * 100

plt.figure(figsize=(6,4))
rating_dist.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title("Ratings Distribution (%)")
plt.xlabel("Star Rating")
plt.ylabel("Percentage (%)")
plt.xticks(rotation=0)
plt.show()

# --- Sentiment Distribution ---
sentiment_dist = df['sentiment_group'].value_counts(normalize=True) * 100

plt.figure(figsize=(6,4))
sentiment_dist.plot(kind='bar', color=['red','grey','green'], edgecolor='black')
plt.title("Sentiment Distribution (%)")
plt.xlabel("Sentiment Group")
plt.ylabel("Percentage (%)")
plt.xticks(rotation=0)
plt.show()

# %%
# =============================
# 📌 11. Top Positive & Negative Reviews
# =============================

# Sort by sentiment score
top_positive = df.sort_values(by='sentiment', ascending=False).head(10)[['review_text','review_rating','sentiment']]
top_negative = df.sort_values(by='sentiment', ascending=True).head(10)[['review_text','review_rating','sentiment']]

print("🔥 Top 10 Positive Reviews (by sentiment):\n")
for i, row in top_positive.iterrows():
    print(f"⭐ Rating: {row['review_rating']} | Sentiment: {round(row['sentiment'],2)}")
    print(row['review_text'])
    print("-"*80)

print("\n⚠️ Top 10 Negative Reviews (by sentiment):\n")
for i, row in top_negative.iterrows():
    print(f"⭐ Rating: {row['review_rating']} | Sentiment: {round(row['sentiment'],2)}")
    print(row['review_text'])
    print("-"*80)
# Out:
# 🔥 Top 10 Positive Reviews (by sentiment):
#
# ⭐ Rating: 5 | Sentiment: 1.0
# Excellent Orthopaedic nurses in Ward 75/76.
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: 1.0
# Had my twins delivered here - wonderful doctor and nurses!
# --------------------------------------------------------------------------------
# ⭐ Rating: 4 | Sentiment: 0.75
# Great place  and good experience.
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: 0.75
# I am warded in Blk 7. The doctors and nurses are extremely supportive and caring. And the vegetarian foods are great!
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: 0.73
# Hi good afternoon
# I need to feedback the doctors and nurses and Admin
# You're doing a great job
# I can give them 100%
# SGH.
# They are doing a very fantastic they understand the patient problem and care . They are very kind and explain nicely and patiently everything is a wonderful.
# Keep it up 👍
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: 0.72
# Warded at blk 4 ward 42 room 5 bed 5 very pleased with the staff nurse and nurses very attentive, polite and helpful. Awesome service
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: 0.7
# Excellent medical services. Great experiences from both clinical and non-clinical staffs. Superb professionalism! :) Keep up the good work!
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: 0.61
# I would like to feedback to all the doctors and all the nurses who taking care of my husband during his stay at Blk 7, Ward 75A Room 8, from 11 August till 13 August 2025 .
# They are very friendly, patience and caring to him.  Can see that they put in a lot of efforts and methods to help on his recovery and can be discharged. Thumbs up for them! 👍🏻🙏🏻🤗
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: 0.6
# Old but good. Best doctors here
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: 0.6
# Good Latest signboard direction & upgrading ...
# --------------------------------------------------------------------------------
#
# ⚠️ Top 10 Negative Reviews (by sentiment):
#
# ⭐ Rating: 1 | Sentiment: -1.0
# Worst service hospital...
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: -0.71
# Meet a lot of sick people but it could be your family members
# --------------------------------------------------------------------------------
# ⭐ Rating: 1 | Sentiment: -0.7
# No dare to leave a msg here . bad and tooo bad experience
# --------------------------------------------------------------------------------
# ⭐ Rating: 1 | Sentiment: -0.62
# Called up the hotline. Picked up by very rude staff. With very rude tone and thereafter hanged up on me. Very bad.
# Would have given zero.
# This is terrifying. Receiving poor attitude even before you step into the place.
# --------------------------------------------------------------------------------
# ⭐ Rating: 1 | Sentiment: -0.55
# There is absolutely no use making an appointment with them. They ask you to come at 2.50pm and make you wait till 4.30 before seeing you. Absolutely horrible patient management
# --------------------------------------------------------------------------------
# ⭐ Rating: 1 | Sentiment: -0.54
# Horrible, 5 - 6 hour wait in accident and emergency.
#
# Patient before us vomited in the entrance to the nurse who takes your blood pressure before you join the ridiculous queue.  The vomit was not cleaned up for at least 2 hours.  After your accident and/or emergency, you can look forward to getting your blood pressure checked while sitting in a pool of vomit, before you begin your 6 hour wait to see a doctor.
# --------------------------------------------------------------------------------
# ⭐ Rating: 1 | Sentiment: -0.45
# This is stupid and funny.First hearing that normal patients that are no need for emergency care under the emergency causes you never make an appointment wasting my money .You think if I know when I sick I will come here?
# --------------------------------------------------------------------------------
# ⭐ Rating: 1 | Sentiment: -0.42
# Why was one visitor allowed in while the accompanying visitor refused entry by Christina Choa
# I can understand if visiting hours are over even though I do see visitors going in and out. Shouldn't the rule apply for all or are there different standards??
# Very confused and disappointed.
# --------------------------------------------------------------------------------
# ⭐ Rating: 3 | Sentiment: -0.4
# Not as before. Uncaring, out to make money from you. Unnecessary procedure suggested to you.
# --------------------------------------------------------------------------------
# ⭐ Rating: 1 | Sentiment: -0.39
# Fareez Fareedah, a team leader at SGH's visitor registration counter is very rude. Looks away and refuses to make eye contact, sits there without saying a word expecting me to know what information to give.
# --------------------------------------------------------------------------------

# %%
rating_dist
# Out:
# review_rating
# 1    49.729730
# 2     4.324324
# 3     4.324324
# 4     8.648649
# 5    32.972973
# Name: proportion, dtype: float64

# %%
# --- Base KPI Metrics ---
kpi_data = {
    "Average Rating": round(df['review_rating'].mean(),2),
    "Average Sentiment": round(df['sentiment'].mean(),2),
    "Response Rate (%)": round(df['owner_answer'].notna().mean()*100,2),
    "One-time Reviewer %": round((df['author_reviews_count'] == 1).mean()*100,2),
    "Frequent Reviewer %": round((df['author_reviews_count'] > 5).mean()*100,2),
    "Avg Review Length": round(df['review_length'].mean(),2),
    "Avg Likes": round(df['review_likes'].mean(skipna=True),2)
}

# Rating % Distribution
rating_dist = df['review_rating'].value_counts(normalize=True).sort_index() * 100
for rating, pct in rating_dist.items():
    kpi_data[f"Rating {rating} %"] = round(pct,2)

# Sentiment % Distribution
sentiment_dist = df['sentiment_group'].value_counts(normalize=True) * 100
for sentiment, pct in sentiment_dist.items():
    kpi_data[f"{sentiment} Sentiment %"] = round(pct,2)

# --- Top Reviews Extraction ---
top_positive = df.sort_values(by='sentiment', ascending=False).head(10)[['review_text','review_rating','sentiment']]
top_negative = df.sort_values(by='sentiment', ascending=True).head(10)[['review_text','review_rating','sentiment']]

# Convert reviews into a single string (shortened for table)
pos_reviews_str = "\n\n".join([f"⭐{row['review_rating']} (sent={round(row['sentiment'],2)}): {row['review_text'][:150]}..." 
                               for _,row in top_positive.iterrows()])

neg_reviews_str = "\n\n".join([f"⭐{row['review_rating']} (sent={round(row['sentiment'],2)}): {row['review_text'][:150]}..." 
                               for _,row in top_negative.iterrows()])

# Add to KPI data
kpi_data["Top 10 Positive Reviews"] = pos_reviews_str
kpi_data["Top 10 Negative Reviews"] = neg_reviews_str

# --- Final KPI Table ---
kpi_df = pd.DataFrame(list(kpi_data.items()), columns=["Metric","Value"])

# Replace the custom module with standard pandas display
# Instead of: import caas_jupyter_tools
# Instead of: caas_jupyter_tools.display_dataframe_to_user("KPI Dashboard with Reviews", kpi_df)
display(kpi_df)  # This is the standard way to display dataframes in Jupyter notebooks
# Out:
#                      Metric                                              Value
# 0            Average Rating                                               2.71
# 1         Average Sentiment                                               0.04
# 2         Response Rate (%)                                               0.54
# 3       One-time Reviewer %                                               8.11
# 4       Frequent Reviewer %                                              71.89
# 5         Avg Review Length                                             340.74
# 6                 Avg Likes                                                NaN
# 7                Rating 1 %                                              49.73
# 8                Rating 2 %                                               4.32
# 9                Rating 3 %                                               4.32
# 10               Rating 4 %                                               8.65
# 11               Rating 5 %                                              32.97
# 12      Neutral Sentiment %                                              44.57
# 13     Positive Sentiment %                                              29.35
# 14     Negative Sentiment %                                              26.09
# 15  Top 10 Positive Reviews  ⭐5 (sent=1.0): Excellent Orthopaedic nurses in...
# 16  Top 10 Negative Reviews  ⭐1 (sent=-1.0): Worst service hospital......\n...

# %%
# =============================
# 📊 Weekly Ratings Trend
# =============================

# Ensure datetime is parsed
df['review_datetime_utc'] = pd.to_datetime(df['review_datetime_utc'], errors='coerce')

# Resample weekly average ratings
weekly_ratings = df.set_index('review_datetime_utc').resample('W')['review_rating'].mean()

# Plot
plt.figure(figsize=(14,6))
weekly_ratings.plot(marker='o', linewidth=1.5, alpha=0.8)
plt.title("Weekly Average Ratings Over Time")
plt.xlabel("Week")
plt.ylabel("Average Rating")
plt.grid(True, alpha=0.3)
plt.show()

# %%
import base64
import pandas as pd
import json
import vertexai
import tiktoken # A popular tokenizer, though not directly from google-generativeai
import time
from vertexai.generative_models import GenerativeModel, Part, SafetySetting
import warnings
warnings.filterwarnings("ignore")

project_name = !(gcloud config get-value core/project)
project_name = project_name[0]

# %%
#Gemini
class LLM_model:
    def __init__(self, project, location, model_name):
        self.project = project
        self.location = location
        self.model_name = model_name
        self.generation_config = {
            "max_output_tokens": 8192,
            "temperature": 1,
            "top_p": 0.95,
        }
        self.safety_settings = [
            SafetySetting(
                category=SafetySetting.HarmCategory.HARM_CATEGORY_HATE_SPEECH,
                threshold=SafetySetting.HarmBlockThreshold.OFF
            ),
            SafetySetting(
                category=SafetySetting.HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT,
                threshold=SafetySetting.HarmBlockThreshold.OFF
            ),
            SafetySetting(
                category=SafetySetting.HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT,
                threshold=SafetySetting.HarmBlockThreshold.OFF
            ),
            SafetySetting(
                category=SafetySetting.HarmCategory.HARM_CATEGORY_HARASSMENT,
                threshold=SafetySetting.HarmBlockThreshold.OFF
            ),
        ]
        vertexai.init(project=self.project, location=self.location)
        self.model = GenerativeModel(self.model_name)

    def complete(self, text):
        chat = self.model.start_chat()
        result=chat.send_message([text],
                                 generation_config=self.generation_config,
                                 safety_settings=self.safety_settings
        )
        text_result=result.candidates[0].content.parts[0].text
        return text_result
# Example usage:
llm_gemini = LLM_model(project_name, 
                       "us-central1", 
                       "gemini-2.5-pro")

# %%
def sentiment_analysis(feedback, llm, llm_type='gemini'):
    prompt = f"""
    Role: You are an AI Specialist analysing customer feedback from Google reviews. Your role is to understand the given context
    and perform the task provided as appropriately.

    Context: The feedbacks are given by the patients or the bystanders of patients who went for treatment to the hospital.

    Task:
    1. Analyze the sentiment of the customer feedback if it’s positive, negative, or neutral.
    2. If the feedback is neither positive nor negative but just neutrally stating an info or suggestion,
       or is a non-meaningful feedback like 'Yes', 'No', 'Nil', 'na', 'N:A', 'N/a', 'n/a',
       'not applicable' or 'no comment', the sentiment is neutral.
    3. If sentiment is positive, return 'Positive'.
    4. If sentiment is negative, return 'Negative'.
    5. If sentiment is neutral, return 'Neutral'. Do not include other words or explanation.

    This is the customer feedback: {feedback}

    Examples:
    Its convenient, easy, fast: Positive.
    Nil: Neutral.
    Customer service not professional: Negative.
    
    Output:
    1. provide the classification of sentiment - Positive, Negative, Neutral   
    
    """

    try:
        if llm_type == 'gemini':
            result = llm.complete(prompt)
        else:
            result = llm.complete(prompt).text
        return result.strip()
    except Exception as e:
        print(f"Error processing row: {e}")
        return None  # Use None unless you're sure np.nan is needed and numpy is imported

# %%
def Information_extraction(feedback, llm, llm_type='gemini'):
    prompt = f"""
    Role: You are an AI Specialist analysing customer feedback from Google reviews. Your role is to understand the given context
    and perform the task provided as appropriately.

    Context: The feedbacks are given by the patients or the bystanders of patients who went for treatment to the hospital.

    Task:
    1. Analyze the feedback from the below mentioned topics and extract the information and provide as an output. If 
    the topics not found, mention as not found.
    1.1 From the whole feedback, extract the core issue, summarize the patient experience in 5 words and then
    follow the below tasks.
    2. Hospital Topic: 
        a. Does the review mention a specific ward, block or room number? if yes, extract it.
        b. Does the review mention about the department e.g: Endoscopy, Pharmacy, etc., if yes, extract it.
        c. Does the review describe whether the hospital is old, upgraded or modern?
    3. Staff & Service Topic:
        a. Does the review mention Doctors? if yes, extract it.
        b. Does the review mention nurses? if yes, extract it.
        c. Does the review mention support or admin staff? if yes, extract it.
        d. Does the review mention specific staff names? Extract them.
    4. Patient Experience:
        a. Does the review mention specific treatments or medical procedures (e.g. delivery, surgery)?
        b. What aspects of service quality are highlighted (e.g. attentiveness, professionalism, rudeness)?
        c. Does the reviewer mention waiting time? if yes, how long?
        d. Does the review mention food quality or any other quality (e.g. bedsheets, bathroom or cafeteria)?
    5. Complaints & Negative Aspects:
        a. Does the reviewer mention rude staff? Extract the details.
        b. Does the reviewer mention delays, long queues or poor management? Extract waiting times if given.
        c. Does the review mention unfair rules or inconsistent policies (e.g. visitor entry)?
        d. Does the reviewer explicitly call the hospital horrible, worst, terrifying, or disappointing?
        e. Does the review suggest profit motive or unnecessary procedures?
        f. Does the reviewer perceive fraudulent activity from the hospital?
    6. For each of the topics and its sub questions, provide output. If not found, mention as "Not found in feedback"

    This is the customer feedback: {feedback}

    Output:
    1. Provide the output in key-value pairs as JSON.
    2. Keys are only the core issue, summary, and the sub-questions (topic names not required).
    3. Values are the extracted output from the feedback.
    """

    # Token estimation
    try:
        import tiktoken
        enc = tiktoken.get_encoding("cl100k_base")
        prompt_tokens = len(enc.encode(prompt))
        print(f"Estimated input tokens (prompt): {prompt_tokens}")
    except ImportError:
        print("Install 'tiktoken' (pip install tiktoken) for token estimation.")
        prompt_tokens = -1

    # LLM completion
    try:
        if llm_type == 'gemini':
            result = llm.complete(prompt)
        else:
            result = llm.complete(prompt).text
        result = result.strip()
    except Exception as e:
        print(f"Error processing row: {e}")
        return None

    # Token estimation for response
    try:
        response_tokens = len(enc.encode(result))
        print(f"Estimated output tokens (response): {response_tokens}")
    except Exception:
        response_tokens = -1

    # Total token count
    if prompt_tokens != -1 and response_tokens != -1:
        total_estimated_tokens = prompt_tokens + response_tokens
        print(f"Total estimated tokens (prompt + response): {total_estimated_tokens}")

    return result

# %%
# Load dataset
df_singaporeGenH = pd.read_excel("Singapore General Hospital.xlsx")

# Display basic info
print(df_singaporeGenH.shape)
df_singaporeGenH.head()
# Out:
# (614, 35)
#                                    query                        name  \
# 0  0x31da196f954c6cd5:0x5c6009b161544a96  Singapore General Hospital
# 1  0x31da196f954c6cd5:0x5c6009b161544a96  Singapore General Hospital
# 2  0x31da196f954c6cd5:0x5c6009b161544a96  Singapore General Hospital
# 3  0x31da196f954c6cd5:0x5c6009b161544a96  Singapore General Hospital
# 4  0x31da196f954c6cd5:0x5c6009b161544a96  Singapore General Hospital
#
#                                google_id                     place_id  \
# 0  0x31da196f954c6cd5:0x5c6009b161544a96  ChIJ1WxMlW8Z2jERlkpUYbEJYFw
# 1  0x31da196f954c6cd5:0x5c6009b161544a96  ChIJ1WxMlW8Z2jERlkpUYbEJYFw
# 2  0x31da196f954c6cd5:0x5c6009b161544a96  ChIJ1WxMlW8Z2jERlkpUYbEJYFw
# 3  0x31da196f954c6cd5:0x5c6009b161544a96  ChIJ1WxMlW8Z2jERlkpUYbEJYFw
# 4  0x31da196f954c6cd5:0x5c6009b161544a96  ChIJ1WxMlW8Z2jERlkpUYbEJYFw
#
#                                        location_link  \
# 0  https://www.google.com/maps/place/Singapore+Ge...
# 1  https://www.google.com/maps/place/Singapore+Ge...
# 2  https://www.google.com/maps/place/Singapore+Ge...
# 3  https://www.google.com/maps/place/Singapore+Ge...
# 4  https://www.google.com/maps/place/Singapore+Ge...
#
#                                         reviews_link  reviews  rating  \
# 0  https://search.google.com/local/reviews?placei...      624     3.4
# 1  https://search.google.com/local/reviews?placei...      624     3.4
# 2  https://search.google.com/local/reviews?placei...      624     3.4
# 3  https://search.google.com/local/reviews?placei...      624     3.4
# 4  https://search.google.com/local/reviews?placei...      624     3.4
#
#                                            review_id  \
# 0  Ci9DQUlRQUNvZENodHljRjlvT21kSmNHVjViMDlmZUhkd1...
# 1  Ci9DQUlRQUNvZENodHljRjlvT2t4Zk1ISldMVnB3WlRkTW...
# 2  Ci9DQUlRQUNvZENodHljRjlvT201NGRFeENVR0owVkVwUG...
# 3  Ci9DQUlRQUNvZENodHljRjlvT25aS2VIUlFjMjFQVTJoWF...
# 4  Ci9DQUlRQUNvZENodHljRjlvT21wQ2FIQjZPRXhvVVVGV1...
#
#                                 review_pagination_id  ... review_rating  \
# 0  CAESYENBRVFBUnBDUTJrNFNVRlNTVzVEWjI5QlVEY3lSMk...  ...             1
# 1  CAESY0NBRVFBaHBFUTJwRlNVRlNTWEJEWjI5QlVEY3lSMl...  ...             1
# 2  CAESY0NBRVFBeHBFUTJwRlNVRlNTWEJEWjI5QlVEY3lSMl...  ...             3
# 3  CAESY0NBRVFCQnBFUTJwRlNVRlNTWEJEWjI5QlVEY3lSMl...  ...             1
# 4  CAESY0NBRVFCUnBFUTJwRlNVRlNTWEJEWjI5QlVEY3lSMl...  ...             5
#
#   review_timestamp  review_datetime_utc review_likes           reviews_id  \
# 0       1756212144  08/26/2025 12:42:24          NaN  6656330906700368534
# 1       1754935232  08/11/2025 18:00:32          NaN  6656330906700368534
# 2       1753671107  07/28/2025 02:51:47          NaN  6656330906700368534
# 3       1753357154  07/24/2025 11:39:14          NaN  6656330906700368534
# 4       1753243774  07/23/2025 04:09:34          NaN  6656330906700368534
#
#    reviews_per_score_1 reviews_per_score_2 reviews_per_score_3  \
# 0                  177                  30                  57
# 1                  177                  30                  57
# 2                  177                  30                  57
# 3                  177                  30                  57
# 4                  177                  30                  57
#
#   reviews_per_score_4  reviews_per_score_5
# 0                  90                  270
# 1                  90                  270
# 2                  90                  270
# 3                  90                  270
# 4                  90                  270
#
# [5 rows x 35 columns]

# %%
with open("text_reviews_SingGenH.txt", "w", encoding="utf-8") as f:
    for i, row in df_singaporeGenH.iterrows():
        f.write(f"--- Review #{i + 1} ---\n")
        f.write(f"Datetime: {row['review_datetime_utc']}\n")
        f.write(f"User: {row['author_title']}\n")
        f.write(f"Review: {row['review_text']}\n")
        f.write("--- End of Review ---\n\n")

# %%
df_singaporeGenH.head().transpose()
# Out:
#                                                                                      0  \
# query                                            0x31da196f954c6cd5:0x5c6009b161544a96
# name                                                        Singapore General Hospital
# google_id                                        0x31da196f954c6cd5:0x5c6009b161544a96
# place_id                                                   ChIJ1WxMlW8Z2jERlkpUYbEJYFw
# location_link                        https://www.google.com/maps/place/Singapore+Ge...
# reviews_link                         https://search.google.com/local/reviews?placei...
# reviews                                                                            624
# rating                                                                             3.4
# review_id                            Ci9DQUlRQUNvZENodHljRjlvT21kSmNHVjViMDlmZUhkd1...
# review_pagination_id                 CAESYENBRVFBUnBDUTJrNFNVRlNTVzVEWjI5QlVEY3lSMk...
# author_link                          https://www.google.com/maps/contrib/1113141405...
# author_title                                                                         M
# author_id                                                        111314140510133503604
# author_image                         https://lh3.googleusercontent.com/a/ACg8ocKr-O...
# author_reviews_count                                                                60
# author_ratings_count                                                                 0
# review_text                          There are rumours of this mysterious Pelvic Fl...
# review_img_urls                                                                    NaN
# review_img_url                                                                     NaN
# review_questions                                                                   NaN
# review_photo_ids                                                                   NaN
# owner_answer                                                                       NaN
# owner_answer_timestamp                                                             NaN
# owner_answer_timestamp_datetime_utc                                                NaN
# review_link                          https://www.google.com/maps/reviews/data=!4m8!...
# review_rating                                                                        1
# review_timestamp                                                            1756212144
# review_datetime_utc                                                08/26/2025 12:42:24
# review_likes                                                                       NaN
# reviews_id                                                         6656330906700368534
# reviews_per_score_1                                                                177
# reviews_per_score_2                                                                 30
# reviews_per_score_3                                                                 57
# reviews_per_score_4                                                                 90
# reviews_per_score_5                                                                270
#
#                                                                                      1  \
# query                                            0x31da196f954c6cd5:0x5c6009b161544a96
# name                                                        Singapore General Hospital
# google_id                                        0x31da196f954c6cd5:0x5c6009b161544a96
# place_id                                                   ChIJ1WxMlW8Z2jERlkpUYbEJYFw
# location_link                        https://www.google.com/maps/place/Singapore+Ge...
# reviews_link                         https://search.google.com/local/reviews?placei...
# reviews                                                                            624
# rating                                                                             3.4
# review_id                            Ci9DQUlRQUNvZENodHljRjlvT2t4Zk1ISldMVnB3WlRkTW...
# review_pagination_id                 CAESY0NBRVFBaHBFUTJwRlNVRlNTWEJEWjI5QlVEY3lSMl...
# author_link                          https://www.google.com/maps/contrib/1123209041...
# author_title                                                                  Alan Tan
# author_id                                                        112320904171329943098
# author_image                         https://lh3.googleusercontent.com/a/ACg8ocLEnI...
# author_reviews_count                                                                 2
# author_ratings_count                                                                 0
# review_text                          Terrible Experience with Sgh.2019 counter staf...
# review_img_urls                                                                    NaN
# review_img_url                                                                     NaN
# review_questions                                                                   NaN
# review_photo_ids                                                                   NaN
# owner_answer                                                                       NaN
# owner_answer_timestamp                                                             NaN
# owner_answer_timestamp_datetime_utc                                                NaN
# review_link                          https://www.google.com/maps/reviews/data=!4m8!...
# review_rating                                                                        1
# review_timestamp                                                            1754935232
# review_datetime_utc                                                08/11/2025 18:00:32
# review_likes                                                                       NaN
# reviews_id                                                         6656330906700368534
# reviews_per_score_1                                                                177
# reviews_per_score_2                                                                 30
# reviews_per_score_3                                                                 57
# reviews_per_score_4                                                                 90
# reviews_per_score_5                                                                270
#
#                                                                                      2  \
# query                                            0x31da196f954c6cd5:0x5c6009b161544a96
# name                                                        Singapore General Hospital
# google_id                                        0x31da196f954c6cd5:0x5c6009b161544a96
# place_id                                                   ChIJ1WxMlW8Z2jERlkpUYbEJYFw
# location_link                        https://www.google.com/maps/place/Singapore+Ge...
# reviews_link                         https://search.google.com/local/reviews?placei...
# reviews                                                                            624
# rating                                                                             3.4
# review_id                            Ci9DQUlRQUNvZENodHljRjlvT201NGRFeENVR0owVkVwUG...
# review_pagination_id                 CAESY0NBRVFBeHBFUTJwRlNVRlNTWEJEWjI5QlVEY3lSMl...
# author_link                          https://www.google.com/maps/contrib/1016598492...
# author_title                                                                   Sam Sin
# author_id                                                        101659849270519198285
# author_image                         https://lh3.googleusercontent.com/a-/ALV-UjV-U...
# author_reviews_count                                                                30
# author_ratings_count                                                                 7
# review_text                          Great hospital with all departments except dif...
# review_img_urls                                                                    NaN
# review_img_url                                                                     NaN
# review_questions                                                                   NaN
# review_photo_ids                                                                   NaN
# owner_answer                                                                       NaN
# owner_answer_timestamp                                                             NaN
# owner_answer_timestamp_datetime_utc                                                NaN
# review_link                          https://www.google.com/maps/reviews/data=!4m8!...
# review_rating                                                                        3
# review_timestamp                                                            1753671107
# review_datetime_utc                                                07/28/2025 02:51:47
# review_likes                                                                       NaN
# reviews_id                                                         6656330906700368534
# reviews_per_score_1                                                                177
# reviews_per_score_2                                                                 30
# reviews_per_score_3                                                                 57
# reviews_per_score_4                                                                 90
# reviews_per_score_5                                                                270
#
#                                                                                      3  \
# query                                            0x31da196f954c6cd5:0x5c6009b161544a96
# name                                                        Singapore General Hospital
# google_id                                        0x31da196f954c6cd5:0x5c6009b161544a96
# place_id                                                   ChIJ1WxMlW8Z2jERlkpUYbEJYFw
# location_link                        https://www.google.com/maps/place/Singapore+Ge...
# reviews_link                         https://search.google.com/local/reviews?placei...
# reviews                                                                            624
# rating                                                                             3.4
# review_id                            Ci9DQUlRQUNvZENodHljRjlvT25aS2VIUlFjMjFQVTJoWF...
# review_pagination_id                 CAESY0NBRVFCQnBFUTJwRlNVRlNTWEJEWjI5QlVEY3lSMl...
# author_link                          https://www.google.com/maps/contrib/1097666967...
# author_title                                                            Christina Tong
# author_id                                                        109766696720313371271
# author_image                         https://lh3.googleusercontent.com/a/ACg8ocKq5M...
# author_reviews_count                                                                 8
# author_ratings_count                                                                 0
# review_text                          I had a very disappointing experience at this ...
# review_img_urls                                                                    NaN
# review_img_url                                                                     NaN
# review_questions                                                                   NaN
# review_photo_ids                                                                   NaN
# owner_answer                                                                       NaN
# owner_answer_timestamp                                                             NaN
# owner_answer_timestamp_datetime_utc                                                NaN
# review_link                          https://www.google.com/maps/reviews/data=!4m8!...
# review_rating                                                                        1
# review_timestamp                                                            1753357154
# review_datetime_utc                                                07/24/2025 11:39:14
# review_likes                                                                       NaN
# reviews_id                                                         6656330906700368534
# reviews_per_score_1                                                                177
# reviews_per_score_2                                                                 30
# reviews_per_score_3                                                                 57
# reviews_per_score_4                                                                 90
# reviews_per_score_5                                                                270
#
#                                                                                      4
# query                                            0x31da196f954c6cd5:0x5c6009b161544a96
# name                                                        Singapore General Hospital
# google_id                                        0x31da196f954c6cd5:0x5c6009b161544a96
# place_id                                                   ChIJ1WxMlW8Z2jERlkpUYbEJYFw
# location_link                        https://www.google.com/maps/place/Singapore+Ge...
# reviews_link                         https://search.google.com/local/reviews?placei...
# reviews                                                                            624
# rating                                                                             3.4
# review_id                            Ci9DQUlRQUNvZENodHljRjlvT21wQ2FIQjZPRXhvVVVGV1...
# review_pagination_id                 CAESY0NBRVFCUnBFUTJwRlNVRlNTWEJEWjI5QlVEY3lSMl...
# author_link                          https://www.google.com/maps/contrib/1086536981...
# author_title                                                                 Alex CHOW
# author_id                                                        108653698109649104675
# author_image                         https://lh3.googleusercontent.com/a/ACg8ocLPAr...
# author_reviews_count                                                                31
# author_ratings_count                                                                 6
# review_text                          A really well structured and managed governmen...
# review_img_urls                                                                    NaN
# review_img_url                                                                     NaN
# review_questions                                                                   NaN
# review_photo_ids                                                                   NaN
# owner_answer                                                                       NaN
# owner_answer_timestamp                                                             NaN
# owner_answer_timestamp_datetime_utc                                                NaN
# review_link                          https://www.google.com/maps/reviews/data=!4m8!...
# review_rating                                                                        5
# review_timestamp                                                            1753243774
# review_datetime_utc                                                07/23/2025 04:09:34
# review_likes                                                                       NaN
# reviews_id                                                         6656330906700368534
# reviews_per_score_1                                                                177
# reviews_per_score_2                                                                 30
# reviews_per_score_3                                                                 57
# reviews_per_score_4                                                                 90
# reviews_per_score_5                                                                270

# %%
df_singaporeGenH_reviewtext = df_singaporeGenH.review_text

# %%
df_singaporeGenH_reviewtext.iloc[1:10]
# Out:
# 1    Terrible Experience with Sgh.2019 counter staf...
# 2    Great hospital with all departments except dif...
# 3    I had a very disappointing experience at this ...
# 4    A really well structured and managed governmen...
# 5                                                  NaN
# 6    Thank you handsome doctor, very serious sore t...
# 7                                                  NaN
# 8    the hospital inpatient and outpatient medical ...
# 9    Absolutely horrible experience at SGH yesterda...
# Name: review_text, dtype: object

# %%
import json
import fitz  # PyMuPDF
counter = 0
# Assuming df_Gleangles_reviewtext and Information_extraction are already defined
with open("review_output_singaporeGenH.txt", "w", encoding="utf-8") as f:
    for idx,review in enumerate(df_singaporeGenH_reviewtext,start=0):
        
        start_time = time.time()
        print(f"Processing row {idx}...")

        example_output = Information_extraction(review, llm_gemini)
        o = example_output.replace('```', '')
        
        cleaned_output = o.replace('json', '')
        
        
        try:
            # If the output contains extra text before/after JSON, isolate the JSON part
            start = cleaned_output.find('{')
            end = cleaned_output.rfind('}') + 1
            json_str = cleaned_output[start:end]

            # Parse the JSON
            ie_output_dict = json.loads(json_str)
        except json.JSONDecodeError as e:
            print("JSON decoding failed:", e)
            print("Raw output:", cleaned_output)
            ie_output_dict = None

        
        f.write("Original Review:\n")
        f.write(str(review) + "\n")
        f.write("Extracted Information:\n")
        f.write(json.dumps(ie_output_dict, indent=4))
        f.write("\n---------------------------------------------------\n")

        f.write("Next Review ########################################\n\n")
        

        elapsed_time = time.time() - start_time
        print(f"Row {idx} processed in {elapsed_time:.2f} seconds.\n")
# Out:
# Processing row 0...
# Estimated input tokens (prompt): 820
# Estimated output tokens (response): 588
# Total estimated tokens (prompt + response): 1408
# Row 0 processed in 20.17 seconds.
#
# Processing row 1...
# Estimated input tokens (prompt): 610
# Estimated output tokens (response): 344
# Total estimated tokens (prompt + response): 954
# Row 1 processed in 15.89 seconds.
#
# Processing row 2...
# Estimated input tokens (prompt): 595
# Estimated output tokens (response): 271
# Total estimated tokens (prompt + response): 866
# Row 2 processed in 11.75 seconds.
#
# Processing row 3...
# Estimated input tokens (prompt): 734
# Estimated output tokens (response): 468
# Total estimated tokens (prompt + response): 1202
# Row 3 processed in 18.15 seconds.
#
# Processing row 4...
# Estimated input tokens (prompt): 575
# Estimated output tokens (response): 294
# Total estimated tokens (prompt + response): 869
# Row 4 processed in 12.31 seconds.
#
# Processing row 5...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 250
# Total estimated tokens (prompt + response): 818
# Row 5 processed in 9.49 seconds.
#
# Processing row 6...
# Estimated input tokens (prompt): 583
# Estimated output tokens (response): 274
# Total estimated tokens (prompt + response): 857
# Row 6 processed in 13.55 seconds.
#
# Processing row 7...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 235
# Total estimated tokens (prompt + response): 803
# Row 7 processed in 7.39 seconds.
#
# Processing row 8...
# Estimated input tokens (prompt): 603
# Estimated output tokens (response): 311
# Total estimated tokens (prompt + response): 914
# Row 8 processed in 12.58 seconds.
#
# Processing row 9...
# Estimated input tokens (prompt): 902
# Estimated output tokens (response): 439
# Total estimated tokens (prompt + response): 1341
# Row 9 processed in 18.23 seconds.
#
# Processing row 10...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 447
# Total estimated tokens (prompt + response): 1015
# Row 10 processed in 15.25 seconds.
#
# Processing row 11...
# Estimated input tokens (prompt): 607
# Estimated output tokens (response): 321
# Total estimated tokens (prompt + response): 928
# Row 11 processed in 14.95 seconds.
#
# Processing row 12...
# Estimated input tokens (prompt): 647
# Estimated output tokens (response): 304
# Total estimated tokens (prompt + response): 951
# Row 12 processed in 15.49 seconds.
#
# Processing row 13...
# Estimated input tokens (prompt): 602
# Estimated output tokens (response): 327
# Total estimated tokens (prompt + response): 929
# Row 13 processed in 12.07 seconds.
#
# Processing row 14...
# Estimated input tokens (prompt): 708
# Estimated output tokens (response): 623
# Total estimated tokens (prompt + response): 1331
# Row 14 processed in 17.54 seconds.
#
# Processing row 15...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 264
# Total estimated tokens (prompt + response): 832
# Row 15 processed in 11.49 seconds.
#
# Processing row 16...
# Estimated input tokens (prompt): 640
# Estimated output tokens (response): 300
# Total estimated tokens (prompt + response): 940
# Row 16 processed in 12.50 seconds.
#
# Processing row 17...
# Estimated input tokens (prompt): 608
# Estimated output tokens (response): 319
# Total estimated tokens (prompt + response): 927
# Row 17 processed in 16.17 seconds.
#
# Processing row 18...
# Estimated input tokens (prompt): 598
# Estimated output tokens (response): 354
# Total estimated tokens (prompt + response): 952
# Row 18 processed in 17.45 seconds.
#
# Processing row 19...
# Estimated input tokens (prompt): 598
# Estimated output tokens (response): 330
# Total estimated tokens (prompt + response): 928
# Row 19 processed in 14.19 seconds.
#
# Processing row 20...
# Estimated input tokens (prompt): 881
# Estimated output tokens (response): 753
# Total estimated tokens (prompt + response): 1634
# Row 20 processed in 26.52 seconds.
#
# Processing row 21...
# Estimated input tokens (prompt): 594
# Estimated output tokens (response): 452
# Total estimated tokens (prompt + response): 1046
# Row 21 processed in 16.34 seconds.
#
# Processing row 22...
# Estimated input tokens (prompt): 584
# Estimated output tokens (response): 453
# Total estimated tokens (prompt + response): 1037
# Row 22 processed in 13.03 seconds.
#
# Processing row 23...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 276
# Total estimated tokens (prompt + response): 844
# Row 23 processed in 9.96 seconds.
#
# Processing row 24...
# Estimated input tokens (prompt): 610
# Estimated output tokens (response): 350
# Total estimated tokens (prompt + response): 960
# Row 24 processed in 16.20 seconds.
#
# Processing row 25...
# Estimated input tokens (prompt): 725
# Estimated output tokens (response): 463
# Total estimated tokens (prompt + response): 1188
# Row 25 processed in 27.60 seconds.
#
# Processing row 26...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 267
# Total estimated tokens (prompt + response): 835
# Row 26 processed in 9.11 seconds.
#
# Processing row 27...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 273
# Total estimated tokens (prompt + response): 841
# Row 27 processed in 10.75 seconds.
#
# Processing row 28...
# Estimated input tokens (prompt): 1035
# Estimated output tokens (response): 454
# Total estimated tokens (prompt + response): 1489
# Row 28 processed in 14.36 seconds.
#
# Processing row 29...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 258
# Total estimated tokens (prompt + response): 826
# Row 29 processed in 12.08 seconds.
#
# Processing row 30...
# Estimated input tokens (prompt): 603
# Estimated output tokens (response): 373
# Total estimated tokens (prompt + response): 976
# Row 30 processed in 14.98 seconds.
#
# Processing row 31...
# Estimated input tokens (prompt): 588
# Estimated output tokens (response): 287
# Total estimated tokens (prompt + response): 875
# Row 31 processed in 11.10 seconds.
#
# Processing row 32...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 284
# Total estimated tokens (prompt + response): 852
# Row 32 processed in 12.23 seconds.
#
# Processing row 33...
# Estimated input tokens (prompt): 608
# Estimated output tokens (response): 296
# Total estimated tokens (prompt + response): 904
# Row 33 processed in 10.96 seconds.
#
# Processing row 34...
# Estimated input tokens (prompt): 619
# Estimated output tokens (response): 272
# Total estimated tokens (prompt + response): 891
# Row 34 processed in 14.48 seconds.
#
# Processing row 35...
# Estimated input tokens (prompt): 616
# Estimated output tokens (response): 412
# Total estimated tokens (prompt + response): 1028
# Row 35 processed in 17.76 seconds.
#
# Processing row 36...
# Estimated input tokens (prompt): 620
# Estimated output tokens (response): 328
# Total estimated tokens (prompt + response): 948
# Row 36 processed in 12.29 seconds.
#
# Processing row 37...
# Estimated input tokens (prompt): 593
# Estimated output tokens (response): 311
# Total estimated tokens (prompt + response): 904
# Row 37 processed in 12.25 seconds.
#
# Processing row 38...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 268
# Total estimated tokens (prompt + response): 836
# Row 38 processed in 9.14 seconds.
#
# Processing row 39...
# Estimated input tokens (prompt): 726
# Estimated output tokens (response): 428
# Total estimated tokens (prompt + response): 1154
# Row 39 processed in 15.88 seconds.
#
# Processing row 40...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 266
# Total estimated tokens (prompt + response): 834
# Row 40 processed in 10.23 seconds.
#
# Processing row 41...
# Estimated input tokens (prompt): 597
# Estimated output tokens (response): 349
# Total estimated tokens (prompt + response): 946
# Row 41 processed in 14.16 seconds.
#
# Processing row 42...
# Estimated input tokens (prompt): 585
# Estimated output tokens (response): 321
# Total estimated tokens (prompt + response): 906
# Row 42 processed in 9.73 seconds.
#
# Processing row 43...
# Estimated input tokens (prompt): 719
# Estimated output tokens (response): 498
# Total estimated tokens (prompt + response): 1217
# Row 43 processed in 18.82 seconds.
#
# Processing row 44...
# Estimated input tokens (prompt): 627
# Estimated output tokens (response): 314
# Total estimated tokens (prompt + response): 941
# Row 44 processed in 12.42 seconds.
#
# Processing row 45...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 265
# Total estimated tokens (prompt + response): 833
# Row 45 processed in 11.43 seconds.
#
# Processing row 46...
# Estimated input tokens (prompt): 600
# Estimated output tokens (response): 340
# Total estimated tokens (prompt + response): 940
# Row 46 processed in 26.33 seconds.
#
# Processing row 47...
# Estimated input tokens (prompt): 1483
# Estimated output tokens (response): 651
# Total estimated tokens (prompt + response): 2134
# Row 47 processed in 21.93 seconds.
#
# Processing row 48...
# Estimated input tokens (prompt): 575
# Estimated output tokens (response): 305
# Total estimated tokens (prompt + response): 880
# Row 48 processed in 12.44 seconds.
#
# Processing row 49...
# Estimated input tokens (prompt): 691
# Estimated output tokens (response): 320
# Total estimated tokens (prompt + response): 1011
# Row 49 processed in 11.90 seconds.
#
# Processing row 50...
# Estimated input tokens (prompt): 659
# Estimated output tokens (response): 384
# Total estimated tokens (prompt + response): 1043
# Row 50 processed in 16.66 seconds.
#
# Processing row 51...
# Estimated input tokens (prompt): 883
# Estimated output tokens (response): 441
# Total estimated tokens (prompt + response): 1324
# Row 51 processed in 19.69 seconds.
#
# Processing row 52...
# Estimated input tokens (prompt): 573
# Estimated output tokens (response): 261
# Total estimated tokens (prompt + response): 834
# Row 52 processed in 14.61 seconds.
#
# Processing row 53...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 260
# Total estimated tokens (prompt + response): 828
# Row 53 processed in 10.38 seconds.
#
# Processing row 54...
# Estimated input tokens (prompt): 884
# Estimated output tokens (response): 506
# Total estimated tokens (prompt + response): 1390
# Row 54 processed in 31.99 seconds.
#
# Processing row 55...
# Estimated input tokens (prompt): 659
# Estimated output tokens (response): 292
# Total estimated tokens (prompt + response): 951
# Row 55 processed in 11.70 seconds.
#
# Processing row 56...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 266
# Total estimated tokens (prompt + response): 834
# Row 56 processed in 8.56 seconds.
#
# Processing row 57...
# Estimated input tokens (prompt): 577
# Estimated output tokens (response): 298
# Total estimated tokens (prompt + response): 875
# Row 57 processed in 12.40 seconds.
#
# Processing row 58...
# Estimated input tokens (prompt): 660
# Estimated output tokens (response): 433
# Total estimated tokens (prompt + response): 1093
# Row 58 processed in 13.87 seconds.
#
# Processing row 59...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 249
# Total estimated tokens (prompt + response): 817
# Row 59 processed in 9.71 seconds.
#
# Processing row 60...
# Estimated input tokens (prompt): 685
# Estimated output tokens (response): 401
# Total estimated tokens (prompt + response): 1086
# Row 60 processed in 17.91 seconds.
#
# Processing row 61...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 287
# Total estimated tokens (prompt + response): 855
# Row 61 processed in 11.83 seconds.
#
# Processing row 62...
# Estimated input tokens (prompt): 667
# Estimated output tokens (response): 321
# Total estimated tokens (prompt + response): 988
# Row 62 processed in 15.04 seconds.
#
# Processing row 63...
# Estimated input tokens (prompt): 812
# Estimated output tokens (response): 342
# Total estimated tokens (prompt + response): 1154
# Row 63 processed in 14.24 seconds.
#
# Processing row 64...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 252
# Total estimated tokens (prompt + response): 820
# Row 64 processed in 9.67 seconds.
#
# Processing row 65...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 280
# Total estimated tokens (prompt + response): 848
# Row 65 processed in 11.85 seconds.
#
# Processing row 66...
# Estimated input tokens (prompt): 578
# Estimated output tokens (response): 298
# Total estimated tokens (prompt + response): 876
# Row 66 processed in 9.20 seconds.
#
# Processing row 67...
# Estimated input tokens (prompt): 636
# Estimated output tokens (response): 414
# Total estimated tokens (prompt + response): 1050
# Row 67 processed in 18.10 seconds.
#
# Processing row 68...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 438
# Total estimated tokens (prompt + response): 1006
# Row 68 processed in 10.04 seconds.
#
# Processing row 69...
# Estimated input tokens (prompt): 836
# Estimated output tokens (response): 636
# Total estimated tokens (prompt + response): 1472
# Row 69 processed in 28.57 seconds.
#
# Processing row 70...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 266
# Total estimated tokens (prompt + response): 834
# Row 70 processed in 10.89 seconds.
#
# Processing row 71...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 249
# Total estimated tokens (prompt + response): 817
# Row 71 processed in 9.22 seconds.
#
# Processing row 72...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 261
# Total estimated tokens (prompt + response): 829
# Row 72 processed in 17.48 seconds.
#
# Processing row 73...
# Estimated input tokens (prompt): 624
# Estimated output tokens (response): 536
# Total estimated tokens (prompt + response): 1160
# Row 73 processed in 15.36 seconds.
#
# Processing row 74...
# Estimated input tokens (prompt): 681
# Estimated output tokens (response): 505
# Total estimated tokens (prompt + response): 1186
# Row 74 processed in 16.81 seconds.
#
# Processing row 75...
# Estimated input tokens (prompt): 652
# Estimated output tokens (response): 419
# Total estimated tokens (prompt + response): 1071
# Row 75 processed in 16.21 seconds.
#
# Processing row 76...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 248
# Total estimated tokens (prompt + response): 816
# Row 76 processed in 10.81 seconds.
#
# Processing row 77...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 264
# Total estimated tokens (prompt + response): 832
# Row 77 processed in 12.19 seconds.
#
# Processing row 78...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 250
# Total estimated tokens (prompt + response): 818
# Row 78 processed in 10.49 seconds.
#
# Processing row 79...
# Estimated input tokens (prompt): 630
# Estimated output tokens (response): 319
# Total estimated tokens (prompt + response): 949
# Row 79 processed in 16.41 seconds.
#
# Processing row 80...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 244
# Total estimated tokens (prompt + response): 812
# Row 80 processed in 11.07 seconds.
#
# Processing row 81...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 264
# Total estimated tokens (prompt + response): 832
# Row 81 processed in 9.55 seconds.
#
# Processing row 82...
# Estimated input tokens (prompt): 968
# Estimated output tokens (response): 680
# Total estimated tokens (prompt + response): 1648
# Row 82 processed in 29.10 seconds.
#
# Processing row 83...
# Estimated input tokens (prompt): 1400
# Estimated output tokens (response): 515
# Total estimated tokens (prompt + response): 1915
# Row 83 processed in 15.64 seconds.
#
# Processing row 84...
# Estimated input tokens (prompt): 582
# Estimated output tokens (response): 292
# Total estimated tokens (prompt + response): 874
# Row 84 processed in 13.92 seconds.
#
# Processing row 85...
# Estimated input tokens (prompt): 632
# Estimated output tokens (response): 400
# Total estimated tokens (prompt + response): 1032
# Row 85 processed in 14.82 seconds.
#
# Processing row 86...
# Estimated input tokens (prompt): 760
# Estimated output tokens (response): 400
# Total estimated tokens (prompt + response): 1160
# Row 86 processed in 14.58 seconds.
#
# Processing row 87...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 261
# Total estimated tokens (prompt + response): 829
# Row 87 processed in 10.57 seconds.
#
# Processing row 88...
# Estimated input tokens (prompt): 1170
# Estimated output tokens (response): 837
# Total estimated tokens (prompt + response): 2007
# Row 88 processed in 26.98 seconds.
#
# Processing row 89...
# Estimated input tokens (prompt): 607
# Estimated output tokens (response): 285
# Total estimated tokens (prompt + response): 892
# Row 89 processed in 13.64 seconds.
#
# Processing row 90...
# Estimated input tokens (prompt): 605
# Estimated output tokens (response): 348
# Total estimated tokens (prompt + response): 953
# Row 90 processed in 16.34 seconds.
#
# Processing row 91...
# Estimated input tokens (prompt): 686
# Estimated output tokens (response): 438
# Total estimated tokens (prompt + response): 1124
# Row 91 processed in 17.43 seconds.
#
# Processing row 92...
# Estimated input tokens (prompt): 678
# Estimated output tokens (response): 398
# Total estimated tokens (prompt + response): 1076
# Row 92 processed in 20.86 seconds.
#
# Processing row 93...
# Estimated input tokens (prompt): 590
# Estimated output tokens (response): 359
# Total estimated tokens (prompt + response): 949
# Row 93 processed in 17.06 seconds.
#
# Processing row 94...
# Estimated input tokens (prompt): 1136
# Estimated output tokens (response): 727
# Total estimated tokens (prompt + response): 1863
# Row 94 processed in 19.12 seconds.
#
# Processing row 95...
# Estimated input tokens (prompt): 730
# Estimated output tokens (response): 431
# Total estimated tokens (prompt + response): 1161
# Row 95 processed in 15.02 seconds.
#
# Processing row 96...
# Estimated input tokens (prompt): 753
# Estimated output tokens (response): 405
# Total estimated tokens (prompt + response): 1158
# Row 96 processed in 18.72 seconds.
#
# Processing row 97...
# Estimated input tokens (prompt): 638
# Estimated output tokens (response): 361
# Total estimated tokens (prompt + response): 999
# Row 97 processed in 14.79 seconds.
#
# Processing row 98...
# Estimated input tokens (prompt): 694
# Estimated output tokens (response): 469
# Total estimated tokens (prompt + response): 1163
# Row 98 processed in 16.55 seconds.
#
# Processing row 99...
# Estimated input tokens (prompt): 575
# Estimated output tokens (response): 326
# Total estimated tokens (prompt + response): 901
# Row 99 processed in 13.07 seconds.
#
# Processing row 100...
# Estimated input tokens (prompt): 598
# Estimated output tokens (response): 277
# Total estimated tokens (prompt + response): 875
# Row 100 processed in 10.79 seconds.
#
# Processing row 101...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 267
# Total estimated tokens (prompt + response): 835
# Row 101 processed in 8.68 seconds.
#
# Processing row 102...
# Estimated input tokens (prompt): 749
# Estimated output tokens (response): 511
# Total estimated tokens (prompt + response): 1260
# Row 102 processed in 18.45 seconds.
#
# Processing row 103...
# Estimated input tokens (prompt): 618
# Estimated output tokens (response): 322
# Total estimated tokens (prompt + response): 940
# Row 103 processed in 12.42 seconds.
#
# Processing row 104...
# Estimated input tokens (prompt): 655
# Estimated output tokens (response): 424
# Total estimated tokens (prompt + response): 1079
# JSON decoding failed: Expecting property name enclosed in double quotes: line 16 column 1 (char 1192)
# Raw output:
# {
#   "core_issue": "The hospital's visitor management system and its waitlist process are described as awful, atrocious, and illogical. The system prevents visitors from entering even when a slot is available if a person who is ahead in the queue has left without being checked in.",
#   "summary": "Awful visitor system, illogical waitlist.",
#   "specific ward, block or room number": "Not found in feedback",
#   "department": "Not found in feedback",
#   "hospital is old, upgraded or modern": "Not found in feedback",
#   "Doctors": "Not found in feedback",
#   "nurses": "Not found in feedback",
#   "support or admin staff": "Not found in feedback",
#   "specific staff names": "Not found in feedback",
#   "specific treatments or medical procedures": "Not found in feedback",
#   "aspects of service quality": "The quality of the visitor management system is highlighted as being poor, with the system described as 'awful' and the waitlist process as 'atrocious' and illogical.",
#   "waiting time": "The review mentions a 'wait list' and being unable to enter, but no specific duration is provided.",
#   "food quality or any other quality": "Not found in feedback",
#   "rude staff": "Not found in feedback",
# _  "delays, long queues or poor management": "Yes, the entire feedback is about the poor management of the visitor waitlist system, which causes delays and has an illogical queueing sequence.",
#   "unfair rules or inconsistent policies": "Yes, the policy preventing a visitor from entering an available slot because a person who has already left is still ahead in the queue is described as an unfair rule that 'does not make sense'.",
#   "explicitly call the hospital horrible, worst, terrifying, or disappointing": "Not found in feedback",
#   "suggest profit motive or unnecessary procedures": "Not found in feedback",
#   "perceive fraudulent activity from the hospital": "Not found in feedback"
# }
#
# Row 104 processed in 19.32 seconds.
#
# Processing row 105...
# Estimated input tokens (prompt): 919
# Estimated output tokens (response): 595
# Total estimated tokens (prompt + response): 1514
# Row 105 processed in 19.36 seconds.
#
# Processing row 106...
# Estimated input tokens (prompt): 610
# Estimated output tokens (response): 296
# Total estimated tokens (prompt + response): 906
# Row 106 processed in 10.28 seconds.
#
# Processing row 107...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 251
# Total estimated tokens (prompt + response): 819
# Row 107 processed in 10.19 seconds.
#
# Processing row 108...
# Estimated input tokens (prompt): 753
# Estimated output tokens (response): 377
# Total estimated tokens (prompt + response): 1130
# Row 108 processed in 18.32 seconds.
#
# Processing row 109...
# Estimated input tokens (prompt): 571
# Estimated output tokens (response): 267
# Total estimated tokens (prompt + response): 838
# Row 109 processed in 17.44 seconds.
#
# Processing row 110...
# Estimated input tokens (prompt): 577
# Estimated output tokens (response): 313
# Total estimated tokens (prompt + response): 890
# Row 110 processed in 19.85 seconds.
#
# Processing row 111...
# Estimated input tokens (prompt): 614
# Estimated output tokens (response): 584
# Total estimated tokens (prompt + response): 1198
# Row 111 processed in 20.01 seconds.
#
# Processing row 112...
# Estimated input tokens (prompt): 648
# Estimated output tokens (response): 403
# Total estimated tokens (prompt + response): 1051
# Row 112 processed in 14.88 seconds.
#
# Processing row 113...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 271
# Total estimated tokens (prompt + response): 839
# Row 113 processed in 15.07 seconds.
#
# Processing row 114...
# Estimated input tokens (prompt): 570
# Estimated output tokens (response): 273
# Total estimated tokens (prompt + response): 843
# Row 114 processed in 12.79 seconds.
#
# Processing row 115...
# Estimated input tokens (prompt): 608
# Estimated output tokens (response): 342
# Total estimated tokens (prompt + response): 950
# Row 115 processed in 13.24 seconds.
#
# Processing row 116...
# Estimated input tokens (prompt): 766
# Estimated output tokens (response): 414
# Total estimated tokens (prompt + response): 1022
# Row 117 processed in 14.67 seconds.
#
# Processing row 118...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 262
# Total estimated tokens (prompt + response): 830
# Row 118 processed in 11.88 seconds.
#
# Processing row 119...
# Estimated input tokens (prompt): 575
# Estimated output tokens (response): 325
# Total estimated tokens (prompt + response): 900
# Row 119 processed in 14.12 seconds.
#
# Processing row 120...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 261
# Total estimated tokens (prompt + response): 829
# Row 120 processed in 11.48 seconds.
#
# Processing row 121...
# Estimated input tokens (prompt): 601
# Estimated output tokens (response): 361
# Total estimated tokens (prompt + response): 962
# Row 121 processed in 14.87 seconds.
#
# Processing row 122...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 254
# Total estimated tokens (prompt + response): 822
# Row 122 processed in 8.20 seconds.
#
# Processing row 123...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 236
# Total estimated tokens (prompt + response): 804
# Row 123 processed in 7.65 seconds.
#
# Processing row 124...
# Estimated input tokens (prompt): 756
# Estimated output tokens (response): 427
# Total estimated tokens (prompt + response): 1183
# Row 124 processed in 16.42 seconds.
#
# Processing row 125...
# Estimated input tokens (prompt): 570
# Estimated output tokens (response): 278
# Total estimated tokens (prompt + response): 848
# Row 125 processed in 18.95 seconds.
#
# Processing row 126...
# Estimated input tokens (prompt): 575
# Estimated output tokens (response): 342
# Total estimated tokens (prompt + response): 917
# Row 126 processed in 10.74 seconds.
#
# Processing row 127...
# Estimated input tokens (prompt): 591
# Estimated output tokens (response): 297
# Total estimated tokens (prompt + response): 888
# Row 127 processed in 12.30 seconds.
#
# Processing row 128...
# Estimated input tokens (prompt): 889
# Estimated output tokens (response): 394
# Total estimated tokens (prompt + response): 1283
# Row 128 processed in 18.00 seconds.
#
# Processing row 129...
# Estimated input tokens (prompt): 573
# Estimated output tokens (response): 270
# Total estimated tokens (prompt + response): 843
# Row 129 processed in 11.36 seconds.
#
# Processing row 130...
# Estimated input tokens (prompt): 575
# Estimated output tokens (response): 304
# Total estimated tokens (prompt + response): 879
# Row 130 processed in 15.24 seconds.
#
# Processing row 131...
# Estimated input tokens (prompt): 575
# Estimated output tokens (response): 283
# Total estimated tokens (prompt + response): 858
# Row 131 processed in 14.21 seconds.
#
# Processing row 132...
# Estimated input tokens (prompt): 946
# Estimated output tokens (response): 707
# Total estimated tokens (prompt + response): 1653
# Row 132 processed in 20.99 seconds.
#
# Processing row 133...
# Estimated input tokens (prompt): 592
# Estimated output tokens (response): 305
# Total estimated tokens (prompt + response): 897
# Row 133 processed in 11.09 seconds.
#
# Processing row 134...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 277
# Total estimated tokens (prompt + response): 845
# Row 134 processed in 21.68 seconds.
#
# Processing row 135...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 242
# Total estimated tokens (prompt + response): 810
# Row 135 processed in 11.11 seconds.
#
# Processing row 136...
# Estimated input tokens (prompt): 576
# Estimated output tokens (response): 274
# Total estimated tokens (prompt + response): 850
# Row 136 processed in 19.31 seconds.
#
# Processing row 137...
# Estimated input tokens (prompt): 595
# Estimated output tokens (response): 289
# Total estimated tokens (prompt + response): 884
# Row 137 processed in 13.95 seconds.
#
# Processing row 138...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 271
# Total estimated tokens (prompt + response): 839
# Row 138 processed in 10.70 seconds.
#
# Processing row 139...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 271
# Total estimated tokens (prompt + response): 839
# Row 139 processed in 8.93 seconds.
#
# Processing row 140...
# Estimated input tokens (prompt): 574
# Estimated output tokens (response): 302
# Total estimated tokens (prompt + response): 876
# Row 140 processed in 13.62 seconds.
#
# Processing row 141...
# Estimated input tokens (prompt): 573
# Estimated output tokens (response): 281
# Total estimated tokens (prompt + response): 854
# Row 141 processed in 19.14 seconds.
#
# Processing row 142...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 258
# Total estimated tokens (prompt + response): 826
# Row 142 processed in 12.68 seconds.
#
# Processing row 143...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 251
# Total estimated tokens (prompt + response): 819
# Row 143 processed in 12.77 seconds.
#
# Processing row 144...
# Estimated input tokens (prompt): 569
# Estimated output tokens (response): 230
# Total estimated tokens (prompt + response): 799
# Row 144 processed in 9.99 seconds.
#
# Processing row 145...
# Estimated input tokens (prompt): 570
# Estimated output tokens (response): 291
# Total estimated tokens (prompt + response): 861
# Row 145 processed in 11.76 seconds.
#
# Processing row 146...
# Estimated input tokens (prompt): 597
# Estimated output tokens (response): 379
# Total estimated tokens (prompt + response): 976
# Row 146 processed in 16.46 seconds.
#
# Processing row 147...
# Estimated input tokens (prompt): 772
# Estimated output tokens (response): 605
# Total estimated tokens (prompt + response): 1377
# Row 147 processed in 19.87 seconds.
#
# Processing row 148...
# Estimated input tokens (prompt): 583
# Estimated output tokens (response): 317
# Total estimated tokens (prompt + response): 900
# Row 148 processed in 12.42 seconds.
#
# Processing row 149...
# Estimated input tokens (prompt): 1160
# Estimated output tokens (response): 422
# Total estimated tokens (prompt + response): 1582
# Row 149 processed in 15.42 seconds.
#
# Processing row 150...
# Estimated input tokens (prompt): 575
# Estimated output tokens (response): 461
# Total estimated tokens (prompt + response): 1036
# Row 150 processed in 19.53 seconds.
#
# Processing row 151...
# Estimated input tokens (prompt): 577
# Estimated output tokens (response): 254
# Total estimated tokens (prompt + response): 831
# Row 151 processed in 12.01 seconds.
#
# Processing row 152...
# Estimated input tokens (prompt): 569
# Estimated output tokens (response): 484
# Total estimated tokens (prompt + response): 1053
# Row 152 processed in 17.66 seconds.
#
# Processing row 153...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 278
# Total estimated tokens (prompt + response): 846
# Row 153 processed in 15.97 seconds.
#
# Processing row 154...
# Estimated input tokens (prompt): 589
# Estimated output tokens (response): 258
# Total estimated tokens (prompt + response): 847
# Row 154 processed in 12.64 seconds.
#
# Processing row 155...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 395
# Total estimated tokens (prompt + response): 963
# Row 155 processed in 11.67 seconds.
#
# Processing row 156...
# Estimated input tokens (prompt): 579
# Estimated output tokens (response): 426
# Total estimated tokens (prompt + response): 1005
# Row 156 processed in 10.60 seconds.
#
# Processing row 157...
# Estimated input tokens (prompt): 653
# Estimated output tokens (response): 305
# Total estimated tokens (prompt + response): 958
# Row 157 processed in 14.04 seconds.
#
# Processing row 158...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 250
# Total estimated tokens (prompt + response): 818
# Row 158 processed in 8.34 seconds.
#
# Processing row 159...
# Estimated input tokens (prompt): 727
# Estimated output tokens (response): 436
# Total estimated tokens (prompt + response): 1163
# Row 159 processed in 16.69 seconds.
#
# Processing row 160...
# Estimated input tokens (prompt): 623
# Estimated output tokens (response): 316
# Total estimated tokens (prompt + response): 939
# Row 160 processed in 13.52 seconds.
#
# Processing row 161...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 252
# Total estimated tokens (prompt + response): 820
# Row 161 processed in 9.56 seconds.
#
# Processing row 162...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 269
# Total estimated tokens (prompt + response): 837
# Row 162 processed in 11.67 seconds.
#
# Processing row 163...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 257
# Total estimated tokens (prompt + response): 825
# Row 163 processed in 11.71 seconds.
#
# Processing row 164...
# Estimated input tokens (prompt): 662
# Estimated output tokens (response): 426
# Total estimated tokens (prompt + response): 1088
# Row 164 processed in 24.22 seconds.
#
# Processing row 165...
# Estimated input tokens (prompt): 569
# Estimated output tokens (response): 284
# Total estimated tokens (prompt + response): 853
# Row 165 processed in 11.89 seconds.
#
# Processing row 166...
# Estimated input tokens (prompt): 709
# Estimated output tokens (response): 355
# Total estimated tokens (prompt + response): 1064
# Row 166 processed in 16.87 seconds.
#
# Processing row 167...
# Estimated input tokens (prompt): 1199
# Estimated output tokens (response): 860
# Total estimated tokens (prompt + response): 2059
# Row 167 processed in 23.99 seconds.
#
# Processing row 168...
# Estimated input tokens (prompt): 638
# Estimated output tokens (response): 323
# Total estimated tokens (prompt + response): 961
# Row 168 processed in 24.76 seconds.
#
# Processing row 169...
# Estimated input tokens (prompt): 675
# Estimated output tokens (response): 625
# Total estimated tokens (prompt + response): 1300
# Row 169 processed in 18.81 seconds.
#
# Processing row 170...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 231
# Total estimated tokens (prompt + response): 799
# Row 170 processed in 8.01 seconds.
#
# Processing row 171...
# Estimated input tokens (prompt): 603
# Estimated output tokens (response): 339
# Total estimated tokens (prompt + response): 942
# Row 171 processed in 16.83 seconds.
#
# Processing row 172...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 259
# Total estimated tokens (prompt + response): 827
# Row 172 processed in 7.57 seconds.
#
# Processing row 173...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 268
# Total estimated tokens (prompt + response): 836
# Row 173 processed in 8.03 seconds.
#
# Processing row 174...
# Estimated input tokens (prompt): 579
# Estimated output tokens (response): 295
# Total estimated tokens (prompt + response): 874
# Row 174 processed in 11.01 seconds.
#
# Processing row 175...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 283
# Total estimated tokens (prompt + response): 851
# Row 175 processed in 9.44 seconds.
#
# Processing row 176...
# Estimated input tokens (prompt): 584
# Estimated output tokens (response): 297
# Total estimated tokens (prompt + response): 881
# Row 176 processed in 12.54 seconds.
#
# Processing row 177...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 246
# Total estimated tokens (prompt + response): 814
# Row 177 processed in 10.56 seconds.
#
# Processing row 178...
# Estimated input tokens (prompt): 703
# Estimated output tokens (response): 313
# Total estimated tokens (prompt + response): 1016
# Row 178 processed in 12.46 seconds.
#
# Processing row 179...
# Estimated input tokens (prompt): 569
# Estimated output tokens (response): 253
# Total estimated tokens (prompt + response): 822
# Row 179 processed in 10.30 seconds.
#
# Processing row 180...
# Estimated input tokens (prompt): 687
# Estimated output tokens (response): 674
# Total estimated tokens (prompt + response): 1361
# JSON decoding failed: Expecting property name enclosed in double quotes: line 11 column 1 (char 1040)
# Raw output:
# {
#   "core_issue": "The patient feels cheated after two check-ups at a specialist clinic. They were charged a very high fee and given a lot of medicine without any diagnosis, and were passed between departments.",
#   "summary": "Expensive, undiagnosed, poor, deceptive service.",
#   "does_the_review_mention_a_specific_ward_block_or_room_number": "Not found in feedback",
#   "does_the_review_mention_about_the_department": "专科门诊 (Specialist outpatient clinic)",
#   "does_the_review_describe_whether_the_hospital_is_old_upgraded_or_modern": "Not found in feedback",
#   "does_the_review_mention_doctors": "Yes, it mentions the staff at the specialist clinic were dismissive, saying only a few words (说几句就了事).",
#   "does_the_review_mention_nurses": "Not found in feedback",
#   "does_the_review_mention_support_or_admin_staff": "Yes, it is implied that staff in different departments were unhelpful, as they kept pushing the patient's case between departments (把事情推来推去各个部门).",
#   "does_the_review_mention_specific_staff_names": "Not found in feedback",
# awesome
#   "does_the_review_mention_specific_treatments_or_medical_procedures": "Body check-up (检查身体).",
#   "what_aspects_of_service_quality_are_highlighted": "Dismissive service from the specialist clinic and poor coordination between departments.",
#   "does_the_reviewer_mention_waiting_time": "Not found in feedback",
#   "does_the_review_mention_food_quality_or_any_other_quality": "Not found in feedback",
#   "does_the_reviewer_mention_rude_staff": "The staff at the specialist clinic are described as dismissive (说几句就了事), which can be interpreted as a form of rude or unprofessional behavior.",
#   "does_the_reviewer_mention_delays_long_queues_or_poor_management": "Yes, poor management is mentioned. The reviewer states they were pushed around between different departments (把事情推来推去各个部门).",
#   "does_the_review_mention_unfair_rules_or_inconsistent_policies": "Not found in feedback",
#   "does_the_reviewer_explicitly_call_the_hospital_horrible_worst_terrifying_or_disappointing": "While not using those exact words, the reviewer expresses deep disappointment and a feeling of being cheated, ending with the accusation: 'Isn't this deceiving the common people's money?' (这不是欺骗老百姓的钱).",
#   "does_the_review_suggest_profit_motive_or_unnecessary_procedures": "Yes, the review strongly suggests a profit motive. The patient was not diagnosed with any illness but was prescribed a lot of medicine and charged a high fee.",
#   "does_the_reviewer_perceive_fraudulent_activity_from_the_hospital": "Yes, the reviewer explicitly accuses the hospital of deception/fraudulent activity by stating, 'Isn't this deceiving the common people's money?' (这不是欺骗老百姓的钱)."
# }
#
# Row 180 processed in 22.58 seconds.
#
# Processing row 181...
# Estimated input tokens (prompt): 572
# Estimated output tokens (response): 282
# Total estimated tokens (prompt + response): 854
# Row 181 processed in 13.84 seconds.
#
# Processing row 182...
# Estimated input tokens (prompt): 717
# Estimated output tokens (response): 361
# Total estimated tokens (prompt + response): 1078
# Row 182 processed in 17.69 seconds.
#
# Processing row 183...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 266
# Total estimated tokens (prompt + response): 834
# Row 183 processed in 10.41 seconds.
#
# Processing row 184...
# Estimated input tokens (prompt): 637
# Estimated output tokens (response): 346
# Total estimated tokens (prompt + response): 983
# JSON decoding failed: Expecting property name enclosed in double quotes: line 15 column 1 (char 860)
# Raw output:
# {
#   "core_issue": "The reviewer faced a lack of clear instructions on how to make a payment and was unable to get an invoice for an insurance claim. Multiple staff members were unable to provide any guidance.",
#   "summary": "Confusing payment, unhelpful staff.",
#   "ward_block_or_room_number": "Not found in feedback",
#   "department": "Not found in feedback",
#   "hospital_old_upgraded_or_modern": "Not found in feedback",
#   "doctors": "Not found in feedback",
#   "nurses": "Not found in feedback",
#   "support_or_admin_staff": "2 to 3 person in SGH staff",
#   "specific_staff_names": "Not found in feedback",
#   "specific_treatments_or_medical_procedures": "consultation",
#   "service_quality_highlighted": "Unhelpful staff who could not provide guidance.",
#   "waiting_time": "Not found in feedback",
#   "food_quality_or_any_other_quality": "Not found in feedback",
# so  "rude_staff_details": "Not found in feedback",
#   "delays_long_queues_or_poor_management": "Poor management is indicated by the lack of a clear payment process, no invoice generation, and staff being unable to guide the patient on the procedure.",
#   "unfair_rules_or_inconsistent_policies": "Not found in feedback",
#   "explicitly_horrible_worst_terrifying_or_disappointing": "The reviewer explicitly stated they were 'Quite disappointed!'",
#   "profit_motive_or_unnecessary_procedures": "Not found in feedback",
#   "perceived_fraudulent_activity": "Not found in feedback"
# }
#
# Row 184 processed in 15.45 seconds.
#
# Processing row 185...
# Estimated input tokens (prompt): 584
# Estimated output tokens (response): 277
# Total estimated tokens (prompt + response): 861
# Row 185 processed in 12.15 seconds.
#
# Processing row 186...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 238
# Total estimated tokens (prompt + response): 806
# Row 186 processed in 8.10 seconds.
#
# Processing row 187...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 264
# Total estimated tokens (prompt + response): 832
# Row 187 processed in 11.91 seconds.
#
# Processing row 188...
# Estimated input tokens (prompt): 587
# Estimated output tokens (response): 311
# Total estimated tokens (prompt + response): 898
# Row 188 processed in 11.84 seconds.
#
# Processing row 189...
# Estimated input tokens (prompt): 615
# Estimated output tokens (response): 293
# Total estimated tokens (prompt + response): 908
# Row 189 processed in 15.93 seconds.
#
# Processing row 190...
# Estimated input tokens (prompt): 622
# Estimated output tokens (response): 316
# Total estimated tokens (prompt + response): 938
# Row 190 processed in 13.06 seconds.
#
# Processing row 191...
# Estimated input tokens (prompt): 645
# Estimated output tokens (response): 359
# Total estimated tokens (prompt + response): 1004
# Row 191 processed in 13.06 seconds.
#
# Processing row 192...
# Estimated input tokens (prompt): 794
# Estimated output tokens (response): 613
# Total estimated tokens (prompt + response): 1407
# Row 192 processed in 19.89 seconds.
#
# Processing row 193...
# Estimated input tokens (prompt): 588
# Estimated output tokens (response): 270
# Total estimated tokens (prompt + response): 858
# Row 193 processed in 9.40 seconds.
#
# Processing row 194...
# Estimated input tokens (prompt): 640
# Estimated output tokens (response): 414
# Total estimated tokens (prompt + response): 1054
# Row 194 processed in 16.54 seconds.
#
# Processing row 195...
# Estimated input tokens (prompt): 603
# Estimated output tokens (response): 298
# Total estimated tokens (prompt + response): 901
# Row 195 processed in 12.26 seconds.
#
# Processing row 196...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 253
# Total estimated tokens (prompt + response): 821
# Row 196 processed in 11.98 seconds.
#
# Processing row 197...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 438
# Total estimated tokens (prompt + response): 1006
# Row 197 processed in 16.17 seconds.
#
# Processing row 198...
# Estimated input tokens (prompt): 585
# Estimated output tokens (response): 286
# Total estimated tokens (prompt + response): 871
# Row 198 processed in 14.31 seconds.
#
# Processing row 199...
# Estimated input tokens (prompt): 571
# Estimated output tokens (response): 282
# Total estimated tokens (prompt + response): 853
# Row 199 processed in 10.98 seconds.
#
# Processing row 200...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 264
# Total estimated tokens (prompt + response): 832
# Row 200 processed in 12.93 seconds.
#
# Processing row 201...
# Estimated input tokens (prompt): 844
# Estimated output tokens (response): 618
# Total estimated tokens (prompt + response): 1462
# Row 201 processed in 13.73 seconds.
#
# Processing row 202...
# Estimated input tokens (prompt): 614
# Estimated output tokens (response): 341
# Total estimated tokens (prompt + response): 955
# Row 202 processed in 13.97 seconds.
#
# Processing row 203...
# Estimated input tokens (prompt): 639
# Estimated output tokens (response): 297
# Total estimated tokens (prompt + response): 936
# Row 203 processed in 12.94 seconds.
#
# Processing row 204...
# Estimated input tokens (prompt): 615
# Estimated output tokens (response): 304
# Total estimated tokens (prompt + response): 919
# Row 204 processed in 12.94 seconds.
#
# Processing row 205...
# Estimated input tokens (prompt): 582
# Estimated output tokens (response): 278
# Total estimated tokens (prompt + response): 860
# Row 205 processed in 11.73 seconds.
#
# Processing row 206...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 268
# Total estimated tokens (prompt + response): 836
# Row 206 processed in 14.21 seconds.
#
# Processing row 207...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 247
# Total estimated tokens (prompt + response): 815
# Row 207 processed in 12.31 seconds.
#
# Processing row 208...
# Estimated input tokens (prompt): 604
# Estimated output tokens (response): 279
# Total estimated tokens (prompt + response): 883
# Row 208 processed in 13.49 seconds.
#
# Processing row 209...
# Estimated input tokens (prompt): 661
# Estimated output tokens (response): 325
# Total estimated tokens (prompt + response): 986
# Row 209 processed in 18.93 seconds.
#
# Processing row 210...
# Estimated input tokens (prompt): 574
# Estimated output tokens (response): 264
# Total estimated tokens (prompt + response): 838
# Row 210 processed in 12.83 seconds.
#
# Processing row 211...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 235
# Total estimated tokens (prompt + response): 803
# Row 211 processed in 8.07 seconds.
#
# Processing row 212...
# Estimated input tokens (prompt): 581
# Estimated output tokens (response): 298
# Total estimated tokens (prompt + response): 879
# Row 212 processed in 10.24 seconds.
#
# Processing row 213...
# Estimated input tokens (prompt): 621
# Estimated output tokens (response): 309
# Total estimated tokens (prompt + response): 930
# Row 213 processed in 10.40 seconds.
#
# Processing row 214...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 251
# Total estimated tokens (prompt + response): 819
# Row 214 processed in 8.94 seconds.
#
# Processing row 215...
# Estimated input tokens (prompt): 617
# Estimated output tokens (response): 319
# Total estimated tokens (prompt + response): 936
# Row 215 processed in 14.78 seconds.
#
# Processing row 216...
# Estimated input tokens (prompt): 617
# Estimated output tokens (response): 357
# Total estimated tokens (prompt + response): 974
# Row 216 processed in 13.52 seconds.
#
# Processing row 217...
# Estimated input tokens (prompt): 577
# Estimated output tokens (response): 318
# Total estimated tokens (prompt + response): 895
# Row 217 processed in 18.34 seconds.
#
# Processing row 218...
# Estimated input tokens (prompt): 610
# Estimated output tokens (response): 279
# Total estimated tokens (prompt + response): 889
# Row 218 processed in 12.33 seconds.
#
# Processing row 219...
# Estimated input tokens (prompt): 575
# Estimated output tokens (response): 264
# Total estimated tokens (prompt + response): 839
# Row 219 processed in 10.96 seconds.
#
# Processing row 220...
# Estimated input tokens (prompt): 577
# Estimated output tokens (response): 296
# Total estimated tokens (prompt + response): 873
# Row 220 processed in 11.31 seconds.
#
# Processing row 221...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 280
# Total estimated tokens (prompt + response): 848
# Row 221 processed in 9.34 seconds.
#
# Processing row 222...
# Estimated input tokens (prompt): 636
# Estimated output tokens (response): 330
# Total estimated tokens (prompt + response): 966
# Row 222 processed in 13.39 seconds.
#
# Processing row 223...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 290
# Total estimated tokens (prompt + response): 858
# Row 223 processed in 19.23 seconds.
#
# Processing row 224...
# Estimated input tokens (prompt): 571
# Estimated output tokens (response): 263
# Total estimated tokens (prompt + response): 834
# Row 224 processed in 11.34 seconds.
#
# Processing row 225...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 270
# Total estimated tokens (prompt + response): 838
# Row 225 processed in 10.10 seconds.
#
# Processing row 226...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 257
# Total estimated tokens (prompt + response): 825
# Row 226 processed in 12.83 seconds.
#
# Processing row 227...
# Estimated input tokens (prompt): 637
# Estimated output tokens (response): 388
# Total estimated tokens (prompt + response): 1025
# Row 227 processed in 18.23 seconds.
#
# Processing row 228...
# ...
#
# Processing row 534...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 272
# Total estimated tokens (prompt + response): 840
# Row 534 processed in 13.40 seconds.
#
# Processing row 535...
# Estimated input tokens (prompt): 573
# Estimated output tokens (response): 291
# Total estimated tokens (prompt + response): 864
# Row 535 processed in 11.03 seconds.
#
# Processing row 536...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 438
# Total estimated tokens (prompt + response): 1006
# Row 536 processed in 13.59 seconds.
#
# Processing row 537...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 270
# Total estimated tokens (prompt + response): 838
# Row 537 processed in 12.82 seconds.
#
# Processing row 538...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 446
# Total estimated tokens (prompt + response): 1014
# Row 538 processed in 17.13 seconds.
#
# Processing row 539...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 240
# Total estimated tokens (prompt + response): 808
# Row 539 processed in 12.40 seconds.
#
# Processing row 540...
# Estimated input tokens (prompt): 608
# Estimated output tokens (response): 310
# Total estimated tokens (prompt + response): 918
# Row 540 processed in 13.13 seconds.
#
# Processing row 541...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 260
# Total estimated tokens (prompt + response): 828
# Row 541 processed in 8.21 seconds.
#
# Processing row 542...
# Estimated input tokens (prompt): 584
# Estimated output tokens (response): 374
# Total estimated tokens (prompt + response): 958
# Row 542 processed in 24.07 seconds.
#
# Processing row 543...
# Estimated input tokens (prompt): 599
# Estimated output tokens (response): 337
# Total estimated tokens (prompt + response): 936
# Row 543 processed in 13.58 seconds.
#
# Processing row 544...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 254
# Total estimated tokens (prompt + response): 822
# Row 544 processed in 10.33 seconds.
#
# Processing row 545...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 274
# Total estimated tokens (prompt + response): 842
# Row 545 processed in 12.82 seconds.
#
# Processing row 546...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 270
# Total estimated tokens (prompt + response): 838
# Row 546 processed in 9.84 seconds.
#
# Processing row 547...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 252
# Total estimated tokens (prompt + response): 820
# Row 547 processed in 11.95 seconds.
#
# Processing row 548...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 272
# Total estimated tokens (prompt + response): 840
# Row 548 processed in 7.93 seconds.
#
# Processing row 549...
# Estimated input tokens (prompt): 577
# Estimated output tokens (response): 244
# Total estimated tokens (prompt + response): 821
# Row 549 processed in 11.90 seconds.
#
# Processing row 550...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 252
# Total estimated tokens (prompt + response): 820
# Row 550 processed in 11.78 seconds.
#
# Processing row 551...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 253
# Total estimated tokens (prompt + response): 821
# Row 551 processed in 13.62 seconds.
#
# Processing row 552...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 262
# Total estimated tokens (prompt + response): 830
# Row 552 processed in 7.79 seconds.
#
# Processing row 553...
# Estimated input tokens (prompt): 601
# Estimated output tokens (response): 322
# Total estimated tokens (prompt + response): 923
# Row 553 processed in 17.89 seconds.
#
# Processing row 554...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 275
# Total estimated tokens (prompt + response): 843
# Row 554 processed in 16.26 seconds.
#
# Processing row 555...
# Estimated input tokens (prompt): 594
# Estimated output tokens (response): 336
# Total estimated tokens (prompt + response): 930
# Row 555 processed in 13.67 seconds.
#
# Processing row 556...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 268
# Total estimated tokens (prompt + response): 836
# Row 556 processed in 9.83 seconds.
#
# Processing row 557...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 281
# Total estimated tokens (prompt + response): 849
# Row 557 processed in 9.74 seconds.
#
# Processing row 558...
# Estimated input tokens (prompt): 757
# Estimated output tokens (response): 612
# Total estimated tokens (prompt + response): 1369
# Row 558 processed in 22.38 seconds.
#
# Processing row 559...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 438
# Total estimated tokens (prompt + response): 1006
# Row 559 processed in 15.82 seconds.
#
# Processing row 560...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 260
# Total estimated tokens (prompt + response): 828
# Row 560 processed in 15.40 seconds.
#
# Processing row 561...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 263
# Total estimated tokens (prompt + response): 831
# Row 561 processed in 11.98 seconds.
#
# Processing row 562...
# Estimated input tokens (prompt): 613
# Estimated output tokens (response): 342
# Total estimated tokens (prompt + response): 955
# Row 562 processed in 13.77 seconds.
#
# Processing row 563...
# Estimated input tokens (prompt): 616
# Estimated output tokens (response): 321
# Total estimated tokens (prompt + response): 937
# Row 563 processed in 19.19 seconds.
#
# Processing row 564...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 284
# Total estimated tokens (prompt + response): 852
# Row 564 processed in 14.24 seconds.
#
# Processing row 565...
# Estimated input tokens (prompt): 569
# Estimated output tokens (response): 277
# Total estimated tokens (prompt + response): 846
# Row 565 processed in 15.61 seconds.
#
# Processing row 566...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 245
# Total estimated tokens (prompt + response): 813
# Row 566 processed in 10.39 seconds.
#
# Processing row 567...
# Estimated input tokens (prompt): 578
# Estimated output tokens (response): 300
# Total estimated tokens (prompt + response): 878
# Row 567 processed in 12.59 seconds.
#
# Processing row 568...
# Estimated input tokens (prompt): 574
# Estimated output tokens (response): 275
# Total estimated tokens (prompt + response): 849
# Row 568 processed in 8.93 seconds.
#
# Processing row 569...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 272
# Total estimated tokens (prompt + response): 840
# Row 569 processed in 8.36 seconds.
#
# Processing row 570...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 261
# Total estimated tokens (prompt + response): 829
# Row 570 processed in 7.13 seconds.
#
# Processing row 571...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 395
# Total estimated tokens (prompt + response): 963
# Row 571 processed in 11.50 seconds.
#
# Processing row 572...
# Estimated input tokens (prompt): 572
# Estimated output tokens (response): 277
# Total estimated tokens (prompt + response): 849
# Row 572 processed in 17.41 seconds.
#
# Processing row 573...
# Estimated input tokens (prompt): 571
# Estimated output tokens (response): 296
# Total estimated tokens (prompt + response): 867
# Row 573 processed in 13.43 seconds.
#
# Processing row 574...
# Estimated input tokens (prompt): 567
# Estimated output tokens (response): 561
# Total estimated tokens (prompt + response): 1128
# Row 574 processed in 19.82 seconds.
#
# Processing row 575...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 235
# Total estimated tokens (prompt + response): 803
# Row 575 processed in 10.58 seconds.
#
# Processing row 576...
# Estimated input tokens (prompt): 580
# Estimated output tokens (response): 312
# Total estimated tokens (prompt + response): 892
# Row 576 processed in 20.19 seconds.
#
# Processing row 577...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 259
# Total estimated tokens (prompt + response): 827
# Row 577 processed in 13.38 seconds.
#
# Processing row 578...
# Estimated input tokens (prompt): 574
# Estimated output tokens (response): 285
# Total estimated tokens (prompt + response): 859
# Row 578 processed in 12.52 seconds.
#
# Processing row 579...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 253
# Total estimated tokens (prompt + response): 821
# Row 579 processed in 8.45 seconds.
#
# Processing row 580...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 235
# Total estimated tokens (prompt + response): 803
# Row 580 processed in 10.89 seconds.
#
# Processing row 581...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 246
# Total estimated tokens (prompt + response): 814
# Row 581 processed in 12.72 seconds.
#
# Processing row 582...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 266
# Total estimated tokens (prompt + response): 834
# Row 582 processed in 8.88 seconds.
#
# Processing row 583...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 277
# Total estimated tokens (prompt + response): 845
# Row 583 processed in 10.70 seconds.
#
# Processing row 584...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 242
# Total estimated tokens (prompt + response): 810
# Row 584 processed in 8.57 seconds.
#
# Processing row 585...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 245
# Total estimated tokens (prompt + response): 813
# Row 585 processed in 8.78 seconds.
#
# Processing row 586...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 267
# Total estimated tokens (prompt + response): 835
# Row 586 processed in 12.28 seconds.
#
# Processing row 587...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 250
# Total estimated tokens (prompt + response): 818
# Row 587 processed in 10.40 seconds.
#
# Processing row 588...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 253
# Total estimated tokens (prompt + response): 821
# Row 588 processed in 8.20 seconds.
#
# Processing row 589...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 438
# Total estimated tokens (prompt + response): 1006
# Row 589 processed in 10.05 seconds.
#
# Processing row 590...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 270
# Total estimated tokens (prompt + response): 838
# Row 590 processed in 15.91 seconds.
#
# Processing row 591...
# Estimated input tokens (prompt): 577
# Estimated output tokens (response): 317
# Total estimated tokens (prompt + response): 894
# Row 591 processed in 21.65 seconds.
#
# Processing row 592...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 438
# Total estimated tokens (prompt + response): 1006
# Row 592 processed in 13.67 seconds.
#
# Processing row 593...
# Estimated input tokens (prompt): 572
# Estimated output tokens (response): 277
# Total estimated tokens (prompt + response): 849
# Row 593 processed in 15.34 seconds.
#
# Processing row 594...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 265
# Total estimated tokens (prompt + response): 833
# Row 594 processed in 18.35 seconds.
#
# Processing row 595...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 253
# Total estimated tokens (prompt + response): 821
# Row 595 processed in 12.26 seconds.
#
# Processing row 596...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 257
# Total estimated tokens (prompt + response): 825
# Row 596 processed in 10.95 seconds.
#
# Processing row 597...
# Estimated input tokens (prompt): 576
# Estimated output tokens (response): 281
# Total estimated tokens (prompt + response): 857
# Row 597 processed in 10.14 seconds.
#
# Processing row 598...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 259
# Total estimated tokens (prompt + response): 827
# Row 598 processed in 10.86 seconds.
#
# Processing row 599...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 438
# Total estimated tokens (prompt + response): 1006
# Row 599 processed in 12.36 seconds.
#
# Processing row 600...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 279
# Total estimated tokens (prompt + response): 847
# Row 600 processed in 11.90 seconds.
#
# Processing row 601...
# Estimated input tokens (prompt): 579
# Estimated output tokens (response): 283
# Total estimated tokens (prompt + response): 862
# JSON decoding failed: Expecting property name enclosed in double quotes: line 14 column 1 (char 741)
# Raw output:
# {
#   "core_issue": "The feedback is a simple statement of fact, indicating that the patient was admitted on a specific date, without any further context, complaint, or praise.",
#   "summary": "Patient admitted on the 22nd.",
#   "ward_block_or_room_number": "Not found in feedback",
#   "department": "Not found in feedback",
#   "hospital_description": "Not found in feedback",
#   "doctors_mentioned": "Not found in feedback",
#   "nurses_mentioned": "Not found in feedback",
#   "support_or_admin_staff_mentioned": "Not found in feedback",
#   "specific_staff_names": "Not found in feedback",
#   "specific_treatments_or_medical_procedures": "Admission",
#   "service_quality_highlighted": "Not found in feedback",
#   "waiting_time": "Not found in feedback",
# food_or_other_quality": "Not found in feedback",
#   "rude_staff_details": "Not found in feedback",
#   "delays_or_poor_management": "Not found in feedback",
#   "unfair_rules_or_inconsistent_policies": "Not found in feedback",
#   "explicit_negative_description": "Not found in feedback",
#   "profit_motive_or_unnecessary_procedures": "Not found in feedback",
#   "perceived_fraudulent_activity": "Not found in feedback"
# }
#
# Row 601 processed in 12.27 seconds.
#
# Processing row 602...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 450
# Total estimated tokens (prompt + response): 1018
# Row 602 processed in 13.51 seconds.
#
# Processing row 603...
# Estimated input tokens (prompt): 570
# Estimated output tokens (response): 266
# Total estimated tokens (prompt + response): 836
# Row 603 processed in 14.80 seconds.
#
# Processing row 604...
# Estimated input tokens (prompt): 569
# Estimated output tokens (response): 263
# Total estimated tokens (prompt + response): 832
# Row 604 processed in 8.68 seconds.
#
# Processing row 605...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 252
# Total estimated tokens (prompt + response): 820
# Row 605 processed in 9.04 seconds.
#
# Processing row 606...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 260
# Total estimated tokens (prompt + response): 828
# Row 606 processed in 8.69 seconds.
#
# Processing row 607...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 270
# Total estimated tokens (prompt + response): 838
# Row 607 processed in 10.66 seconds.
#
# Processing row 608...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 272
# Total estimated tokens (prompt + response): 840
# Row 608 processed in 15.10 seconds.
#
# Processing row 609...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 278
# Total estimated tokens (prompt + response): 846
# Row 609 processed in 11.17 seconds.
#
# Processing row 610...
# Estimated input tokens (prompt): 583
# Estimated output tokens (response): 290
# Total estimated tokens (prompt + response): 873
# Row 610 processed in 12.97 seconds.
#
# Processing row 611...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 259
# Total estimated tokens (prompt + response): 827
# Row 611 processed in 11.68 seconds.
#
# Processing row 612...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 438
# Total estimated tokens (prompt + response): 1006
# Row 612 processed in 10.82 seconds.
#
# Processing row 613...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 272
# Total estimated tokens (prompt + response): 840
# Row 613 processed in 12.87 seconds.
