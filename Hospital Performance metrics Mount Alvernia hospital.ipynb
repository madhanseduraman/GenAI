# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /opt/conda/lib/python3.10/site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in /opt/conda/lib/python3.10/site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)

# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in /opt/conda/lib/python3.10/site-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in /opt/conda/lib/python3.10/site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk>=3.9->textblob) (8.1.8)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk>=3.9->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk>=3.9->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nltk>=3.9->textblob) (4.67.1)

# %%
# ==============================
# 1. Setup & Load Data
# ==============================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from textblob import TextBlob

# Load dataset
df = pd.read_excel("Mount Alvernia hospital.xlsx")

# Display basic info
print(df.shape)
df.head()
# Out:
# (443, 35)
#                                    query                     name  \
# 0  0x31da1746cc0725d3:0x9952f2d57bf4038f  Mount Alvernia Hospital
# 1  0x31da1746cc0725d3:0x9952f2d57bf4038f  Mount Alvernia Hospital
# 2  0x31da1746cc0725d3:0x9952f2d57bf4038f  Mount Alvernia Hospital
# 3  0x31da1746cc0725d3:0x9952f2d57bf4038f  Mount Alvernia Hospital
# 4  0x31da1746cc0725d3:0x9952f2d57bf4038f  Mount Alvernia Hospital
#
#                                google_id                     place_id  \
# 0  0x31da1746cc0725d3:0x9952f2d57bf4038f  ChIJ0yUHzEYX2jERjwP0e9XyUpk
# 1  0x31da1746cc0725d3:0x9952f2d57bf4038f  ChIJ0yUHzEYX2jERjwP0e9XyUpk
# 2  0x31da1746cc0725d3:0x9952f2d57bf4038f  ChIJ0yUHzEYX2jERjwP0e9XyUpk
# 3  0x31da1746cc0725d3:0x9952f2d57bf4038f  ChIJ0yUHzEYX2jERjwP0e9XyUpk
# 4  0x31da1746cc0725d3:0x9952f2d57bf4038f  ChIJ0yUHzEYX2jERjwP0e9XyUpk
#
#                                        location_link  \
# 0  https://www.google.com/maps/place/Mount+Alvern...
# 1  https://www.google.com/maps/place/Mount+Alvern...
# 2  https://www.google.com/maps/place/Mount+Alvern...
# 3  https://www.google.com/maps/place/Mount+Alvern...
# 4  https://www.google.com/maps/place/Mount+Alvern...
#
#                                         reviews_link  reviews  rating  \
# 0  https://search.google.com/local/reviews?placei...      443     3.5
# 1  https://search.google.com/local/reviews?placei...      443     3.5
# 2  https://search.google.com/local/reviews?placei...      443     3.5
# 3  https://search.google.com/local/reviews?placei...      443     3.5
# 4  https://search.google.com/local/reviews?placei...      443     3.5
#
#                                            review_id  \
# 0  Ci9DQUlRQUNvZENodHljRjlvT2xOSU9UVlROVGRxYVhGTV...
# 1  Ci9DQUlRQUNvZENodHljRjlvT2pkaWEzUnBOMWRPYWxZMV...
# 2  Ci9DQUlRQUNvZENodHljRjlvT2tOU1RWTlpSRmxtYVVoUk...
# 3  Ci9DQUlRQUNvZENodHljRjlvT2xCTVgxbzRjazU1Y2tsc2...
# 4  Ci9DQUlRQUNvZENodHljRjlvT25RMGJXZG5NVzlNU1hCTU...
#
#                                 review_pagination_id  ... review_rating  \
# 0  CAESYENBRVFBUnBDUTJrNFNVRlNTVzVEWjI5QlVEY3lSMk...  ...             4
# 1  CAESYENBRVFBaHBDUTJrNFNVRlNTVzVEWjI5QlVEY3lSMk...  ...             3
# 2  CAESY0NBRVFBeHBFUTJwRlNVRlNTWEJEWjI5QlVEY3lSMk...  ...             2
# 3  CAESY0NBRVFCQnBFUTJwRlNVRlNTWEJEWjI5QlVEY3lSMk...  ...             1
# 4  CAESY0NBRVFCUnBFUTJwRlNVRlNTWEJEWjI5QlVEY3lSMl...  ...             5
#
#   review_timestamp  review_datetime_utc review_likes           reviews_id  \
# 0       1755854070  08/22/2025 09:14:30          NaN -7398584239094758513
# 1       1755852758  08/22/2025 08:52:38          NaN -7398584239094758513
# 2       1755657053  08/20/2025 02:30:53          NaN -7398584239094758513
# 3       1755646525  08/19/2025 23:35:25          NaN -7398584239094758513
# 4       1755270597  08/15/2025 15:09:57          NaN -7398584239094758513
#
#    reviews_per_score_1 reviews_per_score_2 reviews_per_score_3  \
# 0                  124                  21                  17
# 1                  124                  21                  17
# 2                  124                  21                  17
# 3                  124                  21                  17
# 4                  124                  21                  17
#
#   reviews_per_score_4  reviews_per_score_5
# 0                  73                  208
# 1                  73                  208
# 2                  73                  208
# 3                  73                  208
# 4                  73                  208
#
# [5 rows x 35 columns]

# %%
df.columns
# Out:
# Index(['query', 'name', 'google_id', 'place_id', 'location_link',
#        'reviews_link', 'reviews', 'rating', 'review_id',
#        'review_pagination_id', 'author_link', 'author_title', 'author_id',
#        'author_image', 'author_reviews_count', 'author_ratings_count',
#        'review_text', 'review_img_urls', 'review_img_url', 'review_questions',
#        'review_photo_ids', 'owner_answer', 'owner_answer_timestamp',
#        'owner_answer_timestamp_datetime_utc', 'review_link', 'review_rating',
#        'review_timestamp', 'review_datetime_utc', 'review_likes', 'reviews_id',
#        'reviews_per_score_1', 'reviews_per_score_2', 'reviews_per_score_3',
#        'reviews_per_score_4', 'reviews_per_score_5'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 35 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   query                                443 non-null    object
#  1   name                                 443 non-null    object
#  2   google_id                            443 non-null    object
#  3   place_id                             443 non-null    object
#  4   location_link                        443 non-null    object
#  5   reviews_link                         443 non-null    object
#  6   reviews                              443 non-null    int64
#  7   rating                               443 non-null    float64
#  8   review_id                            443 non-null    object
#  9   review_pagination_id                 442 non-null    object
#  10  author_link                          443 non-null    object
#  11  author_title                         443 non-null    object
#  12  author_id                            443 non-null    object
#  13  author_image                         443 non-null    object
#  14  author_reviews_count                 443 non-null    int64
#  15  author_ratings_count                 443 non-null    int64
#  16  review_text                          317 non-null    object
#  17  review_img_urls                      28 non-null     object
#  18  review_img_url                       28 non-null     object
#  19  review_questions                     0 non-null      float64
#  20  review_photo_ids                     28 non-null     object
#  21  owner_answer                         27 non-null     object
#  22  owner_answer_timestamp               27 non-null     float64
#  23  owner_answer_timestamp_datetime_utc  27 non-null     object
#  24  review_link                          443 non-null    object
#  25  review_rating                        443 non-null    int64
#  26  review_timestamp                     443 non-null    int64
#  27  review_datetime_utc                  443 non-null    object
#  28  review_likes                         0 non-null      float64
#  29  reviews_id                           443 non-null    int64
#  30  reviews_per_score_1                  443 non-null    int64
#  31  reviews_per_score_2                  443 non-null    int64
#  32  reviews_per_score_3                  443 non-null    int64
#  33  reviews_per_score_4                  443 non-null    int64
#  34  reviews_per_score_5                  443 non-null    int64
# dtypes: float64(4), int64(11), object(20)
# memory usage: 121.3+ KB

# %%
# ==============================
# 2. Data Cleaning
# ==============================
# Remove duplicates
df = df.drop_duplicates()

# Convert datetime column
df['review_datetime_utc'] = pd.to_datetime(df['review_datetime_utc'], errors='coerce')

# Add review text length
df['review_length'] = df['review_text'].astype(str).apply(len)

# Check missing values
print(df.isna().sum())
# Out:
# query                                    0
# name                                     0
# google_id                                0
# place_id                                 0
# location_link                            0
# reviews_link                             0
# reviews                                  0
# rating                                   0
# review_id                                0
# review_pagination_id                     1
# author_link                              0
# author_title                             0
# author_id                                0
# author_image                             0
# author_reviews_count                     0
# author_ratings_count                     0
# review_text                            126
# review_img_urls                        415
# review_img_url                         415
# review_questions                       443
# review_photo_ids                       415
# owner_answer                           416
# owner_answer_timestamp                 416
# owner_answer_timestamp_datetime_utc    416
# review_link                              0
# review_rating                            0
# review_timestamp                         0
# review_datetime_utc                      0
# review_likes                           443
# reviews_id                               0
# reviews_per_score_1                      0
# reviews_per_score_2                      0
# reviews_per_score_3                      0
# reviews_per_score_4                      0
# reviews_per_score_5                      0
# review_length                            0
# dtype: int64

# %%
# ==============================
# 3. Descriptive Statistics
# ==============================
print(df['review_rating'].describe())
print(df['review_length'].describe())

print("Reviewer reviews count stats:")
print(df['author_reviews_count'].describe())

print("Reviewer ratings count stats:")
print(df['author_ratings_count'].describe())

print("Owner response rate:", df['owner_answer'].notna().mean())
# Out:
# count    443.000000
# mean       3.496614
# std        1.723372
# min        1.000000
# 25%        1.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000
# Name: review_rating, dtype: float64
# count     443.000000
# mean      338.790068
# std       548.569814
# min         3.000000
# 25%         3.000000
# 50%       148.000000
# 75%       437.500000
# max      4093.000000
# Name: review_length, dtype: float64
# Reviewer reviews count stats:
# count     443.000000
# mean       86.309255
# std       288.649393
# min         0.000000
# 25%         4.000000
# 50%        14.000000
# 75%        57.000000
# max      4528.000000
# Name: author_reviews_count, dtype: float64
# Reviewer ratings count stats:
# count     443.000000
# mean       38.683973
# std       168.959926
# min         0.000000
# 25%         1.000000
# 50%         3.000000
# 75%        14.000000
# max      2535.000000
# Name: author_ratings_count, dtype: float64
# Owner response rate: 0.060948081264108354

# %%
# ==============================
# 4. Univariate Analysis
# ==============================
sns.countplot(x='review_rating', data=df)
plt.title("Ratings Distribution")
plt.show()

sns.histplot(df['review_length'], bins=30, kde=True)
plt.title("Review Length Distribution")
plt.show()

sns.histplot(df['author_reviews_count'], bins=30)
plt.title("Reviewer Review Count Distribution")
plt.show()

# %%
# ==============================
# 5. Bivariate Analysis
# ==============================
sns.boxplot(x='review_rating', y='review_length', data=df)
plt.title("Review Length vs Rating")
plt.show()

sns.heatmap(df[['review_rating','review_likes','author_reviews_count','review_length']].corr(),
            annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

sns.barplot(x='review_rating', y=df['owner_answer'].notna(), data=df, estimator=np.mean)
plt.title("Owner Response Rate by Rating")
plt.show()

# %%
# ==============================
# 6. Time-based Analysis
# ==============================
df['month'] = df['review_datetime_utc'].dt.to_period("M")

monthly = df.groupby('month').agg(
    avg_rating=('review_rating','mean'),
    review_count=('review_rating','count')
)

monthly.plot(y=['avg_rating','review_count'], subplots=True, figsize=(10,6),
             title=["Average Rating Over Time","Review Count Over Time"])
plt.show()

# %%
# ==============================
# 7. Text Analysis (WordCloud + Sentiment)
# ==============================
# Positive reviews wordcloud
positive_text = " ".join(df[df['review_rating'] >= 4]['review_text'].dropna())
wordcloud_pos = WordCloud(width=800, height=400, background_color='white').generate(positive_text)
plt.imshow(wordcloud_pos, interpolation='bilinear')
plt.axis("off")
plt.title("Positive Reviews WordCloud")
plt.show()

# Negative reviews wordcloud
negative_text = " ".join(df[df['review_rating'] <= 2]['review_text'].dropna())
wordcloud_neg = WordCloud(width=800, height=400, background_color='black').generate(negative_text)
plt.imshow(wordcloud_neg, interpolation='bilinear')
plt.axis("off")
plt.title("Negative Reviews WordCloud")
plt.show()

# Sentiment polarity
df['sentiment'] = df['review_text'].astype(str).apply(lambda x: TextBlob(x).sentiment.polarity)
sns.histplot(df['sentiment'], bins=30, kde=True)
plt.title("Sentiment Distribution")
plt.show()

# %%
# ==============================
# 8. Reviewer Insights
# ==============================
top_reviewers = df.groupby('author_title').size().sort_values(ascending=False).head(10)
print("Top Reviewers:")
print(top_reviewers)

df['is_frequent'] = df['author_reviews_count'] > 5
sns.countplot(x='is_frequent', hue='review_rating', data=df)
plt.title("Frequent vs One-time Reviewers by Rating")
plt.show()
# Out:
# Top Reviewers:
# author_title
# Jan                    2
# Remelyn Pallingayan    1
# Regine Lee             1
# Ratna Megawati         1
# Raine Goh              1
# RONGRONG WENG          1
# ROBERT C.S. TAY        1
# RICO Lee               1
# R. Keung               1
# R                      1
# dtype: int64

# %%
# ==============================
# 9. Owner Response Analysis
# ==============================
neg = df[df['review_rating'] <= 2]
pos = df[df['review_rating'] >= 4]

print("Response rate for negative reviews:", neg['owner_answer'].notna().mean())
print("Response rate for positive reviews:", pos['owner_answer'].notna().mean())
# Out:
# Response rate for negative reviews: 0.1793103448275862
# Response rate for positive reviews: 0.0

# %%
# ==============================
# 10. Aggregate Check
# ==============================
agg_counts = {
    "1_star": df['reviews_per_score_1'].iloc[0],
    "2_star": df['reviews_per_score_2'].iloc[0],
    "3_star": df['reviews_per_score_3'].iloc[0],
    "4_star": df['reviews_per_score_4'].iloc[0],
    "5_star": df['reviews_per_score_5'].iloc[0],
}
print("Aggregated counts from metadata:", agg_counts)

actual_counts = df['review_rating'].value_counts()
print("Actual counts from reviews:", actual_counts)
# Out:
# Aggregated counts from metadata: {'1_star': 124, '2_star': 21, '3_star': 17, '4_star': 73, '5_star': 208}
# Actual counts from reviews: review_rating
# 5    208
# 1    124
# 4     73
# 2     21
# 3     17
# Name: count, dtype: int64

# %% [markdown]
# #### 🏥 Google Reviews EDA + NLP Extension

# %%
# ==============================
# 11. Keyword Extraction (TF-IDF)
# ==============================
from sklearn.feature_extraction.text import TfidfVectorizer

# Use only non-null review text
texts = df['review_text'].dropna().astype(str)

# Vectorize reviews
tfidf = TfidfVectorizer(stop_words='english', max_features=20, ngram_range=(1,2))
tfidf_matrix = tfidf.fit_transform(texts)

# Top keywords
keywords = pd.DataFrame({
    "keyword": tfidf.get_feature_names_out(),
    "score": tfidf_matrix.sum(axis=0).A1
}).sort_values(by="score", ascending=False)

print("Top Keywords (TF-IDF):")
print(keywords.head(20))
# Out:
# Top Keywords (TF-IDF):
#        keyword      score
# 7     hospital  69.999153
# 15       staff  40.855664
# 12      nurses  40.658625
# 6         good  30.511312
# 5   experience  29.250566
# 14     service  26.299142
# 1         care  26.203431
# 19        ward  25.329341
# 11       nurse  25.328980
# 0     alvernia  22.130515
# 3       doctor  21.484870
# 18        time  20.690734
# 16     surgery  19.906174
# 17       thank  18.270738
# 13     patient  18.246380
# 10       mount  17.776889
# 9         like  17.653533
# 2          day  17.577060
# 8         just  15.901882
# 4           dr  11.730378

# %%
# ==============================
# 12. Topic Modeling (LDA)
# ==============================
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer

# Count vectorizer for LDA
cv = CountVectorizer(stop_words='english', max_df=0.9, min_df=5)
cv_matrix = cv.fit_transform(texts)

# Fit LDA model
lda = LatentDirichletAllocation(n_components=5, random_state=42)
lda.fit(cv_matrix)

# Display top words for each topic
def display_topics(model, feature_names, no_top_words=10):
    for idx, topic in enumerate(model.components_):
        print(f"Topic {idx+1}:")
        print(" | ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))
        print("\n")

display_topics(lda, cv.get_feature_names_out())
# Out:
# Topic 1:
# hospital | nurses | staff | alvernia | service | care | ward | good | st | patient
#
#
# Topic 2:
# hospital | staff | nurses | doctor | alvernia | service | medical | time | surgery | experience
#
#
# Topic 3:
# nurse | nurses | asked | just | doctor | care | ward | experience | did | dr
#
#
# Topic 4:
# hospital | bus | shuttle | good | parking | wait | rude | hour | rooms | fever
#
#
# Topic 5:
# hospital | wait | ward | day | staff | told | registration | time | room | like

# %%
# ==============================
# 13. Topic Distribution per Review
# ==============================
topic_values = lda.transform(cv_matrix)

# Create a new DataFrame with the same index as cv_matrix to ensure alignment
# This assumes cv_matrix was created from a subset of df
df_subset = df.iloc[cv_matrix.index] if hasattr(cv_matrix, 'index') else df.head(len(topic_values))

# Add dominant topic to this subset
df_subset['dominant_topic'] = topic_values.argmax(axis=1)

# Plot with the correctly aligned data
sns.countplot(x='dominant_topic', data=df_subset)
plt.title("Most Common Topics in Reviews")
plt.show()

# Alternatively, if you need to keep the original df intact:
# Create a temporary DataFrame for plotting
# temp_df = pd.DataFrame({'dominant_topic': topic_values.argmax(axis=1)})
# sns.countplot(x='dominant_topic', data=temp_df)
# Out:
# /var/tmp/ipykernel_5159/1274790882.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['dominant_topic'] = topic_values.argmax(axis=1)

# %% [markdown]
# # Assistant
# This error occurs because the length of the `topic_values` array (146) doesn't match the length of your DataFrame `df` (185). This mismatch happens when you try to assign the `dominant_topic` column to your DataFrame.
#
# The most likely cause is that your `cv_matrix` (CountVectorizer or TF-IDF matrix) was created using a subset of your data, or some rows were filtered out during preprocessing (perhaps due to empty reviews after text cleaning).
#
# Would you like me to provide the corrected code?

# %% [markdown]
# # KPI Metrics

# %%
import pandas as pd
import numpy as np
from textblob import TextBlob

# Ensure datetime and review length are present
df['review_datetime_utc'] = pd.to_datetime(df['review_datetime_utc'], errors='coerce')
df['review_length'] = df['review_text'].astype(str).apply(len)
df['sentiment'] = df['review_text'].astype(str).apply(lambda x: TextBlob(x).sentiment.polarity)

# %% [markdown]
# # ⭐ 1. Ratings-Based Metrics

# %%
# Average rating
avg_rating = df['review_rating'].mean()
median_rating = df['review_rating'].median()
rating_distribution = df['review_rating'].value_counts(normalize=True) * 100

print("Average Rating:", avg_rating)
print("Median Rating:", median_rating)
print("Rating Distribution (%):\n", rating_distribution)

# Trend over time (monthly)
df['month'] = df['review_datetime_utc'].dt.to_period("M")
rating_trend = df.groupby('month')['review_rating'].mean()
print("Monthly Rating Trend:\n", rating_trend.tail())
# Out:
# Average Rating: 3.4966139954853275
# Median Rating: 4.0
# Rating Distribution (%):
#  review_rating
# 5    46.952596
# 1    27.990971
# 4    16.478555
# 2     4.740406
# 3     3.837472
# Name: proportion, dtype: float64
# Monthly Rating Trend:
#  month
# 2025-04    3.666667
# 2025-05    3.714286
# 2025-06    4.333333
# 2025-07    3.285714
# 2025-08    3.250000
# Freq: M, Name: review_rating, dtype: float64

# %% [markdown]
# # 💬 2. Sentiment Metrics

# %%
avg_sentiment = df['sentiment'].mean()
sentiment_distribution = pd.cut(df['sentiment'], bins=[-1,-0.05,0.05,1], labels=["Negative","Neutral","Positive"]).value_counts(normalize=True) * 100

print("Average Sentiment Score:", avg_sentiment)
print("Sentiment Distribution (%):\n", sentiment_distribution)

# Correlation with rating
corr_sentiment_rating = df[['review_rating','sentiment']].corr().iloc[0,1]
print("Correlation between Sentiment & Rating:", corr_sentiment_rating)
# Out:
# Average Sentiment Score: 0.11072297347794328
# Sentiment Distribution (%):
#  sentiment
# Positive    44.570136
# Neutral     43.891403
# Negative    11.538462
# Name: proportion, dtype: float64
# Correlation between Sentiment & Rating: 0.469945667621553

# %% [markdown]
# # ✍️ 3. Review Quality & Engagement

# %%
avg_review_length = df['review_length'].mean()
avg_likes = df['review_likes'].mean(skipna=True)

print("Average Review Length:", avg_review_length)
print("Average Likes per Review:", avg_likes)

# Length vs rating
length_by_rating = df.groupby('review_rating')['review_length'].mean()
print("Review Length by Rating:\n", length_by_rating)
# Out:
# Average Review Length: 338.7900677200903
# Average Likes per Review: nan
# Review Length by Rating:
#  review_rating
# 1    481.750000
# 2    719.095238
# 3    408.176471
# 4    234.657534
# 5    246.043269
# Name: review_length, dtype: float64

# %% [markdown]
# # 👥 4. Reviewer Behavior

# %%
# One-time vs frequent
one_time_reviewers = (df['author_reviews_count'] == 1).mean() * 100
frequent_reviewers = (df['author_reviews_count'] > 5).mean() * 100

print("One-time Reviewers (%):", one_time_reviewers)
print("Frequent Reviewers (%):", frequent_reviewers)

# Reviewer bias (avg rating by reviewer type)
df['is_frequent'] = df['author_reviews_count'] > 5
bias = df.groupby('is_frequent')['review_rating'].mean()
print("Avg Rating by Reviewer Type:\n", bias)
# Out:
# One-time Reviewers (%): 5.417607223476298
# Frequent Reviewers (%): 71.55756207674943
# Avg Rating by Reviewer Type:
#  is_frequent
# False    3.142857
# True     3.637224
# Name: review_rating, dtype: float64

# %% [markdown]
# # 🔁 5. Owner Response Metrics

# %%
# Overall response rate
response_rate = df['owner_answer'].notna().mean() * 100

# Response rate by rating
response_by_rating = df.groupby('review_rating')['owner_answer'].apply(lambda x: x.notna().mean()*100)

# Response by sentiment
df['sentiment_group'] = pd.cut(df['sentiment'], bins=[-1,-0.05,0.05,1], labels=["Negative","Neutral","Positive"])
response_by_sentiment = df.groupby('sentiment_group')['owner_answer'].apply(lambda x: x.notna().mean()*100)

print("Overall Response Rate (%):", response_rate)
print("Response Rate by Rating (%):\n", response_by_rating)
print("Response Rate by Sentiment (%):\n", response_by_sentiment)
# Out:
# Overall Response Rate (%): 6.094808126410835
# Response Rate by Rating (%):
#  review_rating
# 1    20.161290
# 2     4.761905
# 3     5.882353
# 4     0.000000
# 5     0.000000
# Name: owner_answer, dtype: float64
# Response Rate by Sentiment (%):
#  sentiment_group
# Negative    23.529412
# Neutral      5.670103
# Positive     2.030457
# Name: owner_answer, dtype: float64
# /var/tmp/ipykernel_5159/4059787264.py:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   response_by_sentiment = df.groupby('sentiment_group')['owner_answer'].apply(lambda x: x.notna().mean()*100)

# %% [markdown]
# # 🔁 5. Owner Response Metrics

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# Create a copy of the dataframe with only non-NA reviews
# This ensures we work with the same subset throughout the code
df_clean = df.dropna(subset=['review_text']).copy()
texts = df_clean['review_text'].astype(str)

# ---- TF-IDF ----
tfidf = TfidfVectorizer(stop_words='english', max_features=20, ngram_range=(1,2))
tfidf_matrix = tfidf.fit_transform(texts)
keywords = pd.DataFrame({
    "keyword": tfidf.get_feature_names_out(),
    "score": tfidf_matrix.sum(axis=0).A1
}).sort_values(by="score", ascending=False)
print("Top TF-IDF Keywords:\n", keywords)

# ---- LDA Topic Modeling ----
cv = CountVectorizer(stop_words='english', max_df=0.9, min_df=5)
cv_matrix = cv.fit_transform(texts)

lda = LatentDirichletAllocation(n_components=5, random_state=42)
lda.fit(cv_matrix)

def display_topics(model, feature_names, no_top_words=10):
    topics = {}
    for idx, topic in enumerate(model.components_):
        topics[f"Topic {idx+1}"] = [feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]
    return topics

topics = display_topics(lda, cv.get_feature_names_out())
print("LDA Topics:\n", topics)

# Assign dominant topic per review
# Now we're using df_clean which has the same length as texts
topic_values = lda.transform(cv_matrix)
df_clean['dominant_topic'] = topic_values.argmax(axis=1) + 1

topic_distribution = df_clean['dominant_topic'].value_counts(normalize=True) * 100
print("Topic Distribution (%):\n", topic_distribution)
# Out:
# Top TF-IDF Keywords:
#         keyword      score
# 7     hospital  69.999153
# 15       staff  40.855664
# 12      nurses  40.658625
# 6         good  30.511312
# 5   experience  29.250566
# 14     service  26.299142
# 1         care  26.203431
# 19        ward  25.329341
# 11       nurse  25.328980
# 0     alvernia  22.130515
# 3       doctor  21.484870
# 18        time  20.690734
# 16     surgery  19.906174
# 17       thank  18.270738
# 13     patient  18.246380
# 10       mount  17.776889
# 9         like  17.653533
# 2          day  17.577060
# 8         just  15.901882
# 4           dr  11.730378
# LDA Topics:
#  {'Topic 1': ['hospital', 'nurses', 'staff', 'alvernia', 'service', 'care', 'ward', 'good', 'st', 'patient'], 'Topic 2': ['hospital', 'staff', 'nurses', 'doctor', 'alvernia', 'service', 'medical', 'time', 'surgery', 'experience'], 'Topic 3': ['nurse', 'nurses', 'asked', 'just', 'doctor', 'care', 'ward', 'experience', 'did', 'dr'], 'Topic 4': ['hospital', 'bus', 'shuttle', 'good', 'parking', 'wait', 'rude', 'hour', 'rooms', 'fever'], 'Topic 5': ['hospital', 'wait', 'ward', 'day', 'staff', 'told', 'registration', 'time', 'room', 'like']}
# Topic Distribution (%):
#  dominant_topic
# 1    37.223975
# 2    28.075710
# 5    13.880126
# 3    12.933754
# 4     7.886435
# Name: proportion, dtype: float64

# %% [markdown]
# # 🗝 6. Thematic Insights (TF-IDF & LDA)

# %%
agg_counts = {
    "1_star": df['reviews_per_score_1'].iloc[0],
    "2_star": df['reviews_per_score_2'].iloc[0],
    "3_star": df['reviews_per_score_3'].iloc[0],
    "4_star": df['reviews_per_score_4'].iloc[0],
    "5_star": df['reviews_per_score_5'].iloc[0],
}
actual_counts = df['review_rating'].value_counts()

print("Google Metadata Counts:", agg_counts)
print("Actual Extracted Counts:\n", actual_counts)
# Out:
# Google Metadata Counts: {'1_star': 124, '2_star': 21, '3_star': 17, '4_star': 73, '5_star': 208}
# Actual Extracted Counts:
#  review_rating
# 5    208
# 1    124
# 4     73
# 2     21
# 3     17
# Name: count, dtype: int64

# %%
# =============================
# 1. Setup
# =============================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from textblob import TextBlob
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

sns.set(style="whitegrid", palette="muted", font_scale=1.1)

# Load dataset
#df = pd.read_excel("Outscraper-20250823032119xs76.xlsx")
df['review_datetime_utc'] = pd.to_datetime(df['review_datetime_utc'], errors='coerce')
df['review_length'] = df['review_text'].astype(str).apply(len)
df['sentiment'] = df['review_text'].astype(str).apply(lambda x: TextBlob(x).sentiment.polarity)

# %% [markdown]
# # ⭐ 2. Ratings Overview

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="review_rating", data=df, palette="viridis")
plt.title("Ratings Distribution")
plt.show()

df.groupby(df['review_datetime_utc'].dt.to_period("M"))['review_rating'].mean().plot(figsize=(10,5), marker="o")
plt.title("Average Rating Over Time")
plt.ylabel("Avg Rating")
plt.show()
# Out:
# /var/tmp/ipykernel_5159/998790571.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="review_rating", data=df, palette="viridis")

# %% [markdown]
# # 💬 3. Sentiment Analysis

# %%
df['sentiment_group'] = pd.cut(df['sentiment'], bins=[-1,-0.05,0.05,1], labels=["Negative","Neutral","Positive"])

plt.figure(figsize=(6,4))
sns.countplot(x="sentiment_group", data=df, order=["Negative","Neutral","Positive"], palette="coolwarm")
plt.title("Sentiment Distribution")
plt.show()

sns.scatterplot(x="sentiment", y="review_rating", data=df, alpha=0.5)
plt.title("Sentiment vs Rating")
plt.show()
# Out:
# /var/tmp/ipykernel_5159/3429959399.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="sentiment_group", data=df, order=["Negative","Neutral","Positive"], palette="coolwarm")

# %% [markdown]
# # ✍️ 4. Review Length & Engagement

# %%
sns.histplot(df['review_length'], bins=50, kde=True)
plt.title("Review Length Distribution")
plt.show()

sns.boxplot(x="review_rating", y="review_length", data=df, palette="magma")
plt.title("Review Length by Rating")
plt.show()
# Out:
# /var/tmp/ipykernel_5159/2932125478.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="review_rating", y="review_length", data=df, palette="magma")

# %% [markdown]
# # 👥 5. Reviewer Behavior

# %%
sns.histplot(df['author_reviews_count'], bins=30, log_scale=True)
plt.title("Distribution of Reviewer Activity (# Reviews by Author)")
plt.show()

df['is_frequent'] = df['author_reviews_count'] > 5
sns.boxplot(x="is_frequent", y="review_rating", data=df, palette="Set2")
plt.title("Frequent vs One-Time Reviewers (Rating Bias)")
plt.xticks([0,1], ["One-time","Frequent"])
plt.show()
# Out:
# /var/tmp/ipykernel_5159/3163081248.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="is_frequent", y="review_rating", data=df, palette="Set2")

# %% [markdown]
# # 🔁 6. Owner Response Behavior

# %%
sns.barplot(x="review_rating", y=df['owner_answer'].notna(), data=df, estimator=np.mean, palette="crest")
plt.title("Response Rate by Rating")
plt.ylabel("Response Rate")
plt.show()

sns.barplot(x="sentiment_group", y=df['owner_answer'].notna(), data=df, estimator=np.mean, palette="rocket")
plt.title("Response Rate by Sentiment")
plt.ylabel("Response Rate")
plt.show()
# Out:
# /var/tmp/ipykernel_5159/3810842962.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="review_rating", y=df['owner_answer'].notna(), data=df, estimator=np.mean, palette="crest")
# /var/tmp/ipykernel_5159/3810842962.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="sentiment_group", y=df['owner_answer'].notna(), data=df, estimator=np.mean, palette="rocket")

# %% [markdown]
# # ☁️ 7. Word Cloud & Keywords

# %%
text = " ".join(df['review_text'].dropna().astype(str).values)

wc = WordCloud(width=800, height=400, background_color="white", colormap="viridis").generate(text)
plt.figure(figsize=(12,6))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.title("Most Frequent Words in Reviews")
plt.show()

# TF-IDF Keywords
tfidf = TfidfVectorizer(stop_words='english', max_features=20, ngram_range=(1,2))
tfidf_matrix = tfidf.fit_transform(df['review_text'].dropna().astype(str))
keywords = pd.DataFrame({
    "keyword": tfidf.get_feature_names_out(),
    "score": tfidf_matrix.sum(axis=0).A1
}).sort_values(by="score", ascending=False)

print("Top Keywords:\n", keywords)
# Out:
# Top Keywords:
#         keyword      score
# 7     hospital  69.999153
# 15       staff  40.855664
# 12      nurses  40.658625
# 6         good  30.511312
# 5   experience  29.250566
# 14     service  26.299142
# 1         care  26.203431
# 19        ward  25.329341
# 11       nurse  25.328980
# 0     alvernia  22.130515
# 3       doctor  21.484870
# 18        time  20.690734
# 16     surgery  19.906174
# 17       thank  18.270738
# 13     patient  18.246380
# 10       mount  17.776889
# 9         like  17.653533
# 2          day  17.577060
# 8         just  15.901882
# 4           dr  11.730378

# %% [markdown]
# # 🗝 8. Topic Modeling (LDA)

# %%
cv = CountVectorizer(stop_words='english', max_df=0.9, min_df=5)
cv_matrix = cv.fit_transform(df['review_text'].dropna().astype(str))

lda = LatentDirichletAllocation(n_components=5, random_state=42)
lda.fit(cv_matrix)

def display_topics(model, feature_names, no_top_words=8):
    for idx, topic in enumerate(model.components_):
        print(f"Topic {idx+1}: ", [feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]])

display_topics(lda, cv.get_feature_names_out())
# Out:
# Topic 1:  ['hospital', 'nurses', 'staff', 'alvernia', 'service', 'care', 'ward', 'good']
# Topic 2:  ['hospital', 'staff', 'nurses', 'doctor', 'alvernia', 'service', 'medical', 'time']
# Topic 3:  ['nurse', 'nurses', 'asked', 'just', 'doctor', 'care', 'ward', 'experience']
# Topic 4:  ['hospital', 'bus', 'shuttle', 'good', 'parking', 'wait', 'rude', 'hour']
# Topic 5:  ['hospital', 'wait', 'ward', 'day', 'staff', 'told', 'registration', 'time']

# %% [markdown]
# # 📌 9. KPI Summary (Text Output)

# %%
summary = {
    "Average Rating": round(df['review_rating'].mean(),2),
    "Average Sentiment": round(df['sentiment'].mean(),2),
    "Response Rate (%)": round(df['owner_answer'].notna().mean()*100,2),
    "One-time Reviewer %": round((df['author_reviews_count'] == 1).mean()*100,2),
    "Frequent Reviewer %": round((df['author_reviews_count'] > 5).mean()*100,2),
    "Avg Review Length": round(df['review_length'].mean(),2),
    "Avg Likes": round(df['review_likes'].mean(skipna=True),2)
}
print("📊 KPI Dashboard:\n")
for k,v in summary.items():
    print(f"{k}: {v}")
# Out:
# 📊 KPI Dashboard:
#
# Average Rating: 3.5
# Average Sentiment: 0.11
# Response Rate (%): 6.09
# One-time Reviewer %: 5.42
# Frequent Reviewer %: 71.56
# Avg Review Length: 338.79
# Avg Likes: nan

# %%
# =============================
# 📌 9. Enhanced KPI Summary
# =============================

summary = {
    "Average Rating": round(df['review_rating'].mean(),2),
    "Average Sentiment": round(df['sentiment'].mean(),2),
    "Response Rate (%)": round(df['owner_answer'].notna().mean()*100,2),
    "One-time Reviewer %": round((df['author_reviews_count'] == 1).mean()*100,2),
    "Frequent Reviewer %": round((df['author_reviews_count'] > 5).mean()*100,2),
    "Avg Review Length": round(df['review_length'].mean(),2),
    "Avg Likes": round(df['review_likes'].mean(skipna=True),2)
}

# % Rating distribution
rating_dist = df['review_rating'].value_counts(normalize=True).sort_index() * 100
for rating, pct in rating_dist.items():
    summary[f"Rating {rating} %"] = round(pct,2)

# % Sentiment distribution
sentiment_dist = df['sentiment_group'].value_counts(normalize=True) * 100
for sentiment, pct in sentiment_dist.items():
    summary[f"{sentiment} Sentiment %"] = round(pct,2)

print("📊 KPI Dashboard:\n")
for k,v in summary.items():
    print(f"{k}: {v}")
# Out:
# 📊 KPI Dashboard:
#
# Average Rating: 3.5
# Average Sentiment: 0.11
# Response Rate (%): 6.09
# One-time Reviewer %: 5.42
# Frequent Reviewer %: 71.56
# Avg Review Length: 338.79
# Avg Likes: nan
# Rating 1 %: 27.99
# Rating 2 %: 4.74
# Rating 3 %: 3.84
# Rating 4 %: 16.48
# Rating 5 %: 46.95
# Positive Sentiment %: 44.57
# Neutral Sentiment %: 43.89
# Negative Sentiment %: 11.54

# %%
import matplotlib.pyplot as plt

# =============================
# 📊 10. KPI Visualizations
# =============================

# --- Ratings Distribution ---
rating_dist = df['review_rating'].value_counts(normalize=True).sort_index() * 100

plt.figure(figsize=(6,4))
rating_dist.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title("Ratings Distribution (%)")
plt.xlabel("Star Rating")
plt.ylabel("Percentage (%)")
plt.xticks(rotation=0)
plt.show()

# --- Sentiment Distribution ---
sentiment_dist = df['sentiment_group'].value_counts(normalize=True) * 100

plt.figure(figsize=(6,4))
sentiment_dist.plot(kind='bar', color=['red','grey','green'], edgecolor='black')
plt.title("Sentiment Distribution (%)")
plt.xlabel("Sentiment Group")
plt.ylabel("Percentage (%)")
plt.xticks(rotation=0)
plt.show()

# %%
# =============================
# 📌 11. Top Positive & Negative Reviews
# =============================

# Sort by sentiment score
top_positive = df.sort_values(by='sentiment', ascending=False).head(10)[['review_text','review_rating','sentiment']]
top_negative = df.sort_values(by='sentiment', ascending=True).head(10)[['review_text','review_rating','sentiment']]

print("🔥 Top 10 Positive Reviews (by sentiment):\n")
for i, row in top_positive.iterrows():
    print(f"⭐ Rating: {row['review_rating']} | Sentiment: {round(row['sentiment'],2)}")
    print(row['review_text'])
    print("-"*80)

print("\n⚠️ Top 10 Negative Reviews (by sentiment):\n")
for i, row in top_negative.iterrows():
    print(f"⭐ Rating: {row['review_rating']} | Sentiment: {round(row['sentiment'],2)}")
    print(row['review_text'])
    print("-"*80)
# Out:
# 🔥 Top 10 Positive Reviews (by sentiment):
#
# ⭐ Rating: 5 | Sentiment: 1.0
# We had picnic on the field beside it scenery was breathtaking
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: 1.0
# The best hospital in Town.
# --------------------------------------------------------------------------------
# ⭐ Rating: 4 | Sentiment: 0.88
# A Good one!
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: 0.84
# Mount A is good service for OT booking and everything they can handle and when my clinic call &WA to book they very good 👍🏻 and nurse service very good too when I give birth my child
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: 0.8
# Had a great experience re their Health Screening. Would recommend.
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: 0.8
# The staffs are genuinely amazing & helpful. Had a great experience!
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: 0.78
# Very nice and serene hospital...
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: 0.77
# Love this hospital. Great staff excellent facilities.
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: 0.7
# Good hospital facilities.
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: 0.7
# Good location , staff and well run
# --------------------------------------------------------------------------------
#
# ⚠️ Top 10 Negative Reviews (by sentiment):
#
# ⭐ Rating: 1 | Sentiment: -1.0
# No way to contact staff for claims. Very bad post-medical service!
# --------------------------------------------------------------------------------
# ⭐ Rating: 1 | Sentiment: -0.91
# Very bad experience there
# --------------------------------------------------------------------------------
# ⭐ Rating: 1 | Sentiment: -0.87
# Bad Service from the A&E Doctor and Nurses!
# --------------------------------------------------------------------------------
# ⭐ Rating: 1 | Sentiment: -0.58
# I had very bad experience in the diagnostic iimaging department,The nurse was not skillful and the radiographer was very impatient during the scanning .
# --------------------------------------------------------------------------------
# ⭐ Rating: 4 | Sentiment: -0.53
# At least the nurses and doctors are here to help the children if they got lost, the parents and relatives blame me for not looking after their children. What’s wrong of getting a nurses or doctors to come and help. Bloody nuisance.
# --------------------------------------------------------------------------------
# ⭐ Rating: 1 | Sentiment: -0.5
# Difficult to get parking
# --------------------------------------------------------------------------------
# ⭐ Rating: 1 | Sentiment: -0.5
# literally suffocating inside this place the way the doctor acts is creepy
# --------------------------------------------------------------------------------
# ⭐ Rating: 1 | Sentiment: -0.45
# Went to A&E with chest pains( turned out to be indigestion)
# Was told that a chest x-ray was needed. The Filipino Radiographer was rude and impatient. Had a very unpleasant experience.
# --------------------------------------------------------------------------------
# ⭐ Rating: 1 | Sentiment: -0.43
# I was not allowed to visit my grandmother with the reason being I could not provide with the concierge my grandmother’s bed number. I was also not allowed to find out from the admission counter where my grandmother is. Absurd. Horrible people and management showing an absolute lack of compassion.
# --------------------------------------------------------------------------------
# ⭐ Rating: 1 | Sentiment: -0.4
# So slow and lousy nurse. Who tf go hospital to see nurse google search for diagnosis…
# --------------------------------------------------------------------------------

# %%
rating_dist
# Out:
# review_rating
# 1    27.990971
# 2     4.740406
# 3     3.837472
# 4    16.478555
# 5    46.952596
# Name: proportion, dtype: float64

# %%
# --- Base KPI Metrics ---
kpi_data = {
    "Average Rating": round(df['review_rating'].mean(),2),
    "Average Sentiment": round(df['sentiment'].mean(),2),
    "Response Rate (%)": round(df['owner_answer'].notna().mean()*100,2),
    "One-time Reviewer %": round((df['author_reviews_count'] == 1).mean()*100,2),
    "Frequent Reviewer %": round((df['author_reviews_count'] > 5).mean()*100,2),
    "Avg Review Length": round(df['review_length'].mean(),2),
    "Avg Likes": round(df['review_likes'].mean(skipna=True),2)
}

# Rating % Distribution
rating_dist = df['review_rating'].value_counts(normalize=True).sort_index() * 100
for rating, pct in rating_dist.items():
    kpi_data[f"Rating {rating} %"] = round(pct,2)

# Sentiment % Distribution
sentiment_dist = df['sentiment_group'].value_counts(normalize=True) * 100
for sentiment, pct in sentiment_dist.items():
    kpi_data[f"{sentiment} Sentiment %"] = round(pct,2)

# --- Top Reviews Extraction ---
top_positive = df.sort_values(by='sentiment', ascending=False).head(10)[['review_text','review_rating','sentiment']]
top_negative = df.sort_values(by='sentiment', ascending=True).head(10)[['review_text','review_rating','sentiment']]

# Convert reviews into a single string (shortened for table)
pos_reviews_str = "\n\n".join([f"⭐{row['review_rating']} (sent={round(row['sentiment'],2)}): {row['review_text'][:150]}..." 
                               for _,row in top_positive.iterrows()])

neg_reviews_str = "\n\n".join([f"⭐{row['review_rating']} (sent={round(row['sentiment'],2)}): {row['review_text'][:150]}..." 
                               for _,row in top_negative.iterrows()])

# Add to KPI data
kpi_data["Top 10 Positive Reviews"] = pos_reviews_str
kpi_data["Top 10 Negative Reviews"] = neg_reviews_str

# --- Final KPI Table ---
kpi_df = pd.DataFrame(list(kpi_data.items()), columns=["Metric","Value"])

# Replace the custom module with standard pandas display
# Instead of: import caas_jupyter_tools
# Instead of: caas_jupyter_tools.display_dataframe_to_user("KPI Dashboard with Reviews", kpi_df)
display(kpi_df)  # This is the standard way to display dataframes in Jupyter notebooks
# Out:
#                      Metric                                              Value
# 0            Average Rating                                                3.5
# 1         Average Sentiment                                               0.11
# 2         Response Rate (%)                                               6.09
# 3       One-time Reviewer %                                               5.42
# 4       Frequent Reviewer %                                              71.56
# 5         Avg Review Length                                             338.79
# 6                 Avg Likes                                                NaN
# 7                Rating 1 %                                              27.99
# 8                Rating 2 %                                               4.74
# 9                Rating 3 %                                               3.84
# 10               Rating 4 %                                              16.48
# 11               Rating 5 %                                              46.95
# 12     Positive Sentiment %                                              44.57
# 13      Neutral Sentiment %                                              43.89
# 14     Negative Sentiment %                                              11.54
# 15  Top 10 Positive Reviews  ⭐5 (sent=1.0): We had picnic on the field besi...
# 16  Top 10 Negative Reviews  ⭐1 (sent=-1.0): No way to contact staff for cl...

# %%
# =============================
# 📊 Weekly Ratings Trend
# =============================

# Ensure datetime is parsed
df['review_datetime_utc'] = pd.to_datetime(df['review_datetime_utc'], errors='coerce')

# Resample weekly average ratings
weekly_ratings = df.set_index('review_datetime_utc').resample('W')['review_rating'].mean()

# Plot
plt.figure(figsize=(14,6))
weekly_ratings.plot(marker='o', linewidth=1.5, alpha=0.8)
plt.title("Weekly Average Ratings Over Time")
plt.xlabel("Week")
plt.ylabel("Average Rating")
plt.grid(True, alpha=0.3)
plt.show()

# %%
import base64
import pandas as pd
import json
import vertexai
import tiktoken # A popular tokenizer, though not directly from google-generativeai
import time
from vertexai.generative_models import GenerativeModel, Part, SafetySetting
import warnings
warnings.filterwarnings("ignore")

project_name = !(gcloud config get-value core/project)
project_name = project_name[0]

# %%
#Gemini
class LLM_model:
    def __init__(self, project, location, model_name):
        self.project = project
        self.location = location
        self.model_name = model_name
        self.generation_config = {
            "max_output_tokens": 8192,
            "temperature": 1,
            "top_p": 0.95,
        }
        self.safety_settings = [
            SafetySetting(
                category=SafetySetting.HarmCategory.HARM_CATEGORY_HATE_SPEECH,
                threshold=SafetySetting.HarmBlockThreshold.OFF
            ),
            SafetySetting(
                category=SafetySetting.HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT,
                threshold=SafetySetting.HarmBlockThreshold.OFF
            ),
            SafetySetting(
                category=SafetySetting.HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT,
                threshold=SafetySetting.HarmBlockThreshold.OFF
            ),
            SafetySetting(
                category=SafetySetting.HarmCategory.HARM_CATEGORY_HARASSMENT,
                threshold=SafetySetting.HarmBlockThreshold.OFF
            ),
        ]
        vertexai.init(project=self.project, location=self.location)
        self.model = GenerativeModel(self.model_name)

    def complete(self, text):
        chat = self.model.start_chat()
        result=chat.send_message([text],
                                 generation_config=self.generation_config,
                                 safety_settings=self.safety_settings
        )
        text_result=result.candidates[0].content.parts[0].text
        return text_result
# Example usage:
llm_gemini = LLM_model(project_name, 
                       "us-central1", 
                       "gemini-2.5-pro")

# %%
def sentiment_analysis(feedback, llm, llm_type='gemini'):
    prompt = f"""
    Role: You are an AI Specialist analysing customer feedback from Google reviews. Your role is to understand the given context
    and perform the task provided as appropriately.

    Context: The feedbacks are given by the patients or the bystanders of patients who went for treatment to the hospital.

    Task:
    1. Analyze the sentiment of the customer feedback if it’s positive, negative, or neutral.
    2. If the feedback is neither positive nor negative but just neutrally stating an info or suggestion,
       or is a non-meaningful feedback like 'Yes', 'No', 'Nil', 'na', 'N:A', 'N/a', 'n/a',
       'not applicable' or 'no comment', the sentiment is neutral.
    3. If sentiment is positive, return 'Positive'.
    4. If sentiment is negative, return 'Negative'.
    5. If sentiment is neutral, return 'Neutral'. Do not include other words or explanation.

    This is the customer feedback: {feedback}

    Examples:
    Its convenient, easy, fast: Positive.
    Nil: Neutral.
    Customer service not professional: Negative.
    
    Output:
    1. provide the classification of sentiment - Positive, Negative, Neutral   
    
    """

    try:
        if llm_type == 'gemini':
            result = llm.complete(prompt)
        else:
            result = llm.complete(prompt).text
        return result.strip()
    except Exception as e:
        print(f"Error processing row: {e}")
        return None  # Use None unless you're sure np.nan is needed and numpy is imported

# %%
def Information_extraction(feedback, llm, llm_type='gemini'):
    prompt = f"""
    Role: You are an AI Specialist analysing customer feedback from Google reviews. Your role is to understand the given context
    and perform the task provided as appropriately.

    Context: The feedbacks are given by the patients or the bystanders of patients who went for treatment to the hospital.

    Task:
    1. Analyze the feedback from the below mentioned topics and extract the information and provide as an output. If 
    the topics not found, mention as not found.
    1.1 From the whole feedback, extract the core issue, summarize the patient experience in 5 words and then
    follow the below tasks.
    2. Hospital Topic: 
        a. Does the review mention a specific ward, block or room number? if yes, extract it.
        b. Does the review mention about the department e.g: Endoscopy, Pharmacy, etc., if yes, extract it.
        c. Does the review describe whether the hospital is old, upgraded or modern?
    3. Staff & Service Topic:
        a. Does the review mention Doctors? if yes, extract it.
        b. Does the review mention nurses? if yes, extract it.
        c. Does the review mention support or admin staff? if yes, extract it.
        d. Does the review mention specific staff names? Extract them.
    4. Patient Experience:
        a. Does the review mention specific treatments or medical procedures (e.g. delivery, surgery)?
        b. What aspects of service quality are highlighted (e.g. attentiveness, professionalism, rudeness)?
        c. Does the reviewer mention waiting time? if yes, how long?
        d. Does the review mention food quality or any other quality (e.g. bedsheets, bathroom or cafeteria)?
    5. Complaints & Negative Aspects:
        a. Does the reviewer mention rude staff? Extract the details.
        b. Does the reviewer mention delays, long queues or poor management? Extract waiting times if given.
        c. Does the review mention unfair rules or inconsistent policies (e.g. visitor entry)?
        d. Does the reviewer explicitly call the hospital horrible, worst, terrifying, or disappointing?
        e. Does the review suggest profit motive or unnecessary procedures?
        f. Does the reviewer perceive fraudulent activity from the hospital?
    6. For each of the topics and its sub questions, provide output. If not found, mention as "Not found in feedback"

    This is the customer feedback: {feedback}

    Output:
    1. Provide the output in key-value pairs as JSON.
    2. Keys are only the core issue, summary, and the sub-questions (topic names not required).
    3. Values are the extracted output from the feedback.
    """

    # Token estimation
    try:
        import tiktoken
        enc = tiktoken.get_encoding("cl100k_base")
        prompt_tokens = len(enc.encode(prompt))
        print(f"Estimated input tokens (prompt): {prompt_tokens}")
    except ImportError:
        print("Install 'tiktoken' (pip install tiktoken) for token estimation.")
        prompt_tokens = -1

    # LLM completion
    try:
        if llm_type == 'gemini':
            result = llm.complete(prompt)
        else:
            result = llm.complete(prompt).text
        result = result.strip()
    except Exception as e:
        print(f"Error processing row: {e}")
        return None

    # Token estimation for response
    try:
        response_tokens = len(enc.encode(result))
        print(f"Estimated output tokens (response): {response_tokens}")
    except Exception:
        response_tokens = -1

    # Total token count
    if prompt_tokens != -1 and response_tokens != -1:
        total_estimated_tokens = prompt_tokens + response_tokens
        print(f"Total estimated tokens (prompt + response): {total_estimated_tokens}")

    return result

# %%
# Load dataset
df_MtAlv = pd.read_excel("Mount Alvernia hospital.xlsx")

# Display basic info
print(df_MtAlv.shape)
df_MtAlv.head()
# Out:
# (443, 35)
#                                    query                     name  \
# 0  0x31da1746cc0725d3:0x9952f2d57bf4038f  Mount Alvernia Hospital
# 1  0x31da1746cc0725d3:0x9952f2d57bf4038f  Mount Alvernia Hospital
# 2  0x31da1746cc0725d3:0x9952f2d57bf4038f  Mount Alvernia Hospital
# 3  0x31da1746cc0725d3:0x9952f2d57bf4038f  Mount Alvernia Hospital
# 4  0x31da1746cc0725d3:0x9952f2d57bf4038f  Mount Alvernia Hospital
#
#                                google_id                     place_id  \
# 0  0x31da1746cc0725d3:0x9952f2d57bf4038f  ChIJ0yUHzEYX2jERjwP0e9XyUpk
# 1  0x31da1746cc0725d3:0x9952f2d57bf4038f  ChIJ0yUHzEYX2jERjwP0e9XyUpk
# 2  0x31da1746cc0725d3:0x9952f2d57bf4038f  ChIJ0yUHzEYX2jERjwP0e9XyUpk
# 3  0x31da1746cc0725d3:0x9952f2d57bf4038f  ChIJ0yUHzEYX2jERjwP0e9XyUpk
# 4  0x31da1746cc0725d3:0x9952f2d57bf4038f  ChIJ0yUHzEYX2jERjwP0e9XyUpk
#
#                                        location_link  \
# 0  https://www.google.com/maps/place/Mount+Alvern...
# 1  https://www.google.com/maps/place/Mount+Alvern...
# 2  https://www.google.com/maps/place/Mount+Alvern...
# 3  https://www.google.com/maps/place/Mount+Alvern...
# 4  https://www.google.com/maps/place/Mount+Alvern...
#
#                                         reviews_link  reviews  rating  \
# 0  https://search.google.com/local/reviews?placei...      443     3.5
# 1  https://search.google.com/local/reviews?placei...      443     3.5
# 2  https://search.google.com/local/reviews?placei...      443     3.5
# 3  https://search.google.com/local/reviews?placei...      443     3.5
# 4  https://search.google.com/local/reviews?placei...      443     3.5
#
#                                            review_id  \
# 0  Ci9DQUlRQUNvZENodHljRjlvT2xOSU9UVlROVGRxYVhGTV...
# 1  Ci9DQUlRQUNvZENodHljRjlvT2pkaWEzUnBOMWRPYWxZMV...
# 2  Ci9DQUlRQUNvZENodHljRjlvT2tOU1RWTlpSRmxtYVVoUk...
# 3  Ci9DQUlRQUNvZENodHljRjlvT2xCTVgxbzRjazU1Y2tsc2...
# 4  Ci9DQUlRQUNvZENodHljRjlvT25RMGJXZG5NVzlNU1hCTU...
#
#                                 review_pagination_id  ... review_rating  \
# 0  CAESYENBRVFBUnBDUTJrNFNVRlNTVzVEWjI5QlVEY3lSMk...  ...             4
# 1  CAESYENBRVFBaHBDUTJrNFNVRlNTVzVEWjI5QlVEY3lSMk...  ...             3
# 2  CAESY0NBRVFBeHBFUTJwRlNVRlNTWEJEWjI5QlVEY3lSMk...  ...             2
# 3  CAESY0NBRVFCQnBFUTJwRlNVRlNTWEJEWjI5QlVEY3lSMk...  ...             1
# 4  CAESY0NBRVFCUnBFUTJwRlNVRlNTWEJEWjI5QlVEY3lSMl...  ...             5
#
#   review_timestamp  review_datetime_utc review_likes           reviews_id  \
# 0       1755854070  08/22/2025 09:14:30          NaN -7398584239094758513
# 1       1755852758  08/22/2025 08:52:38          NaN -7398584239094758513
# 2       1755657053  08/20/2025 02:30:53          NaN -7398584239094758513
# 3       1755646525  08/19/2025 23:35:25          NaN -7398584239094758513
# 4       1755270597  08/15/2025 15:09:57          NaN -7398584239094758513
#
#    reviews_per_score_1 reviews_per_score_2 reviews_per_score_3  \
# 0                  124                  21                  17
# 1                  124                  21                  17
# 2                  124                  21                  17
# 3                  124                  21                  17
# 4                  124                  21                  17
#
#   reviews_per_score_4  reviews_per_score_5
# 0                  73                  208
# 1                  73                  208
# 2                  73                  208
# 3                  73                  208
# 4                  73                  208
#
# [5 rows x 35 columns]

# %%
with open("text_reviews_MountAlv.txt", "w", encoding="utf-8") as f:
    for i, row in df_MtAlv.iterrows():
        f.write(f"--- Review #{i + 1} ---\n")
        f.write(f"Datetime: {row['review_datetime_utc']}\n")
        f.write(f"User: {row['author_title']}\n")
        f.write(f"Review: {row['review_text']}\n")
        f.write("--- End of Review ---\n\n")

# %%
df_MtAlv.head().transpose()


df_MtAlv_reviewtext = df_MtAlv.review_text


df_MtAlv_reviewtext.iloc[1:10]
# Out:
# 1    Amazing check in process.\nHad to wait half an...
# 2    AOSC got to work on their time management. We ...
# 3    在这边住院我感觉自己像罪犯，六人病房每天定时被要求拉开床帘，抽屉的东西还会未经同意被护士全拿...
# 4    Delivering at Mt Alvernia was the best decisio...
# 5    Underwent an op and was warded for a 2 night s...
# 6    The staff are so caring and attentive towards ...
# 7    I had a surgery here. Won’t go into details bu...
# 8    非常感谢这两天对我爸爸的照顾，今天也是爸爸的生日，没想到出院前还给我爸爸过了一个难忘的生日！...
# 9    At first was told by nurse that the report wou...
# Name: review_text, dtype: object

# %%
import json
import fitz  # PyMuPDF
counter = 0
# Assuming df_Gleangles_reviewtext and Information_extraction are already defined
with open("review_output_MtAlvernia.txt", "w", encoding="utf-8") as f:
    for idx,review in enumerate(df_MtAlv_reviewtext,start=0):
        
        start_time = time.time()
        print(f"Processing row {idx}...")

        example_output = Information_extraction(review, llm_gemini)
        o = example_output.replace('```', '')
        
        cleaned_output = o.replace('json', '')
        
        
        try:
            # If the output contains extra text before/after JSON, isolate the JSON part
            start = cleaned_output.find('{')
            end = cleaned_output.rfind('}') + 1
            json_str = cleaned_output[start:end]

            # Parse the JSON
            ie_output_dict = json.loads(json_str)
        except json.JSONDecodeError as e:
            print("JSON decoding failed:", e)
            print("Raw output:", cleaned_output)
            ie_output_dict = None

        
        f.write("Original Review:\n")
        f.write(str(review) + "\n")
        f.write("Extracted Information:\n")
        f.write(json.dumps(ie_output_dict, indent=4))
        f.write("\n---------------------------------------------------\n")

        f.write("Next Review ########################################\n\n")
        

        elapsed_time = time.time() - start_time
        print(f"Row {idx} processed in {elapsed_time:.2f} seconds.\n")
# Out:
# Processing row 0...
# Estimated input tokens (prompt): 695
# Estimated output tokens (response): 469
# Total estimated tokens (prompt + response): 1164
# Row 0 processed in 19.20 seconds.
#
# Processing row 1...
# Estimated input tokens (prompt): 593
# Estimated output tokens (response): 310
# Total estimated tokens (prompt + response): 903
# Row 1 processed in 17.74 seconds.
#
# Processing row 2...
# Estimated input tokens (prompt): 749
# Estimated output tokens (response): 643
# Total estimated tokens (prompt + response): 1392
# Row 2 processed in 24.68 seconds.
#
# Processing row 3...
# Estimated input tokens (prompt): 778
# Estimated output tokens (response): 460
# Total estimated tokens (prompt + response): 1238
# Row 3 processed in 20.02 seconds.
#
# Processing row 4...
# Estimated input tokens (prompt): 855
# Estimated output tokens (response): 390
# Total estimated tokens (prompt + response): 1245
# Row 4 processed in 12.07 seconds.
#
# Processing row 5...
# Estimated input tokens (prompt): 639
# Estimated output tokens (response): 326
# Total estimated tokens (prompt + response): 965
# Row 5 processed in 13.56 seconds.
#
# Processing row 6...
# Estimated input tokens (prompt): 592
# Estimated output tokens (response): 295
# Total estimated tokens (prompt + response): 887
# Row 6 processed in 10.72 seconds.
#
# Processing row 7...
# Estimated input tokens (prompt): 635
# Estimated output tokens (response): 480
# Total estimated tokens (prompt + response): 1115
# Row 7 processed in 18.58 seconds.
#
# Processing row 8...
# Estimated input tokens (prompt): 665
# Estimated output tokens (response): 362
# Total estimated tokens (prompt + response): 1027
# Row 8 processed in 14.57 seconds.
#
# Processing row 9...
# Estimated input tokens (prompt): 679
# Estimated output tokens (response): 440
# Total estimated tokens (prompt + response): 1119
# Row 9 processed in 17.13 seconds.
#
# Processing row 10...
# Estimated input tokens (prompt): 584
# Estimated output tokens (response): 302
# Total estimated tokens (prompt + response): 886
# Row 10 processed in 20.41 seconds.
#
# Processing row 11...
# Estimated input tokens (prompt): 609
# Estimated output tokens (response): 348
# Total estimated tokens (prompt + response): 957
# Row 11 processed in 13.26 seconds.
#
# Processing row 12...
# Estimated input tokens (prompt): 911
# Estimated output tokens (response): 559
# Total estimated tokens (prompt + response): 1470
# Row 12 processed in 19.51 seconds.
#
# Processing row 13...
# Estimated input tokens (prompt): 644
# Estimated output tokens (response): 292
# Total estimated tokens (prompt + response): 936
# Row 13 processed in 13.81 seconds.
#
# Processing row 14...
# Estimated input tokens (prompt): 575
# Estimated output tokens (response): 291
# Total estimated tokens (prompt + response): 866
# Row 14 processed in 13.00 seconds.
#
# Processing row 15...
# Estimated input tokens (prompt): 1310
# Estimated output tokens (response): 774
# Total estimated tokens (prompt + response): 2084
# Row 15 processed in 18.32 seconds.
#
# Processing row 16...
# Estimated input tokens (prompt): 775
# Estimated output tokens (response): 519
# Total estimated tokens (prompt + response): 1294
# Row 16 processed in 16.66 seconds.
#
# Processing row 17...
# Estimated input tokens (prompt): 755
# Estimated output tokens (response): 326
# Total estimated tokens (prompt + response): 1081
# Row 17 processed in 16.56 seconds.
#
# Processing row 18...
# Estimated input tokens (prompt): 591
# Estimated output tokens (response): 321
# Total estimated tokens (prompt + response): 912
# Row 18 processed in 10.72 seconds.
#
# Processing row 19...
# Estimated input tokens (prompt): 677
# Estimated output tokens (response): 362
# Total estimated tokens (prompt + response): 1039
# Row 19 processed in 17.82 seconds.
#
# Processing row 20...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 253
# Total estimated tokens (prompt + response): 821
# Row 20 processed in 8.20 seconds.
#
# Processing row 21...
# Estimated input tokens (prompt): 589
# Estimated output tokens (response): 303
# Total estimated tokens (prompt + response): 892
# Row 21 processed in 14.42 seconds.
#
# Processing row 22...
# Estimated input tokens (prompt): 858
# Estimated output tokens (response): 374
# Total estimated tokens (prompt + response): 1232
# Row 22 processed in 15.56 seconds.
#
# Processing row 23...
# Estimated input tokens (prompt): 590
# Estimated output tokens (response): 275
# Total estimated tokens (prompt + response): 865
# Row 23 processed in 14.53 seconds.
#
# Processing row 24...
# Estimated input tokens (prompt): 643
# Estimated output tokens (response): 327
# Total estimated tokens (prompt + response): 970
# Row 24 processed in 11.85 seconds.
#
# Processing row 25...
# Estimated input tokens (prompt): 869
# Estimated output tokens (response): 509
# Total estimated tokens (prompt + response): 1378
# Row 25 processed in 24.31 seconds.
#
# Processing row 26...
# Estimated input tokens (prompt): 1070
# Estimated output tokens (response): 792
# Total estimated tokens (prompt + response): 1862
# Row 26 processed in 23.61 seconds.
#
# Processing row 27...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 329
# Total estimated tokens (prompt + response): 897
# Row 27 processed in 10.72 seconds.
#
# Processing row 28...
# Estimated input tokens (prompt): 582
# Estimated output tokens (response): 315
# Total estimated tokens (prompt + response): 897
# JSON decoding failed: Expecting property name enclosed in double quotes: line 13 column 2 (char 809)
# Raw output:
# {
#   "core_issue": "The feedback is entirely positive, highlighting the hospital's clean and peaceful environment and the friendly services provided.",
#   "summary": "Clean, peaceful, friendly services hospital.",
#   "ward_block_or_room_number": "Not found in feedback",
#   "department": "Not found in feedback",
#   "hospital_description": "The hospital is described as 'very clean' and 'peaceful'.",
#   "doctors": "Not found in feedback",
#   "nurses": "Not found in feedback",
#   "support_or_admin_staff": "The review mentions 'friendly services', which implies positive interaction with staff, but does not specify their roles.",
#   "staff_names": "Not found in feedback",
#   "treatments_or_medical_procedures": "Not found in feedback",
#   "service_quality_highlighted": "The review highlights 'friendly services'.",
#  করারwaiting_time": "Not found in feedback",
#   "food_or_other_quality": "The quality of the hospital environment is highlighted as 'very clean' and 'peaceful'.",
#   "rude_staff": "Not found in feedback",
#   "delays_or_poor_management": "Not found in feedback",
#   "unfair_rules_or_inconsistent_policies": "Not found in feedback",
#   "explicitly_negative_description": "Not found in feedback",
#   "profit_motive_or_unnecessary_procedures": "Not found in feedback",
#   "perceived_fraudulent_activity": "Not found in feedback"
# }
#
# Row 28 processed in 17.44 seconds.
#
# Processing row 29...
# Estimated input tokens (prompt): 615
# Estimated output tokens (response): 265
# Total estimated tokens (prompt + response): 880
# Row 29 processed in 14.13 seconds.
#
# Processing row 30...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 264
# Total estimated tokens (prompt + response): 832
# Row 30 processed in 14.44 seconds.
#
# Processing row 31...
# Estimated input tokens (prompt): 737
# Estimated output tokens (response): 305
# Total estimated tokens (prompt + response): 1042
# Row 31 processed in 12.43 seconds.
#
# Processing row 32...
# Estimated input tokens (prompt): 826
# Estimated output tokens (response): 401
# Total estimated tokens (prompt + response): 1227
# Row 32 processed in 13.82 seconds.
#
# Processing row 33...
# Estimated input tokens (prompt): 701
# Estimated output tokens (response): 374
# Total estimated tokens (prompt + response): 1075
# Row 33 processed in 10.15 seconds.
#
# Processing row 34...
# Estimated input tokens (prompt): 636
# Estimated output tokens (response): 344
# Total estimated tokens (prompt + response): 980
# Row 34 processed in 15.00 seconds.
#
# Processing row 35...
# Estimated input tokens (prompt): 764
# Estimated output tokens (response): 289
# Total estimated tokens (prompt + response): 1053
# Row 35 processed in 12.32 seconds.
#
# Processing row 36...
# Estimated input tokens (prompt): 607
# Estimated output tokens (response): 272
# Total estimated tokens (prompt + response): 879
# Row 36 processed in 11.64 seconds.
#
# Processing row 37...
# Estimated input tokens (prompt): 583
# Estimated output tokens (response): 304
# Total estimated tokens (prompt + response): 887
# Row 37 processed in 11.36 seconds.
#
# Processing row 38...
# Estimated input tokens (prompt): 631
# Estimated output tokens (response): 436
# Total estimated tokens (prompt + response): 1067
# Row 38 processed in 16.08 seconds.
#
# Processing row 39...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 273
# Total estimated tokens (prompt + response): 841
# Row 39 processed in 12.97 seconds.
#
# Processing row 40...
# Estimated input tokens (prompt): 681
# Estimated output tokens (response): 324
# Total estimated tokens (prompt + response): 1005
# Row 40 processed in 11.76 seconds.
#
# Processing row 41...
# Estimated input tokens (prompt): 604
# Estimated output tokens (response): 430
# Total estimated tokens (prompt + response): 1034
# Row 41 processed in 20.26 seconds.
#
# Processing row 42...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 265
# Total estimated tokens (prompt + response): 833
# Row 42 processed in 12.23 seconds.
#
# Processing row 43...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 259
# Total estimated tokens (prompt + response): 827
# Row 43 processed in 11.00 seconds.
#
# Processing row 44...
# Estimated input tokens (prompt): 643
# Estimated output tokens (response): 383
# Total estimated tokens (prompt + response): 1026
# Row 44 processed in 15.56 seconds.
#
# Processing row 45...
# Estimated input tokens (prompt): 855
# Estimated output tokens (response): 704
# Total estimated tokens (prompt + response): 1559
# Row 45 processed in 27.31 seconds.
#
# Processing row 46...
# Estimated input tokens (prompt): 694
# Estimated output tokens (response): 418
# Total estimated tokens (prompt + response): 1112
# Row 46 processed in 16.27 seconds.
#
# Processing row 47...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 259
# Total estimated tokens (prompt + response): 827
# Row 47 processed in 8.43 seconds.
#
# Processing row 48...
# Estimated input tokens (prompt): 749
# Estimated output tokens (response): 304
# Total estimated tokens (prompt + response): 1053
# Row 48 processed in 13.70 seconds.
#
# Processing row 49...
# Estimated input tokens (prompt): 608
# Estimated output tokens (response): 295
# Total estimated tokens (prompt + response): 903
# Row 49 processed in 11.95 seconds.
#
# Processing row 50...
# Estimated input tokens (prompt): 599
# Estimated output tokens (response): 426
# Total estimated tokens (prompt + response): 1025
# Row 50 processed in 18.30 seconds.
#
# Processing row 51...
# Estimated input tokens (prompt): 604
# Estimated output tokens (response): 274
# Total estimated tokens (prompt + response): 878
# Row 51 processed in 14.10 seconds.
#
# Processing row 52...
# Estimated input tokens (prompt): 730
# Estimated output tokens (response): 503
# Total estimated tokens (prompt + response): 1233
# Row 52 processed in 16.87 seconds.
#
# Processing row 53...
# Estimated input tokens (prompt): 574
# Estimated output tokens (response): 279
# Total estimated tokens (prompt + response): 853
# Row 53 processed in 17.70 seconds.
#
# Processing row 54...
# Estimated input tokens (prompt): 664
# Estimated output tokens (response): 296
# Total estimated tokens (prompt + response): 960
# Row 54 processed in 11.87 seconds.
#
# Processing row 55...
# Estimated input tokens (prompt): 616
# Estimated output tokens (response): 311
# Total estimated tokens (prompt + response): 927
# Row 55 processed in 17.71 seconds.
#
# Processing row 56...
# Estimated input tokens (prompt): 755
# Estimated output tokens (response): 590
# Total estimated tokens (prompt + response): 1345
# Row 56 processed in 19.67 seconds.
#
# Processing row 57...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 240
# Total estimated tokens (prompt + response): 808
# Row 57 processed in 10.77 seconds.
#
# Processing row 58...
# Estimated input tokens (prompt): 674
# Estimated output tokens (response): 303
# Total estimated tokens (prompt + response): 977
# Row 58 processed in 14.21 seconds.
#
# Processing row 59...
# Estimated input tokens (prompt): 692
# Estimated output tokens (response): 403
# Total estimated tokens (prompt + response): 1095
# Row 59 processed in 15.81 seconds.
#
# Processing row 60...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 267
# Total estimated tokens (prompt + response): 835
# Row 60 processed in 10.85 seconds.
#
# Processing row 61...
# Estimated input tokens (prompt): 1004
# Estimated output tokens (response): 404
# Total estimated tokens (prompt + response): 1408
# Row 61 processed in 15.94 seconds.
#
# Processing row 62...
# Estimated input tokens (prompt): 661
# Estimated output tokens (response): 268
# Total estimated tokens (prompt + response): 929
# Row 62 processed in 10.11 seconds.
#
# Processing row 63...
# Estimated input tokens (prompt): 653
# Estimated output tokens (response): 325
# Total estimated tokens (prompt + response): 978
# Row 63 processed in 12.80 seconds.
#
# Processing row 64...
# Estimated input tokens (prompt): 637
# Estimated output tokens (response): 373
# Total estimated tokens (prompt + response): 1010
# Row 64 processed in 14.16 seconds.
#
# Processing row 65...
# Estimated input tokens (prompt): 569
# Estimated output tokens (response): 247
# Total estimated tokens (prompt + response): 816
# Row 65 processed in 9.64 seconds.
#
# Processing row 66...
# Estimated input tokens (prompt): 684
# Estimated output tokens (response): 313
# Total estimated tokens (prompt + response): 997
# Row 66 processed in 15.82 seconds.
#
# Processing row 67...
# Estimated input tokens (prompt): 682
# Estimated output tokens (response): 501
# Total estimated tokens (prompt + response): 1183
# Row 67 processed in 14.01 seconds.
#
# Processing row 68...
# Estimated input tokens (prompt): 646
# Estimated output tokens (response): 357
# Total estimated tokens (prompt + response): 1003
# Row 68 processed in 17.70 seconds.
#
# Processing row 69...
# Estimated input tokens (prompt): 907
# Estimated output tokens (response): 447
# Total estimated tokens (prompt + response): 1354
# Row 69 processed in 12.86 seconds.
#
# Processing row 70...
# Estimated input tokens (prompt): 574
# Estimated output tokens (response): 327
# Total estimated tokens (prompt + response): 901
# Row 70 processed in 12.51 seconds.
#
# Processing row 71...
# Estimated input tokens (prompt): 601
# Estimated output tokens (response): 288
# Total estimated tokens (prompt + response): 889
# Row 71 processed in 14.54 seconds.
#
# Processing row 72...
# Estimated input tokens (prompt): 611
# Estimated output tokens (response): 299
# Total estimated tokens (prompt + response): 910
# Row 72 processed in 12.76 seconds.
#
# Processing row 73...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 249
# Total estimated tokens (prompt + response): 817
# Row 73 processed in 9.14 seconds.
#
# Processing row 74...
# Estimated input tokens (prompt): 595
# Estimated output tokens (response): 288
# Total estimated tokens (prompt + response): 883
# Row 74 processed in 14.71 seconds.
#
# Processing row 75...
# Estimated input tokens (prompt): 649
# Estimated output tokens (response): 351
# Total estimated tokens (prompt + response): 1000
# Row 75 processed in 14.25 seconds.
#
# Processing row 76...
# Estimated input tokens (prompt): 661
# Estimated output tokens (response): 350
# Total estimated tokens (prompt + response): 1011
# Row 76 processed in 15.55 seconds.
#
# Processing row 77...
# Estimated input tokens (prompt): 896
# Estimated output tokens (response): 677
# Total estimated tokens (prompt + response): 1573
# Row 77 processed in 32.88 seconds.
#
# Processing row 78...
# Estimated input tokens (prompt): 827
# Estimated output tokens (response): 744
# Total estimated tokens (prompt + response): 1571
# Row 78 processed in 20.27 seconds.
#
# Processing row 79...
# Estimated input tokens (prompt): 1495
# Estimated output tokens (response): 931
# Total estimated tokens (prompt + response): 2426
# Row 79 processed in 21.91 seconds.
#
# Processing row 80...
# Estimated input tokens (prompt): 631
# Estimated output tokens (response): 333
# Total estimated tokens (prompt + response): 964
# Row 80 processed in 13.79 seconds.
#
# Processing row 81...
# Estimated input tokens (prompt): 596
# Estimated output tokens (response): 314
# Total estimated tokens (prompt + response): 910
# Row 81 processed in 11.78 seconds.
#
# Processing row 82...
# Estimated input tokens (prompt): 670
# Estimated output tokens (response): 514
# Total estimated tokens (prompt + response): 1184
# Row 82 processed in 17.67 seconds.
#
# Processing row 83...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 264
# Total estimated tokens (prompt + response): 832
# Row 83 processed in 9.58 seconds.
#
# Processing row 84...
# Estimated input tokens (prompt): 596
# Estimated output tokens (response): 276
# Total estimated tokens (prompt + response): 872
# Row 84 processed in 10.92 seconds.
#
# Processing row 85...
# Estimated input tokens (prompt): 959
# Estimated output tokens (response): 482
# Total estimated tokens (prompt + response): 1441
# Row 85 processed in 17.72 seconds.
#
# Processing row 86...
# Estimated input tokens (prompt): 581
# Estimated output tokens (response): 265
# Total estimated tokens (prompt + response): 846
# Row 86 processed in 13.01 seconds.
#
# Processing row 87...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 244
# Total estimated tokens (prompt + response): 812
# Row 87 processed in 11.71 seconds.
#
# Processing row 88...
# Estimated input tokens (prompt): 602
# Estimated output tokens (response): 377
# Total estimated tokens (prompt + response): 979
# Row 88 processed in 14.98 seconds.
#
# Processing row 89...
# Estimated input tokens (prompt): 683
# Estimated output tokens (response): 347
# Total estimated tokens (prompt + response): 1030
# Row 89 processed in 13.13 seconds.
#
# Processing row 90...
# Estimated input tokens (prompt): 625
# Estimated output tokens (response): 286
# Total estimated tokens (prompt + response): 911
# Row 90 processed in 15.42 seconds.
#
# Processing row 91...
# Estimated input tokens (prompt): 763
# Estimated output tokens (response): 353
# Total estimated tokens (prompt + response): 1116
# Row 91 processed in 18.30 seconds.
#
# Processing row 92...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 259
# Total estimated tokens (prompt + response): 827
# Row 92 processed in 9.69 seconds.
#
# Processing row 93...
# Estimated input tokens (prompt): 609
# Estimated output tokens (response): 344
# Total estimated tokens (prompt + response): 953
# Row 93 processed in 13.04 seconds.
#
# Processing row 94...
# Estimated input tokens (prompt): 845
# Estimated output tokens (response): 528
# Total estimated tokens (prompt + response): 1373
# Row 94 processed in 19.46 seconds.
#
# Processing row 95...
# Estimated input tokens (prompt): 586
# Estimated output tokens (response): 320
# Total estimated tokens (prompt + response): 906
# Row 95 processed in 15.46 seconds.
#
# Processing row 96...
# Estimated input tokens (prompt): 604
# Estimated output tokens (response): 311
# Total estimated tokens (prompt + response): 915
# Row 96 processed in 12.26 seconds.
#
# Processing row 97...
# Estimated input tokens (prompt): 617
# Estimated output tokens (response): 307
# Total estimated tokens (prompt + response): 924
# Row 97 processed in 14.60 seconds.
#
# Processing row 98...
# Estimated input tokens (prompt): 578
# Estimated output tokens (response): 267
# Total estimated tokens (prompt + response): 845
# Row 98 processed in 9.20 seconds.
#
# Processing row 99...
# Estimated input tokens (prompt): 615
# Estimated output tokens (response): 377
# Total estimated tokens (prompt + response): 992
# Row 99 processed in 14.31 seconds.
#
# Processing row 100...
# Estimated input tokens (prompt): 981
# Estimated output tokens (response): 552
# Total estimated tokens (prompt + response): 1533
# Row 100 processed in 19.97 seconds.
#
# Processing row 101...
# Estimated input tokens (prompt): 734
# Estimated output tokens (response): 490
# Total estimated tokens (prompt + response): 1224
# Row 101 processed in 18.26 seconds.
#
# Processing row 102...
# Estimated input tokens (prompt): 677
# Estimated output tokens (response): 469
# Total estimated tokens (prompt + response): 1146
# Row 102 processed in 17.43 seconds.
#
# Processing row 103...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 238
# Total estimated tokens (prompt + response): 806
# Row 103 processed in 8.41 seconds.
#
# Processing row 104...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 438
# Total estimated tokens (prompt + response): 1006
# Row 104 processed in 11.62 seconds.
#
# Processing row 105...
# Estimated input tokens (prompt): 895
# Estimated output tokens (response): 386
# Total estimated tokens (prompt + response): 1281
# Row 105 processed in 14.57 seconds.
#
# Processing row 106...
# Estimated input tokens (prompt): 861
# Estimated output tokens (response): 675
# Total estimated tokens (prompt + response): 1536
# Row 106 processed in 16.02 seconds.
#
# Processing row 107...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 243
# Total estimated tokens (prompt + response): 811
# Row 107 processed in 9.36 seconds.
#
# Processing row 108...
# Estimated input tokens (prompt): 610
# Estimated output tokens (response): 356
# Total estimated tokens (prompt + response): 966
# Row 108 processed in 13.91 seconds.
#
# Processing row 109...
# Estimated input tokens (prompt): 583
# Estimated output tokens (response): 264
# Total estimated tokens (prompt + response): 847
# Row 109 processed in 9.01 seconds.
#
# Processing row 110...
# Estimated input tokens (prompt): 600
# Estimated output tokens (response): 304
# Total estimated tokens (prompt + response): 904
# Row 110 processed in 16.02 seconds.
#
# Processing row 111...
# Estimated input tokens (prompt): 659
# Estimated output tokens (response): 273
# Total estimated tokens (prompt + response): 932
# Row 111 processed in 11.74 seconds.
#
# Processing row 112...
# Estimated input tokens (prompt): 606
# Estimated output tokens (response): 391
# Total estimated tokens (prompt + response): 997
# Row 112 processed in 16.78 seconds.
#
# Processing row 113...
# Estimated input tokens (prompt): 706
# Estimated output tokens (response): 400
# Total estimated tokens (prompt + response): 1106
# Row 113 processed in 12.14 seconds.
#
# Processing row 114...
# Estimated input tokens (prompt): 696
# Estimated output tokens (response): 497
# Total estimated tokens (prompt + response): 1193
# Row 114 processed in 18.97 seconds.
#
# Processing row 115...
# Estimated input tokens (prompt): 678
# Estimated output tokens (response): 504
# Total estimated tokens (prompt + response): 1182
# Row 115 processed in 13.08 seconds.
#
# Processing row 116...
# Estimated input tokens (prompt): 668
# Estimated output tokens (response): 323
# Total estimated tokens (prompt + response): 991
# Row 116 processed in 20.59 seconds.
#
# Processing row 117...
# Estimated input tokens (prompt): 766
# Estimated output tokens (response): 438
# Total estimated tokens (prompt + response): 1204
# Row 117 processed in 18.16 seconds.
#
# Processing row 118...
# Estimated input tokens (prompt): 708
# Estimated output tokens (response): 617
# Total estimated tokens (prompt + response): 1325
# Row 118 processed in 19.31 seconds.
#
# Processing row 119...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 248
# Total estimated tokens (prompt + response): 816
# Row 119 processed in 10.80 seconds.
#
# Processing row 120...
# Estimated input tokens (prompt): 707
# Estimated output tokens (response): 434
# Total estimated tokens (prompt + response): 1141
# Row 120 processed in 17.12 seconds.
#
# Processing row 121...
# Estimated input tokens (prompt): 687
# Estimated output tokens (response): 334
# Total estimated tokens (prompt + response): 1021
# Row 121 processed in 18.79 seconds.
#
# Processing row 122...
# Estimated input tokens (prompt): 606
# Estimated output tokens (response): 380
# Total estimated tokens (prompt + response): 986
# Row 122 processed in 16.08 seconds.
#
# Processing row 123...
# Estimated input tokens (prompt): 683
# Estimated output tokens (response): 566
# Total estimated tokens (prompt + response): 1249
# Row 123 processed in 17.82 seconds.
#
# Processing row 124...
# Estimated input tokens (prompt): 653
# Estimated output tokens (response): 336
# Total estimated tokens (prompt + response): 989
# Row 124 processed in 11.01 seconds.
#
# Processing row 125...
# Estimated input tokens (prompt): 1025
# Estimated output tokens (response): 777
# Total estimated tokens (prompt + response): 1802
# Row 125 processed in 21.19 seconds.
#
# Processing row 126...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 272
# Total estimated tokens (prompt + response): 840
# Row 126 processed in 14.87 seconds.
#
# Processing row 127...
# Estimated input tokens (prompt): 603
# Estimated output tokens (response): 281
# Total estimated tokens (prompt + response): 884
# Row 127 processed in 15.33 seconds.
#
# Processing row 128...
# Estimated input tokens (prompt): 706
# Estimated output tokens (response): 407
# Total estimated tokens (prompt + response): 1113
# Row 128 processed in 15.28 seconds.
#
# Processing row 129...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 248
# Total estimated tokens (prompt + response): 816
# Row 129 processed in 9.89 seconds.
#
# Processing row 130...
# Estimated input tokens (prompt): 836
# Estimated output tokens (response): 427
# Total estimated tokens (prompt + response): 1263
# Row 130 processed in 19.42 seconds.
#
# Processing row 131...
# Estimated input tokens (prompt): 621
# Estimated output tokens (response): 293
# Total estimated tokens (prompt + response): 914
# Row 131 processed in 14.16 seconds.
#
# Processing row 132...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 263
# Total estimated tokens (prompt + response): 831
# Row 132 processed in 7.77 seconds.
#
# Processing row 133...
# Estimated input tokens (prompt): 630
# Estimated output tokens (response): 319
# Total estimated tokens (prompt + response): 949
# Row 133 processed in 9.12 seconds.
#
# Processing row 134...
# Estimated input tokens (prompt): 645
# Estimated output tokens (response): 393
# Total estimated tokens (prompt + response): 1038
# Row 134 processed in 16.06 seconds.
#
# Processing row 135...
# Estimated input tokens (prompt): 679
# Estimated output tokens (response): 328
# Total estimated tokens (prompt + response): 1007
# Row 135 processed in 13.23 seconds.
#
# Processing row 136...
# Estimated input tokens (prompt): 693
# Estimated output tokens (response): 369
# Total estimated tokens (prompt + response): 1062
# Row 136 processed in 14.91 seconds.
#
# Processing row 137...
# Estimated input tokens (prompt): 603
# Estimated output tokens (response): 313
# Total estimated tokens (prompt + response): 916
# Row 137 processed in 9.88 seconds.
#
# Processing row 138...
# Estimated input tokens (prompt): 688
# Estimated output tokens (response): 375
# Total estimated tokens (prompt + response): 1063
# Row 138 processed in 19.36 seconds.
#
# Processing row 139...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 268
# Total estimated tokens (prompt + response): 836
# Row 139 processed in 14.07 seconds.
#
# Processing row 140...
# Estimated input tokens (prompt): 716
# Estimated output tokens (response): 429
# Total estimated tokens (prompt + response): 1145
# Row 140 processed in 14.34 seconds.
#
# Processing row 141...
# Estimated input tokens (prompt): 599
# Estimated output tokens (response): 274
# Total estimated tokens (prompt + response): 873
# Row 141 processed in 12.24 seconds.
#
# Processing row 142...
# Estimated input tokens (prompt): 619
# Estimated output tokens (response): 392
# Total estimated tokens (prompt + response): 1011
# Row 142 processed in 13.47 seconds.
#
# Processing row 143...
# Estimated input tokens (prompt): 1346
# Estimated output tokens (response): 591
# Total estimated tokens (prompt + response): 1937
# Row 143 processed in 26.22 seconds.
#
# Processing row 144...
# Estimated input tokens (prompt): 882
# Estimated output tokens (response): 445
# Total estimated tokens (prompt + response): 1327
# Row 144 processed in 13.94 seconds.
#
# Processing row 145...
# Estimated input tokens (prompt): 618
# Estimated output tokens (response): 338
# Total estimated tokens (prompt + response): 956
# Row 145 processed in 14.75 seconds.
#
# Processing row 146...
# Estimated input tokens (prompt): 851
# Estimated output tokens (response): 638
# Total estimated tokens (prompt + response): 1489
# Row 146 processed in 17.90 seconds.
#
# Processing row 147...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 456
# Total estimated tokens (prompt + response): 1024
# Row 147 processed in 16.10 seconds.
#
# Processing row 148...
# Estimated input tokens (prompt): 665
# Estimated output tokens (response): 366
# Total estimated tokens (prompt + response): 1031
# Row 148 processed in 14.03 seconds.
#
# Processing row 149...
# Estimated input tokens (prompt): 611
# Estimated output tokens (response): 375
# Total estimated tokens (prompt + response): 986
# Row 149 processed in 15.02 seconds.
#
# Processing row 150...
# Estimated input tokens (prompt): 580
# Estimated output tokens (response): 271
# Total estimated tokens (prompt + response): 851
# Row 150 processed in 13.81 seconds.
#
# Processing row 151...
# Estimated input tokens (prompt): 612
# Estimated output tokens (response): 360
# Total estimated tokens (prompt + response): 972
# Row 151 processed in 15.20 seconds.
#
# Processing row 152...
# Estimated input tokens (prompt): 639
# Estimated output tokens (response): 389
# Total estimated tokens (prompt + response): 1028
# Row 152 processed in 17.93 seconds.
#
# Processing row 153...
# Estimated input tokens (prompt): 674
# Estimated output tokens (response): 310
# Total estimated tokens (prompt + response): 984
# Row 153 processed in 15.20 seconds.
#
# Processing row 154...
# Estimated input tokens (prompt): 586
# Estimated output tokens (response): 290
# Total estimated tokens (prompt + response): 876
# Row 154 processed in 10.78 seconds.
#
# Processing row 155...
# Estimated input tokens (prompt): 862
# Estimated output tokens (response): 598
# Total estimated tokens (prompt + response): 1460
# Row 155 processed in 21.67 seconds.
#
# Processing row 156...
# Estimated input tokens (prompt): 718
# Estimated output tokens (response): 447
# Total estimated tokens (prompt + response): 1165
# Row 156 processed in 16.38 seconds.
#
# Processing row 157...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 262
# Total estimated tokens (prompt + response): 830
# Row 157 processed in 11.38 seconds.
#
# Processing row 158...
# Estimated input tokens (prompt): 612
# Estimated output tokens (response): 328
# Total estimated tokens (prompt + response): 940
# Row 158 processed in 14.19 seconds.
#
# Processing row 159...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 252
# Total estimated tokens (prompt + response): 820
# Row 159 processed in 8.33 seconds.
#
# Processing row 160...
# Estimated input tokens (prompt): 664
# Estimated output tokens (response): 415
# Total estimated tokens (prompt + response): 1079
# Row 160 processed in 16.51 seconds.
#
# Processing row 161...
# Estimated input tokens (prompt): 764
# Estimated output tokens (response): 683
# Total estimated tokens (prompt + response): 1447
# Row 161 processed in 16.12 seconds.
#
# Processing row 162...
# Estimated input tokens (prompt): 812
# Estimated output tokens (response): 542
# Total estimated tokens (prompt + response): 1354
# Row 162 processed in 15.50 seconds.
#
# Processing row 163...
# Estimated input tokens (prompt): 738
# Estimated output tokens (response): 540
# Total estimated tokens (prompt + response): 1278
# Row 163 processed in 17.77 seconds.
#
# Processing row 164...
# Estimated input tokens (prompt): 1394
# Estimated output tokens (response): 419
# Total estimated tokens (prompt + response): 1813
# Row 164 processed in 22.51 seconds.
#
# Processing row 165...
# Estimated input tokens (prompt): 590
# Estimated output tokens (response): 310
# Total estimated tokens (prompt + response): 900
# Row 165 processed in 10.94 seconds.
#
# Processing row 166...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 266
# Total estimated tokens (prompt + response): 834
# Row 166 processed in 12.04 seconds.
#
# Processing row 167...
# Estimated input tokens (prompt): 635
# Estimated output tokens (response): 357
# Total estimated tokens (prompt + response): 992
# Row 167 processed in 17.98 seconds.
#
# Processing row 168...
# Estimated input tokens (prompt): 577
# Estimated output tokens (response): 295
# Total estimated tokens (prompt + response): 872
# Row 168 processed in 10.32 seconds.
#
# Processing row 169...
# Estimated input tokens (prompt): 606
# Estimated output tokens (response): 325
# Total estimated tokens (prompt + response): 931
# Row 169 processed in 13.23 seconds.
#
# Processing row 170...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 268
# Total estimated tokens (prompt + response): 836
# Row 170 processed in 7.60 seconds.
#
# Processing row 171...
# Estimated input tokens (prompt): 693
# Estimated output tokens (response): 590
# Total estimated tokens (prompt + response): 1283
# Row 171 processed in 16.88 seconds.
#
# Processing row 172...
# Estimated input tokens (prompt): 642
# Estimated output tokens (response): 503
# Total estimated tokens (prompt + response): 1145
# Row 172 processed in 18.23 seconds.
#
# Processing row 173...
# Estimated input tokens (prompt): 778
# Estimated output tokens (response): 399
# Total estimated tokens (prompt + response): 1177
# Row 173 processed in 9.82 seconds.
#
# Processing row 174...
# Estimated input tokens (prompt): 603
# Estimated output tokens (response): 281
# Total estimated tokens (prompt + response): 884
# Row 174 processed in 12.66 seconds.
#
# Processing row 175...
# Estimated input tokens (prompt): 641
# Estimated output tokens (response): 381
# Total estimated tokens (prompt + response): 1022
# Row 175 processed in 16.16 seconds.
#
# Processing row 176...
# Estimated input tokens (prompt): 589
# Estimated output tokens (response): 321
# Total estimated tokens (prompt + response): 910
# Row 176 processed in 11.43 seconds.
#
# Processing row 177...
# Estimated input tokens (prompt): 575
# Estimated output tokens (response): 312
# Total estimated tokens (prompt + response): 887
# Row 177 processed in 13.35 seconds.
#
# Processing row 178...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 255
# Total estimated tokens (prompt + response): 823
# Row 178 processed in 9.58 seconds.
#
# Processing row 179...
# Estimated input tokens (prompt): 631
# Estimated output tokens (response): 341
# Total estimated tokens (prompt + response): 972
# Row 179 processed in 18.39 seconds.
#
# Processing row 180...
# Estimated input tokens (prompt): 667
# Estimated output tokens (response): 333
# Total estimated tokens (prompt + response): 1000
# Row 180 processed in 15.19 seconds.
#
# Processing row 181...
# Estimated input tokens (prompt): 710
# Estimated output tokens (response): 425
# Total estimated tokens (prompt + response): 1135
# Row 181 processed in 15.39 seconds.
#
# Processing row 182...
# Estimated input tokens (prompt): 745
# Estimated output tokens (response): 300
# Total estimated tokens (prompt + response): 1045
# Row 182 processed in 15.64 seconds.
#
# Processing row 183...
# Estimated input tokens (prompt): 648
# Estimated output tokens (response): 341
# Total estimated tokens (prompt + response): 989
# Row 183 processed in 25.21 seconds.
#
# Processing row 184...
# Estimated input tokens (prompt): 600
# Estimated output tokens (response): 303
# Total estimated tokens (prompt + response): 903
# Row 184 processed in 16.22 seconds.
#
# Processing row 185...
# Estimated input tokens (prompt): 703
# Estimated output tokens (response): 362
# Total estimated tokens (prompt + response): 1065
# Row 185 processed in 14.22 seconds.
#
# Processing row 186...
# Estimated input tokens (prompt): 669
# Estimated output tokens (response): 538
# Total estimated tokens (prompt + response): 1207
# Row 186 processed in 21.79 seconds.
#
# Processing row 187...
# Estimated input tokens (prompt): 579
# Estimated output tokens (response): 260
# Total estimated tokens (prompt + response): 839
# Row 187 processed in 12.05 seconds.
#
# Processing row 188...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 267
# Total estimated tokens (prompt + response): 835
# Row 188 processed in 10.91 seconds.
#
# Processing row 189...
# Estimated input tokens (prompt): 1645
# Estimated output tokens (response): 756
# Total estimated tokens (prompt + response): 2401
# Row 189 processed in 26.41 seconds.
#
# Processing row 190...
# Estimated input tokens (prompt): 609
# Estimated output tokens (response): 327
# Total estimated tokens (prompt + response): 936
# Row 190 processed in 12.60 seconds.
#
# Processing row 191...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 263
# Total estimated tokens (prompt + response): 831
# Row 191 processed in 10.75 seconds.
#
# Processing row 192...
# Estimated input tokens (prompt): 916
# Estimated output tokens (response): 758
# Total estimated tokens (prompt + response): 1674
# Row 192 processed in 24.07 seconds.
#
# Processing row 193...
# Estimated input tokens (prompt): 585
# Estimated output tokens (response): 341
# Total estimated tokens (prompt + response): 926
# Row 193 processed in 11.04 seconds.
#
# Processing row 194...
# Estimated input tokens (prompt): 657
# Estimated output tokens (response): 303
# Total estimated tokens (prompt + response): 960
# Row 194 processed in 16.88 seconds.
#
# Processing row 195...
# Estimated input tokens (prompt): 746
# Estimated output tokens (response): 395
# Total estimated tokens (prompt + response): 1141
# Row 195 processed in 13.69 seconds.
#
# Processing row 196...
# Estimated input tokens (prompt): 675
# Estimated output tokens (response): 596
# Total estimated tokens (prompt + response): 1271
# Row 196 processed in 21.85 seconds.
#
# Processing row 197...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 249
# Total estimated tokens (prompt + response): 817
# Row 197 processed in 12.13 seconds.
#
# Processing row 198...
# Estimated input tokens (prompt): 723
# Estimated output tokens (response): 476
# Total estimated tokens (prompt + response): 1199
# Row 198 processed in 18.42 seconds.
#
# Processing row 199...
# Estimated input tokens (prompt): 593
# Estimated output tokens (response): 308
# Total estimated tokens (prompt + response): 901
# Row 199 processed in 13.47 seconds.
#
# Processing row 200...
# Estimated input tokens (prompt): 628
# Estimated output tokens (response): 347
# Total estimated tokens (prompt + response): 975
# Row 200 processed in 14.94 seconds.
#
# Processing row 201...
# Estimated input tokens (prompt): 619
# Estimated output tokens (response): 346
# Total estimated tokens (prompt + response): 965
# Row 201 processed in 13.23 seconds.
#
# Processing row 202...
# Estimated input tokens (prompt): 597
# Estimated output tokens (response): 308
# Total estimated tokens (prompt + response): 905
# Row 202 processed in 15.63 seconds.
#
# Processing row 203...
# Estimated input tokens (prompt): 610
# Estimated output tokens (response): 312
# Total estimated tokens (prompt + response): 922
# Row 203 processed in 14.59 seconds.
#
# Processing row 204...
# Estimated input tokens (prompt): 617
# Estimated output tokens (response): 289
# Total estimated tokens (prompt + response): 906
# Row 204 processed in 12.09 seconds.
#
# Processing row 205...
# Estimated input tokens (prompt): 627
# Estimated output tokens (response): 333
# Total estimated tokens (prompt + response): 960
# Row 205 processed in 16.10 seconds.
#
# Processing row 206...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 250
# Total estimated tokens (prompt + response): 818
# Row 206 processed in 10.23 seconds.
#
# Processing row 207...
# Estimated input tokens (prompt): 585
# Estimated output tokens (response): 393
# Total estimated tokens (prompt + response): 978
# Row 207 processed in 14.56 seconds.
#
# Processing row 208...
# Estimated input tokens (prompt): 627
# Estimated output tokens (response): 286
# Total estimated tokens (prompt + response): 913
# Row 208 processed in 12.28 seconds.
#
# Processing row 209...
# Estimated input tokens (prompt): 637
# Estimated output tokens (response): 357
# Total estimated tokens (prompt + response): 994
# Row 209 processed in 11.55 seconds.
#
# Processing row 210...
# Estimated input tokens (prompt): 676
# Estimated output tokens (response): 495
# Total estimated tokens (prompt + response): 1171
# Row 210 processed in 17.90 seconds.
#
# Processing row 211...
# Estimated input tokens (prompt): 607
# Estimated output tokens (response): 257
# Total estimated tokens (prompt + response): 864
# Row 211 processed in 12.02 seconds.
#
# Processing row 212...
# Estimated input tokens (prompt): 597
# Estimated output tokens (response): 312
# Total estimated tokens (prompt + response): 909
# Row 212 processed in 13.75 seconds.
#
# Processing row 213...
# Estimated input tokens (prompt): 581
# Estimated output tokens (response): 325
# Total estimated tokens (prompt + response): 906
# Row 213 processed in 12.02 seconds.
#
# Processing row 214...
# Estimated input tokens (prompt): 624
# Estimated output tokens (response): 334
# Total estimated tokens (prompt + response): 958
# Row 214 processed in 15.06 seconds.
#
# Processing row 215...
# Estimated input tokens (prompt): 670
# Estimated output tokens (response): 396
# Total estimated tokens (prompt + response): 1066
# Row 215 processed in 22.76 seconds.
#
# Processing row 216...
# Estimated input tokens (prompt): 571
# Estimated output tokens (response): 255
# Total estimated tokens (prompt + response): 826
# Row 216 processed in 8.99 seconds.
#
# Processing row 217...
# Estimated input tokens (prompt): 990
# Estimated output tokens (response): 545
# Total estimated tokens (prompt + response): 1535
# JSON decoding failed: Expecting property name enclosed in double quotes: line 7 column 1 (char 403)
# Raw output:
# {
#   "core_issue": "The patient was incorrectly and unfairly billed over $900 for using the 'labour ward' as part of a 'package', even though she never entered that ward.",
#   "summary": "Great nurses, atrocious billing administration.",
#   "specific_ward_block_room_number": "labour ward, Operating Theatre",
#   "department": "Operating Theatre",
#   "hospital_old_upgraded_modern": "Not found in feedback",
# e  "doctors": "my gynae (gynecologist)",
#   "nurses": "Yes, the review states the nurses were 'great', 'kind, attentive and very sweet'. The reviewer recognized some from her previous delivery.",
#   "support_admin_staff": "Yes, 'hospital administration' (described as atrocious) and 'counter staff' are mentioned.",
#   "specific_staff_names": "Not found in feedback",
#   "specific_treatments_medical_procedures": "delivery, csec (Caesarean section), emergency csec, operation",
#   "service_quality_highlighted": "Nurses are highlighted for being 'great', 'kind', 'attentive', and 'sweet'. The hospital administration is highlighted for being 'atrocious'.",
#   "waiting_time": "The review mentions 'waited to be admitted' but does not specify the duration.",
#   "food_quality_other_quality": "Not found in feedback",
#   "rude_staff": "The hospital administration is described as 'atrocious', and the counter staff is described as being insistent on adding an incorrect charge to the bill.",
#   "delays_long_queues_poor_management": "Poor management is highlighted by the billing issue, where there was a clear miscommunication and insistence on a wrong charge. Ward nurses and administration were in disagreement over the bill.",
#   "unfair_rules_inconsistent_policies": "Yes, the reviewer was forced to pay for a 'package' that included a 900+ charge for the labour ward, a service she never used. The policy was inconsistent as the charge was not on the initial bill but was added later by the counter staff.",
#   "explicitly_call_hospital_horrible_worst": "The reviewer states, 'The hospital deserves none' of the stars.",
#   "profit_motive_unnecessary_procedures": "Yes, the hospital's insistence on charging an extra 900+ for a service that was not used is perceived as being profit-driven.",
#   "perceive_fraudulent_activity": "Yes, the reviewer perceives the charge as fraudulent by stating, 'I didn't step into the ward why should I pay for it?'"
# }
#
# Row 217 processed in 23.88 seconds.
#
# Processing row 218...
# Estimated input tokens (prompt): 662
# Estimated output tokens (response): 349
# Total estimated tokens (prompt + response): 1011
# Row 218 processed in 13.17 seconds.
#
# Processing row 219...
# Estimated input tokens (prompt): 635
# Estimated output tokens (response): 285
# Total estimated tokens (prompt + response): 920
# Row 219 processed in 14.11 seconds.
#
# Processing row 220...
# Estimated input tokens (prompt): 617
# Estimated output tokens (response): 347
# Total estimated tokens (prompt + response): 964
# Row 220 processed in 18.40 seconds.
#
# Processing row 221...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 257
# Total estimated tokens (prompt + response): 825
# Row 221 processed in 9.43 seconds.
#
# Processing row 222...
# Estimated input tokens (prompt): 713
# Estimated output tokens (response): 388
# Total estimated tokens (prompt + response): 1101
# Row 222 processed in 14.69 seconds.
#
# Processing row 223...
# Estimated input tokens (prompt): 889
# Estimated output tokens (response): 411
# Total estimated tokens (prompt + response): 1300
# Row 223 processed in 16.41 seconds.
#
# Processing row 224...
# Estimated input tokens (prompt): 750
# Estimated output tokens (response): 376
# Total estimated tokens (prompt + response): 1126
# Row 224 processed in 16.43 seconds.
#
# Processing row 225...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 264
# Total estimated tokens (prompt + response): 832
# Row 225 processed in 10.46 seconds.
#
# Processing row 226...
# Estimated input tokens (prompt): 619
# Estimated output tokens (response): 372
# Total estimated tokens (prompt + response): 991
# Row 226 processed in 17.91 seconds.
#
# Processing row 227...
# Estimated input tokens (prompt): 643
# Estimated output tokens (response): 332
# Total estimated tokens (prompt + response): 975
# Row 227 processed in 20.55 seconds.
#
# Processing row 228...
# Estimated input tokens (prompt): 1385
# Estimated output tokens (response): 861
# Total estimated tokens (prompt + response): 2246
# Row 228 processed in 25.63 seconds.
#
# Processing row 229...
# Estimated input tokens (prompt): 818
# Estimated output tokens (response): 511
# Total estimated tokens (prompt + response): 1329
# Row 229 processed in 21.69 seconds.
#
# Processing row 230...
# Estimated input tokens (prompt): 899
# Estimated output tokens (response): 822
# Total estimated tokens (prompt + response): 1721
# Row 230 processed in 30.50 seconds.
#
# Processing row 231...
# Estimated input tokens (prompt): 581
# Estimated output tokens (response): 314
# Total estimated tokens (prompt + response): 895
# Row 231 processed in 10.04 seconds.
#
# Processing row 232...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 253
# Total estimated tokens (prompt + response): 821
# Row 232 processed in 10.06 seconds.
#
# Processing row 233...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 265
# Total estimated tokens (prompt + response): 833
# Row 233 processed in 8.20 seconds.
#
# Processing row 234...
# Estimated input tokens (prompt): 656
# Estimated output tokens (response): 353
# Total estimated tokens (prompt + response): 1009
# Row 234 processed in 13.34 seconds.
#
# Processing row 235...
# Estimated input tokens (prompt): 690
# Estimated output tokens (response): 419
# Total estimated tokens (prompt + response): 1109
# Row 235 processed in 14.99 seconds.
#
# Processing row 236...
# Estimated input tokens (prompt): 707
# Estimated output tokens (response): 395
# Total estimated tokens (prompt + response): 1102
# Row 236 processed in 18.95 seconds.
#
# Processing row 237...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 249
# Total estimated tokens (prompt + response): 817
# Row 237 processed in 8.01 seconds.
#
# Processing row 238...
# Estimated input tokens (prompt): 613
# Estimated output tokens (response): 354
# Total estimated tokens (prompt + response): 967
# Row 238 processed in 11.93 seconds.
#
# Processing row 239...
# Estimated input tokens (prompt): 664
# Estimated output tokens (response): 475
# Total estimated tokens (prompt + response): 1139
# Row 239 processed in 16.63 seconds.
#
# Processing row 240...
# Estimated input tokens (prompt): 847
# ...
#   "waiting_time": "Not found in feedback",
#   "food_quality_or_any_other_quality": "Not found in feedback",
#   "rude_staff": "Not found in feedback",
#   "delays_long_queues_or_poor_management": "Not found in feedback",
#   "unfair_rules_or_inconsistent_policies": "Not found in feedback",
#   "explicitly_call_the_hospital_horrible_worst_terrifying_or_disappointing": "Not found in feedback",
#   "suggest_profit_motive_or_unnecessary_procedures": "Not found in feedback",
#   "perceive_fraudulent_activity": "Not found in feedback"
# }
#
# Row 365 processed in 12.66 seconds.
#
# Processing row 366...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 257
# Total estimated tokens (prompt + response): 825
# Row 366 processed in 10.07 seconds.
#
# Processing row 367...
# Estimated input tokens (prompt): 587
# Estimated output tokens (response): 298
# Total estimated tokens (prompt + response): 885
# Row 367 processed in 11.28 seconds.
#
# Processing row 368...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 256
# Total estimated tokens (prompt + response): 824
# Row 368 processed in 14.34 seconds.
#
# Processing row 369...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 264
# Total estimated tokens (prompt + response): 832
# Row 369 processed in 13.36 seconds.
#
# Processing row 370...
# Estimated input tokens (prompt): 680
# Estimated output tokens (response): 434
# Total estimated tokens (prompt + response): 1114
# Row 370 processed in 17.05 seconds.
#
# Processing row 371...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 264
# Total estimated tokens (prompt + response): 832
# Row 371 processed in 13.29 seconds.
#
# Processing row 372...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 389
# Total estimated tokens (prompt + response): 957
# Row 372 processed in 11.54 seconds.
#
# Processing row 373...
# Estimated input tokens (prompt): 585
# Estimated output tokens (response): 256
# Total estimated tokens (prompt + response): 841
# Row 373 processed in 9.67 seconds.
#
# Processing row 374...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 272
# Total estimated tokens (prompt + response): 840
# Row 374 processed in 12.58 seconds.
#
# Processing row 375...
# Estimated input tokens (prompt): 642
# Estimated output tokens (response): 272
# Total estimated tokens (prompt + response): 914
# Row 375 processed in 16.53 seconds.
#
# Processing row 376...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 268
# Total estimated tokens (prompt + response): 836
# Row 376 processed in 8.91 seconds.
#
# Processing row 377...
# Estimated input tokens (prompt): 572
# Estimated output tokens (response): 292
# Total estimated tokens (prompt + response): 864
# Row 377 processed in 18.71 seconds.
#
# Processing row 378...
# Estimated input tokens (prompt): 675
# Estimated output tokens (response): 421
# Total estimated tokens (prompt + response): 1096
# Row 378 processed in 17.18 seconds.
#
# Processing row 379...
# Estimated input tokens (prompt): 574
# Estimated output tokens (response): 296
# Total estimated tokens (prompt + response): 870
# Row 379 processed in 16.02 seconds.
#
# Processing row 380...
# Estimated input tokens (prompt): 570
# Estimated output tokens (response): 273
# Total estimated tokens (prompt + response): 843
# Row 380 processed in 14.81 seconds.
#
# Processing row 381...
# Estimated input tokens (prompt): 598
# Estimated output tokens (response): 286
# Total estimated tokens (prompt + response): 884
# Row 381 processed in 14.92 seconds.
#
# Processing row 382...
# Estimated input tokens (prompt): 593
# Estimated output tokens (response): 528
# Total estimated tokens (prompt + response): 1121
# Row 382 processed in 19.22 seconds.
#
# Processing row 383...
# Estimated input tokens (prompt): 985
# Estimated output tokens (response): 556
# Total estimated tokens (prompt + response): 1541
# Row 383 processed in 25.24 seconds.
#
# Processing row 384...
# Estimated input tokens (prompt): 584
# Estimated output tokens (response): 293
# Total estimated tokens (prompt + response): 877
# Row 384 processed in 12.01 seconds.
#
# Processing row 385...
# Estimated input tokens (prompt): 578
# Estimated output tokens (response): 278
# Total estimated tokens (prompt + response): 856
# Row 385 processed in 11.88 seconds.
#
# Processing row 386...
# Estimated input tokens (prompt): 570
# Estimated output tokens (response): 298
# Total estimated tokens (prompt + response): 868
# Row 386 processed in 13.61 seconds.
#
# Processing row 387...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 289
# Total estimated tokens (prompt + response): 857
# Row 387 processed in 11.91 seconds.
#
# Processing row 388...
# Estimated input tokens (prompt): 571
# Estimated output tokens (response): 285
# Total estimated tokens (prompt + response): 856
# Row 388 processed in 17.91 seconds.
#
# Processing row 389...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 233
# Total estimated tokens (prompt + response): 801
# Row 389 processed in 13.59 seconds.
#
# Processing row 390...
# Estimated input tokens (prompt): 572
# Estimated output tokens (response): 279
# Total estimated tokens (prompt + response): 851
# Row 390 processed in 13.66 seconds.
#
# Processing row 391...
# Estimated input tokens (prompt): 617
# Estimated output tokens (response): 319
# Total estimated tokens (prompt + response): 936
# Row 391 processed in 12.84 seconds.
#
# Processing row 392...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 274
# Total estimated tokens (prompt + response): 842
# Row 392 processed in 13.67 seconds.
#
# Processing row 393...
# Estimated input tokens (prompt): 577
# Estimated output tokens (response): 267
# Total estimated tokens (prompt + response): 844
# Row 393 processed in 7.22 seconds.
#
# Processing row 394...
# Estimated input tokens (prompt): 572
# Estimated output tokens (response): 282
# Total estimated tokens (prompt + response): 854
# Row 394 processed in 14.46 seconds.
#
# Processing row 395...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 259
# Total estimated tokens (prompt + response): 827
# Row 395 processed in 11.22 seconds.
#
# Processing row 396...
# Estimated input tokens (prompt): 638
# Estimated output tokens (response): 483
# Total estimated tokens (prompt + response): 1121
# Row 396 processed in 16.71 seconds.
#
# Processing row 397...
# Estimated input tokens (prompt): 630
# Estimated output tokens (response): 533
# Total estimated tokens (prompt + response): 1163
# Row 397 processed in 18.28 seconds.
#
# Processing row 398...
# Estimated input tokens (prompt): 657
# Estimated output tokens (response): 474
# Total estimated tokens (prompt + response): 1131
# Row 398 processed in 16.18 seconds.
#
# Processing row 399...
# Estimated input tokens (prompt): 634
# Estimated output tokens (response): 373
# Total estimated tokens (prompt + response): 1007
# Row 399 processed in 16.76 seconds.
#
# Processing row 400...
# Estimated input tokens (prompt): 575
# Estimated output tokens (response): 268
# Total estimated tokens (prompt + response): 843
# Row 400 processed in 10.09 seconds.
#
# Processing row 401...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 271
# Total estimated tokens (prompt + response): 839
# Row 401 processed in 25.19 seconds.
#
# Processing row 402...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 447
# Total estimated tokens (prompt + response): 1015
# Row 402 processed in 13.65 seconds.
#
# Processing row 403...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 250
# Total estimated tokens (prompt + response): 818
# Row 403 processed in 8.03 seconds.
#
# Processing row 404...
# Estimated input tokens (prompt): 609
# Estimated output tokens (response): 278
# Total estimated tokens (prompt + response): 887
# JSON decoding failed: Expecting property name enclosed in double quotes: line 16 column 1 (char 846)
# Raw output:
# {
#   "core_issue": "The feedback is positive, highlighting excellent service, room standards, and unique spiritual support provided by nuns.",
#   "summary": "Excellent service, rooms, spiritual care.",
#   "ward_block_room": "Wards (general)",
#   "department": "Chapel",
#   "hospital_condition": "Not found in feedback",
#   "doctors": "Not found in feedback",
#   "nurses": "Not found in feedback",
#   "support_admin_staff": "Nuns who go around the wards.",
#   "staff_names": "Not found in feedback",
#   "treatments_procedures": "Prayers and holy communion for Catholic patients.",
#   "service_quality": "The hospital is praised for its service, described as one of the 'nicest hospitals around'.",
#   "waiting_time": "Not found in feedback",
#   "food_other_quality": "The 'standard of rooms' is mentioned positively.",
#   "rude_staff": "Not found in feedback",
# so  "delays_poor_management": "Not found in feedback",
#   "unfair_rules": "Not found in feedback",
#   "explicitly_negative_description": "Not found in feedback",
#   "profit_motive_unnecessary_procedures": "Not found in feedback",
#   "fraudulent_activity": "Not found in feedback"
# }
#
# Row 404 processed in 17.04 seconds.
#
# Processing row 405...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 440
# Total estimated tokens (prompt + response): 1008
# Row 405 processed in 11.77 seconds.
#
# Processing row 406...
# Estimated input tokens (prompt): 819
# Estimated output tokens (response): 634
# Total estimated tokens (prompt + response): 1453
# Row 406 processed in 22.28 seconds.
#
# Processing row 407...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 262
# Total estimated tokens (prompt + response): 830
# Row 407 processed in 16.93 seconds.
#
# Processing row 408...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 271
# Total estimated tokens (prompt + response): 839
# Row 408 processed in 16.21 seconds.
#
# Processing row 409...
# Estimated input tokens (prompt): 572
# Estimated output tokens (response): 247
# Total estimated tokens (prompt + response): 819
# Row 409 processed in 12.68 seconds.
#
# Processing row 410...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 266
# Total estimated tokens (prompt + response): 834
# Row 410 processed in 12.60 seconds.
#
# Processing row 411...
# Estimated input tokens (prompt): 583
# Estimated output tokens (response): 299
# Total estimated tokens (prompt + response): 882
# Row 411 processed in 14.91 seconds.
#
# Processing row 412...
# Estimated input tokens (prompt): 645
# Estimated output tokens (response): 373
# Total estimated tokens (prompt + response): 1018
# Row 412 processed in 16.75 seconds.
#
# Processing row 413...
# Estimated input tokens (prompt): 578
# Estimated output tokens (response): 298
# Total estimated tokens (prompt + response): 876
# Row 413 processed in 13.79 seconds.
#
# Processing row 414...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 261
# Total estimated tokens (prompt + response): 829
# Row 414 processed in 9.88 seconds.
#
# Processing row 415...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 266
# Total estimated tokens (prompt + response): 834
# Row 415 processed in 9.57 seconds.
#
# Processing row 416...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 270
# Total estimated tokens (prompt + response): 838
# Row 416 processed in 11.58 seconds.
#
# Processing row 417...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 268
# Total estimated tokens (prompt + response): 836
# Row 417 processed in 9.68 seconds.
#
# Processing row 418...
# Estimated input tokens (prompt): 605
# Estimated output tokens (response): 311
# Total estimated tokens (prompt + response): 916
# Row 418 processed in 17.24 seconds.
#
# Processing row 419...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 257
# Total estimated tokens (prompt + response): 825
# Row 419 processed in 11.77 seconds.
#
# Processing row 420...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 263
# Total estimated tokens (prompt + response): 831
# Row 420 processed in 11.71 seconds.
#
# Processing row 421...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 247
# Total estimated tokens (prompt + response): 815
# Row 421 processed in 13.98 seconds.
#
# Processing row 422...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 438
# Total estimated tokens (prompt + response): 1006
# Row 422 processed in 21.09 seconds.
#
# Processing row 423...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 241
# Total estimated tokens (prompt + response): 809
# Row 423 processed in 10.29 seconds.
#
# Processing row 424...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 251
# Total estimated tokens (prompt + response): 819
# Row 424 processed in 11.35 seconds.
#
# Processing row 425...
# Estimated input tokens (prompt): 572
# Estimated output tokens (response): 282
# Total estimated tokens (prompt + response): 854
# Row 425 processed in 19.82 seconds.
#
# Processing row 426...
# Estimated input tokens (prompt): 571
# Estimated output tokens (response): 288
# Total estimated tokens (prompt + response): 859
# Row 426 processed in 17.51 seconds.
#
# Processing row 427...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 264
# Total estimated tokens (prompt + response): 832
# Row 427 processed in 8.52 seconds.
#
# Processing row 428...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 262
# Total estimated tokens (prompt + response): 830
# Row 428 processed in 10.53 seconds.
#
# Processing row 429...
# Estimated input tokens (prompt): 618
# Estimated output tokens (response): 503
# Total estimated tokens (prompt + response): 1121
# Row 429 processed in 25.54 seconds.
#
# Processing row 430...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 266
# Total estimated tokens (prompt + response): 834
# Row 430 processed in 10.89 seconds.
#
# Processing row 431...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 438
# Total estimated tokens (prompt + response): 1006
# Row 431 processed in 10.23 seconds.
#
# Processing row 432...
# Estimated input tokens (prompt): 595
# Estimated output tokens (response): 375
# Total estimated tokens (prompt + response): 970
# Row 432 processed in 15.04 seconds.
#
# Processing row 433...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 395
# Total estimated tokens (prompt + response): 963
# Row 433 processed in 12.92 seconds.
#
# Processing row 434...
# Estimated input tokens (prompt): 573
# Estimated output tokens (response): 280
# Total estimated tokens (prompt + response): 853
# Row 434 processed in 13.31 seconds.
#
# Processing row 435...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 256
# Total estimated tokens (prompt + response): 824
# Row 435 processed in 11.70 seconds.
#
# Processing row 436...
# Estimated input tokens (prompt): 715
# Estimated output tokens (response): 621
# Total estimated tokens (prompt + response): 1336
# Row 436 processed in 14.15 seconds.
#
# Processing row 437...
# Estimated input tokens (prompt): 656
# Estimated output tokens (response): 302
# Total estimated tokens (prompt + response): 958
# Row 437 processed in 13.14 seconds.
#
# Processing row 438...
# Estimated input tokens (prompt): 585
# Estimated output tokens (response): 302
# Total estimated tokens (prompt + response): 887
# Row 438 processed in 12.08 seconds.
#
# Processing row 439...
# Estimated input tokens (prompt): 585
# Estimated output tokens (response): 294
# Total estimated tokens (prompt + response): 879
# Row 439 processed in 11.69 seconds.
#
# Processing row 440...
# Estimated input tokens (prompt): 587
# Estimated output tokens (response): 266
# Total estimated tokens (prompt + response): 853
# Row 440 processed in 13.62 seconds.
#
# Processing row 441...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 247
# Total estimated tokens (prompt + response): 815
# Row 441 processed in 15.86 seconds.
#
# Processing row 442...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 250
# Total estimated tokens (prompt + response): 818
# Row 442 processed in 12.37 seconds.
