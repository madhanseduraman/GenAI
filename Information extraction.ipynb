# %%
import base64
import pandas as pd
import json
import vertexai
import tiktoken # A popular tokenizer, though not directly from google-generativeai
import time
from vertexai.generative_models import GenerativeModel, Part, SafetySetting
import warnings
warnings.filterwarnings("ignore")

project_name = !(gcloud config get-value core/project)
project_name = project_name[0]

# %%
#Gemini
class LLM_model:
    def __init__(self, project, location, model_name):
        self.project = project
        self.location = location
        self.model_name = model_name
        self.generation_config = {
            "max_output_tokens": 8192,
            "temperature": 1,
            "top_p": 0.95,
        }
        self.safety_settings = [
            SafetySetting(
                category=SafetySetting.HarmCategory.HARM_CATEGORY_HATE_SPEECH,
                threshold=SafetySetting.HarmBlockThreshold.OFF
            ),
            SafetySetting(
                category=SafetySetting.HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT,
                threshold=SafetySetting.HarmBlockThreshold.OFF
            ),
            SafetySetting(
                category=SafetySetting.HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT,
                threshold=SafetySetting.HarmBlockThreshold.OFF
            ),
            SafetySetting(
                category=SafetySetting.HarmCategory.HARM_CATEGORY_HARASSMENT,
                threshold=SafetySetting.HarmBlockThreshold.OFF
            ),
        ]
        vertexai.init(project=self.project, location=self.location)
        self.model = GenerativeModel(self.model_name)

    def complete(self, text):
        chat = self.model.start_chat()
        result=chat.send_message([text],
                                 generation_config=self.generation_config,
                                 safety_settings=self.safety_settings
        )
        text_result=result.candidates[0].content.parts[0].text
        return text_result
# Example usage:
llm_gemini = LLM_model(project_name, 
                       "us-central1", 
                       "gemini-2.5-pro")

# %%
#example_text = "tell me about Prudential Insurance"
#gemini_generated_text = llm_gemini.complete(example_text)
#print(gemini_generated_text.strip())
#gemini_generated_text.

# %%
def sentiment_analysis(feedback, llm, llm_type='gemini'):
    
    # Configure the sentiment analysis prompt or question
    prompt = (
        """
        Role: You are an AI Specialist analysing customer feebdack from Google reviews. Your role is to understand the given context
        and perform the task provided as appropriately.
        
        Context: The feedbacks are given by the patients or the bystander of patients who went for the treatment to the hospital.
        
        Task: 
        1. Analyze the sentiment of the customer feedback if it’s positive, negative, or neutral. 
        2. If the feedback is neither positive nor negative but just neutrally stating an info or suggestion, 
        or is a non-meaningful feedback like 'Yes', 'No', 'Nil', 'na', 'N:A', 'N/a', 'n/a', 
        'not applicable' or 'no comment', the sentiment is neutral. 
        3. If sentiment is positive, return 'Positive'. 
        4. If sentiment is negative, return 'Negative'.
        5. If sentiment is neutral, return 'Neutral'. Do not include other words or explanation.
        
        This is the customer feedback: {feedback}. 
        
        Here are examples in this format Feedback-Sentiment:
        Its convenient, easy, fast: Positive.
        Nil: Neutral, 
        Customer service not professional-Negative.
        
    """
    )
    try:
        messages = [
            {"role": "specialist", "content": prompt}
        ]
        # result = llm.invoke(messages).content
        if llm_type=='gemini':
            result = llm.complete(prompt)
        else:
            result = llm.complete(prompt).text
        return result.strip()  # Using strip() to remove leading/trailing whitespace
    except Exception as e:
        print(f"Error processing row: {e}")
        return np.nan

# %%
def sentiment_analysis(feedback, llm, llm_type='gemini'):
    prompt = f"""
    Role: You are an AI Specialist analysing customer feedback from Google reviews. Your role is to understand the given context
    and perform the task provided as appropriately.

    Context: The feedbacks are given by the patients or the bystanders of patients who went for treatment to the hospital.

    Task:
    1. Analyze the sentiment of the customer feedback if it’s positive, negative, or neutral.
    2. If the feedback is neither positive nor negative but just neutrally stating an info or suggestion,
       or is a non-meaningful feedback like 'Yes', 'No', 'Nil', 'na', 'N:A', 'N/a', 'n/a',
       'not applicable' or 'no comment', the sentiment is neutral.
    3. If sentiment is positive, return 'Positive'.
    4. If sentiment is negative, return 'Negative'.
    5. If sentiment is neutral, return 'Neutral'. Do not include other words or explanation.

    This is the customer feedback: {feedback}

    Examples:
    Its convenient, easy, fast: Positive.
    Nil: Neutral.
    Customer service not professional: Negative.
    
    Output:
    1. provide the classification of sentiment - Positive, Negative, Neutral   
    
    """

    try:
        if llm_type == 'gemini':
            result = llm.complete(prompt)
        else:
            result = llm.complete(prompt).text
        return result.strip()
    except Exception as e:
        print(f"Error processing row: {e}")
        return None  # Use None unless you're sure np.nan is needed and numpy is imported

# %%
example_text="Helpful customer service officer"
example_output=sentiment_analysis(example_text, llm_gemini)
print(example_output)
# Out:
# Positive

# %%
def Information_extraction(feedback, llm, llm_type='gemini'):
    prompt = f"""
    Role: You are an AI Specialist analysing customer feedback from Google reviews. Your role is to understand the given context
    and perform the task provided as appropriately.

    Context: The feedbacks are given by the patients or the bystanders of patients who went for treatment to the hospital.

    Task:
    1. Analyze the feedback from the below mentioned topics and extract the information and provide as an output. If 
    the topics not found, mention as not found.
    1.1 From the whole feedback, extract the core issue, summarize the patient experience in 5 words and then
    follow the below tasks.
    2. Hospital Topic: 
        a. Does the review mention a specific ward, block or room number? if yes, extract it.
        b. Does the review mention about the department e.g: Endoscopy, Pharmacy, etc., if yes, extract it.
        c. Does the review describe whether the hospital is old, upgraded or modern?
    3. Staff & Service Topic:
        a. Does the review mention Doctors? if yes, extract it.
        b. Does the review mention nurses? if yes, extract it.
        c. Does the review mention support or admin staff? if yes, extract it.
        d. Does the review mention specific staff names? Extract them.
    4. Patient Experience:
        a. Does the review mention specific treatments or medical procedures (e.g. delivery, surgery)?
        b. What aspects of service quality are highlighted (e.g. attentiveness, professionalism, rudeness)?
        c. Does the reviewer mention waiting time? if yes, how long?
        d. Does the review mention food quality or any other quality (e.g. bedsheets, bathroom or cafeteria)?
    5. Complaints & Negative Aspects:
        a. Does the reviewer mention rude staff? Extract the details.
        b. Does the reviewer mention delays, long queues or poor management? Extract waiting times if given.
        c. Does the review mention unfair rules or inconsistent policies (e.g. visitor entry)?
        d. Does the reviewer explicitly call the hospital horrible, worst, terrifying, or disappointing?
        e. Does the review suggest profit motive or unnecessary procedures?
        f. Does the reviewer perceive fraudulent activity from the hospital?
    6. For each of the topics and its sub questions, provide output. If not found, mention as "Not found in feedback"

    This is the customer feedback: {feedback}

    Output:
    1. Provide the output in key-value pairs as JSON.
    2. Keys are only the core issue, summary, and the sub-questions (topic names not required).
    3. Values are the extracted output from the feedback.
    """

    # Token estimation
    try:
        import tiktoken
        enc = tiktoken.get_encoding("cl100k_base")
        prompt_tokens = len(enc.encode(prompt))
        print(f"Estimated input tokens (prompt): {prompt_tokens}")
    except ImportError:
        print("Install 'tiktoken' (pip install tiktoken) for token estimation.")
        prompt_tokens = -1

    # LLM completion
    try:
        if llm_type == 'gemini':
            result = llm.complete(prompt)
        else:
            result = llm.complete(prompt).text
        result = result.strip()
    except Exception as e:
        print(f"Error processing row: {e}")
        return None

    # Token estimation for response
    try:
        response_tokens = len(enc.encode(result))
        print(f"Estimated output tokens (response): {response_tokens}")
    except Exception:
        response_tokens = -1

    # Total token count
    if prompt_tokens != -1 and response_tokens != -1:
        total_estimated_tokens = prompt_tokens + response_tokens
        print(f"Total estimated tokens (prompt + response): {total_estimated_tokens}")

    return result

# %%
feedback = """
Gleneagles Hospital overcharged us during childbirth by admitting our newborn to the NICU. When the baby was transferred to KK Hospital, they discharged the infant immediately. During the 1 day stay in NICU, our baby was subjected to repeated and seemingly unnecessary needle procedures. Additionally, the nursing staff fed the baby a formula that caused vomiting. Although we requested a change in formula, it was only temporarily adjusted — and was later switched back to the original formula after a nurse shift change.

"""

# %%
#example_output=Information_extraction(feedback, llm_gemini)
#print(example_output)

# %%
df_Gleangles = pd.read_excel("Gleneagles Hospitalv2.xlsx")

# %%
df_Gleangles.head().transpose()
# Out:
#                                                                                      0  \
# query                                            0x31da1a2024d17459:0x2559534cd241d05c
# name                                                               Gleneagles Hospital
# google_id                                        0x31da1a2024d17459:0x2559534cd241d05c
# place_id                                                   ChIJWXTRJCAa2jERXNBB0kxTWSU
# location_link                        https://www.google.com/maps/place/Gleneagles+H...
# reviews_link                         https://search.google.com/local/reviews?placei...
# reviews                                                                            448
# rating                                                                             3.5
# review_id                            Ci9DQUlRQUNvZENodHljRjlvT25wRVNtWnVhbHBRZFdwdm...
# review_pagination_id                 CAESY0NBRVFBUnBFUTJwRlNVRlNTWEJEWjI5QlVEY3lSMk...
# author_link                          https://www.google.com/maps/contrib/1129231924...
# author_title                                                                       K P
# author_id                                                        112923192474907858798
# author_image                         https://lh3.googleusercontent.com/a/ACg8ocKFJS...
# author_reviews_count                                                                28
# author_ratings_count                                                                 4
# review_text                            Incredible caring staff, cleanliness and qualit
# review_img_urls                                                                    NaN
# review_img_url                                                                     NaN
# review_questions                                                                   NaN
# review_photo_ids                                                                   NaN
# owner_answer                         Dear K P,\nThank you for your kind compliments...
# owner_answer_timestamp                                                    1755828345.0
# owner_answer_timestamp_datetime_utc                                08/22/2025 02:05:45
# review_link                          https://www.google.com/maps/reviews/data=!4m8!...
# review_rating                                                                        5
# review_timestamp                                                            1755681317
# review_datetime_utc                                                08/20/2025 09:15:17
# review_likes                                                                       NaN
# reviews_id                                                         2691273841740730460
# reviews_per_score_1                                                                110
# reviews_per_score_2                                                                 28
# reviews_per_score_3                                                                 40
# reviews_per_score_4                                                                 58
# reviews_per_score_5                                                                212
#
#                                                                                      1  \
# query                                            0x31da1a2024d17459:0x2559534cd241d05c
# name                                                               Gleneagles Hospital
# google_id                                        0x31da1a2024d17459:0x2559534cd241d05c
# place_id                                                   ChIJWXTRJCAa2jERXNBB0kxTWSU
# location_link                        https://www.google.com/maps/place/Gleneagles+H...
# reviews_link                         https://search.google.com/local/reviews?placei...
# reviews                                                                            448
# rating                                                                             3.5
# review_id                            Ci9DQUlRQUNvZENodHljRjlvT2pKS2NYZEZhM1psVmtaRU...
# review_pagination_id                 CAESYENBRVFBaHBDUTJrNFNVRlNTVzVEWjI5QlVEY3lSMk...
# author_link                          https://www.google.com/maps/contrib/1034916234...
# author_title                                                                      CJ J
# author_id                                                        103491623424438316318
# author_image                         https://lh3.googleusercontent.com/a/ACg8ocKPxd...
# author_reviews_count                                                                 2
# author_ratings_count                                                                 0
# review_text                          Premium hospital, substandard service\n\nI wis...
# review_img_urls                                                                    NaN
# review_img_url                                                                     NaN
# review_questions                                                                   NaN
# review_photo_ids                                                                   NaN
# owner_answer                         Dear CJ J,\nThank you for taking the time to s...
# owner_answer_timestamp                                                    1755652589.0
# owner_answer_timestamp_datetime_utc                                08/20/2025 01:16:29
# review_link                          https://www.google.com/maps/reviews/data=!4m8!...
# review_rating                                                                        1
# review_timestamp                                                            1755580500
# review_datetime_utc                                                08/19/2025 05:15:00
# review_likes                                                                       NaN
# reviews_id                                                         2691273841740730460
# reviews_per_score_1                                                                110
# reviews_per_score_2                                                                 28
# reviews_per_score_3                                                                 40
# reviews_per_score_4                                                                 58
# reviews_per_score_5                                                                212
#
#                                                                                      2  \
# query                                            0x31da1a2024d17459:0x2559534cd241d05c
# name                                                               Gleneagles Hospital
# google_id                                        0x31da1a2024d17459:0x2559534cd241d05c
# place_id                                                   ChIJWXTRJCAa2jERXNBB0kxTWSU
# location_link                        https://www.google.com/maps/place/Gleneagles+H...
# reviews_link                         https://search.google.com/local/reviews?placei...
# reviews                                                                            448
# rating                                                                             3.5
# review_id                            Ci9DQUlRQUNvZENodHljRjlvT25sNFYyWlFWMk5JWm5Fd0...
# review_pagination_id                 CAESY0NBRVFBeHBFUTJwRlNVRlNTWEJEWjI5QlVEY3lSMl...
# author_link                          https://www.google.com/maps/contrib/1168888403...
# author_title                                                                  Ryan Sun
# author_id                                                        116888840300799112611
# author_image                         https://lh3.googleusercontent.com/a/ACg8ocJKXz...
# author_reviews_count                                                                 2
# author_ratings_count                                                                 0
# review_text                                                      Test writing a review
# review_img_urls                                                                    NaN
# review_img_url                                                                     NaN
# review_questions                                                                   NaN
# review_photo_ids                                                                   NaN
# owner_answer                         Dear Ryan Sun ,\nThank you for taking the time...
# owner_answer_timestamp                                                    1755652030.0
# owner_answer_timestamp_datetime_utc                                08/20/2025 01:07:10
# review_link                          https://www.google.com/maps/reviews/data=!4m8!...
# review_rating                                                                        5
# review_timestamp                                                            1755451910
# review_datetime_utc                                                08/17/2025 17:31:50
# review_likes                                                                       NaN
# reviews_id                                                         2691273841740730460
# reviews_per_score_1                                                                110
# reviews_per_score_2                                                                 28
# reviews_per_score_3                                                                 40
# reviews_per_score_4                                                                 58
# reviews_per_score_5                                                                212
#
#                                                                                      3  \
# query                                            0x31da1a2024d17459:0x2559534cd241d05c
# name                                                               Gleneagles Hospital
# google_id                                        0x31da1a2024d17459:0x2559534cd241d05c
# place_id                                                   ChIJWXTRJCAa2jERXNBB0kxTWSU
# location_link                        https://www.google.com/maps/place/Gleneagles+H...
# reviews_link                         https://search.google.com/local/reviews?placei...
# reviews                                                                            448
# rating                                                                             3.5
# review_id                            Ci9DQUlRQUNvZENodHljRjlvT2xSWGJHOTRXR280V2xsaG...
# review_pagination_id                 CAESYENBRVFCQnBDUTJrNFNVRlNTVzVEWjI5QlVEY3lSMl...
# author_link                          https://www.google.com/maps/contrib/1035502646...
# author_title                                                               Abdul Kadir
# author_id                                                        103550264671586095542
# author_image                         https://lh3.googleusercontent.com/a-/ALV-UjX49...
# author_reviews_count                                                                 1
# author_ratings_count                                                                 2
# review_text                                                                        NaN
# review_img_urls                                                                    NaN
# review_img_url                                                                     NaN
# review_questions                                                                   NaN
# review_photo_ids                                                                   NaN
# owner_answer                         Dear Abdul Kadir,\nThank you for taking the ti...
# owner_answer_timestamp                                                    1755226614.0
# owner_answer_timestamp_datetime_utc                                08/15/2025 02:56:54
# review_link                          https://www.google.com/maps/reviews/data=!4m8!...
# review_rating                                                                        5
# review_timestamp                                                            1755222088
# review_datetime_utc                                                08/15/2025 01:41:28
# review_likes                                                                       NaN
# reviews_id                                                         2691273841740730460
# reviews_per_score_1                                                                110
# reviews_per_score_2                                                                 28
# reviews_per_score_3                                                                 40
# reviews_per_score_4                                                                 58
# reviews_per_score_5                                                                212
#
#                                                                                      4
# query                                            0x31da1a2024d17459:0x2559534cd241d05c
# name                                                               Gleneagles Hospital
# google_id                                        0x31da1a2024d17459:0x2559534cd241d05c
# place_id                                                   ChIJWXTRJCAa2jERXNBB0kxTWSU
# location_link                        https://www.google.com/maps/place/Gleneagles+H...
# reviews_link                         https://search.google.com/local/reviews?placei...
# reviews                                                                            448
# rating                                                                             3.5
# review_id                            Ci9DQUlRQUNvZENodHljRjlvT2pCSGRGZEpWbk5KTTFKQ1...
# review_pagination_id                 CAESY0NBRVFCUnBFUTJwRlNVRlNTWEJEWjI5QlVEY3lSMl...
# author_link                          https://www.google.com/maps/contrib/1026153367...
# author_title                                                              Jonathan Lim
# author_id                                                        102615336774422836496
# author_image                         https://lh3.googleusercontent.com/a/ACg8ocL3TQ...
# author_reviews_count                                                                 1
# author_ratings_count                                                                 0
# review_text                          Hospital facility is good. however, it took me...
# review_img_urls                                                                    NaN
# review_img_url                                                                     NaN
# review_questions                                                                   NaN
# review_photo_ids                                                                   NaN
# owner_answer                         Dear Jonathan Lim,\nThank you for sharing your...
# owner_answer_timestamp                                                    1754286242.0
# owner_answer_timestamp_datetime_utc                                08/04/2025 05:44:02
# review_link                          https://www.google.com/maps/reviews/data=!4m8!...
# review_rating                                                                        3
# review_timestamp                                                            1754266556
# review_datetime_utc                                                08/04/2025 00:15:56
# review_likes                                                                       NaN
# reviews_id                                                         2691273841740730460
# reviews_per_score_1                                                                110
# reviews_per_score_2                                                                 28
# reviews_per_score_3                                                                 40
# reviews_per_score_4                                                                 58
# reviews_per_score_5                                                                212

# %%
df_Gleangles_reviewtext = df_Gleangles.review_text

# %%
df_Gleangles_reviewtext.iloc[1:10]
# Out:
# 1    Premium hospital, substandard service\n\nI wis...
# 2                                Test writing a review
# 3                                                  NaN
# 4    Hospital facility is good. however, it took me...
# 5                                                  NaN
# 6    I had my first surgery here 11 years ago, and ...
# 7    My very first hospitalization experience was a...
# 8    Bad experience for me, the hospital staff is r...
# 9    Gleneagles Hospital overcharged us during chil...
# Name: review_text, dtype: object

# %%
import json
import fitz  # PyMuPDF
counter = 0
# Assuming df_Gleangles_reviewtext and Information_extraction are already defined
with open("review_output_Gleneagles.txt", "w", encoding="utf-8") as f:
    for idx,review in enumerate(df_Gleangles_reviewtext,start=0):
        
        start_time = time.time()
        print(f"Processing row {idx}...")

        example_output = Information_extraction(review, llm_gemini)
        #o = example_output.replace('```', '')
        
        #cleaned_output = o.replace('json', '')
        
        
        try:
            # If the output contains extra text before/after JSON, isolate the JSON part
            start = example_output.find('{')
            end = example_output.rfind('}') + 1
            json_str = example_output[start:end]

            # Parse the JSON
            ie_output_dict = json.loads(json_str)
        except json.JSONDecodeError as e:
            print("JSON decoding failed:", e)
            print("Raw output:", example_output)
            ie_output_dict = None

        
        f.write("Original Review:\n")
        f.write(str(review) + "\n")
        f.write("Extracted Information:\n")
        f.write(json.dumps(ie_output_dict, indent=4))
        f.write("\n---------------------------------------------------\n")

        f.write("Next Review ########################################\n\n")
        

        elapsed_time = time.time() - start_time
        print(f"Row {idx} processed in {elapsed_time:.2f} seconds.\n")
# Out:
# Processing row 0...
# Estimated input tokens (prompt): 575
# Estimated output tokens (response): 306
# Total estimated tokens (prompt + response): 881
# Row 0 processed in 11.68 seconds.
#
# Processing row 1...
# Estimated input tokens (prompt): 1017
# Estimated output tokens (response): 577
# Total estimated tokens (prompt + response): 1594
# Row 1 processed in 18.10 seconds.
#
# Processing row 2...
# Estimated input tokens (prompt): 571
# Estimated output tokens (response): 289
# Total estimated tokens (prompt + response): 860
# Row 2 processed in 18.59 seconds.
#
# Processing row 3...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 249
# Total estimated tokens (prompt + response): 817
# Row 3 processed in 9.25 seconds.
#
# Processing row 4...
# Estimated input tokens (prompt): 605
# Estimated output tokens (response): 542
# Total estimated tokens (prompt + response): 1147
# Row 4 processed in 19.30 seconds.
#
# Processing row 5...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 246
# Total estimated tokens (prompt + response): 814
# Row 5 processed in 11.65 seconds.
#
# Processing row 6...
# Estimated input tokens (prompt): 777
# Estimated output tokens (response): 305
# Total estimated tokens (prompt + response): 1082
# Row 6 processed in 15.40 seconds.
#
# Processing row 7...
# Estimated input tokens (prompt): 756
# Estimated output tokens (response): 359
# Total estimated tokens (prompt + response): 1115
# Row 7 processed in 16.42 seconds.
#
# Processing row 8...
# Estimated input tokens (prompt): 630
# Estimated output tokens (response): 350
# Total estimated tokens (prompt + response): 980
# Row 8 processed in 14.66 seconds.
#
# Processing row 9...
# Estimated input tokens (prompt): 665
# Estimated output tokens (response): 471
# Total estimated tokens (prompt + response): 1136
# Row 9 processed in 19.18 seconds.
#
# Processing row 10...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 438
# Total estimated tokens (prompt + response): 1006
# Row 10 processed in 13.34 seconds.
#
# Processing row 11...
# Estimated input tokens (prompt): 707
# Estimated output tokens (response): 317
# Total estimated tokens (prompt + response): 1024
# Row 11 processed in 11.93 seconds.
#
# Processing row 12...
# Estimated input tokens (prompt): 944
# Estimated output tokens (response): 696
# Total estimated tokens (prompt + response): 1640
# Row 12 processed in 22.04 seconds.
#
# Processing row 13...
# Estimated input tokens (prompt): 695
# Estimated output tokens (response): 502
# Total estimated tokens (prompt + response): 1197
# Row 13 processed in 19.90 seconds.
#
# Processing row 14...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 263
# Total estimated tokens (prompt + response): 831
# Row 14 processed in 11.80 seconds.
#
# Processing row 15...
# Estimated input tokens (prompt): 663
# Estimated output tokens (response): 342
# Total estimated tokens (prompt + response): 1005
# Row 15 processed in 18.51 seconds.
#
# Processing row 16...
# Estimated input tokens (prompt): 648
# Estimated output tokens (response): 306
# Total estimated tokens (prompt + response): 954
# Row 16 processed in 16.67 seconds.
#
# Processing row 17...
# Estimated input tokens (prompt): 641
# Estimated output tokens (response): 410
# Total estimated tokens (prompt + response): 1051
# Row 17 processed in 14.55 seconds.
#
# Processing row 18...
# Estimated input tokens (prompt): 621
# Estimated output tokens (response): 323
# Total estimated tokens (prompt + response): 944
# Row 18 processed in 12.03 seconds.
#
# Processing row 19...
# Estimated input tokens (prompt): 785
# Estimated output tokens (response): 582
# Total estimated tokens (prompt + response): 1367
# Row 19 processed in 17.95 seconds.
#
# Processing row 20...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 253
# Total estimated tokens (prompt + response): 821
# Row 20 processed in 10.67 seconds.
#
# Processing row 21...
# Estimated input tokens (prompt): 823
# Estimated output tokens (response): 344
# Total estimated tokens (prompt + response): 1167
# Row 21 processed in 19.00 seconds.
#
# Processing row 22...
# Estimated input tokens (prompt): 636
# Estimated output tokens (response): 312
# Total estimated tokens (prompt + response): 948
# Row 22 processed in 12.58 seconds.
#
# Processing row 23...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 249
# Total estimated tokens (prompt + response): 817
# Row 23 processed in 9.42 seconds.
#
# Processing row 24...
# Estimated input tokens (prompt): 592
# Estimated output tokens (response): 298
# Total estimated tokens (prompt + response): 890
# Row 24 processed in 13.34 seconds.
#
# Processing row 25...
# Estimated input tokens (prompt): 651
# Estimated output tokens (response): 470
# Total estimated tokens (prompt + response): 1121
# Row 25 processed in 14.90 seconds.
#
# Processing row 26...
# Estimated input tokens (prompt): 643
# Estimated output tokens (response): 403
# Total estimated tokens (prompt + response): 1046
# Row 26 processed in 31.07 seconds.
#
# Processing row 27...
# Estimated input tokens (prompt): 737
# Estimated output tokens (response): 346
# Total estimated tokens (prompt + response): 1083
# Row 27 processed in 14.06 seconds.
#
# Processing row 28...
# Estimated input tokens (prompt): 786
# Estimated output tokens (response): 401
# Total estimated tokens (prompt + response): 1187
# Row 28 processed in 15.42 seconds.
#
# Processing row 29...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 273
# Total estimated tokens (prompt + response): 841
# Row 29 processed in 12.78 seconds.
#
# Processing row 30...
# Estimated input tokens (prompt): 747
# Estimated output tokens (response): 342
# Total estimated tokens (prompt + response): 1089
# Row 30 processed in 12.84 seconds.
#
# Processing row 31...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 296
# Total estimated tokens (prompt + response): 864
# Row 31 processed in 14.90 seconds.
#
# Processing row 32...
# Estimated input tokens (prompt): 761
# Estimated output tokens (response): 438
# Total estimated tokens (prompt + response): 1199
# Row 32 processed in 13.06 seconds.
#
# Processing row 33...
# Estimated input tokens (prompt): 826
# Estimated output tokens (response): 496
# Total estimated tokens (prompt + response): 1322
# Row 33 processed in 14.37 seconds.
#
# Processing row 34...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 261
# Total estimated tokens (prompt + response): 829
# Row 34 processed in 10.00 seconds.
#
# Processing row 35...
# Estimated input tokens (prompt): 697
# Estimated output tokens (response): 290
# Total estimated tokens (prompt + response): 987
# JSON decoding failed: Expecting value: line 1 column 1 (char 0)
# Raw output: ```json
# {
#   "core_issue": "The feedback is an expression of heartfelt gratitude for the exceptional, kind, and compassionate care provided by specific staff members during a patient's stay.",
#   "summary": "Grateful for exceptional, compassionate care.",
#   "ward_block_room_number": "Ward 9 East",
#   "department_mention": "Not found in feedback",
#   "hospital_description": "Not found in feedback",
#   "doctors_mention": "Not found in feedback",
#   "nurses_mention": "Not found in feedback",
#   "support_admin_staff_mention": "Not found in feedback",
#   "specific_staff_names": "Jacqueline, Kevin, Anne, Kathleen and Prema",
#   "treatments_medical_procedures": "Not found in feedback",
#   "service_quality_highlighted": "Exceptional care, kindness, patience, consideration, attentive, thoughtful, going above and beyond, unwavering dedication, warmth, and compassion.",
#   "waiting_time": "Not found in feedback",
#   "food_or_other_quality": "Not found in feedback",
#   "rude_staff_details": "Not found in feedback",
#   "delays_long_queues_poor_management": "Not found in feedback",
#   "unfair_rules_inconsistent_policies": "Not found in feedback",
#   "explicitly_horrible_worst": "Not found in feedback",
# <x_bin_64>
# Row 35 processed in 14.99 seconds.
#
# Processing row 36...
# Estimated input tokens (prompt): 577
# Estimated output tokens (response): 279
# Total estimated tokens (prompt + response): 856
# Row 36 processed in 12.41 seconds.
#
# Processing row 37...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 290
# Total estimated tokens (prompt + response): 858
# Row 37 processed in 10.83 seconds.
#
# Processing row 38...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 237
# Total estimated tokens (prompt + response): 805
# Row 38 processed in 6.89 seconds.
#
# Processing row 39...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 256
# Total estimated tokens (prompt + response): 824
# Row 39 processed in 11.00 seconds.
#
# Processing row 40...
# Estimated input tokens (prompt): 625
# Estimated output tokens (response): 302
# Total estimated tokens (prompt + response): 927
# Row 40 processed in 12.95 seconds.
#
# Processing row 41...
# Estimated input tokens (prompt): 575
# Estimated output tokens (response): 311
# Total estimated tokens (prompt + response): 886
# Row 41 processed in 8.86 seconds.
#
# Processing row 42...
# Estimated input tokens (prompt): 932
# Estimated output tokens (response): 437
# Total estimated tokens (prompt + response): 1369
# Row 42 processed in 15.56 seconds.
#
# Processing row 43...
# Estimated input tokens (prompt): 582
# Estimated output tokens (response): 275
# Total estimated tokens (prompt + response): 857
# Row 43 processed in 9.88 seconds.
#
# Processing row 44...
# Estimated input tokens (prompt): 579
# Estimated output tokens (response): 282
# Total estimated tokens (prompt + response): 861
# Row 44 processed in 11.94 seconds.
#
# Processing row 45...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 237
# Total estimated tokens (prompt + response): 805
# Row 45 processed in 8.76 seconds.
#
# Processing row 46...
# Estimated input tokens (prompt): 583
# Estimated output tokens (response): 301
# Total estimated tokens (prompt + response): 884
# Row 46 processed in 12.38 seconds.
#
# Processing row 47...
# Estimated input tokens (prompt): 610
# Estimated output tokens (response): 485
# Total estimated tokens (prompt + response): 1095
# Row 47 processed in 16.31 seconds.
#
# Processing row 48...
# Estimated input tokens (prompt): 854
# Estimated output tokens (response): 509
# Total estimated tokens (prompt + response): 1363
# Row 48 processed in 17.15 seconds.
#
# Processing row 49...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 389
# Total estimated tokens (prompt + response): 957
# Row 49 processed in 14.24 seconds.
#
# Processing row 50...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 258
# Total estimated tokens (prompt + response): 826
# Row 50 processed in 10.18 seconds.
#
# Processing row 51...
# Estimated input tokens (prompt): 574
# Estimated output tokens (response): 273
# Total estimated tokens (prompt + response): 847
# Row 51 processed in 10.42 seconds.
#
# Processing row 52...
# Estimated input tokens (prompt): 1029
# Estimated output tokens (response): 824
# Total estimated tokens (prompt + response): 1853
# Row 52 processed in 31.09 seconds.
#
# Processing row 53...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 264
# Total estimated tokens (prompt + response): 832
# Row 53 processed in 9.76 seconds.
#
# Processing row 54...
# Estimated input tokens (prompt): 640
# Estimated output tokens (response): 292
# Total estimated tokens (prompt + response): 932
# Row 54 processed in 10.81 seconds.
#
# Processing row 55...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 289
# Total estimated tokens (prompt + response): 857
# Row 55 processed in 11.61 seconds.
#
# Processing row 56...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 266
# Total estimated tokens (prompt + response): 834
# Row 56 processed in 9.54 seconds.
#
# Processing row 57...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 262
# Total estimated tokens (prompt + response): 830
# Row 57 processed in 17.54 seconds.
#
# Processing row 58...
# Estimated input tokens (prompt): 849
# Estimated output tokens (response): 536
# Total estimated tokens (prompt + response): 1385
# Row 58 processed in 20.45 seconds.
#
# Processing row 59...
# Estimated input tokens (prompt): 623
# Estimated output tokens (response): 421
# Total estimated tokens (prompt + response): 1044
# Row 59 processed in 17.33 seconds.
#
# Processing row 60...
# Estimated input tokens (prompt): 676
# Estimated output tokens (response): 423
# Total estimated tokens (prompt + response): 1099
# Row 60 processed in 18.89 seconds.
#
# Processing row 61...
# Estimated input tokens (prompt): 591
# Estimated output tokens (response): 267
# Total estimated tokens (prompt + response): 858
# Row 61 processed in 10.74 seconds.
#
# Processing row 62...
# Estimated input tokens (prompt): 571
# Estimated output tokens (response): 250
# Total estimated tokens (prompt + response): 821
# Row 62 processed in 9.91 seconds.
#
# Processing row 63...
# Estimated input tokens (prompt): 622
# Estimated output tokens (response): 375
# Total estimated tokens (prompt + response): 997
# Row 63 processed in 15.26 seconds.
#
# Processing row 64...
# Estimated input tokens (prompt): 576
# Estimated output tokens (response): 260
# Total estimated tokens (prompt + response): 836
# Row 64 processed in 8.15 seconds.
#
# Processing row 65...
# Estimated input tokens (prompt): 574
# Estimated output tokens (response): 274
# Total estimated tokens (prompt + response): 848
# Row 65 processed in 8.74 seconds.
#
# Processing row 66...
# Estimated input tokens (prompt): 627
# Estimated output tokens (response): 330
# Total estimated tokens (prompt + response): 957
# Row 66 processed in 19.23 seconds.
#
# Processing row 67...
# Estimated input tokens (prompt): 788
# Estimated output tokens (response): 447
# Total estimated tokens (prompt + response): 1235
# Row 67 processed in 16.55 seconds.
#
# Processing row 68...
# Estimated input tokens (prompt): 655
# Estimated output tokens (response): 276
# Total estimated tokens (prompt + response): 931
# Row 68 processed in 17.99 seconds.
#
# Processing row 69...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 438
# Total estimated tokens (prompt + response): 1006
# Row 69 processed in 19.95 seconds.
#
# Processing row 70...
# Estimated input tokens (prompt): 584
# Estimated output tokens (response): 268
# Total estimated tokens (prompt + response): 852
# Row 70 processed in 15.07 seconds.
#
# Processing row 71...
# Estimated input tokens (prompt): 605
# Estimated output tokens (response): 379
# Total estimated tokens (prompt + response): 984
# Row 71 processed in 16.85 seconds.
#
# Processing row 72...
# Estimated input tokens (prompt): 641
# Estimated output tokens (response): 323
# Total estimated tokens (prompt + response): 964
# Row 72 processed in 14.82 seconds.
#
# Processing row 73...
# Estimated input tokens (prompt): 590
# Estimated output tokens (response): 314
# Total estimated tokens (prompt + response): 904
# Row 73 processed in 13.68 seconds.
#
# Processing row 74...
# Estimated input tokens (prompt): 579
# Estimated output tokens (response): 282
# Total estimated tokens (prompt + response): 861
# Row 74 processed in 16.44 seconds.
#
# Processing row 75...
# Estimated input tokens (prompt): 586
# Estimated output tokens (response): 472
# Total estimated tokens (prompt + response): 1058
# Row 75 processed in 17.04 seconds.
#
# Processing row 76...
# Estimated input tokens (prompt): 726
# Estimated output tokens (response): 435
# Total estimated tokens (prompt + response): 1161
# Row 76 processed in 17.51 seconds.
#
# Processing row 77...
# Estimated input tokens (prompt): 631
# Estimated output tokens (response): 345
# Total estimated tokens (prompt + response): 976
# Row 77 processed in 20.69 seconds.
#
# Processing row 78...
# Estimated input tokens (prompt): 573
# Estimated output tokens (response): 308
# Total estimated tokens (prompt + response): 881
# Row 78 processed in 19.51 seconds.
#
# Processing row 79...
# Estimated input tokens (prompt): 632
# Estimated output tokens (response): 354
# Total estimated tokens (prompt + response): 986
# Row 79 processed in 15.83 seconds.
#
# Processing row 80...
# Estimated input tokens (prompt): 574
# Estimated output tokens (response): 251
# Total estimated tokens (prompt + response): 825
# Row 80 processed in 12.72 seconds.
#
# Processing row 81...
# Estimated input tokens (prompt): 642
# Estimated output tokens (response): 324
# Total estimated tokens (prompt + response): 966
# Row 81 processed in 15.07 seconds.
#
# Processing row 82...
# Estimated input tokens (prompt): 784
# Estimated output tokens (response): 482
# Total estimated tokens (prompt + response): 1266
# Row 82 processed in 23.37 seconds.
#
# Processing row 83...
# Estimated input tokens (prompt): 625
# Estimated output tokens (response): 405
# Total estimated tokens (prompt + response): 1030
# Row 83 processed in 14.25 seconds.
#
# Processing row 84...
# Estimated input tokens (prompt): 860
# Estimated output tokens (response): 666
# Total estimated tokens (prompt + response): 1526
# Row 84 processed in 29.12 seconds.
#
# Processing row 85...
# Estimated input tokens (prompt): 646
# Estimated output tokens (response): 291
# Total estimated tokens (prompt + response): 937
# Row 85 processed in 15.81 seconds.
#
# Processing row 86...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 259
# Total estimated tokens (prompt + response): 827
# Row 86 processed in 9.17 seconds.
#
# Processing row 87...
# Estimated input tokens (prompt): 577
# Estimated output tokens (response): 296
# Total estimated tokens (prompt + response): 873
# Row 87 processed in 20.86 seconds.
#
# Processing row 88...
# Estimated input tokens (prompt): 583
# Estimated output tokens (response): 313
# Total estimated tokens (prompt + response): 896
# Row 88 processed in 13.75 seconds.
#
# Processing row 89...
# Estimated input tokens (prompt): 611
# Estimated output tokens (response): 293
# Total estimated tokens (prompt + response): 904
# Row 89 processed in 17.93 seconds.
#
# Processing row 90...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 438
# Total estimated tokens (prompt + response): 1006
# Row 90 processed in 11.11 seconds.
#
# Processing row 91...
# Estimated input tokens (prompt): 571
# Estimated output tokens (response): 269
# Total estimated tokens (prompt + response): 840
# Row 91 processed in 10.90 seconds.
#
# Processing row 92...
# Estimated input tokens (prompt): 572
# Estimated output tokens (response): 278
# Total estimated tokens (prompt + response): 850
# Row 92 processed in 10.11 seconds.
#
# Processing row 93...
# Estimated input tokens (prompt): 755
# Estimated output tokens (response): 487
# Total estimated tokens (prompt + response): 1242
# Row 93 processed in 18.24 seconds.
#
# Processing row 94...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 257
# Total estimated tokens (prompt + response): 825
# Row 94 processed in 10.51 seconds.
#
# Processing row 95...
# Estimated input tokens (prompt): 585
# Estimated output tokens (response): 338
# Total estimated tokens (prompt + response): 923
# Row 95 processed in 11.75 seconds.
#
# Processing row 96...
# Estimated input tokens (prompt): 572
# Estimated output tokens (response): 286
# Total estimated tokens (prompt + response): 858
# Row 96 processed in 11.90 seconds.
#
# Processing row 97...
# Estimated input tokens (prompt): 607
# Estimated output tokens (response): 300
# Total estimated tokens (prompt + response): 907
# Row 97 processed in 13.80 seconds.
#
# Processing row 98...
# Estimated input tokens (prompt): 1105
# Estimated output tokens (response): 820
# Total estimated tokens (prompt + response): 1925
# Row 98 processed in 28.47 seconds.
#
# Processing row 99...
# Estimated input tokens (prompt): 636
# Estimated output tokens (response): 377
# Total estimated tokens (prompt + response): 1013
# Row 99 processed in 15.22 seconds.
#
# Processing row 100...
# Estimated input tokens (prompt): 770
# Estimated output tokens (response): 595
# Total estimated tokens (prompt + response): 1365
# Row 100 processed in 18.33 seconds.
#
# Processing row 101...
# Estimated input tokens (prompt): 779
# Estimated output tokens (response): 609
# Total estimated tokens (prompt + response): 1388
# Row 101 processed in 21.98 seconds.
#
# Processing row 102...
# Estimated input tokens (prompt): 619
# Estimated output tokens (response): 333
# Total estimated tokens (prompt + response): 952
# Row 102 processed in 17.20 seconds.
#
# Processing row 103...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 266
# Total estimated tokens (prompt + response): 834
# Row 103 processed in 13.68 seconds.
#
# Processing row 104...
# Estimated input tokens (prompt): 645
# Estimated output tokens (response): 583
# Total estimated tokens (prompt + response): 1228
# Row 104 processed in 23.35 seconds.
#
# Processing row 105...
# Estimated input tokens (prompt): 663
# Estimated output tokens (response): 395
# Total estimated tokens (prompt + response): 1058
# Row 105 processed in 17.60 seconds.
#
# Processing row 106...
# Estimated input tokens (prompt): 595
# Estimated output tokens (response): 299
# Total estimated tokens (prompt + response): 894
# Row 106 processed in 10.05 seconds.
#
# Processing row 107...
# Estimated input tokens (prompt): 748
# Estimated output tokens (response): 402
# Total estimated tokens (prompt + response): 1150
# Row 107 processed in 17.58 seconds.
#
# Processing row 108...
# Estimated input tokens (prompt): 642
# Estimated output tokens (response): 332
# Total estimated tokens (prompt + response): 974
# Row 108 processed in 15.61 seconds.
#
# Processing row 109...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 235
# Total estimated tokens (prompt + response): 803
# Row 109 processed in 9.20 seconds.
#
# Processing row 110...
# Estimated input tokens (prompt): 750
# Estimated output tokens (response): 394
# Total estimated tokens (prompt + response): 1144
# Row 110 processed in 20.64 seconds.
#
# Processing row 111...
# Estimated input tokens (prompt): 705
# Estimated output tokens (response): 491
# Total estimated tokens (prompt + response): 1196
# Row 111 processed in 15.23 seconds.
#
# Processing row 112...
# Estimated input tokens (prompt): 640
# Estimated output tokens (response): 388
# Total estimated tokens (prompt + response): 1028
# Row 112 processed in 16.87 seconds.
#
# Processing row 113...
# Estimated input tokens (prompt): 649
# Estimated output tokens (response): 296
# Total estimated tokens (prompt + response): 945
# Row 113 processed in 15.89 seconds.
#
# Processing row 114...
# Estimated input tokens (prompt): 705
# Estimated output tokens (response): 329
# Total estimated tokens (prompt + response): 1034
# Row 114 processed in 16.41 seconds.
#
# Processing row 115...
# Estimated input tokens (prompt): 1137
# Estimated output tokens (response): 605
# Total estimated tokens (prompt + response): 1742
# Row 115 processed in 16.26 seconds.
#
# Processing row 116...
# Estimated input tokens (prompt): 632
# Estimated output tokens (response): 381
# Total estimated tokens (prompt + response): 1013
# Row 116 processed in 17.07 seconds.
#
# Processing row 117...
# Estimated input tokens (prompt): 594
# Estimated output tokens (response): 326
# Total estimated tokens (prompt + response): 920
# Row 117 processed in 12.82 seconds.
#
# Processing row 118...
# Estimated input tokens (prompt): 625
# Estimated output tokens (response): 360
# Total estimated tokens (prompt + response): 985
# Row 118 processed in 14.91 seconds.
#
# Processing row 119...
# Estimated input tokens (prompt): 799
# Estimated output tokens (response): 439
# Total estimated tokens (prompt + response): 1238
# Row 119 processed in 19.72 seconds.
#
# Processing row 120...
# Estimated input tokens (prompt): 582
# Estimated output tokens (response): 345
# Total estimated tokens (prompt + response): 927
# Row 120 processed in 13.30 seconds.
#
# Processing row 121...
# Estimated input tokens (prompt): 752
# Estimated output tokens (response): 556
# Total estimated tokens (prompt + response): 1308
# Row 121 processed in 18.62 seconds.
#
# Processing row 122...
# Estimated input tokens (prompt): 1135
# Estimated output tokens (response): 769
# Total estimated tokens (prompt + response): 1904
# Row 122 processed in 29.47 seconds.
#
# Processing row 123...
# Estimated input tokens (prompt): 1313
# Estimated output tokens (response): 674
# Total estimated tokens (prompt + response): 1987
# Row 123 processed in 22.14 seconds.
#
# Processing row 124...
# Estimated input tokens (prompt): 754
# Estimated output tokens (response): 558
# Total estimated tokens (prompt + response): 1312
# Row 124 processed in 18.40 seconds.
#
# Processing row 125...
# Estimated input tokens (prompt): 684
# Estimated output tokens (response): 292
# Total estimated tokens (prompt + response): 976
# Row 125 processed in 15.24 seconds.
#
# Processing row 126...
# Estimated input tokens (prompt): 616
# Estimated output tokens (response): 316
# Total estimated tokens (prompt + response): 932
# Row 126 processed in 16.04 seconds.
#
# Processing row 127...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 287
# Total estimated tokens (prompt + response): 855
# Row 127 processed in 11.45 seconds.
#
# Processing row 128...
# Estimated input tokens (prompt): 803
# Estimated output tokens (response): 489
# Total estimated tokens (prompt + response): 1292
# Row 128 processed in 18.07 seconds.
#
# Processing row 129...
# Estimated input tokens (prompt): 619
# Estimated output tokens (response): 318
# Total estimated tokens (prompt + response): 937
# Row 129 processed in 14.81 seconds.
#
# Processing row 130...
# Estimated input tokens (prompt): 574
# Estimated output tokens (response): 288
# Total estimated tokens (prompt + response): 862
# Row 130 processed in 11.54 seconds.
#
# Processing row 131...
# Estimated input tokens (prompt): 898
# Estimated output tokens (response): 614
# Total estimated tokens (prompt + response): 1512
# Row 131 processed in 23.92 seconds.
#
# Processing row 132...
# Estimated input tokens (prompt): 602
# Estimated output tokens (response): 318
# Total estimated tokens (prompt + response): 920
# Row 132 processed in 13.77 seconds.
#
# Processing row 133...
# Estimated input tokens (prompt): 641
# Estimated output tokens (response): 364
# Total estimated tokens (prompt + response): 1005
# Row 133 processed in 15.74 seconds.
#
# Processing row 134...
# Estimated input tokens (prompt): 842
# Estimated output tokens (response): 517
# Total estimated tokens (prompt + response): 1359
# Row 134 processed in 19.33 seconds.
#
# Processing row 135...
# Estimated input tokens (prompt): 615
# Estimated output tokens (response): 299
# Total estimated tokens (prompt + response): 914
# Row 135 processed in 12.22 seconds.
#
# Processing row 136...
# Estimated input tokens (prompt): 641
# Estimated output tokens (response): 400
# Total estimated tokens (prompt + response): 1041
# Row 136 processed in 15.80 seconds.
#
# Processing row 137...
# Estimated input tokens (prompt): 622
# Estimated output tokens (response): 357
# Total estimated tokens (prompt + response): 979
# Row 137 processed in 14.78 seconds.
#
# Processing row 138...
# Estimated input tokens (prompt): 570
# Estimated output tokens (response): 263
# Total estimated tokens (prompt + response): 833
# Row 138 processed in 12.30 seconds.
#
# Processing row 139...
# Estimated input tokens (prompt): 637
# Estimated output tokens (response): 315
# Total estimated tokens (prompt + response): 952
# Row 139 processed in 18.21 seconds.
#
# Processing row 140...
# Estimated input tokens (prompt): 922
# Estimated output tokens (response): 732
# Total estimated tokens (prompt + response): 1654
# Row 140 processed in 25.54 seconds.
#
# Processing row 141...
# Estimated input tokens (prompt): 637
# Estimated output tokens (response): 290
# Total estimated tokens (prompt + response): 927
# Row 141 processed in 11.64 seconds.
#
# Processing row 142...
# Estimated input tokens (prompt): 571
# Estimated output tokens (response): 269
# Total estimated tokens (prompt + response): 840
# Row 142 processed in 13.32 seconds.
#
# Processing row 143...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 247
# Total estimated tokens (prompt + response): 815
# Row 143 processed in 9.78 seconds.
#
# Processing row 144...
# Estimated input tokens (prompt): 699
# Estimated output tokens (response): 338
# Total estimated tokens (prompt + response): 1037
# Row 144 processed in 12.53 seconds.
#
# Processing row 145...
# Estimated input tokens (prompt): 573
# Estimated output tokens (response): 465
# Total estimated tokens (prompt + response): 1038
# Row 145 processed in 16.92 seconds.
#
# Processing row 146...
# Estimated input tokens (prompt): 589
# Estimated output tokens (response): 277
# Total estimated tokens (prompt + response): 866
# Row 146 processed in 8.40 seconds.
#
# Processing row 147...
# Estimated input tokens (prompt): 746
# Estimated output tokens (response): 402
# Total estimated tokens (prompt + response): 1148
# Row 147 processed in 20.43 seconds.
#
# Processing row 148...
# Estimated input tokens (prompt): 610
# Estimated output tokens (response): 326
# Total estimated tokens (prompt + response): 936
# Row 148 processed in 16.60 seconds.
#
# Processing row 149...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 257
# Total estimated tokens (prompt + response): 825
# Row 149 processed in 10.05 seconds.
#
# Processing row 150...
# Estimated input tokens (prompt): 699
# Estimated output tokens (response): 464
# Total estimated tokens (prompt + response): 1163
# Row 150 processed in 23.58 seconds.
#
# Processing row 151...
# Estimated input tokens (prompt): 678
# Estimated output tokens (response): 526
# Total estimated tokens (prompt + response): 1204
# Row 151 processed in 17.28 seconds.
#
# Processing row 152...
# Estimated input tokens (prompt): 615
# Estimated output tokens (response): 331
# Total estimated tokens (prompt + response): 946
# Row 152 processed in 15.28 seconds.
#
# Processing row 153...
# Estimated input tokens (prompt): 570
# Estimated output tokens (response): 310
# Total estimated tokens (prompt + response): 880
# Row 153 processed in 21.02 seconds.
#
# Processing row 154...
# Estimated input tokens (prompt): 570
# Estimated output tokens (response): 268
# Total estimated tokens (prompt + response): 838
# Row 154 processed in 17.54 seconds.
#
# Processing row 155...
# Estimated input tokens (prompt): 592
# Estimated output tokens (response): 294
# Total estimated tokens (prompt + response): 886
# Row 155 processed in 12.04 seconds.
#
# Processing row 156...
# Estimated input tokens (prompt): 570
# Estimated output tokens (response): 242
# Total estimated tokens (prompt + response): 812
# Row 156 processed in 8.85 seconds.
#
# Processing row 157...
# Estimated input tokens (prompt): 587
# Estimated output tokens (response): 318
# Total estimated tokens (prompt + response): 905
# Row 157 processed in 15.81 seconds.
#
# Processing row 158...
# Estimated input tokens (prompt): 637
# Estimated output tokens (response): 373
# Total estimated tokens (prompt + response): 1010
# Row 158 processed in 12.95 seconds.
#
# Processing row 159...
# Estimated input tokens (prompt): 628
# Estimated output tokens (response): 367
# Total estimated tokens (prompt + response): 995
# Row 159 processed in 15.07 seconds.
#
# Processing row 160...
# Estimated input tokens (prompt): 620
# Estimated output tokens (response): 376
# Total estimated tokens (prompt + response): 996
# Row 160 processed in 13.58 seconds.
#
# Processing row 161...
# Estimated input tokens (prompt): 621
# Estimated output tokens (response): 370
# Total estimated tokens (prompt + response): 991
# Row 161 processed in 18.39 seconds.
#
# Processing row 162...
# Estimated input tokens (prompt): 661
# Estimated output tokens (response): 338
# Total estimated tokens (prompt + response): 999
# Row 162 processed in 19.15 seconds.
#
# Processing row 163...
# Estimated input tokens (prompt): 588
# Estimated output tokens (response): 298
# Total estimated tokens (prompt + response): 886
# Row 163 processed in 11.65 seconds.
#
# Processing row 164...
# Estimated input tokens (prompt): 574
# Estimated output tokens (response): 243
# Total estimated tokens (prompt + response): 817
# Row 164 processed in 11.25 seconds.
#
# Processing row 165...
# Estimated input tokens (prompt): 598
# Estimated output tokens (response): 372
# Total estimated tokens (prompt + response): 970
# Row 165 processed in 16.99 seconds.
#
# Processing row 166...
# Estimated input tokens (prompt): 586
# Estimated output tokens (response): 255
# Total estimated tokens (prompt + response): 841
# Row 166 processed in 10.91 seconds.
#
# Processing row 167...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 253
# Total estimated tokens (prompt + response): 821
# Row 167 processed in 13.05 seconds.
#
# Processing row 168...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 250
# Total estimated tokens (prompt + response): 818
# Row 168 processed in 6.50 seconds.
#
# Processing row 169...
# Estimated input tokens (prompt): 635
# Estimated output tokens (response): 359
# Total estimated tokens (prompt + response): 994
# Row 169 processed in 15.55 seconds.
#
# Processing row 170...
# Estimated input tokens (prompt): 634
# Estimated output tokens (response): 380
# Total estimated tokens (prompt + response): 1014
# Row 170 processed in 15.40 seconds.
#
# Processing row 171...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 255
# Total estimated tokens (prompt + response): 823
# Row 171 processed in 9.67 seconds.
#
# Processing row 172...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 271
# Total estimated tokens (prompt + response): 839
# Row 172 processed in 10.24 seconds.
#
# Processing row 173...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 232
# Total estimated tokens (prompt + response): 800
# Row 173 processed in 10.29 seconds.
#
# Processing row 174...
# Estimated input tokens (prompt): 575
# Estimated output tokens (response): 289
# Total estimated tokens (prompt + response): 864
# Row 174 processed in 12.53 seconds.
#
# Processing row 175...
# Estimated input tokens (prompt): 638
# Estimated output tokens (response): 278
# Total estimated tokens (prompt + response): 916
# Row 175 processed in 16.93 seconds.
#
# Processing row 176...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 276
# Total estimated tokens (prompt + response): 844
# Row 176 processed in 9.68 seconds.
#
# Processing row 177...
# Estimated input tokens (prompt): 658
# Estimated output tokens (response): 416
# Total estimated tokens (prompt + response): 1074
# Row 177 processed in 19.71 seconds.
#
# Processing row 178...
# Estimated input tokens (prompt): 689
# Estimated output tokens (response): 357
# Total estimated tokens (prompt + response): 1046
# Row 178 processed in 13.49 seconds.
#
# Processing row 179...
# Estimated input tokens (prompt): 774
# Estimated output tokens (response): 411
# Total estimated tokens (prompt + response): 1185
# Row 179 processed in 22.30 seconds.
#
# Processing row 180...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 249
# Total estimated tokens (prompt + response): 817
# Row 180 processed in 7.89 seconds.
#
# Processing row 181...
# Estimated input tokens (prompt): 1268
# Estimated output tokens (response): 923
# Total estimated tokens (prompt + response): 2191
# Row 181 processed in 21.53 seconds.
#
# Processing row 182...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 252
# Total estimated tokens (prompt + response): 820
# Row 182 processed in 11.36 seconds.
#
# Processing row 183...
# Estimated input tokens (prompt): 569
# Estimated output tokens (response): 257
# Total estimated tokens (prompt + response): 826
# Row 183 processed in 12.82 seconds.
#
# Processing row 184...
# Estimated input tokens (prompt): 667
# Estimated output tokens (response): 345
# Total estimated tokens (prompt + response): 1012
# Row 184 processed in 15.24 seconds.
#
# Processing row 185...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 241
# Total estimated tokens (prompt + response): 809
# Row 185 processed in 10.16 seconds.
#
# Processing row 186...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 261
# Total estimated tokens (prompt + response): 829
# Row 186 processed in 11.14 seconds.
#
# Processing row 187...
# Estimated input tokens (prompt): 617
# Estimated output tokens (response): 313
# Total estimated tokens (prompt + response): 930
# Row 187 processed in 16.85 seconds.
#
# Processing row 188...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 273
# Total estimated tokens (prompt + response): 841
# Row 188 processed in 12.82 seconds.
#
# Processing row 189...
# Estimated input tokens (prompt): 572
# Estimated output tokens (response): 282
# Total estimated tokens (prompt + response): 854
# Row 189 processed in 15.36 seconds.
#
# Processing row 190...
# Estimated input tokens (prompt): 737
# Estimated output tokens (response): 587
# Total estimated tokens (prompt + response): 1324
# Row 190 processed in 22.93 seconds.
#
# Processing row 191...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 231
# Total estimated tokens (prompt + response): 799
# Row 191 processed in 7.52 seconds.
#
# Processing row 192...
# Estimated input tokens (prompt): 569
# Estimated output tokens (response): 239
# Total estimated tokens (prompt + response): 808
# Row 192 processed in 15.09 seconds.
#
# Processing row 193...
# Estimated input tokens (prompt): 577
# Estimated output tokens (response): 304
# Total estimated tokens (prompt + response): 881
# Row 193 processed in 10.66 seconds.
#
# Processing row 194...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 241
# Total estimated tokens (prompt + response): 809
# Row 194 processed in 7.64 seconds.
#
# Processing row 195...
# Estimated input tokens (prompt): 569
# Estimated output tokens (response): 282
# Total estimated tokens (prompt + response): 851
# Row 195 processed in 10.11 seconds.
#
# Processing row 196...
# Estimated input tokens (prompt): 746
# Estimated output tokens (response): 591
# Total estimated tokens (prompt + response): 1337
# Row 196 processed in 20.78 seconds.
#
# Processing row 197...
# Estimated input tokens (prompt): 1279
# Estimated output tokens (response): 619
# Total estimated tokens (prompt + response): 1898
# Row 197 processed in 26.30 seconds.
#
# Processing row 198...
# Estimated input tokens (prompt): 820
# Estimated output tokens (response): 509
# Total estimated tokens (prompt + response): 1329
# Row 198 processed in 18.37 seconds.
#
# Processing row 199...
# Estimated input tokens (prompt): 572
# Estimated output tokens (response): 275
# Total estimated tokens (prompt + response): 847
# Row 199 processed in 11.17 seconds.
#
# Processing row 200...
# Estimated input tokens (prompt): 652
# Estimated output tokens (response): 289
# Total estimated tokens (prompt + response): 941
# Row 200 processed in 19.18 seconds.
#
# Processing row 201...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 438
# Total estimated tokens (prompt + response): 1006
# Row 201 processed in 12.21 seconds.
#
# Processing row 202...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 237
# Total estimated tokens (prompt + response): 805
# Row 202 processed in 7.13 seconds.
#
# Processing row 203...
# Estimated input tokens (prompt): 574
# Estimated output tokens (response): 286
# Total estimated tokens (prompt + response): 860
# Row 203 processed in 12.13 seconds.
#
# Processing row 204...
# Estimated input tokens (prompt): 642
# Estimated output tokens (response): 460
# Total estimated tokens (prompt + response): 1102
# Row 204 processed in 15.63 seconds.
#
# Processing row 205...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 266
# Total estimated tokens (prompt + response): 834
# Row 205 processed in 13.15 seconds.
#
# Processing row 206...
# Estimated input tokens (prompt): 572
# Estimated output tokens (response): 281
# Total estimated tokens (prompt + response): 853
# Row 206 processed in 14.60 seconds.
#
# Processing row 207...
# Estimated input tokens (prompt): 842
# Estimated output tokens (response): 471
# Total estimated tokens (prompt + response): 1313
# JSON decoding failed: Expecting property name enclosed in double quotes: line 15 column 1 (char 898)
# Raw output: ```json
# {
#   "core_issue": "The patient is dissatisfied with the hospital's billing practices, citing repeated charges for the same blood test and an unexpected, non-disclosed fee for a follow-up consultation 얼굴 to collect the report.",
#   "summary": "Repeated tests, unfair billing experience.",
#   "ward_block_room": "Not found in feedback",
#   "department": "Raffles clinic, Lab",
#   "hospital_infrastructure_age": "Not found in feedback",
#   "doctors": "Dr. Vivian Lim, doc",
#   "nurses": "Not found in feedback",
#   "support_admin_staff": "Receptionist",
#   "staff_names": "Dr. Vivian Lim",
#   "treatments_procedures": "Blood test, Consultation",
#   "service_quality_highlighted": "The reviewer highlights a lack of transparency and professionalism in billing and communication.",
#   "waiting_time": "The patient had to rest for 30 minutes before a repeat test.",
#   "food_other_quality": "Not found in feedback",
# soal  "rude_staff_details": "The review does not use the word 'rude', but implies the receptionist was unhelpful and enforced unfair charges by asking the patient to pay for a follow-up consultation to collect a report, a charge that was not previously disclosed.",
#   "delays_poor_management": "The reviewer complains about poor management of billing and communication, evidenced by being charged multiple times for repeated tests and for a follow-up consultation to collect a report.",
#   "unfair_rules_inconsistent_policies": "The policy of charging $120 for a 'follow up consultation' just to collect a report was perceived as an unfair rule, especially as it was not communicated to the patient beforehand.",
#   "explicit_negative_description": "Yes, the reviewer explicitly states 'Very bad experience' twice.",
#   "profit_motive_unnecessary_procedures": "Yes, the reviewer questions why a test had to be repeated, sent to two different labs, and paid for each time, suggesting a profit motive.",
#   "perceived_fraudulent_activity": "The reviewer does not use the word 'fraud', but perceives the billing practices as unfair and questions the legitimacy of the charges, implying they feel cheated by the unexpected costs."
# }
# ```
# Row 207 processed in 30.51 seconds.
#
# Processing row 208...
# Estimated input tokens (prompt): 601
# Estimated output tokens (response): 337
# Total estimated tokens (prompt + response): 938
# Row 208 processed in 19.56 seconds.
#
# Processing row 209...
# Estimated input tokens (prompt): 631
# Estimated output tokens (response): 376
# Total estimated tokens (prompt + response): 1007
# Row 209 processed in 17.64 seconds.
#
# Processing row 210...
# Estimated input tokens (prompt): 578
# Estimated output tokens (response): 299
# Total estimated tokens (prompt + response): 877
# Row 210 processed in 11.24 seconds.
#
# Processing row 211...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 246
# Total estimated tokens (prompt + response): 814
# Row 211 processed in 10.06 seconds.
#
# Processing row 212...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 276
# Total estimated tokens (prompt + response): 844
# Row 212 processed in 10.11 seconds.
#
# Processing row 213...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 247
# Total estimated tokens (prompt + response): 815
# Row 213 processed in 11.10 seconds.
#
# Processing row 214...
# Estimated input tokens (prompt): 635
# Estimated output tokens (response): 304
# Total estimated tokens (prompt + response): 939
# Row 214 processed in 15.86 seconds.
#
# Processing row 215...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 438
# Total estimated tokens (prompt + response): 1006
# Row 215 processed in 13.07 seconds.
#
# Processing row 216...
# Estimated input tokens (prompt): 733
# Estimated output tokens (response): 378
# Total estimated tokens (prompt + response): 1111
# Row 216 processed in 22.73 seconds.
#
# Processing row 217...
# Estimated input tokens (prompt): 662
# Estimated output tokens (response): 546
# Total estimated tokens (prompt + response): 1208
# Row 217 processed in 18.68 seconds.
#
# Processing row 218...
# Estimated input tokens (prompt): 592
# Estimated output tokens (response): 442
# Total estimated tokens (prompt + response): 1034
# Row 218 processed in 14.75 seconds.
#
# Processing row 219...
# Estimated input tokens (prompt): 586
# Estimated output tokens (response): 285
# Total estimated tokens (prompt + response): 871
# Row 219 processed in 11.55 seconds.
#
# Processing row 220...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 271
# Total estimated tokens (prompt + response): 839
# Row 220 processed in 8.44 seconds.
#
# Processing row 221...
# Estimated input tokens (prompt): 588
# Estimated output tokens (response): 324
# Total estimated tokens (prompt + response): 912
# Row 221 processed in 12.66 seconds.
#
# Processing row 222...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 268
# Total estimated tokens (prompt + response): 836
# Row 222 processed in 9.35 seconds.
#
# Processing row 223...
# Estimated input tokens (prompt): 604
# Estimated output tokens (response): 328
# Total estimated tokens (prompt + response): 932
# Row 223 processed in 14.97 seconds.
#
# Processing row 224...
# Estimated input tokens (prompt): 652
# Estimated output tokens (response): 550
# Total estimated tokens (prompt + response): 1202
# Row 224 processed in 18.36 seconds.
#
# Processing row 225...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 253
# Total estimated tokens (prompt + response): 821
# Row 225 processed in 9.45 seconds.
#
# Processing row 226...
# Estimated input tokens (prompt): 692
# Estimated output tokens (response): 418
# Total estimated tokens (prompt + response): 1110
# Row 226 processed in 23.33 seconds.
#
# Processing row 227...
# Estimated input tokens (prompt): 572
# Estimated output tokens (response): 277
# Total estimated tokens (prompt + response): 849
# Row 227 processed in 14.38 seconds.
#
# Processing row 228...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 447
# Total estimated tokens (prompt + response): 1015
# Row 228 processed in 12.03 seconds.
#
# Processing row 229...
# Estimated input tokens (prompt): 571
# Estimated output tokens (response): 261
# Total estimated tokens (prompt + response): 832
# Row 229 processed in 10.97 seconds.
#
# Processing row 230...
# Estimated input tokens (prompt): 638
# Estimated output tokens (response): 416
# Total estimated tokens (prompt + response): 1054
# Row 230 processed in 17.86 seconds.
#
# Processing row 231...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 272
# Total estimated tokens (prompt + response): 840
# Row 231 processed in 10.54 seconds.
#
# Processing row 232...
# Estimated input tokens (prompt): 722
# Estimated output tokens (response): 400
# Total estimated tokens (prompt + response): 1122
# Row 232 processed in 15.86 seconds.
#
# Processing row 233...
# Estimated input tokens (prompt): 570
# Estimated output tokens (response): 278
# Total estimated tokens (prompt + response): 848
# Row 233 processed in 10.40 seconds.
#
# Processing row 234...
# Estimated input tokens (prompt): 582
# Estimated output tokens (response): 317
# Total estimated tokens (prompt + response): 899
# Row 234 processed in 16.00 seconds.
#
# Processing row 235...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 266
# Total estimated tokens (prompt + response): 834
# Row 235 processed in 14.59 seconds.
#
# Processing row 236...
# Estimated input tokens (prompt): 581
# Estimated output tokens (response): 266
# Total estimated tokens (prompt + response): 847
# Row 236 processed in 11.79 seconds.
#
# Processing row 237...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 270
# Total estimated tokens (prompt + response): 838
# Row 237 processed in 10.15 seconds.
#
# Processing row 238...
# Estimated input tokens (prompt): 583
# Estimated output tokens (response): 304
# Total estimated tokens (prompt + response): 887
# Row 238 processed in 12.01 seconds.
#
# Processing row 239...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 246
# Total estimated tokens (prompt + response): 814
# Row 239 processed in 14.49 seconds.
#
# Processing row 240...
# Estimated input tokens (prompt): 577
# Estimated output tokens (response): 277
# Total estimated tokens (prompt + response): 854
# Row 240 processed in 11.27 seconds.
#
# Processing row 241...
# Estimated input tokens (prompt): 661
# Estimated output tokens (response): 598
# Total estimated tokens (prompt + response): 1259
# Row 241 processed in 21.66 seconds.
#
# Processing row 242...
# Estimated input tokens (prompt): 577
# ...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 269
# Total estimated tokens (prompt + response): 837
# Row 355 processed in 15.23 seconds.
#
# Processing row 356...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 272
# Total estimated tokens (prompt + response): 840
# Row 356 processed in 10.53 seconds.
#
# Processing row 357...
# Estimated input tokens (prompt): 695
# Estimated output tokens (response): 446
# Total estimated tokens (prompt + response): 1141
# Row 357 processed in 18.40 seconds.
#
# Processing row 358...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 251
# Total estimated tokens (prompt + response): 819
# Row 358 processed in 10.27 seconds.
#
# Processing row 359...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 250
# Total estimated tokens (prompt + response): 818
# Row 359 processed in 11.65 seconds.
#
# Processing row 360...
# Estimated input tokens (prompt): 573
# Estimated output tokens (response): 297
# Total estimated tokens (prompt + response): 870
# Row 360 processed in 14.66 seconds.
#
# Processing row 361...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 272
# Total estimated tokens (prompt + response): 840
# Row 361 processed in 10.48 seconds.
#
# Processing row 362...
# Estimated input tokens (prompt): 573
# Estimated output tokens (response): 281
# Total estimated tokens (prompt + response): 854
# Row 362 processed in 11.16 seconds.
#
# Processing row 363...
# Estimated input tokens (prompt): 596
# Estimated output tokens (response): 295
# Total estimated tokens (prompt + response): 891
# Row 363 processed in 12.17 seconds.
#
# Processing row 364...
# Estimated input tokens (prompt): 633
# Estimated output tokens (response): 524
# Total estimated tokens (prompt + response): 1157
# Row 364 processed in 18.85 seconds.
#
# Processing row 365...
# Estimated input tokens (prompt): 571
# Estimated output tokens (response): 269
# Total estimated tokens (prompt + response): 840
# Row 365 processed in 13.81 seconds.
#
# Processing row 366...
# Estimated input tokens (prompt): 573
# Estimated output tokens (response): 300
# Total estimated tokens (prompt + response): 873
# Row 366 processed in 14.61 seconds.
#
# Processing row 367...
# Estimated input tokens (prompt): 741
# Estimated output tokens (response): 352
# Total estimated tokens (prompt + response): 1093
# Row 367 processed in 23.32 seconds.
#
# Processing row 368...
# Estimated input tokens (prompt): 839
# Estimated output tokens (response): 771
# Total estimated tokens (prompt + response): 1610
# Row 368 processed in 20.21 seconds.
#
# Processing row 369...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 274
# Total estimated tokens (prompt + response): 842
# Row 369 processed in 12.91 seconds.
#
# Processing row 370...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 249
# Total estimated tokens (prompt + response): 817
# Row 370 processed in 10.32 seconds.
#
# Processing row 371...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 264
# Total estimated tokens (prompt + response): 832
# Row 371 processed in 12.60 seconds.
#
# Processing row 372...
# Estimated input tokens (prompt): 630
# Estimated output tokens (response): 353
# Total estimated tokens (prompt + response): 983
# Row 372 processed in 16.39 seconds.
#
# Processing row 373...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 247
# Total estimated tokens (prompt + response): 815
# Row 373 processed in 9.23 seconds.
#
# Processing row 374...
# Estimated input tokens (prompt): 569
# Estimated output tokens (response): 259
# Total estimated tokens (prompt + response): 828
# Row 374 processed in 12.48 seconds.
#
# Processing row 375...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 243
# Total estimated tokens (prompt + response): 811
# Row 375 processed in 11.93 seconds.
#
# Processing row 376...
# Estimated input tokens (prompt): 581
# Estimated output tokens (response): 262
# Total estimated tokens (prompt + response): 843
# Row 376 processed in 12.59 seconds.
#
# Processing row 377...
# Estimated input tokens (prompt): 632
# Estimated output tokens (response): 305
# Total estimated tokens (prompt + response): 937
# Row 377 processed in 23.46 seconds.
#
# Processing row 378...
# Estimated input tokens (prompt): 570
# Estimated output tokens (response): 451
# Total estimated tokens (prompt + response): 1021
# Row 378 processed in 16.65 seconds.
#
# Processing row 379...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 438
# Total estimated tokens (prompt + response): 1006
# Row 379 processed in 16.92 seconds.
#
# Processing row 380...
# Estimated input tokens (prompt): 585
# Estimated output tokens (response): 280
# Total estimated tokens (prompt + response): 865
# Row 380 processed in 13.55 seconds.
#
# Processing row 381...
# Estimated input tokens (prompt): 585
# Estimated output tokens (response): 313
# Total estimated tokens (prompt + response): 898
# Row 381 processed in 13.35 seconds.
#
# Processing row 382...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 252
# Total estimated tokens (prompt + response): 820
# Row 382 processed in 9.19 seconds.
#
# Processing row 383...
# Estimated input tokens (prompt): 569
# Estimated output tokens (response): 293
# Total estimated tokens (prompt + response): 862
# Row 383 processed in 13.72 seconds.
#
# Processing row 384...
# Estimated input tokens (prompt): 710
# Estimated output tokens (response): 398
# Total estimated tokens (prompt + response): 1108
# Row 384 processed in 19.44 seconds.
#
# Processing row 385...
# Estimated input tokens (prompt): 702
# Estimated output tokens (response): 391
# Total estimated tokens (prompt + response): 1093
# Row 385 processed in 15.82 seconds.
#
# Processing row 386...
# Estimated input tokens (prompt): 574
# Estimated output tokens (response): 243
# Total estimated tokens (prompt + response): 817
# Row 386 processed in 7.91 seconds.
#
# Processing row 387...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 229
# Total estimated tokens (prompt + response): 797
# Row 387 processed in 10.71 seconds.
#
# Processing row 388...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 264
# Total estimated tokens (prompt + response): 832
# Row 388 processed in 10.61 seconds.
#
# Processing row 389...
# Estimated input tokens (prompt): 569
# Estimated output tokens (response): 278
# Total estimated tokens (prompt + response): 847
# Row 389 processed in 10.86 seconds.
#
# Processing row 390...
# Estimated input tokens (prompt): 572
# Estimated output tokens (response): 265
# Total estimated tokens (prompt + response): 837
# Row 390 processed in 13.66 seconds.
#
# Processing row 391...
# Estimated input tokens (prompt): 593
# Estimated output tokens (response): 317
# Total estimated tokens (prompt + response): 910
# Row 391 processed in 15.46 seconds.
#
# Processing row 392...
# Estimated input tokens (prompt): 593
# Estimated output tokens (response): 515
# Total estimated tokens (prompt + response): 1108
# Row 392 processed in 17.12 seconds.
#
# Processing row 393...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 264
# Total estimated tokens (prompt + response): 832
# Row 393 processed in 13.68 seconds.
#
# Processing row 394...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 269
# Total estimated tokens (prompt + response): 837
# Row 394 processed in 9.60 seconds.
#
# Processing row 395...
# Estimated input tokens (prompt): 580
# Estimated output tokens (response): 295
# Total estimated tokens (prompt + response): 875
# Row 395 processed in 10.70 seconds.
#
# Processing row 396...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 280
# Total estimated tokens (prompt + response): 848
# Row 396 processed in 13.82 seconds.
#
# Processing row 397...
# Estimated input tokens (prompt): 673
# Estimated output tokens (response): 324
# Total estimated tokens (prompt + response): 997
# Row 397 processed in 14.11 seconds.
#
# Processing row 398...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 438
# Total estimated tokens (prompt + response): 1006
# Row 398 processed in 30.71 seconds.
#
# Processing row 399...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 235
# Total estimated tokens (prompt + response): 803
# Row 399 processed in 12.75 seconds.
#
# Processing row 400...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 438
# Total estimated tokens (prompt + response): 1006
# Row 400 processed in 14.75 seconds.
#
# Processing row 401...
# Estimated input tokens (prompt): 571
# Estimated output tokens (response): 266
# Total estimated tokens (prompt + response): 837
# Row 401 processed in 14.22 seconds.
#
# Processing row 402...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 242
# Total estimated tokens (prompt + response): 810
# Row 402 processed in 8.87 seconds.
#
# Processing row 403...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 255
# Total estimated tokens (prompt + response): 823
# Row 403 processed in 9.56 seconds.
#
# Processing row 404...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 265
# Total estimated tokens (prompt + response): 833
# Row 404 processed in 9.45 seconds.
#
# Processing row 405...
# Estimated input tokens (prompt): 654
# Estimated output tokens (response): 595
# Total estimated tokens (prompt + response): 1249
# Row 405 processed in 21.63 seconds.
#
# Processing row 406...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 270
# Total estimated tokens (prompt + response): 838
# Row 406 processed in 8.20 seconds.
#
# Processing row 407...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 266
# Total estimated tokens (prompt + response): 834
# Row 407 processed in 14.66 seconds.
#
# Processing row 408...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 253
# Total estimated tokens (prompt + response): 821
# Row 408 processed in 9.30 seconds.
#
# Processing row 409...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 254
# Total estimated tokens (prompt + response): 822
# Row 409 processed in 12.37 seconds.
#
# Processing row 410...
# Estimated input tokens (prompt): 607
# Estimated output tokens (response): 517
# Total estimated tokens (prompt + response): 1124
# Row 410 processed in 16.98 seconds.
#
# Processing row 411...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 253
# Total estimated tokens (prompt + response): 821
# Row 411 processed in 10.00 seconds.
#
# Processing row 412...
# Estimated input tokens (prompt): 585
# Estimated output tokens (response): 298
# Total estimated tokens (prompt + response): 883
# Row 412 processed in 12.78 seconds.
#
# Processing row 413...
# Estimated input tokens (prompt): 579
# Estimated output tokens (response): 314
# Total estimated tokens (prompt + response): 893
# Row 413 processed in 10.72 seconds.
#
# Processing row 414...
# Estimated input tokens (prompt): 577
# Estimated output tokens (response): 292
# Total estimated tokens (prompt + response): 869
# Row 414 processed in 12.01 seconds.
#
# Processing row 415...
# Estimated input tokens (prompt): 610
# Estimated output tokens (response): 337
# Total estimated tokens (prompt + response): 947
# Row 415 processed in 14.66 seconds.
#
# Processing row 416...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 265
# Total estimated tokens (prompt + response): 833
# Row 416 processed in 13.06 seconds.
#
# Processing row 417...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 251
# Total estimated tokens (prompt + response): 819
# Row 417 processed in 11.44 seconds.
#
# Processing row 418...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 256
# Total estimated tokens (prompt + response): 824
# Row 418 processed in 8.41 seconds.
#
# Processing row 419...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 252
# Total estimated tokens (prompt + response): 820
# Row 419 processed in 7.75 seconds.
#
# Processing row 420...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 268
# Total estimated tokens (prompt + response): 836
# Row 420 processed in 16.43 seconds.
#
# Processing row 421...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 245
# Total estimated tokens (prompt + response): 813
# Row 421 processed in 9.48 seconds.
#
# Processing row 422...
# Estimated input tokens (prompt): 577
# Estimated output tokens (response): 265
# Total estimated tokens (prompt + response): 842
# Row 422 processed in 10.44 seconds.
#
# Processing row 423...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 255
# Total estimated tokens (prompt + response): 823
# Row 423 processed in 9.91 seconds.
#
# Processing row 424...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 281
# Total estimated tokens (prompt + response): 849
# Row 424 processed in 11.26 seconds.
#
# Processing row 425...
# Estimated input tokens (prompt): 642
# Estimated output tokens (response): 408
# Total estimated tokens (prompt + response): 1050
# Row 425 processed in 13.90 seconds.
#
# Processing row 426...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 245
# Total estimated tokens (prompt + response): 813
# Row 426 processed in 13.83 seconds.
#
# Processing row 427...
# Estimated input tokens (prompt): 574
# Estimated output tokens (response): 293
# Total estimated tokens (prompt + response): 867
# Row 427 processed in 10.74 seconds.
#
# Processing row 428...
# Estimated input tokens (prompt): 656
# Estimated output tokens (response): 338
# Total estimated tokens (prompt + response): 994
# Row 428 processed in 15.19 seconds.
#
# Processing row 429...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 270
# Total estimated tokens (prompt + response): 838
# Row 429 processed in 9.41 seconds.
#
# Processing row 430...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 253
# Total estimated tokens (prompt + response): 821
# Row 430 processed in 8.55 seconds.
#
# Processing row 431...
# Estimated input tokens (prompt): 574
# Estimated output tokens (response): 301
# Total estimated tokens (prompt + response): 875
# Row 431 processed in 18.04 seconds.
#
# Processing row 432...
# Estimated input tokens (prompt): 788
# Estimated output tokens (response): 589
# Total estimated tokens (prompt + response): 1377
# Row 432 processed in 17.96 seconds.
#
# Processing row 433...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 248
# Total estimated tokens (prompt + response): 816
# Row 433 processed in 9.69 seconds.
#
# Processing row 434...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 277
# Total estimated tokens (prompt + response): 845
# Row 434 processed in 12.89 seconds.
#
# Processing row 435...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 248
# Total estimated tokens (prompt + response): 816
# Row 435 processed in 9.81 seconds.
#
# Processing row 436...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 272
# Total estimated tokens (prompt + response): 840
# Row 436 processed in 11.29 seconds.
#
# Processing row 437...
# Estimated input tokens (prompt): 689
# Estimated output tokens (response): 405
# Total estimated tokens (prompt + response): 1094
# Row 437 processed in 18.03 seconds.
#
# Processing row 438...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 249
# Total estimated tokens (prompt + response): 817
# Row 438 processed in 8.87 seconds.
#
# Processing row 439...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 261
# Total estimated tokens (prompt + response): 829
# Row 439 processed in 11.51 seconds.
#
# Processing row 440...
# Estimated input tokens (prompt): 574
# Estimated output tokens (response): 296
# Total estimated tokens (prompt + response): 870
# Row 440 processed in 12.06 seconds.
#
# Processing row 441...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 252
# Total estimated tokens (prompt + response): 820
# Row 441 processed in 12.24 seconds.

# %% [markdown]
# ### Step 2: Convert .txt to .pdf
# with open("review_output.txt", "r", encoding="utf-8") as f:
#     text = f.read()
#
# doc = fitz.open()
# lines = text.split('\n')
# chunk = ""
# chunks = []
# line_count = 0
# max_lines_per_page = 50
#
# for line in lines:
#     chunk += line + '\n'
#     line_count += 1
#     if line_count >= max_lines_per_page:
#         chunks.append(chunk)
#         chunk = ""
#         line_count = 0
# if chunk:
#     chunks.append(chunk)
#
# for chunk in chunks:
#     page = doc.new_page()
#     rect = fitz.Rect(50, 50, 550, 800)
#     page.insert_textbox(rect, chunk, fontsize=11, fontname="helv")
#
# doc.save("review_output.pdf")
# doc.close()

# %%
df_

# %%
with open("text_reviews_Glenagles.txt", "w", encoding="utf-8") as f:
    for i, row in df_Gleangles.iterrows():
        f.write(f"--- Review #{i + 1} ---\n")
        f.write(f"Datetime: {row['review_datetime_utc']}\n")
        f.write(f"User: {row['author_title']}\n")
        f.write(f"Review: {row['review_text']}\n")
        f.write("--- End of Review ---\n\n")

# %%
df_Gleangles.head().transpose()
# Out:
#                                                                                      0  \
# query                                            0x31da1a2024d17459:0x2559534cd241d05c
# name                                                               Gleneagles Hospital
# google_id                                        0x31da1a2024d17459:0x2559534cd241d05c
# place_id                                                   ChIJWXTRJCAa2jERXNBB0kxTWSU
# location_link                        https://www.google.com/maps/place/Gleneagles+H...
# reviews_link                         https://search.google.com/local/reviews?placei...
# reviews                                                                            448
# rating                                                                             3.5
# review_id                            Ci9DQUlRQUNvZENodHljRjlvT25wRVNtWnVhbHBRZFdwdm...
# review_pagination_id                 CAESY0NBRVFBUnBFUTJwRlNVRlNTWEJEWjI5QlVEY3lSMk...
# author_link                          https://www.google.com/maps/contrib/1129231924...
# author_title                                                                       K P
# author_id                                                        112923192474907858798
# author_image                         https://lh3.googleusercontent.com/a/ACg8ocKFJS...
# author_reviews_count                                                                28
# author_ratings_count                                                                 4
# review_text                            Incredible caring staff, cleanliness and qualit
# review_img_urls                                                                    NaN
# review_img_url                                                                     NaN
# review_questions                                                                   NaN
# review_photo_ids                                                                   NaN
# owner_answer                         Dear K P,\nThank you for your kind compliments...
# owner_answer_timestamp                                                    1755828345.0
# owner_answer_timestamp_datetime_utc                                08/22/2025 02:05:45
# review_link                          https://www.google.com/maps/reviews/data=!4m8!...
# review_rating                                                                        5
# review_timestamp                                                            1755681317
# review_datetime_utc                                                08/20/2025 09:15:17
# review_likes                                                                       NaN
# reviews_id                                                         2691273841740730460
# reviews_per_score_1                                                                110
# reviews_per_score_2                                                                 28
# reviews_per_score_3                                                                 40
# reviews_per_score_4                                                                 58
# reviews_per_score_5                                                                212
#
#                                                                                      1  \
# query                                            0x31da1a2024d17459:0x2559534cd241d05c
# name                                                               Gleneagles Hospital
# google_id                                        0x31da1a2024d17459:0x2559534cd241d05c
# place_id                                                   ChIJWXTRJCAa2jERXNBB0kxTWSU
# location_link                        https://www.google.com/maps/place/Gleneagles+H...
# reviews_link                         https://search.google.com/local/reviews?placei...
# reviews                                                                            448
# rating                                                                             3.5
# review_id                            Ci9DQUlRQUNvZENodHljRjlvT2pKS2NYZEZhM1psVmtaRU...
# review_pagination_id                 CAESYENBRVFBaHBDUTJrNFNVRlNTVzVEWjI5QlVEY3lSMk...
# author_link                          https://www.google.com/maps/contrib/1034916234...
# author_title                                                                      CJ J
# author_id                                                        103491623424438316318
# author_image                         https://lh3.googleusercontent.com/a/ACg8ocKPxd...
# author_reviews_count                                                                 2
# author_ratings_count                                                                 0
# review_text                          Premium hospital, substandard service\n\nI wis...
# review_img_urls                                                                    NaN
# review_img_url                                                                     NaN
# review_questions                                                                   NaN
# review_photo_ids                                                                   NaN
# owner_answer                         Dear CJ J,\nThank you for taking the time to s...
# owner_answer_timestamp                                                    1755652589.0
# owner_answer_timestamp_datetime_utc                                08/20/2025 01:16:29
# review_link                          https://www.google.com/maps/reviews/data=!4m8!...
# review_rating                                                                        1
# review_timestamp                                                            1755580500
# review_datetime_utc                                                08/19/2025 05:15:00
# review_likes                                                                       NaN
# reviews_id                                                         2691273841740730460
# reviews_per_score_1                                                                110
# reviews_per_score_2                                                                 28
# reviews_per_score_3                                                                 40
# reviews_per_score_4                                                                 58
# reviews_per_score_5                                                                212
#
#                                                                                      2  \
# query                                            0x31da1a2024d17459:0x2559534cd241d05c
# name                                                               Gleneagles Hospital
# google_id                                        0x31da1a2024d17459:0x2559534cd241d05c
# place_id                                                   ChIJWXTRJCAa2jERXNBB0kxTWSU
# location_link                        https://www.google.com/maps/place/Gleneagles+H...
# reviews_link                         https://search.google.com/local/reviews?placei...
# reviews                                                                            448
# rating                                                                             3.5
# review_id                            Ci9DQUlRQUNvZENodHljRjlvT25sNFYyWlFWMk5JWm5Fd0...
# review_pagination_id                 CAESY0NBRVFBeHBFUTJwRlNVRlNTWEJEWjI5QlVEY3lSMl...
# author_link                          https://www.google.com/maps/contrib/1168888403...
# author_title                                                                  Ryan Sun
# author_id                                                        116888840300799112611
# author_image                         https://lh3.googleusercontent.com/a/ACg8ocJKXz...
# author_reviews_count                                                                 2
# author_ratings_count                                                                 0
# review_text                                                      Test writing a review
# review_img_urls                                                                    NaN
# review_img_url                                                                     NaN
# review_questions                                                                   NaN
# review_photo_ids                                                                   NaN
# owner_answer                         Dear Ryan Sun ,\nThank you for taking the time...
# owner_answer_timestamp                                                    1755652030.0
# owner_answer_timestamp_datetime_utc                                08/20/2025 01:07:10
# review_link                          https://www.google.com/maps/reviews/data=!4m8!...
# review_rating                                                                        5
# review_timestamp                                                            1755451910
# review_datetime_utc                                                08/17/2025 17:31:50
# review_likes                                                                       NaN
# reviews_id                                                         2691273841740730460
# reviews_per_score_1                                                                110
# reviews_per_score_2                                                                 28
# reviews_per_score_3                                                                 40
# reviews_per_score_4                                                                 58
# reviews_per_score_5                                                                212
#
#                                                                                      3  \
# query                                            0x31da1a2024d17459:0x2559534cd241d05c
# name                                                               Gleneagles Hospital
# google_id                                        0x31da1a2024d17459:0x2559534cd241d05c
# place_id                                                   ChIJWXTRJCAa2jERXNBB0kxTWSU
# location_link                        https://www.google.com/maps/place/Gleneagles+H...
# reviews_link                         https://search.google.com/local/reviews?placei...
# reviews                                                                            448
# rating                                                                             3.5
# review_id                            Ci9DQUlRQUNvZENodHljRjlvT2xSWGJHOTRXR280V2xsaG...
# review_pagination_id                 CAESYENBRVFCQnBDUTJrNFNVRlNTVzVEWjI5QlVEY3lSMl...
# author_link                          https://www.google.com/maps/contrib/1035502646...
# author_title                                                               Abdul Kadir
# author_id                                                        103550264671586095542
# author_image                         https://lh3.googleusercontent.com/a-/ALV-UjX49...
# author_reviews_count                                                                 1
# author_ratings_count                                                                 2
# review_text                                                                        NaN
# review_img_urls                                                                    NaN
# review_img_url                                                                     NaN
# review_questions                                                                   NaN
# review_photo_ids                                                                   NaN
# owner_answer                         Dear Abdul Kadir,\nThank you for taking the ti...
# owner_answer_timestamp                                                    1755226614.0
# owner_answer_timestamp_datetime_utc                                08/15/2025 02:56:54
# review_link                          https://www.google.com/maps/reviews/data=!4m8!...
# review_rating                                                                        5
# review_timestamp                                                            1755222088
# review_datetime_utc                                                08/15/2025 01:41:28
# review_likes                                                                       NaN
# reviews_id                                                         2691273841740730460
# reviews_per_score_1                                                                110
# reviews_per_score_2                                                                 28
# reviews_per_score_3                                                                 40
# reviews_per_score_4                                                                 58
# reviews_per_score_5                                                                212
#
#                                                                                      4
# query                                            0x31da1a2024d17459:0x2559534cd241d05c
# name                                                               Gleneagles Hospital
# google_id                                        0x31da1a2024d17459:0x2559534cd241d05c
# place_id                                                   ChIJWXTRJCAa2jERXNBB0kxTWSU
# location_link                        https://www.google.com/maps/place/Gleneagles+H...
# reviews_link                         https://search.google.com/local/reviews?placei...
# reviews                                                                            448
# rating                                                                             3.5
# review_id                            Ci9DQUlRQUNvZENodHljRjlvT2pCSGRGZEpWbk5KTTFKQ1...
# review_pagination_id                 CAESY0NBRVFCUnBFUTJwRlNVRlNTWEJEWjI5QlVEY3lSMl...
# author_link                          https://www.google.com/maps/contrib/1026153367...
# author_title                                                              Jonathan Lim
# author_id                                                        102615336774422836496
# author_image                         https://lh3.googleusercontent.com/a/ACg8ocL3TQ...
# author_reviews_count                                                                 1
# author_ratings_count                                                                 0
# review_text                          Hospital facility is good. however, it took me...
# review_img_urls                                                                    NaN
# review_img_url                                                                     NaN
# review_questions                                                                   NaN
# review_photo_ids                                                                   NaN
# owner_answer                         Dear Jonathan Lim,\nThank you for sharing your...
# owner_answer_timestamp                                                    1754286242.0
# owner_answer_timestamp_datetime_utc                                08/04/2025 05:44:02
# review_link                          https://www.google.com/maps/reviews/data=!4m8!...
# review_rating                                                                        3
# review_timestamp                                                            1754266556
# review_datetime_utc                                                08/04/2025 00:15:56
# review_likes                                                                       NaN
# reviews_id                                                         2691273841740730460
# reviews_per_score_1                                                                110
# reviews_per_score_2                                                                 28
# reviews_per_score_3                                                                 40
# reviews_per_score_4                                                                 58
# reviews_per_score_5                                                                212
