# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /opt/conda/lib/python3.10/site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in /opt/conda/lib/python3.10/site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)

# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in /opt/conda/lib/python3.10/site-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in /opt/conda/lib/python3.10/site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk>=3.9->textblob) (8.1.8)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk>=3.9->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk>=3.9->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nltk>=3.9->textblob) (4.67.1)

# %%
# ==============================
# 1. Setup & Load Data
# ==============================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from textblob import TextBlob

# Load dataset
df = pd.read_excel("Mount Elizabeth Hospital.xlsx")

# Display basic info
print(df.shape)
df.head()
# Out:
# (519, 35)
#                                    query                      name  \
# 0  0x31da19925a494a9d:0xe3db3f1109109b86  Mount Elizabeth Hospital
# 1  0x31da19925a494a9d:0xe3db3f1109109b86  Mount Elizabeth Hospital
# 2  0x31da19925a494a9d:0xe3db3f1109109b86  Mount Elizabeth Hospital
# 3  0x31da19925a494a9d:0xe3db3f1109109b86  Mount Elizabeth Hospital
# 4  0x31da19925a494a9d:0xe3db3f1109109b86  Mount Elizabeth Hospital
#
#                                google_id                     place_id  \
# 0  0x31da19925a494a9d:0xe3db3f1109109b86  ChIJnUpJWpIZ2jERhpsQCRE_2-M
# 1  0x31da19925a494a9d:0xe3db3f1109109b86  ChIJnUpJWpIZ2jERhpsQCRE_2-M
# 2  0x31da19925a494a9d:0xe3db3f1109109b86  ChIJnUpJWpIZ2jERhpsQCRE_2-M
# 3  0x31da19925a494a9d:0xe3db3f1109109b86  ChIJnUpJWpIZ2jERhpsQCRE_2-M
# 4  0x31da19925a494a9d:0xe3db3f1109109b86  ChIJnUpJWpIZ2jERhpsQCRE_2-M
#
#                                        location_link  \
# 0  https://www.google.com/maps/place/Mount+Elizab...
# 1  https://www.google.com/maps/place/Mount+Elizab...
# 2  https://www.google.com/maps/place/Mount+Elizab...
# 3  https://www.google.com/maps/place/Mount+Elizab...
# 4  https://www.google.com/maps/place/Mount+Elizab...
#
#                                         reviews_link  reviews  rating  \
# 0  https://search.google.com/local/reviews?placei...      527     3.6
# 1  https://search.google.com/local/reviews?placei...      527     3.6
# 2  https://search.google.com/local/reviews?placei...      527     3.6
# 3  https://search.google.com/local/reviews?placei...      527     3.6
# 4  https://search.google.com/local/reviews?placei...      527     3.6
#
#                                            review_id  \
# 0  Ci9DQUlRQUNvZENodHljRjlvT2pCUWRGRklPRlExUVVGa0...
# 1  Ci9DQUlRQUNvZENodHljRjlvT2taVk1HUkhRelp5UTA1dl...
# 2  Ci9DQUlRQUNvZENodHljRjlvT2s5eFNIRTBVWGRQUTB4Mm...
# 3  Ci9DQUlRQUNvZENodHljRjlvT21oSlRUWk9MVzloTnpGWl...
# 4  Ci9DQUlRQUNvZENodHljRjlvT21WU2NIRlJOa1E0UkdGVV...
#
#                                 review_pagination_id  ... review_rating  \
# 0  CAESYENBRVFBUnBDUTJrNFNVRlNTVzVEWjI5QlVEY3lSMk...  ...             5
# 1  CAESY0NBRVFBaHBFUTJwRlNVRlNTWEJEWjI5QlVEY3lSMk...  ...             5
# 2  CAESYENBRVFBeHBDUTJrNFNVRlNTVzVEWjI5QlVEY3lSMl...  ...             1
# 3  CAESYENBRVFCQnBDUTJrNFNVRlNTVzVEWjI5QlVEY3lSMl...  ...             1
# 4  CAESYENBRVFCUnBDUTJrNFNVRlNTVzVEWjI5QlVEY3lSMm...  ...             5
#
#   review_timestamp  review_datetime_utc review_likes           reviews_id  \
# 0       1756278043  08/27/2025 07:00:43          NaN -2027957864801199226
# 1       1755667212  08/20/2025 05:20:12          NaN -2027957864801199226
# 2       1753760320  07/29/2025 03:38:40          NaN -2027957864801199226
# 3       1753580132  07/27/2025 01:35:32          NaN -2027957864801199226
# 4       1752249513  07/11/2025 15:58:33          NaN -2027957864801199226
#
#    reviews_per_score_1 reviews_per_score_2 reviews_per_score_3  \
# 0                  131                  30                  28
# 1                  131                  30                  28
# 2                  131                  30                  28
# 3                  131                  30                  28
# 4                  131                  30                  28
#
#   reviews_per_score_4  reviews_per_score_5
# 0                  54                  284
# 1                  54                  284
# 2                  54                  284
# 3                  54                  284
# 4                  54                  284
#
# [5 rows x 35 columns]

# %%
df.columns
# Out:
# Index(['query', 'name', 'google_id', 'place_id', 'location_link',
#        'reviews_link', 'reviews', 'rating', 'review_id',
#        'review_pagination_id', 'author_link', 'author_title', 'author_id',
#        'author_image', 'author_reviews_count', 'author_ratings_count',
#        'review_text', 'review_img_urls', 'review_img_url', 'review_questions',
#        'review_photo_ids', 'owner_answer', 'owner_answer_timestamp',
#        'owner_answer_timestamp_datetime_utc', 'review_link', 'review_rating',
#        'review_timestamp', 'review_datetime_utc', 'review_likes', 'reviews_id',
#        'reviews_per_score_1', 'reviews_per_score_2', 'reviews_per_score_3',
#        'reviews_per_score_4', 'reviews_per_score_5'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 519 entries, 0 to 518
# Data columns (total 35 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   query                                519 non-null    object
#  1   name                                 519 non-null    object
#  2   google_id                            519 non-null    object
#  3   place_id                             519 non-null    object
#  4   location_link                        519 non-null    object
#  5   reviews_link                         519 non-null    object
#  6   reviews                              519 non-null    int64
#  7   rating                               519 non-null    float64
#  8   review_id                            519 non-null    object
#  9   review_pagination_id                 518 non-null    object
#  10  author_link                          519 non-null    object
#  11  author_title                         519 non-null    object
#  12  author_id                            519 non-null    object
#  13  author_image                         519 non-null    object
#  14  author_reviews_count                 519 non-null    int64
#  15  author_ratings_count                 519 non-null    int64
#  16  review_text                          335 non-null    object
#  17  review_img_urls                      54 non-null     object
#  18  review_img_url                       54 non-null     object
#  19  review_questions                     0 non-null      float64
#  20  review_photo_ids                     54 non-null     object
#  21  owner_answer                         205 non-null    object
#  22  owner_answer_timestamp               205 non-null    float64
#  23  owner_answer_timestamp_datetime_utc  205 non-null    object
#  24  review_link                          519 non-null    object
#  25  review_rating                        519 non-null    int64
#  26  review_timestamp                     519 non-null    int64
#  27  review_datetime_utc                  519 non-null    object
#  28  review_likes                         0 non-null      float64
#  29  reviews_id                           519 non-null    int64
#  30  reviews_per_score_1                  519 non-null    int64
#  31  reviews_per_score_2                  519 non-null    int64
#  32  reviews_per_score_3                  519 non-null    int64
#  33  reviews_per_score_4                  519 non-null    int64
#  34  reviews_per_score_5                  519 non-null    int64
# dtypes: float64(4), int64(11), object(20)
# memory usage: 142.0+ KB

# %%
# ==============================
# 2. Data Cleaning
# ==============================
# Remove duplicates
df = df.drop_duplicates()

# Convert datetime column
df['review_datetime_utc'] = pd.to_datetime(df['review_datetime_utc'], errors='coerce')

# Add review text length
df['review_length'] = df['review_text'].astype(str).apply(len)

# Check missing values
print(df.isna().sum())
# Out:
# query                                    0
# name                                     0
# google_id                                0
# place_id                                 0
# location_link                            0
# reviews_link                             0
# reviews                                  0
# rating                                   0
# review_id                                0
# review_pagination_id                     1
# author_link                              0
# author_title                             0
# author_id                                0
# author_image                             0
# author_reviews_count                     0
# author_ratings_count                     0
# review_text                            184
# review_img_urls                        465
# review_img_url                         465
# review_questions                       519
# review_photo_ids                       465
# owner_answer                           314
# owner_answer_timestamp                 314
# owner_answer_timestamp_datetime_utc    314
# review_link                              0
# review_rating                            0
# review_timestamp                         0
# review_datetime_utc                      0
# review_likes                           519
# reviews_id                               0
# reviews_per_score_1                      0
# reviews_per_score_2                      0
# reviews_per_score_3                      0
# reviews_per_score_4                      0
# reviews_per_score_5                      0
# review_length                            0
# dtype: int64

# %%
# ==============================
# 3. Descriptive Statistics
# ==============================
print(df['review_rating'].describe())
print(df['review_length'].describe())

print("Reviewer reviews count stats:")
print(df['author_reviews_count'].describe())

print("Reviewer ratings count stats:")
print(df['author_ratings_count'].describe())

print("Owner response rate:", df['owner_answer'].notna().mean())
# Out:
# count    519.00000
# mean       3.60501
# std        1.71414
# min        1.00000
# 25%        1.00000
# 50%        5.00000
# 75%        5.00000
# max        5.00000
# Name: review_rating, dtype: float64
# count     519.000000
# mean      239.433526
# std       450.908700
# min         3.000000
# 25%         3.000000
# 50%        45.000000
# 75%       259.500000
# max      3685.000000
# Name: review_length, dtype: float64
# Reviewer reviews count stats:
# count     519.000000
# mean      107.258189
# std       301.197076
# min         0.000000
# 25%         3.000000
# 50%        15.000000
# 75%        70.500000
# max      5087.000000
# Name: author_reviews_count, dtype: float64
# Reviewer ratings count stats:
# count     519.000000
# mean       40.441233
# std       127.871783
# min         0.000000
# 25%         1.000000
# 50%         4.000000
# 75%        21.000000
# max      1239.000000
# Name: author_ratings_count, dtype: float64
# Owner response rate: 0.394990366088632

# %%
# ==============================
# 4. Univariate Analysis
# ==============================
sns.countplot(x='review_rating', data=df)
plt.title("Ratings Distribution")
plt.show()

sns.histplot(df['review_length'], bins=30, kde=True)
plt.title("Review Length Distribution")
plt.show()

sns.histplot(df['author_reviews_count'], bins=30)
plt.title("Reviewer Review Count Distribution")
plt.show()

# %%
# ==============================
# 5. Bivariate Analysis
# ==============================
sns.boxplot(x='review_rating', y='review_length', data=df)
plt.title("Review Length vs Rating")
plt.show()

sns.heatmap(df[['review_rating','review_likes','author_reviews_count','review_length']].corr(),
            annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

sns.barplot(x='review_rating', y=df['owner_answer'].notna(), data=df, estimator=np.mean)
plt.title("Owner Response Rate by Rating")
plt.show()

# %%
# ==============================
# 6. Time-based Analysis
# ==============================
df['month'] = df['review_datetime_utc'].dt.to_period("M")

monthly = df.groupby('month').agg(
    avg_rating=('review_rating','mean'),
    review_count=('review_rating','count')
)

monthly.plot(y=['avg_rating','review_count'], subplots=True, figsize=(10,6),
             title=["Average Rating Over Time","Review Count Over Time"])
plt.show()

# %%
# ==============================
# 7. Text Analysis (WordCloud + Sentiment)
# ==============================
# Positive reviews wordcloud
positive_text = " ".join(df[df['review_rating'] >= 4]['review_text'].dropna())
wordcloud_pos = WordCloud(width=800, height=400, background_color='white').generate(positive_text)
plt.imshow(wordcloud_pos, interpolation='bilinear')
plt.axis("off")
plt.title("Positive Reviews WordCloud")
plt.show()

# Negative reviews wordcloud
negative_text = " ".join(df[df['review_rating'] <= 2]['review_text'].dropna())
wordcloud_neg = WordCloud(width=800, height=400, background_color='black').generate(negative_text)
plt.imshow(wordcloud_neg, interpolation='bilinear')
plt.axis("off")
plt.title("Negative Reviews WordCloud")
plt.show()

# Sentiment polarity
df['sentiment'] = df['review_text'].astype(str).apply(lambda x: TextBlob(x).sentiment.polarity)
sns.histplot(df['sentiment'], bins=30, kde=True)
plt.title("Sentiment Distribution")
plt.show()

# %%
# ==============================
# 8. Reviewer Insights
# ==============================
top_reviewers = df.groupby('author_title').size().sort_values(ascending=False).head(10)
print("Top Reviewers:")
print(top_reviewers)

df['is_frequent'] = df['author_reviews_count'] > 5
sns.countplot(x='is_frequent', hue='review_rating', data=df)
plt.title("Frequent vs One-time Reviewers by Rating")
plt.show()
# Out:
# Top Reviewers:
# author_title
# S S                2
# Ruth Tan           1
# Ruijie SK Chong    1
# Rudresh Kumar      1
# Ruben Licera       1
# Rohit Lokray       1
# Robin Ong          1
# Rizky Piccardo     1
# Riki Yohanes       1
# Rifat Ahmed        1
# dtype: int64

# %%
# ==============================
# 9. Owner Response Analysis
# ==============================
neg = df[df['review_rating'] <= 2]
pos = df[df['review_rating'] >= 4]

print("Response rate for negative reviews:", neg['owner_answer'].notna().mean())
print("Response rate for positive reviews:", pos['owner_answer'].notna().mean())
# Out:
# Response rate for negative reviews: 0.6459627329192547
# Response rate for positive reviews: 0.2818181818181818

# %%
# ==============================
# 10. Aggregate Check
# ==============================
agg_counts = {
    "1_star": df['reviews_per_score_1'].iloc[0],
    "2_star": df['reviews_per_score_2'].iloc[0],
    "3_star": df['reviews_per_score_3'].iloc[0],
    "4_star": df['reviews_per_score_4'].iloc[0],
    "5_star": df['reviews_per_score_5'].iloc[0],
}
print("Aggregated counts from metadata:", agg_counts)

actual_counts = df['review_rating'].value_counts()
print("Actual counts from reviews:", actual_counts)
# Out:
# Aggregated counts from metadata: {'1_star': 131, '2_star': 30, '3_star': 28, '4_star': 54, '5_star': 284}
# Actual counts from reviews: review_rating
# 5    276
# 1    131
# 4     54
# 2     30
# 3     28
# Name: count, dtype: int64

# %% [markdown]
# #### 🏥 Google Reviews EDA + NLP Extension

# %%
# ==============================
# 11. Keyword Extraction (TF-IDF)
# ==============================
from sklearn.feature_extraction.text import TfidfVectorizer

# Use only non-null review text
texts = df['review_text'].dropna().astype(str)

# Vectorize reviews
tfidf = TfidfVectorizer(stop_words='english', max_features=20, ngram_range=(1,2))
tfidf_matrix = tfidf.fit_transform(texts)

# Top keywords
keywords = pd.DataFrame({
    "keyword": tfidf.get_feature_names_out(),
    "score": tfidf_matrix.sum(axis=0).A1
}).sort_values(by="score", ascending=False)

print("Top Keywords (TF-IDF):")
print(keywords.head(20))
# Out:
# Top Keywords (TF-IDF):
#             keyword      score
# 6          hospital  70.955124
# 17            staff  37.759319
# 15          service  34.681916
# 5              good  26.883168
# 16        singapore  22.923136
# 1            doctor  22.258259
# 12           nurses  21.501268
# 2           doctors  19.982201
# 4        experience  19.169664
# 10            mount  18.494609
# 19             time  18.218455
# 14           really  17.725766
# 7              just  16.750160
# 3         elizabeth  16.747877
# 9           medical  16.274744
# 13          patient  15.544388
# 11  mount elizabeth  14.249894
# 0               day  13.798537
# 8              like  13.305203
# 18          surgery  12.830575

# %%
# ==============================
# 12. Topic Modeling (LDA)
# ==============================
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer

# Count vectorizer for LDA
cv = CountVectorizer(stop_words='english', max_df=0.9, min_df=5)
cv_matrix = cv.fit_transform(texts)

# Fit LDA model
lda = LatentDirichletAllocation(n_components=5, random_state=42)
lda.fit(cv_matrix)

# Display top words for each topic
def display_topics(model, feature_names, no_top_words=10):
    for idx, topic in enumerate(model.components_):
        print(f"Topic {idx+1}:")
        print(" | ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))
        print("\n")

display_topics(lda, cv.get_feature_names_out())
# Out:
# Topic 1:
# hospital | nurse | patient | staff | doctor | asked | time | come | test | just
#
#
# Topic 2:
# hospital | staff | service | singapore | dr | surgery | mount | elizabeth | care | best
#
#
# Topic 3:
# service | hospital | experience | nurses | great | asked | stay | poor | really | delivery
#
#
# Topic 4:
# hospital | staff | nurses | mt | baby | friendly | like | hospitals | ward | really
#
#
# Topic 5:
# doctor | good | hospital | treatment | place | got | clinic | di | medicine | patients

# %%
# ==============================
# 13. Topic Distribution per Review
# ==============================
topic_values = lda.transform(cv_matrix)

# Create a new DataFrame with the same index as cv_matrix to ensure alignment
# This assumes cv_matrix was created from a subset of df
df_subset = df.iloc[cv_matrix.index] if hasattr(cv_matrix, 'index') else df.head(len(topic_values))

# Add dominant topic to this subset
df_subset['dominant_topic'] = topic_values.argmax(axis=1)

# Plot with the correctly aligned data
sns.countplot(x='dominant_topic', data=df_subset)
plt.title("Most Common Topics in Reviews")
plt.show()

# Alternatively, if you need to keep the original df intact:
# Create a temporary DataFrame for plotting
# temp_df = pd.DataFrame({'dominant_topic': topic_values.argmax(axis=1)})
# sns.countplot(x='dominant_topic', data=temp_df)
# Out:
# /var/tmp/ipykernel_5317/1274790882.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['dominant_topic'] = topic_values.argmax(axis=1)

# %% [markdown]
# # Assistant
# This error occurs because the length of the `topic_values` array (146) doesn't match the length of your DataFrame `df` (185). This mismatch happens when you try to assign the `dominant_topic` column to your DataFrame.
#
# The most likely cause is that your `cv_matrix` (CountVectorizer or TF-IDF matrix) was created using a subset of your data, or some rows were filtered out during preprocessing (perhaps due to empty reviews after text cleaning).
#
# Would you like me to provide the corrected code?

# %% [markdown]
# # KPI Metrics

# %%
import pandas as pd
import numpy as np
from textblob import TextBlob

# Ensure datetime and review length are present
df['review_datetime_utc'] = pd.to_datetime(df['review_datetime_utc'], errors='coerce')
df['review_length'] = df['review_text'].astype(str).apply(len)
df['sentiment'] = df['review_text'].astype(str).apply(lambda x: TextBlob(x).sentiment.polarity)

# %% [markdown]
# # ⭐ 1. Ratings-Based Metrics

# %%
# Average rating
avg_rating = df['review_rating'].mean()
median_rating = df['review_rating'].median()
rating_distribution = df['review_rating'].value_counts(normalize=True) * 100

print("Average Rating:", avg_rating)
print("Median Rating:", median_rating)
print("Rating Distribution (%):\n", rating_distribution)

# Trend over time (monthly)
df['month'] = df['review_datetime_utc'].dt.to_period("M")
rating_trend = df.groupby('month')['review_rating'].mean()
print("Monthly Rating Trend:\n", rating_trend.tail())
# Out:
# Average Rating: 3.605009633911368
# Median Rating: 5.0
# Rating Distribution (%):
#  review_rating
# 5    53.179191
# 1    25.240848
# 4    10.404624
# 2     5.780347
# 3     5.394990
# Name: proportion, dtype: float64
# Monthly Rating Trend:
#  month
# 2025-04    2.600000
# 2025-05    2.714286
# 2025-06    3.666667
# 2025-07    3.000000
# 2025-08    5.000000
# Freq: M, Name: review_rating, dtype: float64

# %% [markdown]
# # 💬 2. Sentiment Metrics

# %%
avg_sentiment = df['sentiment'].mean()
sentiment_distribution = pd.cut(df['sentiment'], bins=[-1,-0.05,0.05,1], labels=["Negative","Neutral","Positive"]).value_counts(normalize=True) * 100

print("Average Sentiment Score:", avg_sentiment)
print("Sentiment Distribution (%):\n", sentiment_distribution)

# Correlation with rating
corr_sentiment_rating = df[['review_rating','sentiment']].corr().iloc[0,1]
print("Correlation between Sentiment & Rating:", corr_sentiment_rating)
# Out:
# Average Sentiment Score: 0.10222944351416138
# Sentiment Distribution (%):
#  sentiment
# Neutral     53.501946
# Positive    35.408560
# Negative    11.089494
# Name: proportion, dtype: float64
# Correlation between Sentiment & Rating: 0.381734661356967

# %% [markdown]
# # ✍️ 3. Review Quality & Engagement

# %%
avg_review_length = df['review_length'].mean()
avg_likes = df['review_likes'].mean(skipna=True)

print("Average Review Length:", avg_review_length)
print("Average Likes per Review:", avg_likes)

# Length vs rating
length_by_rating = df.groupby('review_rating')['review_length'].mean()
print("Review Length by Rating:\n", length_by_rating)
# Out:
# Average Review Length: 239.4335260115607
# Average Likes per Review: nan
# Review Length by Rating:
#  review_rating
# 1    477.618321
# 2    360.566667
# 3    253.357143
# 4    110.370370
# 5    137.054348
# Name: review_length, dtype: float64

# %% [markdown]
# # 👥 4. Reviewer Behavior

# %%
# One-time vs frequent
one_time_reviewers = (df['author_reviews_count'] == 1).mean() * 100
frequent_reviewers = (df['author_reviews_count'] > 5).mean() * 100

print("One-time Reviewers (%):", one_time_reviewers)
print("Frequent Reviewers (%):", frequent_reviewers)

# Reviewer bias (avg rating by reviewer type)
df['is_frequent'] = df['author_reviews_count'] > 5
bias = df.groupby('is_frequent')['review_rating'].mean()
print("Avg Rating by Reviewer Type:\n", bias)
# Out:
# One-time Reviewers (%): 8.285163776493256
# Frequent Reviewers (%): 65.3179190751445
# Avg Rating by Reviewer Type:
#  is_frequent
# False    3.616667
# True     3.598820
# Name: review_rating, dtype: float64

# %% [markdown]
# # 🔁 5. Owner Response Metrics

# %%
# Overall response rate
response_rate = df['owner_answer'].notna().mean() * 100

# Response rate by rating
response_by_rating = df.groupby('review_rating')['owner_answer'].apply(lambda x: x.notna().mean()*100)

# Response by sentiment
df['sentiment_group'] = pd.cut(df['sentiment'], bins=[-1,-0.05,0.05,1], labels=["Negative","Neutral","Positive"])
response_by_sentiment = df.groupby('sentiment_group')['owner_answer'].apply(lambda x: x.notna().mean()*100)

print("Overall Response Rate (%):", response_rate)
print("Response Rate by Rating (%):\n", response_by_rating)
print("Response Rate by Sentiment (%):\n", response_by_sentiment)
# Out:
# Overall Response Rate (%): 39.4990366088632
# Response Rate by Rating (%):
#  review_rating
# 1    67.175573
# 2    53.333333
# 3    28.571429
# 4    18.518519
# 5    30.072464
# Name: owner_answer, dtype: float64
# Response Rate by Sentiment (%):
#  sentiment_group
# Negative    70.175439
# Neutral     29.090909
# Positive    45.054945
# Name: owner_answer, dtype: float64
# /var/tmp/ipykernel_5317/4059787264.py:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   response_by_sentiment = df.groupby('sentiment_group')['owner_answer'].apply(lambda x: x.notna().mean()*100)

# %% [markdown]
# # 🔁 5. Owner Response Metrics

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# Create a copy of the dataframe with only non-NA reviews
# This ensures we work with the same subset throughout the code
df_clean = df.dropna(subset=['review_text']).copy()
texts = df_clean['review_text'].astype(str)

# ---- TF-IDF ----
tfidf = TfidfVectorizer(stop_words='english', max_features=20, ngram_range=(1,2))
tfidf_matrix = tfidf.fit_transform(texts)
keywords = pd.DataFrame({
    "keyword": tfidf.get_feature_names_out(),
    "score": tfidf_matrix.sum(axis=0).A1
}).sort_values(by="score", ascending=False)
print("Top TF-IDF Keywords:\n", keywords)

# ---- LDA Topic Modeling ----
cv = CountVectorizer(stop_words='english', max_df=0.9, min_df=5)
cv_matrix = cv.fit_transform(texts)

lda = LatentDirichletAllocation(n_components=5, random_state=42)
lda.fit(cv_matrix)

def display_topics(model, feature_names, no_top_words=10):
    topics = {}
    for idx, topic in enumerate(model.components_):
        topics[f"Topic {idx+1}"] = [feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]
    return topics

topics = display_topics(lda, cv.get_feature_names_out())
print("LDA Topics:\n", topics)

# Assign dominant topic per review
# Now we're using df_clean which has the same length as texts
topic_values = lda.transform(cv_matrix)
df_clean['dominant_topic'] = topic_values.argmax(axis=1) + 1

topic_distribution = df_clean['dominant_topic'].value_counts(normalize=True) * 100
print("Topic Distribution (%):\n", topic_distribution)
# Out:
# Top TF-IDF Keywords:
#              keyword      score
# 6          hospital  70.955124
# 17            staff  37.759319
# 15          service  34.681916
# 5              good  26.883168
# 16        singapore  22.923136
# 1            doctor  22.258259
# 12           nurses  21.501268
# 2           doctors  19.982201
# 4        experience  19.169664
# 10            mount  18.494609
# 19             time  18.218455
# 14           really  17.725766
# 7              just  16.750160
# 3         elizabeth  16.747877
# 9           medical  16.274744
# 13          patient  15.544388
# 11  mount elizabeth  14.249894
# 0               day  13.798537
# 8              like  13.305203
# 18          surgery  12.830575
# LDA Topics:
#  {'Topic 1': ['hospital', 'nurse', 'patient', 'staff', 'doctor', 'asked', 'time', 'come', 'test', 'just'], 'Topic 2': ['hospital', 'staff', 'service', 'singapore', 'dr', 'surgery', 'mount', 'elizabeth', 'care', 'best'], 'Topic 3': ['service', 'hospital', 'experience', 'nurses', 'great', 'asked', 'stay', 'poor', 'really', 'delivery'], 'Topic 4': ['hospital', 'staff', 'nurses', 'mt', 'baby', 'friendly', 'like', 'hospitals', 'ward', 'really'], 'Topic 5': ['doctor', 'good', 'hospital', 'treatment', 'place', 'got', 'clinic', 'di', 'medicine', 'patients']}
# Topic Distribution (%):
#  dominant_topic
# 1    29.552239
# 2    24.179104
# 5    19.402985
# 3    14.029851
# 4    12.835821
# Name: proportion, dtype: float64

# %% [markdown]
# # 🗝 6. Thematic Insights (TF-IDF & LDA)

# %%
agg_counts = {
    "1_star": df['reviews_per_score_1'].iloc[0],
    "2_star": df['reviews_per_score_2'].iloc[0],
    "3_star": df['reviews_per_score_3'].iloc[0],
    "4_star": df['reviews_per_score_4'].iloc[0],
    "5_star": df['reviews_per_score_5'].iloc[0],
}
actual_counts = df['review_rating'].value_counts()

print("Google Metadata Counts:", agg_counts)
print("Actual Extracted Counts:\n", actual_counts)
# Out:
# Google Metadata Counts: {'1_star': 131, '2_star': 30, '3_star': 28, '4_star': 54, '5_star': 284}
# Actual Extracted Counts:
#  review_rating
# 5    276
# 1    131
# 4     54
# 2     30
# 3     28
# Name: count, dtype: int64

# %%
# =============================
# 1. Setup
# =============================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from textblob import TextBlob
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

sns.set(style="whitegrid", palette="muted", font_scale=1.1)

# Load dataset
#df = pd.read_excel("Outscraper-20250823032119xs76.xlsx")
df['review_datetime_utc'] = pd.to_datetime(df['review_datetime_utc'], errors='coerce')
df['review_length'] = df['review_text'].astype(str).apply(len)
df['sentiment'] = df['review_text'].astype(str).apply(lambda x: TextBlob(x).sentiment.polarity)

# %% [markdown]
# # ⭐ 2. Ratings Overview

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="review_rating", data=df, palette="viridis")
plt.title("Ratings Distribution")
plt.show()

df.groupby(df['review_datetime_utc'].dt.to_period("M"))['review_rating'].mean().plot(figsize=(10,5), marker="o")
plt.title("Average Rating Over Time")
plt.ylabel("Avg Rating")
plt.show()
# Out:
# /var/tmp/ipykernel_5317/998790571.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="review_rating", data=df, palette="viridis")

# %% [markdown]
# # 💬 3. Sentiment Analysis

# %%
df['sentiment_group'] = pd.cut(df['sentiment'], bins=[-1,-0.05,0.05,1], labels=["Negative","Neutral","Positive"])

plt.figure(figsize=(6,4))
sns.countplot(x="sentiment_group", data=df, order=["Negative","Neutral","Positive"], palette="coolwarm")
plt.title("Sentiment Distribution")
plt.show()

sns.scatterplot(x="sentiment", y="review_rating", data=df, alpha=0.5)
plt.title("Sentiment vs Rating")
plt.show()
# Out:
# /var/tmp/ipykernel_5317/3429959399.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="sentiment_group", data=df, order=["Negative","Neutral","Positive"], palette="coolwarm")

# %% [markdown]
# # ✍️ 4. Review Length & Engagement

# %%
sns.histplot(df['review_length'], bins=50, kde=True)
plt.title("Review Length Distribution")
plt.show()

sns.boxplot(x="review_rating", y="review_length", data=df, palette="magma")
plt.title("Review Length by Rating")
plt.show()
# Out:
# /var/tmp/ipykernel_5317/2932125478.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="review_rating", y="review_length", data=df, palette="magma")

# %% [markdown]
# # 👥 5. Reviewer Behavior

# %%
sns.histplot(df['author_reviews_count'], bins=30, log_scale=True)
plt.title("Distribution of Reviewer Activity (# Reviews by Author)")
plt.show()

df['is_frequent'] = df['author_reviews_count'] > 5
sns.boxplot(x="is_frequent", y="review_rating", data=df, palette="Set2")
plt.title("Frequent vs One-Time Reviewers (Rating Bias)")
plt.xticks([0,1], ["One-time","Frequent"])
plt.show()
# Out:
# /var/tmp/ipykernel_5317/3163081248.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="is_frequent", y="review_rating", data=df, palette="Set2")

# %% [markdown]
# # 🔁 6. Owner Response Behavior

# %%
sns.barplot(x="review_rating", y=df['owner_answer'].notna(), data=df, estimator=np.mean, palette="crest")
plt.title("Response Rate by Rating")
plt.ylabel("Response Rate")
plt.show()

sns.barplot(x="sentiment_group", y=df['owner_answer'].notna(), data=df, estimator=np.mean, palette="rocket")
plt.title("Response Rate by Sentiment")
plt.ylabel("Response Rate")
plt.show()
# Out:
# /var/tmp/ipykernel_5317/3810842962.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="review_rating", y=df['owner_answer'].notna(), data=df, estimator=np.mean, palette="crest")
# /var/tmp/ipykernel_5317/3810842962.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="sentiment_group", y=df['owner_answer'].notna(), data=df, estimator=np.mean, palette="rocket")

# %% [markdown]
# # ☁️ 7. Word Cloud & Keywords

# %%
text = " ".join(df['review_text'].dropna().astype(str).values)

wc = WordCloud(width=800, height=400, background_color="white", colormap="viridis").generate(text)
plt.figure(figsize=(12,6))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.title("Most Frequent Words in Reviews")
plt.show()

# TF-IDF Keywords
tfidf = TfidfVectorizer(stop_words='english', max_features=20, ngram_range=(1,2))
tfidf_matrix = tfidf.fit_transform(df['review_text'].dropna().astype(str))
keywords = pd.DataFrame({
    "keyword": tfidf.get_feature_names_out(),
    "score": tfidf_matrix.sum(axis=0).A1
}).sort_values(by="score", ascending=False)

print("Top Keywords:\n", keywords)
# Out:
# Top Keywords:
#              keyword      score
# 6          hospital  70.955124
# 17            staff  37.759319
# 15          service  34.681916
# 5              good  26.883168
# 16        singapore  22.923136
# 1            doctor  22.258259
# 12           nurses  21.501268
# 2           doctors  19.982201
# 4        experience  19.169664
# 10            mount  18.494609
# 19             time  18.218455
# 14           really  17.725766
# 7              just  16.750160
# 3         elizabeth  16.747877
# 9           medical  16.274744
# 13          patient  15.544388
# 11  mount elizabeth  14.249894
# 0               day  13.798537
# 8              like  13.305203
# 18          surgery  12.830575

# %% [markdown]
# # 🗝 8. Topic Modeling (LDA)

# %%
cv = CountVectorizer(stop_words='english', max_df=0.9, min_df=5)
cv_matrix = cv.fit_transform(df['review_text'].dropna().astype(str))

lda = LatentDirichletAllocation(n_components=5, random_state=42)
lda.fit(cv_matrix)

def display_topics(model, feature_names, no_top_words=8):
    for idx, topic in enumerate(model.components_):
        print(f"Topic {idx+1}: ", [feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]])

display_topics(lda, cv.get_feature_names_out())
# Out:
# Topic 1:  ['hospital', 'nurse', 'patient', 'staff', 'doctor', 'asked', 'time', 'come']
# Topic 2:  ['hospital', 'staff', 'service', 'singapore', 'dr', 'surgery', 'mount', 'elizabeth']
# Topic 3:  ['service', 'hospital', 'experience', 'nurses', 'great', 'asked', 'stay', 'poor']
# Topic 4:  ['hospital', 'staff', 'nurses', 'mt', 'baby', 'friendly', 'like', 'hospitals']
# Topic 5:  ['doctor', 'good', 'hospital', 'treatment', 'place', 'got', 'clinic', 'di']

# %% [markdown]
# # 📌 9. KPI Summary (Text Output)

# %%
summary = {
    "Average Rating": round(df['review_rating'].mean(),2),
    "Average Sentiment": round(df['sentiment'].mean(),2),
    "Response Rate (%)": round(df['owner_answer'].notna().mean()*100,2),
    "One-time Reviewer %": round((df['author_reviews_count'] == 1).mean()*100,2),
    "Frequent Reviewer %": round((df['author_reviews_count'] > 5).mean()*100,2),
    "Avg Review Length": round(df['review_length'].mean(),2),
    "Avg Likes": round(df['review_likes'].mean(skipna=True),2)
}
print("📊 KPI Dashboard:\n")
for k,v in summary.items():
    print(f"{k}: {v}")
# Out:
# 📊 KPI Dashboard:
#
# Average Rating: 3.61
# Average Sentiment: 0.1
# Response Rate (%): 39.5
# One-time Reviewer %: 8.29
# Frequent Reviewer %: 65.32
# Avg Review Length: 239.43
# Avg Likes: nan

# %%
# =============================
# 📌 9. Enhanced KPI Summary
# =============================

summary = {
    "Average Rating": round(df['review_rating'].mean(),2),
    "Average Sentiment": round(df['sentiment'].mean(),2),
    "Response Rate (%)": round(df['owner_answer'].notna().mean()*100,2),
    "One-time Reviewer %": round((df['author_reviews_count'] == 1).mean()*100,2),
    "Frequent Reviewer %": round((df['author_reviews_count'] > 5).mean()*100,2),
    "Avg Review Length": round(df['review_length'].mean(),2),
    "Avg Likes": round(df['review_likes'].mean(skipna=True),2)
}

# % Rating distribution
rating_dist = df['review_rating'].value_counts(normalize=True).sort_index() * 100
for rating, pct in rating_dist.items():
    summary[f"Rating {rating} %"] = round(pct,2)

# % Sentiment distribution
sentiment_dist = df['sentiment_group'].value_counts(normalize=True) * 100
for sentiment, pct in sentiment_dist.items():
    summary[f"{sentiment} Sentiment %"] = round(pct,2)

print("📊 KPI Dashboard:\n")
for k,v in summary.items():
    print(f"{k}: {v}")
# Out:
# 📊 KPI Dashboard:
#
# Average Rating: 3.61
# Average Sentiment: 0.1
# Response Rate (%): 39.5
# One-time Reviewer %: 8.29
# Frequent Reviewer %: 65.32
# Avg Review Length: 239.43
# Avg Likes: nan
# Rating 1 %: 25.24
# Rating 2 %: 5.78
# Rating 3 %: 5.39
# Rating 4 %: 10.4
# Rating 5 %: 53.18
# Neutral Sentiment %: 53.5
# Positive Sentiment %: 35.41
# Negative Sentiment %: 11.09

# %%
import matplotlib.pyplot as plt

# =============================
# 📊 10. KPI Visualizations
# =============================

# --- Ratings Distribution ---
rating_dist = df['review_rating'].value_counts(normalize=True).sort_index() * 100

plt.figure(figsize=(6,4))
rating_dist.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title("Ratings Distribution (%)")
plt.xlabel("Star Rating")
plt.ylabel("Percentage (%)")
plt.xticks(rotation=0)
plt.show()

# --- Sentiment Distribution ---
sentiment_dist = df['sentiment_group'].value_counts(normalize=True) * 100

plt.figure(figsize=(6,4))
sentiment_dist.plot(kind='bar', color=['red','grey','green'], edgecolor='black')
plt.title("Sentiment Distribution (%)")
plt.xlabel("Sentiment Group")
plt.ylabel("Percentage (%)")
plt.xticks(rotation=0)
plt.show()

# %%
# =============================
# 📌 11. Top Positive & Negative Reviews
# =============================

# Sort by sentiment score
top_positive = df.sort_values(by='sentiment', ascending=False).head(10)[['review_text','review_rating','sentiment']]
top_negative = df.sort_values(by='sentiment', ascending=True).head(10)[['review_text','review_rating','sentiment']]

print("🔥 Top 10 Positive Reviews (by sentiment):\n")
for i, row in top_positive.iterrows():
    print(f"⭐ Rating: {row['review_rating']} | Sentiment: {round(row['sentiment'],2)}")
    print(row['review_text'])
    print("-"*80)

print("\n⚠️ Top 10 Negative Reviews (by sentiment):\n")
for i, row in top_negative.iterrows():
    print(f"⭐ Rating: {row['review_rating']} | Sentiment: {round(row['sentiment'],2)}")
    print(row['review_text'])
    print("-"*80)
# Out:
# 🔥 Top 10 Positive Reviews (by sentiment):
#
# ⭐ Rating: 4 | Sentiment: 1.0
# Excellent as well as de charges...
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: 1.0
# Awesome experience
# --------------------------------------------------------------------------------
# ⭐ Rating: 4 | Sentiment: 1.0
# it is a best class hospital
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: 1.0
# Locals hail this as one of the best hospitals in Singapore
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: 1.0
# Best hospital in the world..excellent service
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: 1.0
# Best hospital in singapore 🇸🇬🇸🇬🇸🇬❤
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: 1.0
# Best Hospital
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: 1.0
# Awesome.
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: 1.0
# Excellent prices. 3 hours in hospital 2.500 $. 😉
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: 1.0
# Excellent surgical Hospital.
# --------------------------------------------------------------------------------
#
# ⚠️ Top 10 Negative Reviews (by sentiment):
#
# ⭐ Rating: 5 | Sentiment: -1.0
# Fira Syafira Cepet sembuh Ya ma
# Papa kangen ma Fira Syafira
# Papa gk mau hilang mama
# :'(
# --------------------------------------------------------------------------------
# ⭐ Rating: 1 | Sentiment: -1.0
# Worst parking situation ever
# --------------------------------------------------------------------------------
# ⭐ Rating: 2 | Sentiment: -1.0
# Awfully overpriced.
# --------------------------------------------------------------------------------
# ⭐ Rating: 1 | Sentiment: -1.0
# Terrible.
# --------------------------------------------------------------------------------
# ⭐ Rating: 2 | Sentiment: -1.0
# Without mentioning about doctor quality, the service is awful. I am foreigner coming for PET check but they keep dragging my schedule. Until am about to stave that i got my turn, despite of my booking since i havent come to Singapore. What a horrible experience
# --------------------------------------------------------------------------------
# ⭐ Rating: 2 | Sentiment: -0.61
# This hospital is not what it used to be. Bad experience from A&E through to discharge. Staff training is very poor.
# --------------------------------------------------------------------------------
# ⭐ Rating: 3 | Sentiment: -0.52
# Very poor customer service. I asked to book just tests but was scheduled for a visit to the doctor instead. In the end, I chose another hospital because the customer service officer had no clue or understanding of what I was asking for.
# --------------------------------------------------------------------------------
# ⭐ Rating: 1 | Sentiment: -0.51
# Went for a Sapphire exec check
# Extremely uncoordinated efforts between clinics. Poor operations management within the radiology clinic. Pathetic service and empathy by the staff.
# --------------------------------------------------------------------------------
# ⭐ Rating: 1 | Sentiment: -0.45
# Very bad service. I am admitted under my company LOG. However, mount Elizabeth charge to my personal insurance. When I write to them asking what is happening, no one reply me. I need to settle between 2 insurance company myself
# --------------------------------------------------------------------------------
# ⭐ Rating: 1 | Sentiment: -0.42
# Went down to e pharmacy to get medicine as ive got e prescription letter from my doctor but pharmacist name Poh Wan Lin was just so very rude. Abit disappointed with e treatment that ive got. Haizzz!
# --------------------------------------------------------------------------------

# %%
rating_dist
# Out:
# review_rating
# 1    25.240848
# 2     5.780347
# 3     5.394990
# 4    10.404624
# 5    53.179191
# Name: proportion, dtype: float64

# %%
# --- Base KPI Metrics ---
kpi_data = {
    "Average Rating": round(df['review_rating'].mean(),2),
    "Average Sentiment": round(df['sentiment'].mean(),2),
    "Response Rate (%)": round(df['owner_answer'].notna().mean()*100,2),
    "One-time Reviewer %": round((df['author_reviews_count'] == 1).mean()*100,2),
    "Frequent Reviewer %": round((df['author_reviews_count'] > 5).mean()*100,2),
    "Avg Review Length": round(df['review_length'].mean(),2),
    "Avg Likes": round(df['review_likes'].mean(skipna=True),2)
}

# Rating % Distribution
rating_dist = df['review_rating'].value_counts(normalize=True).sort_index() * 100
for rating, pct in rating_dist.items():
    kpi_data[f"Rating {rating} %"] = round(pct,2)

# Sentiment % Distribution
sentiment_dist = df['sentiment_group'].value_counts(normalize=True) * 100
for sentiment, pct in sentiment_dist.items():
    kpi_data[f"{sentiment} Sentiment %"] = round(pct,2)

# --- Top Reviews Extraction ---
top_positive = df.sort_values(by='sentiment', ascending=False).head(10)[['review_text','review_rating','sentiment']]
top_negative = df.sort_values(by='sentiment', ascending=True).head(10)[['review_text','review_rating','sentiment']]

# Convert reviews into a single string (shortened for table)
pos_reviews_str = "\n\n".join([f"⭐{row['review_rating']} (sent={round(row['sentiment'],2)}): {row['review_text'][:150]}..." 
                               for _,row in top_positive.iterrows()])

neg_reviews_str = "\n\n".join([f"⭐{row['review_rating']} (sent={round(row['sentiment'],2)}): {row['review_text'][:150]}..." 
                               for _,row in top_negative.iterrows()])

# Add to KPI data
kpi_data["Top 10 Positive Reviews"] = pos_reviews_str
kpi_data["Top 10 Negative Reviews"] = neg_reviews_str

# --- Final KPI Table ---
kpi_df = pd.DataFrame(list(kpi_data.items()), columns=["Metric","Value"])

# Replace the custom module with standard pandas display
# Instead of: import caas_jupyter_tools
# Instead of: caas_jupyter_tools.display_dataframe_to_user("KPI Dashboard with Reviews", kpi_df)
display(kpi_df)  # This is the standard way to display dataframes in Jupyter notebooks
# Out:
#                      Metric                                              Value
# 0            Average Rating                                               3.61
# 1         Average Sentiment                                                0.1
# 2         Response Rate (%)                                               39.5
# 3       One-time Reviewer %                                               8.29
# 4       Frequent Reviewer %                                              65.32
# 5         Avg Review Length                                             239.43
# 6                 Avg Likes                                                NaN
# 7                Rating 1 %                                              25.24
# 8                Rating 2 %                                               5.78
# 9                Rating 3 %                                               5.39
# 10               Rating 4 %                                               10.4
# 11               Rating 5 %                                              53.18
# 12      Neutral Sentiment %                                               53.5
# 13     Positive Sentiment %                                              35.41
# 14     Negative Sentiment %                                              11.09
# 15  Top 10 Positive Reviews  ⭐4 (sent=1.0): Excellent as well as de charges...
# 16  Top 10 Negative Reviews  ⭐5 (sent=-1.0): Fira Syafira Cepet sembuh Ya m...

# %%
# =============================
# 📊 Weekly Ratings Trend
# =============================

# Ensure datetime is parsed
df['review_datetime_utc'] = pd.to_datetime(df['review_datetime_utc'], errors='coerce')

# Resample weekly average ratings
weekly_ratings = df.set_index('review_datetime_utc').resample('W')['review_rating'].mean()

# Plot
plt.figure(figsize=(14,6))
weekly_ratings.plot(marker='o', linewidth=1.5, alpha=0.8)
plt.title("Weekly Average Ratings Over Time")
plt.xlabel("Week")
plt.ylabel("Average Rating")
plt.grid(True, alpha=0.3)
plt.show()

# %%
import base64
import pandas as pd
import json
import vertexai
import tiktoken # A popular tokenizer, though not directly from google-generativeai
import time
from vertexai.generative_models import GenerativeModel, Part, SafetySetting
import warnings
warnings.filterwarnings("ignore")

project_name = !(gcloud config get-value core/project)
project_name = project_name[0]

# %%
#Gemini
class LLM_model:
    def __init__(self, project, location, model_name):
        self.project = project
        self.location = location
        self.model_name = model_name
        self.generation_config = {
            "max_output_tokens": 8192,
            "temperature": 1,
            "top_p": 0.95,
        }
        self.safety_settings = [
            SafetySetting(
                category=SafetySetting.HarmCategory.HARM_CATEGORY_HATE_SPEECH,
                threshold=SafetySetting.HarmBlockThreshold.OFF
            ),
            SafetySetting(
                category=SafetySetting.HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT,
                threshold=SafetySetting.HarmBlockThreshold.OFF
            ),
            SafetySetting(
                category=SafetySetting.HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT,
                threshold=SafetySetting.HarmBlockThreshold.OFF
            ),
            SafetySetting(
                category=SafetySetting.HarmCategory.HARM_CATEGORY_HARASSMENT,
                threshold=SafetySetting.HarmBlockThreshold.OFF
            ),
        ]
        vertexai.init(project=self.project, location=self.location)
        self.model = GenerativeModel(self.model_name)

    def complete(self, text):
        chat = self.model.start_chat()
        result=chat.send_message([text],
                                 generation_config=self.generation_config,
                                 safety_settings=self.safety_settings
        )
        text_result=result.candidates[0].content.parts[0].text
        return text_result
# Example usage:
llm_gemini = LLM_model(project_name, 
                       "us-central1", 
                       "gemini-2.5-pro")

# %%
def sentiment_analysis(feedback, llm, llm_type='gemini'):
    prompt = f"""
    Role: You are an AI Specialist analysing customer feedback from Google reviews. Your role is to understand the given context
    and perform the task provided as appropriately.

    Context: The feedbacks are given by the patients or the bystanders of patients who went for treatment to the hospital.

    Task:
    1. Analyze the sentiment of the customer feedback if it’s positive, negative, or neutral.
    2. If the feedback is neither positive nor negative but just neutrally stating an info or suggestion,
       or is a non-meaningful feedback like 'Yes', 'No', 'Nil', 'na', 'N:A', 'N/a', 'n/a',
       'not applicable' or 'no comment', the sentiment is neutral.
    3. If sentiment is positive, return 'Positive'.
    4. If sentiment is negative, return 'Negative'.
    5. If sentiment is neutral, return 'Neutral'. Do not include other words or explanation.

    This is the customer feedback: {feedback}

    Examples:
    Its convenient, easy, fast: Positive.
    Nil: Neutral.
    Customer service not professional: Negative.
    
    Output:
    1. provide the classification of sentiment - Positive, Negative, Neutral   
    
    """

    try:
        if llm_type == 'gemini':
            result = llm.complete(prompt)
        else:
            result = llm.complete(prompt).text
        return result.strip()
    except Exception as e:
        print(f"Error processing row: {e}")
        return None  # Use None unless you're sure np.nan is needed and numpy is imported

# %%
def Information_extraction(feedback, llm, llm_type='gemini'):
    prompt = f"""
    Role: You are an AI Specialist analysing customer feedback from Google reviews. Your role is to understand the given context
    and perform the task provided as appropriately.

    Context: The feedbacks are given by the patients or the bystanders of patients who went for treatment to the hospital.

    Task:
    1. Analyze the feedback from the below mentioned topics and extract the information and provide as an output. If 
    the topics not found, mention as not found.
    1.1 From the whole feedback, extract the core issue, summarize the patient experience in 5 words and then
    follow the below tasks.
    2. Hospital Topic: 
        a. Does the review mention a specific ward, block or room number? if yes, extract it.
        b. Does the review mention about the department e.g: Endoscopy, Pharmacy, etc., if yes, extract it.
        c. Does the review describe whether the hospital is old, upgraded or modern?
    3. Staff & Service Topic:
        a. Does the review mention Doctors? if yes, extract it.
        b. Does the review mention nurses? if yes, extract it.
        c. Does the review mention support or admin staff? if yes, extract it.
        d. Does the review mention specific staff names? Extract them.
    4. Patient Experience:
        a. Does the review mention specific treatments or medical procedures (e.g. delivery, surgery)?
        b. What aspects of service quality are highlighted (e.g. attentiveness, professionalism, rudeness)?
        c. Does the reviewer mention waiting time? if yes, how long?
        d. Does the review mention food quality or any other quality (e.g. bedsheets, bathroom or cafeteria)?
    5. Complaints & Negative Aspects:
        a. Does the reviewer mention rude staff? Extract the details.
        b. Does the reviewer mention delays, long queues or poor management? Extract waiting times if given.
        c. Does the review mention unfair rules or inconsistent policies (e.g. visitor entry)?
        d. Does the reviewer explicitly call the hospital horrible, worst, terrifying, or disappointing?
        e. Does the review suggest profit motive or unnecessary procedures?
        f. Does the reviewer perceive fraudulent activity from the hospital?
    6. For each of the topics and its sub questions, provide output. If not found, mention as "Not found in feedback"

    This is the customer feedback: {feedback}

    Output:
    1. Provide the output in key-value pairs as JSON.
    2. Keys are only the core issue, summary, and the sub-questions (topic names not required).
    3. Values are the extracted output from the feedback.
    """

    # Token estimation
    try:
        import tiktoken
        enc = tiktoken.get_encoding("cl100k_base")
        prompt_tokens = len(enc.encode(prompt))
        print(f"Estimated input tokens (prompt): {prompt_tokens}")
    except ImportError:
        print("Install 'tiktoken' (pip install tiktoken) for token estimation.")
        prompt_tokens = -1

    # LLM completion
    try:
        if llm_type == 'gemini':
            result = llm.complete(prompt)
        else:
            result = llm.complete(prompt).text
        result = result.strip()
    except Exception as e:
        print(f"Error processing row: {e}")
        return None

    # Token estimation for response
    try:
        response_tokens = len(enc.encode(result))
        print(f"Estimated output tokens (response): {response_tokens}")
    except Exception:
        response_tokens = -1

    # Total token count
    if prompt_tokens != -1 and response_tokens != -1:
        total_estimated_tokens = prompt_tokens + response_tokens
        print(f"Total estimated tokens (prompt + response): {total_estimated_tokens}")

    return result

# %%
# Load dataset
df_MtEli = pd.read_excel("Mount Elizabeth Hospital.xlsx")
# Display basic info
print(df_MtEli.shape)
df_MtEli.head()
# Out:
# (519, 35)
#                                    query                      name  \
# 0  0x31da19925a494a9d:0xe3db3f1109109b86  Mount Elizabeth Hospital
# 1  0x31da19925a494a9d:0xe3db3f1109109b86  Mount Elizabeth Hospital
# 2  0x31da19925a494a9d:0xe3db3f1109109b86  Mount Elizabeth Hospital
# 3  0x31da19925a494a9d:0xe3db3f1109109b86  Mount Elizabeth Hospital
# 4  0x31da19925a494a9d:0xe3db3f1109109b86  Mount Elizabeth Hospital
#
#                                google_id                     place_id  \
# 0  0x31da19925a494a9d:0xe3db3f1109109b86  ChIJnUpJWpIZ2jERhpsQCRE_2-M
# 1  0x31da19925a494a9d:0xe3db3f1109109b86  ChIJnUpJWpIZ2jERhpsQCRE_2-M
# 2  0x31da19925a494a9d:0xe3db3f1109109b86  ChIJnUpJWpIZ2jERhpsQCRE_2-M
# 3  0x31da19925a494a9d:0xe3db3f1109109b86  ChIJnUpJWpIZ2jERhpsQCRE_2-M
# 4  0x31da19925a494a9d:0xe3db3f1109109b86  ChIJnUpJWpIZ2jERhpsQCRE_2-M
#
#                                        location_link  \
# 0  https://www.google.com/maps/place/Mount+Elizab...
# 1  https://www.google.com/maps/place/Mount+Elizab...
# 2  https://www.google.com/maps/place/Mount+Elizab...
# 3  https://www.google.com/maps/place/Mount+Elizab...
# 4  https://www.google.com/maps/place/Mount+Elizab...
#
#                                         reviews_link  reviews  rating  \
# 0  https://search.google.com/local/reviews?placei...      527     3.6
# 1  https://search.google.com/local/reviews?placei...      527     3.6
# 2  https://search.google.com/local/reviews?placei...      527     3.6
# 3  https://search.google.com/local/reviews?placei...      527     3.6
# 4  https://search.google.com/local/reviews?placei...      527     3.6
#
#                                            review_id  \
# 0  Ci9DQUlRQUNvZENodHljRjlvT2pCUWRGRklPRlExUVVGa0...
# 1  Ci9DQUlRQUNvZENodHljRjlvT2taVk1HUkhRelp5UTA1dl...
# 2  Ci9DQUlRQUNvZENodHljRjlvT2s5eFNIRTBVWGRQUTB4Mm...
# 3  Ci9DQUlRQUNvZENodHljRjlvT21oSlRUWk9MVzloTnpGWl...
# 4  Ci9DQUlRQUNvZENodHljRjlvT21WU2NIRlJOa1E0UkdGVV...
#
#                                 review_pagination_id  ... review_rating  \
# 0  CAESYENBRVFBUnBDUTJrNFNVRlNTVzVEWjI5QlVEY3lSMk...  ...             5
# 1  CAESY0NBRVFBaHBFUTJwRlNVRlNTWEJEWjI5QlVEY3lSMk...  ...             5
# 2  CAESYENBRVFBeHBDUTJrNFNVRlNTVzVEWjI5QlVEY3lSMl...  ...             1
# 3  CAESYENBRVFCQnBDUTJrNFNVRlNTVzVEWjI5QlVEY3lSMl...  ...             1
# 4  CAESYENBRVFCUnBDUTJrNFNVRlNTVzVEWjI5QlVEY3lSMm...  ...             5
#
#   review_timestamp  review_datetime_utc review_likes           reviews_id  \
# 0       1756278043  08/27/2025 07:00:43          NaN -2027957864801199226
# 1       1755667212  08/20/2025 05:20:12          NaN -2027957864801199226
# 2       1753760320  07/29/2025 03:38:40          NaN -2027957864801199226
# 3       1753580132  07/27/2025 01:35:32          NaN -2027957864801199226
# 4       1752249513  07/11/2025 15:58:33          NaN -2027957864801199226
#
#    reviews_per_score_1 reviews_per_score_2 reviews_per_score_3  \
# 0                  131                  30                  28
# 1                  131                  30                  28
# 2                  131                  30                  28
# 3                  131                  30                  28
# 4                  131                  30                  28
#
#   reviews_per_score_4  reviews_per_score_5
# 0                  54                  284
# 1                  54                  284
# 2                  54                  284
# 3                  54                  284
# 4                  54                  284
#
# [5 rows x 35 columns]

# %%
with open("text_reviews_MountEli.txt", "w", encoding="utf-8") as f:
    for i, row in df_MtEli.iterrows():
        f.write(f"--- Review #{i + 1} ---\n")
        f.write(f"Datetime: {row['review_datetime_utc']}\n")
        f.write(f"User: {row['author_title']}\n")
        f.write(f"Review: {row['review_text']}\n")
        f.write("--- End of Review ---\n\n")

# %%
df_MtEli.head().transpose()


df_MtEli_reviewtext = df_MtEli.review_text


df_MtEli_reviewtext.iloc[1:10]
# Out:
# 1    Went to A&E after hours- even for a non-urgent...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                          Famous and legende hospital
# 6    I tried to fill a prescription for warfarin, t...
# 7    Review for Dr. Nicolas Kon – Mount Elizabeth H...
# 8                                                  NaN
# 9                                            Terrible.
# Name: review_text, dtype: object

# %%
import json
import fitz  # PyMuPDF
counter = 0
# Assuming df_Gleangles_reviewtext and Information_extraction are already defined
with open("review_output_MtElizabeth.txt", "w", encoding="utf-8") as f:
    for idx,review in enumerate(df_MtEli_reviewtext,start=0):
        
        start_time = time.time()
        print(f"Processing row {idx}...")

        example_output = Information_extraction(review, llm_gemini)
        o = example_output.replace('```', '')
        
        cleaned_output = o.replace('json', '')
        
        
        try:
            # If the output contains extra text before/after JSON, isolate the JSON part
            start = cleaned_output.find('{')
            end = cleaned_output.rfind('}') + 1
            json_str = cleaned_output[start:end]

            # Parse the JSON
            ie_output_dict = json.loads(json_str)
        except json.JSONDecodeError as e:
            print("JSON decoding failed:", e)
            print("Raw output:", cleaned_output)
            ie_output_dict = None

        
        f.write("Original Review:\n")
        f.write(str(review) + "\n")
        f.write("Extracted Information:\n")
        f.write(json.dumps(ie_output_dict, indent=4))
        f.write("\n---------------------------------------------------\n")

        f.write("Next Review ########################################\n\n")
        

        elapsed_time = time.time() - start_time
        print(f"Row {idx} processed in {elapsed_time:.2f} seconds.\n")
# Out:
# Processing row 0...
# Estimated input tokens (prompt): 584
# Estimated output tokens (response): 277
# Total estimated tokens (prompt + response): 861
# Row 0 processed in 12.93 seconds.
#
# Processing row 1...
# Estimated input tokens (prompt): 647
# Estimated output tokens (response): 479
# Total estimated tokens (prompt + response): 1126
# Row 1 processed in 19.18 seconds.
#
# Processing row 2...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 438
# Total estimated tokens (prompt + response): 1006
# Row 2 processed in 11.42 seconds.
#
# Processing row 3...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 263
# Total estimated tokens (prompt + response): 831
# Row 3 processed in 9.80 seconds.
#
# Processing row 4...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 439
# Total estimated tokens (prompt + response): 1007
# Row 4 processed in 11.64 seconds.
#
# Processing row 5...
# Estimated input tokens (prompt): 572
# Estimated output tokens (response): 258
# Total estimated tokens (prompt + response): 830
# Row 5 processed in 10.40 seconds.
#
# Processing row 6...
# Estimated input tokens (prompt): 765
# Estimated output tokens (response): 332
# Total estimated tokens (prompt + response): 1097
# Row 6 processed in 14.25 seconds.
#
# Processing row 7...
# Estimated input tokens (prompt): 816
# Estimated output tokens (response): 389
# Total estimated tokens (prompt + response): 1205
# Row 7 processed in 19.17 seconds.
#
# Processing row 8...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 254
# Total estimated tokens (prompt + response): 822
# Row 8 processed in 9.41 seconds.
#
# Processing row 9...
# Estimated input tokens (prompt): 569
# Estimated output tokens (response): 300
# Total estimated tokens (prompt + response): 869
# Row 9 processed in 12.86 seconds.
#
# Processing row 10...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 261
# Total estimated tokens (prompt + response): 829
# Row 10 processed in 14.29 seconds.
#
# Processing row 11...
# Estimated input tokens (prompt): 573
# Estimated output tokens (response): 476
# Total estimated tokens (prompt + response): 1049
# Row 11 processed in 14.09 seconds.
#
# Processing row 12...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 271
# Total estimated tokens (prompt + response): 839
# Row 12 processed in 11.96 seconds.
#
# Processing row 13...
# Estimated input tokens (prompt): 614
# Estimated output tokens (response): 332
# Total estimated tokens (prompt + response): 946
# Row 13 processed in 15.06 seconds.
#
# Processing row 14...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 278
# Total estimated tokens (prompt + response): 846
# Row 14 processed in 12.23 seconds.
#
# Processing row 15...
# Estimated input tokens (prompt): 729
# Estimated output tokens (response): 495
# Total estimated tokens (prompt + response): 1224
# Row 15 processed in 18.40 seconds.
#
# Processing row 16...
# Estimated input tokens (prompt): 771
# Estimated output tokens (response): 369
# Total estimated tokens (prompt + response): 1140
# Row 16 processed in 23.34 seconds.
#
# Processing row 17...
# Estimated input tokens (prompt): 692
# Estimated output tokens (response): 521
# Total estimated tokens (prompt + response): 1213
# Row 17 processed in 18.53 seconds.
#
# Processing row 18...
# Estimated input tokens (prompt): 707
# Estimated output tokens (response): 546
# Total estimated tokens (prompt + response): 1253
# Row 18 processed in 17.39 seconds.
#
# Processing row 19...
# Estimated input tokens (prompt): 655
# Estimated output tokens (response): 513
# Total estimated tokens (prompt + response): 1168
# Row 19 processed in 15.79 seconds.
#
# Processing row 20...
# Estimated input tokens (prompt): 588
# Estimated output tokens (response): 491
# Total estimated tokens (prompt + response): 1079
# Row 20 processed in 17.57 seconds.
#
# Processing row 21...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 240
# Total estimated tokens (prompt + response): 808
# Row 21 processed in 9.10 seconds.
#
# Processing row 22...
# Estimated input tokens (prompt): 790
# Estimated output tokens (response): 493
# Total estimated tokens (prompt + response): 1283
# Row 22 processed in 19.29 seconds.
#
# Processing row 23...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 250
# Total estimated tokens (prompt + response): 818
# Row 23 processed in 11.41 seconds.
#
# Processing row 24...
# Estimated input tokens (prompt): 691
# Estimated output tokens (response): 403
# Total estimated tokens (prompt + response): 1094
# Row 24 processed in 16.81 seconds.
#
# Processing row 25...
# Estimated input tokens (prompt): 621
# Estimated output tokens (response): 350
# Total estimated tokens (prompt + response): 971
# Row 25 processed in 14.34 seconds.
#
# Processing row 26...
# Estimated input tokens (prompt): 630
# Estimated output tokens (response): 314
# Total estimated tokens (prompt + response): 944
# Row 26 processed in 12.60 seconds.
#
# Processing row 27...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 287
# Total estimated tokens (prompt + response): 855
# Row 27 processed in 13.20 seconds.
#
# Processing row 28...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 257
# Total estimated tokens (prompt + response): 825
# Row 28 processed in 9.22 seconds.
#
# Processing row 29...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 284
# Total estimated tokens (prompt + response): 852
# Row 29 processed in 12.11 seconds.
#
# Processing row 30...
# Estimated input tokens (prompt): 645
# Estimated output tokens (response): 364
# Total estimated tokens (prompt + response): 1009
# Row 30 processed in 16.87 seconds.
#
# Processing row 31...
# Estimated input tokens (prompt): 829
# Estimated output tokens (response): 484
# Total estimated tokens (prompt + response): 1313
# Row 31 processed in 18.73 seconds.
#
# Processing row 32...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 266
# Total estimated tokens (prompt + response): 834
# Row 32 processed in 12.94 seconds.
#
# Processing row 33...
# Estimated input tokens (prompt): 806
# Estimated output tokens (response): 360
# Total estimated tokens (prompt + response): 1166
# Row 33 processed in 14.59 seconds.
#
# Processing row 34...
# Estimated input tokens (prompt): 636
# Estimated output tokens (response): 388
# Total estimated tokens (prompt + response): 1024
# Row 34 processed in 16.24 seconds.
#
# Processing row 35...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 249
# Total estimated tokens (prompt + response): 817
# Row 35 processed in 10.48 seconds.
#
# Processing row 36...
# Estimated input tokens (prompt): 793
# Estimated output tokens (response): 549
# Total estimated tokens (prompt + response): 1342
# Row 36 processed in 31.41 seconds.
#
# Processing row 37...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 438
# Total estimated tokens (prompt + response): 1006
# Row 37 processed in 12.90 seconds.
#
# Processing row 38...
# Estimated input tokens (prompt): 672
# Estimated output tokens (response): 296
# Total estimated tokens (prompt + response): 968
# Row 38 processed in 10.70 seconds.
#
# Processing row 39...
# Estimated input tokens (prompt): 949
# Estimated output tokens (response): 635
# Total estimated tokens (prompt + response): 1584
# Row 39 processed in 19.57 seconds.
#
# Processing row 40...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 236
# Total estimated tokens (prompt + response): 804
# Row 40 processed in 10.53 seconds.
#
# Processing row 41...
# Estimated input tokens (prompt): 722
# Estimated output tokens (response): 508
# Total estimated tokens (prompt + response): 1230
# Row 41 processed in 22.00 seconds.
#
# Processing row 42...
# Estimated input tokens (prompt): 637
# Estimated output tokens (response): 394
# Total estimated tokens (prompt + response): 1031
# Row 42 processed in 14.86 seconds.
#
# Processing row 43...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 249
# Total estimated tokens (prompt + response): 817
# Row 43 processed in 10.37 seconds.
#
# Processing row 44...
# Estimated input tokens (prompt): 828
# Estimated output tokens (response): 625
# Total estimated tokens (prompt + response): 1453
# Row 44 processed in 21.31 seconds.
#
# Processing row 45...
# Estimated input tokens (prompt): 586
# Estimated output tokens (response): 259
# Total estimated tokens (prompt + response): 845
# Row 45 processed in 23.49 seconds.
#
# Processing row 46...
# Estimated input tokens (prompt): 590
# Estimated output tokens (response): 477
# Total estimated tokens (prompt + response): 1067
# Row 46 processed in 15.52 seconds.
#
# Processing row 47...
# Estimated input tokens (prompt): 638
# Estimated output tokens (response): 380
# Total estimated tokens (prompt + response): 1018
# Row 47 processed in 13.73 seconds.
#
# Processing row 48...
# Estimated input tokens (prompt): 707
# Estimated output tokens (response): 572
# Total estimated tokens (prompt + response): 1279
# Row 48 processed in 13.51 seconds.
#
# Processing row 49...
# Estimated input tokens (prompt): 706
# Estimated output tokens (response): 390
# Total estimated tokens (prompt + response): 1096
# Row 49 processed in 13.19 seconds.
#
# Processing row 50...
# Estimated input tokens (prompt): 636
# Estimated output tokens (response): 306
# Total estimated tokens (prompt + response): 942
# Row 50 processed in 15.77 seconds.
#
# Processing row 51...
# Estimated input tokens (prompt): 655
# Estimated output tokens (response): 357
# Total estimated tokens (prompt + response): 1012
# Row 51 processed in 14.95 seconds.
#
# Processing row 52...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 249
# Total estimated tokens (prompt + response): 817
# Row 52 processed in 9.25 seconds.
#
# Processing row 53...
# Estimated input tokens (prompt): 706
# Estimated output tokens (response): 413
# Total estimated tokens (prompt + response): 1119
# Row 53 processed in 14.61 seconds.
#
# Processing row 54...
# Estimated input tokens (prompt): 571
# Estimated output tokens (response): 288
# Total estimated tokens (prompt + response): 859
# Row 54 processed in 11.16 seconds.
#
# Processing row 55...
# Estimated input tokens (prompt): 675
# Estimated output tokens (response): 391
# Total estimated tokens (prompt + response): 1066
# Row 55 processed in 20.46 seconds.
#
# Processing row 56...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 256
# Total estimated tokens (prompt + response): 824
# Row 56 processed in 8.80 seconds.
#
# Processing row 57...
# Estimated input tokens (prompt): 679
# Estimated output tokens (response): 332
# Total estimated tokens (prompt + response): 1011
# Row 57 processed in 14.07 seconds.
#
# Processing row 58...
# Estimated input tokens (prompt): 759
# Estimated output tokens (response): 309
# Total estimated tokens (prompt + response): 1068
# Row 58 processed in 12.31 seconds.
#
# Processing row 59...
# Estimated input tokens (prompt): 589
# Estimated output tokens (response): 321
# Total estimated tokens (prompt + response): 910
# Row 59 processed in 11.05 seconds.
#
# Processing row 60...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 438
# Total estimated tokens (prompt + response): 1006
# Row 60 processed in 11.73 seconds.
#
# Processing row 61...
# Estimated input tokens (prompt): 799
# Estimated output tokens (response): 617
# Total estimated tokens (prompt + response): 1416
# Row 61 processed in 19.98 seconds.
#
# Processing row 62...
# Estimated input tokens (prompt): 669
# Estimated output tokens (response): 327
# Total estimated tokens (prompt + response): 996
# Row 62 processed in 13.73 seconds.
#
# Processing row 63...
# Estimated input tokens (prompt): 625
# Estimated output tokens (response): 284
# Total estimated tokens (prompt + response): 909
# Row 63 processed in 15.97 seconds.
#
# Processing row 64...
# Estimated input tokens (prompt): 712
# Estimated output tokens (response): 340
# Total estimated tokens (prompt + response): 1052
# Row 64 processed in 13.22 seconds.
#
# Processing row 65...
# Estimated input tokens (prompt): 581
# Estimated output tokens (response): 328
# Total estimated tokens (prompt + response): 909
# Row 65 processed in 13.39 seconds.
#
# Processing row 66...
# Estimated input tokens (prompt): 613
# Estimated output tokens (response): 347
# Total estimated tokens (prompt + response): 960
# Row 66 processed in 15.48 seconds.
#
# Processing row 67...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 243
# Total estimated tokens (prompt + response): 811
# Row 67 processed in 9.94 seconds.
#
# Processing row 68...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 253
# Total estimated tokens (prompt + response): 821
# Row 68 processed in 9.78 seconds.
#
# Processing row 69...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 264
# Total estimated tokens (prompt + response): 832
# Row 69 processed in 10.85 seconds.
#
# Processing row 70...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 439
# Total estimated tokens (prompt + response): 1007
# Row 70 processed in 11.67 seconds.
#
# Processing row 71...
# Estimated input tokens (prompt): 1066
# Estimated output tokens (response): 373
# Total estimated tokens (prompt + response): 1439
# Row 71 processed in 18.36 seconds.
#
# Processing row 72...
# Estimated input tokens (prompt): 613
# Estimated output tokens (response): 322
# Total estimated tokens (prompt + response): 935
# Row 72 processed in 15.38 seconds.
#
# Processing row 73...
# Estimated input tokens (prompt): 614
# Estimated output tokens (response): 358
# Total estimated tokens (prompt + response): 972
# Row 73 processed in 18.23 seconds.
#
# Processing row 74...
# Estimated input tokens (prompt): 640
# Estimated output tokens (response): 493
# Total estimated tokens (prompt + response): 1133
# Row 74 processed in 17.47 seconds.
#
# Processing row 75...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 272
# Total estimated tokens (prompt + response): 840
# Row 75 processed in 14.93 seconds.
#
# Processing row 76...
# Estimated input tokens (prompt): 576
# Estimated output tokens (response): 256
# Total estimated tokens (prompt + response): 832
# Row 76 processed in 11.58 seconds.
#
# Processing row 77...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 257
# Total estimated tokens (prompt + response): 825
# Row 77 processed in 9.65 seconds.
#
# Processing row 78...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 251
# Total estimated tokens (prompt + response): 819
# Row 78 processed in 11.61 seconds.
#
# Processing row 79...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 258
# Total estimated tokens (prompt + response): 826
# Row 79 processed in 8.50 seconds.
#
# Processing row 80...
# Estimated input tokens (prompt): 619
# Estimated output tokens (response): 260
# Total estimated tokens (prompt + response): 879
# Row 80 processed in 17.74 seconds.
#
# Processing row 81...
# Estimated input tokens (prompt): 577
# Estimated output tokens (response): 286
# Total estimated tokens (prompt + response): 863
# Row 81 processed in 15.47 seconds.
#
# Processing row 82...
# Estimated input tokens (prompt): 611
# Estimated output tokens (response): 325
# Total estimated tokens (prompt + response): 936
# Row 82 processed in 13.40 seconds.
#
# Processing row 83...
# Estimated input tokens (prompt): 602
# Estimated output tokens (response): 501
# Total estimated tokens (prompt + response): 1103
# Row 83 processed in 15.11 seconds.
#
# Processing row 84...
# Estimated input tokens (prompt): 1159
# Estimated output tokens (response): 580
# Total estimated tokens (prompt + response): 1739
# Row 84 processed in 18.66 seconds.
#
# Processing row 85...
# Estimated input tokens (prompt): 620
# Estimated output tokens (response): 370
# Total estimated tokens (prompt + response): 990
# Row 85 processed in 19.11 seconds.
#
# Processing row 86...
# Estimated input tokens (prompt): 665
# Estimated output tokens (response): 343
# Total estimated tokens (prompt + response): 1008
# Row 86 processed in 12.86 seconds.
#
# Processing row 87...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 262
# Total estimated tokens (prompt + response): 830
# Row 87 processed in 12.08 seconds.
#
# Processing row 88...
# Estimated input tokens (prompt): 610
# Estimated output tokens (response): 368
# Total estimated tokens (prompt + response): 978
# Row 88 processed in 12.86 seconds.
#
# Processing row 89...
# Estimated input tokens (prompt): 586
# Estimated output tokens (response): 404
# Total estimated tokens (prompt + response): 990
# Row 89 processed in 17.43 seconds.
#
# Processing row 90...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 252
# Total estimated tokens (prompt + response): 820
# Row 90 processed in 9.14 seconds.
#
# Processing row 91...
# Estimated input tokens (prompt): 583
# Estimated output tokens (response): 290
# Total estimated tokens (prompt + response): 873
# Row 91 processed in 14.22 seconds.
#
# Processing row 92...
# Estimated input tokens (prompt): 826
# Estimated output tokens (response): 396
# Total estimated tokens (prompt + response): 1222
# Row 92 processed in 18.02 seconds.
#
# Processing row 93...
# Estimated input tokens (prompt): 569
# Estimated output tokens (response): 253
# Total estimated tokens (prompt + response): 822
# Row 93 processed in 8.32 seconds.
#
# Processing row 94...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 252
# Total estimated tokens (prompt + response): 820
# Row 94 processed in 10.24 seconds.
#
# Processing row 95...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 254
# Total estimated tokens (prompt + response): 822
# Row 95 processed in 10.06 seconds.
#
# Processing row 96...
# Estimated input tokens (prompt): 720
# Estimated output tokens (response): 445
# Total estimated tokens (prompt + response): 1165
# Row 96 processed in 17.41 seconds.
#
# Processing row 97...
# Estimated input tokens (prompt): 633
# Estimated output tokens (response): 380
# Total estimated tokens (prompt + response): 1013
# Row 97 processed in 13.04 seconds.
#
# Processing row 98...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 254
# Total estimated tokens (prompt + response): 822
# Row 98 processed in 10.68 seconds.
#
# Processing row 99...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 270
# Total estimated tokens (prompt + response): 838
# Row 99 processed in 14.04 seconds.
#
# Processing row 100...
# Estimated input tokens (prompt): 1057
# Estimated output tokens (response): 574
# Total estimated tokens (prompt + response): 1631
# Row 100 processed in 17.08 seconds.
#
# Processing row 101...
# Estimated input tokens (prompt): 716
# Estimated output tokens (response): 449
# Total estimated tokens (prompt + response): 1165
# Row 101 processed in 18.26 seconds.
#
# Processing row 102...
# Estimated input tokens (prompt): 610
# Estimated output tokens (response): 484
# Total estimated tokens (prompt + response): 1094
# Row 102 processed in 16.17 seconds.
#
# Processing row 103...
# Estimated input tokens (prompt): 846
# Estimated output tokens (response): 436
# Total estimated tokens (prompt + response): 1282
# Row 103 processed in 17.69 seconds.
#
# Processing row 104...
# Estimated input tokens (prompt): 599
# Estimated output tokens (response): 361
# Total estimated tokens (prompt + response): 960
# Row 104 processed in 16.81 seconds.
#
# Processing row 105...
# Estimated input tokens (prompt): 582
# Estimated output tokens (response): 345
# Total estimated tokens (prompt + response): 927
# Row 105 processed in 11.41 seconds.
#
# Processing row 106...
# Estimated input tokens (prompt): 792
# Estimated output tokens (response): 396
# Total estimated tokens (prompt + response): 1188
# Row 106 processed in 21.67 seconds.
#
# Processing row 107...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 266
# Total estimated tokens (prompt + response): 834
# Row 107 processed in 11.66 seconds.
#
# Processing row 108...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 438
# Total estimated tokens (prompt + response): 1006
# Row 108 processed in 9.89 seconds.
#
# Processing row 109...
# Estimated input tokens (prompt): 945
# Estimated output tokens (response): 598
# Total estimated tokens (prompt + response): 1543
# Row 109 processed in 25.53 seconds.
#
# Processing row 110...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 271
# Total estimated tokens (prompt + response): 839
# Row 110 processed in 14.13 seconds.
#
# Processing row 111...
# Estimated input tokens (prompt): 1008
# Estimated output tokens (response): 391
# Total estimated tokens (prompt + response): 1399
# Row 111 processed in 18.32 seconds.
#
# Processing row 112...
# Estimated input tokens (prompt): 587
# Estimated output tokens (response): 359
# Total estimated tokens (prompt + response): 946
# Row 112 processed in 11.21 seconds.
#
# Processing row 113...
# Estimated input tokens (prompt): 593
# Estimated output tokens (response): 308
# Total estimated tokens (prompt + response): 901
# Row 113 processed in 11.46 seconds.
#
# Processing row 114...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 266
# Total estimated tokens (prompt + response): 834
# Row 114 processed in 10.72 seconds.
#
# Processing row 115...
# Estimated input tokens (prompt): 649
# Estimated output tokens (response): 396
# Total estimated tokens (prompt + response): 1045
# Row 115 processed in 14.92 seconds.
#
# Processing row 116...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 251
# Total estimated tokens (prompt + response): 819
# Row 116 processed in 8.73 seconds.
#
# Processing row 117...
# Estimated input tokens (prompt): 618
# Estimated output tokens (response): 319
# Total estimated tokens (prompt + response): 937
# Row 117 processed in 12.58 seconds.
#
# Processing row 118...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 252
# Total estimated tokens (prompt + response): 820
# Row 118 processed in 9.83 seconds.
#
# Processing row 119...
# Estimated input tokens (prompt): 596
# Estimated output tokens (response): 322
# Total estimated tokens (prompt + response): 918
# Row 119 processed in 15.50 seconds.
#
# Processing row 120...
# Estimated input tokens (prompt): 825
# Estimated output tokens (response): 528
# Total estimated tokens (prompt + response): 1353
# Row 120 processed in 22.76 seconds.
#
# Processing row 121...
# Estimated input tokens (prompt): 732
# Estimated output tokens (response): 494
# Total estimated tokens (prompt + response): 1226
# Row 121 processed in 14.43 seconds.
#
# Processing row 122...
# Estimated input tokens (prompt): 689
# Estimated output tokens (response): 389
# Total estimated tokens (prompt + response): 1078
# Row 122 processed in 13.85 seconds.
#
# Processing row 123...
# Estimated input tokens (prompt): 647
# Estimated output tokens (response): 327
# Total estimated tokens (prompt + response): 974
# Row 123 processed in 12.22 seconds.
#
# Processing row 124...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 261
# Total estimated tokens (prompt + response): 829
# Row 124 processed in 9.85 seconds.
#
# Processing row 125...
# Estimated input tokens (prompt): 712
# Estimated output tokens (response): 417
# Total estimated tokens (prompt + response): 1129
# Row 125 processed in 20.36 seconds.
#
# Processing row 126...
# Estimated input tokens (prompt): 635
# Estimated output tokens (response): 341
# Total estimated tokens (prompt + response): 976
# Row 126 processed in 15.51 seconds.
#
# Processing row 127...
# Estimated input tokens (prompt): 679
# Estimated output tokens (response): 552
# Total estimated tokens (prompt + response): 1231
# Row 127 processed in 18.04 seconds.
#
# Processing row 128...
# Estimated input tokens (prompt): 597
# Estimated output tokens (response): 355
# Total estimated tokens (prompt + response): 952
# Row 128 processed in 13.58 seconds.
#
# Processing row 129...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 243
# Total estimated tokens (prompt + response): 811
# Row 129 processed in 7.04 seconds.
#
# Processing row 130...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 438
# Total estimated tokens (prompt + response): 1006
# Row 130 processed in 12.15 seconds.
#
# Processing row 131...
# Estimated input tokens (prompt): 663
# Estimated output tokens (response): 400
# Total estimated tokens (prompt + response): 1063
# Row 131 processed in 16.70 seconds.
#
# Processing row 132...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 269
# Total estimated tokens (prompt + response): 837
# Row 132 processed in 12.10 seconds.
#
# Processing row 133...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 249
# Total estimated tokens (prompt + response): 817
# Row 133 processed in 8.73 seconds.
#
# Processing row 134...
# Estimated input tokens (prompt): 1008
# Estimated output tokens (response): 539
# Total estimated tokens (prompt + response): 1547
# Row 134 processed in 20.51 seconds.
#
# Processing row 135...
# Estimated input tokens (prompt): 818
# Estimated output tokens (response): 368
# Total estimated tokens (prompt + response): 1186
# Row 135 processed in 12.83 seconds.
#
# Processing row 136...
# Estimated input tokens (prompt): 591
# Estimated output tokens (response): 326
# Total estimated tokens (prompt + response): 917
# Row 136 processed in 14.85 seconds.
#
# Processing row 137...
# Estimated input tokens (prompt): 628
# Estimated output tokens (response): 330
# Total estimated tokens (prompt + response): 958
# Row 137 processed in 12.53 seconds.
#
# Processing row 138...
# Estimated input tokens (prompt): 643
# Estimated output tokens (response): 448
# Total estimated tokens (prompt + response): 1091
# Row 138 processed in 20.10 seconds.
#
# Processing row 139...
# Estimated input tokens (prompt): 764
# Estimated output tokens (response): 553
# Total estimated tokens (prompt + response): 1317
# Row 139 processed in 18.10 seconds.
#
# Processing row 140...
# Estimated input tokens (prompt): 691
# Estimated output tokens (response): 369
# Total estimated tokens (prompt + response): 1060
# Row 140 processed in 18.23 seconds.
#
# Processing row 141...
# Estimated input tokens (prompt): 607
# Estimated output tokens (response): 289
# Total estimated tokens (prompt + response): 896
# Row 141 processed in 12.76 seconds.
#
# Processing row 142...
# Estimated input tokens (prompt): 787
# Estimated output tokens (response): 522
# Total estimated tokens (prompt + response): 1309
# Row 142 processed in 19.17 seconds.
#
# Processing row 143...
# Estimated input tokens (prompt): 880
# Estimated output tokens (response): 519
# Total estimated tokens (prompt + response): 1399
# Row 143 processed in 20.52 seconds.
#
# Processing row 144...
# Estimated input tokens (prompt): 661
# Estimated output tokens (response): 420
# Total estimated tokens (prompt + response): 1081
# Row 144 processed in 22.89 seconds.
#
# Processing row 145...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 273
# Total estimated tokens (prompt + response): 841
# Row 145 processed in 10.19 seconds.
#
# Processing row 146...
# Estimated input tokens (prompt): 571
# Estimated output tokens (response): 324
# Total estimated tokens (prompt + response): 895
# Row 146 processed in 12.72 seconds.
#
# Processing row 147...
# Estimated input tokens (prompt): 598
# Estimated output tokens (response): 334
# Total estimated tokens (prompt + response): 932
# Row 147 processed in 12.76 seconds.
#
# Processing row 148...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 260
# Total estimated tokens (prompt + response): 828
# Row 148 processed in 11.63 seconds.
#
# Processing row 149...
# Estimated input tokens (prompt): 610
# Estimated output tokens (response): 459
# Total estimated tokens (prompt + response): 1069
# Row 149 processed in 20.51 seconds.
#
# Processing row 150...
# Estimated input tokens (prompt): 622
# Estimated output tokens (response): 346
# Total estimated tokens (prompt + response): 968
# Row 150 processed in 22.23 seconds.
#
# Processing row 151...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 238
# Total estimated tokens (prompt + response): 806
# Row 151 processed in 8.32 seconds.
#
# Processing row 152...
# Estimated input tokens (prompt): 975
# Estimated output tokens (response): 511
# Total estimated tokens (prompt + response): 1486
# Row 152 processed in 23.77 seconds.
#
# Processing row 153...
# Estimated input tokens (prompt): 888
# Estimated output tokens (response): 591
# Total estimated tokens (prompt + response): 1479
# Row 153 processed in 18.05 seconds.
#
# Processing row 154...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 265
# Total estimated tokens (prompt + response): 833
# Row 154 processed in 11.67 seconds.
#
# Processing row 155...
# Estimated input tokens (prompt): 572
# Estimated output tokens (response): 275
# Total estimated tokens (prompt + response): 847
# Row 155 processed in 11.01 seconds.
#
# Processing row 156...
# Estimated input tokens (prompt): 797
# Estimated output tokens (response): 365
# Total estimated tokens (prompt + response): 1162
# Row 156 processed in 17.74 seconds.
#
# Processing row 157...
# Estimated input tokens (prompt): 604
# Estimated output tokens (response): 514
# Total estimated tokens (prompt + response): 1118
# Row 157 processed in 16.41 seconds.
#
# Processing row 158...
# Estimated input tokens (prompt): 614
# Estimated output tokens (response): 401
# Total estimated tokens (prompt + response): 1015
# Row 158 processed in 12.84 seconds.
#
# Processing row 159...
# Estimated input tokens (prompt): 602
# Estimated output tokens (response): 306
# Total estimated tokens (prompt + response): 908
# Row 159 processed in 16.97 seconds.
#
# Processing row 160...
# Estimated input tokens (prompt): 583
# Estimated output tokens (response): 360
# Total estimated tokens (prompt + response): 943
# Row 160 processed in 12.24 seconds.
#
# Processing row 161...
# Estimated input tokens (prompt): 687
# Estimated output tokens (response): 328
# Total estimated tokens (prompt + response): 1015
# Row 161 processed in 17.11 seconds.
#
# Processing row 162...
# Estimated input tokens (prompt): 617
# Estimated output tokens (response): 291
# Total estimated tokens (prompt + response): 908
# Row 162 processed in 12.17 seconds.
#
# Processing row 163...
# Estimated input tokens (prompt): 629
# Estimated output tokens (response): 329
# Total estimated tokens (prompt + response): 958
# Row 163 processed in 15.16 seconds.
#
# Processing row 164...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 254
# Total estimated tokens (prompt + response): 822
# Row 164 processed in 10.73 seconds.
#
# Processing row 165...
# Estimated input tokens (prompt): 588
# Estimated output tokens (response): 286
# Total estimated tokens (prompt + response): 874
# Row 165 processed in 10.55 seconds.
#
# Processing row 166...
# Estimated input tokens (prompt): 747
# Estimated output tokens (response): 392
# Total estimated tokens (prompt + response): 1139
# Row 166 processed in 17.48 seconds.
#
# Processing row 167...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 270
# Total estimated tokens (prompt + response): 838
# Row 167 processed in 13.16 seconds.
#
# Processing row 168...
# Estimated input tokens (prompt): 746
# Estimated output tokens (response): 394
# Total estimated tokens (prompt + response): 1140
# Row 168 processed in 18.18 seconds.
#
# Processing row 169...
# Estimated input tokens (prompt): 633
# Estimated output tokens (response): 415
# Total estimated tokens (prompt + response): 1048
# Row 169 processed in 15.78 seconds.
#
# Processing row 170...
# Estimated input tokens (prompt): 1056
# Estimated output tokens (response): 680
# Total estimated tokens (prompt + response): 1736
# Row 170 processed in 17.22 seconds.
#
# Processing row 171...
# Estimated input tokens (prompt): 756
# Estimated output tokens (response): 655
# Total estimated tokens (prompt + response): 1411
# Row 171 processed in 23.24 seconds.
#
# Processing row 172...
# Estimated input tokens (prompt): 620
# Estimated output tokens (response): 398
# Total estimated tokens (prompt + response): 1018
# Row 172 processed in 14.96 seconds.
#
# Processing row 173...
# Estimated input tokens (prompt): 614
# Estimated output tokens (response): 292
# Total estimated tokens (prompt + response): 906
# Row 173 processed in 16.63 seconds.
#
# Processing row 174...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 252
# Total estimated tokens (prompt + response): 820
# Row 174 processed in 14.61 seconds.
#
# Processing row 175...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 294
# Total estimated tokens (prompt + response): 862
# Row 175 processed in 11.92 seconds.
#
# Processing row 176...
# Estimated input tokens (prompt): 589
# Estimated output tokens (response): 277
# Total estimated tokens (prompt + response): 866
# Row 176 processed in 12.40 seconds.
#
# Processing row 177...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 239
# Total estimated tokens (prompt + response): 807
# Row 177 processed in 9.70 seconds.
#
# Processing row 178...
# Estimated input tokens (prompt): 598
# Estimated output tokens (response): 376
# Total estimated tokens (prompt + response): 974
# Row 178 processed in 15.55 seconds.
#
# Processing row 179...
# Estimated input tokens (prompt): 605
# Estimated output tokens (response): 362
# Total estimated tokens (prompt + response): 967
# Row 179 processed in 14.08 seconds.
#
# Processing row 180...
# Estimated input tokens (prompt): 613
# Estimated output tokens (response): 283
# Total estimated tokens (prompt + response): 896
# Row 180 processed in 15.04 seconds.
#
# Processing row 181...
# Estimated input tokens (prompt): 726
# Estimated output tokens (response): 385
# Total estimated tokens (prompt + response): 1111
# Row 181 processed in 16.59 seconds.
#
# Processing row 182...
# Estimated input tokens (prompt): 621
# Estimated output tokens (response): 316
# Total estimated tokens (prompt + response): 937
# Row 182 processed in 20.49 seconds.
#
# Processing row 183...
# Estimated input tokens (prompt): 605
# Estimated output tokens (response): 312
# Total estimated tokens (prompt + response): 917
# Row 183 processed in 13.42 seconds.
#
# Processing row 184...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 455
# Total estimated tokens (prompt + response): 1023
# Row 184 processed in 13.65 seconds.
#
# Processing row 185...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 255
# Total estimated tokens (prompt + response): 823
# Row 185 processed in 8.81 seconds.
#
# Processing row 186...
# Estimated input tokens (prompt): 624
# Estimated output tokens (response): 392
# Total estimated tokens (prompt + response): 1016
# Row 186 processed in 17.01 seconds.
#
# Processing row 187...
# Estimated input tokens (prompt): 646
# Estimated output tokens (response): 359
# Total estimated tokens (prompt + response): 1005
# Row 187 processed in 17.01 seconds.
#
# Processing row 188...
# Estimated input tokens (prompt): 902
# Estimated output tokens (response): 599
# Total estimated tokens (prompt + response): 1501
# Row 188 processed in 25.50 seconds.
#
# Processing row 189...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 395
# Total estimated tokens (prompt + response): 963
# Row 189 processed in 10.05 seconds.
#
# Processing row 190...
# Estimated input tokens (prompt): 1023
# Estimated output tokens (response): 500
# Total estimated tokens (prompt + response): 1523
# Row 190 processed in 20.46 seconds.
#
# Processing row 191...
# Estimated input tokens (prompt): 572
# Estimated output tokens (response): 468
# Total estimated tokens (prompt + response): 1040
# Row 191 processed in 18.52 seconds.
#
# Processing row 192...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 264
# Total estimated tokens (prompt + response): 832
# Row 192 processed in 10.65 seconds.
#
# Processing row 193...
# Estimated input tokens (prompt): 632
# Estimated output tokens (response): 296
# Total estimated tokens (prompt + response): 928
# Row 193 processed in 20.57 seconds.
#
# Processing row 194...
# Estimated input tokens (prompt): 647
# Estimated output tokens (response): 374
# Total estimated tokens (prompt + response): 1021
# Row 194 processed in 16.97 seconds.
#
# Processing row 195...
# Estimated input tokens (prompt): 590
# Estimated output tokens (response): 314
# Total estimated tokens (prompt + response): 904
# Row 195 processed in 8.05 seconds.
#
# Processing row 196...
# Estimated input tokens (prompt): 569
# Estimated output tokens (response): 279
# Total estimated tokens (prompt + response): 848
# Row 196 processed in 11.14 seconds.
#
# Processing row 197...
# Estimated input tokens (prompt): 572
# Estimated output tokens (response): 286
# Total estimated tokens (prompt + response): 858
# Row 197 processed in 13.14 seconds.
#
# Processing row 198...
# Estimated input tokens (prompt): 676
# Estimated output tokens (response): 497
# Total estimated tokens (prompt + response): 1173
# Row 198 processed in 19.76 seconds.
#
# Processing row 199...
# Estimated input tokens (prompt): 582
# Estimated output tokens (response): 270
# Total estimated tokens (prompt + response): 852
# Row 199 processed in 16.42 seconds.
#
# Processing row 200...
# Estimated input tokens (prompt): 600
# Estimated output tokens (response): 363
# Total estimated tokens (prompt + response): 963
# Row 200 processed in 11.71 seconds.
#
# Processing row 201...
# Estimated input tokens (prompt): 581
# Estimated output tokens (response): 267
# Total estimated tokens (prompt + response): 848
# Row 201 processed in 10.69 seconds.
#
# Processing row 202...
# Estimated input tokens (prompt): 604
# Estimated output tokens (response): 583
# Total estimated tokens (prompt + response): 1187
# Row 202 processed in 26.09 seconds.
#
# Processing row 203...
# Estimated input tokens (prompt): 821
# Estimated output tokens (response): 367
# Total estimated tokens (prompt + response): 1188
# Row 203 processed in 17.83 seconds.
#
# Processing row 204...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 238
# Total estimated tokens (prompt + response): 806
# Row 204 processed in 8.76 seconds.
#
# Processing row 205...
# Estimated input tokens (prompt): 579
# Estimated output tokens (response): 290
# Total estimated tokens (prompt + response): 869
# Row 205 processed in 16.29 seconds.
#
# Processing row 206...
# Estimated input tokens (prompt): 597
# Estimated output tokens (response): 360
# Total estimated tokens (prompt + response): 957
# Row 206 processed in 12.90 seconds.
#
# Processing row 207...
# Estimated input tokens (prompt): 632
# Estimated output tokens (response): 275
# Total estimated tokens (prompt + response): 907
# Row 207 processed in 13.11 seconds.
#
# Processing row 208...
# Estimated input tokens (prompt): 669
# Estimated output tokens (response): 637
# Total estimated tokens (prompt + response): 1306
# Row 208 processed in 21.89 seconds.
#
# Processing row 209...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 299
# Total estimated tokens (prompt + response): 867
# Row 209 processed in 10.57 seconds.
#
# Processing row 210...
# Estimated input tokens (prompt): 768
# Estimated output tokens (response): 645
# Total estimated tokens (prompt + response): 1413
# Row 210 processed in 22.08 seconds.
#
# Processing row 211...
# Estimated input tokens (prompt): 594
# Estimated output tokens (response): 291
# Total estimated tokens (prompt + response): 885
# Row 211 processed in 10.89 seconds.
#
# Processing row 212...
# Estimated input tokens (prompt): 677
# Estimated output tokens (response): 565
# Total estimated tokens (prompt + response): 1242
# Row 212 processed in 17.54 seconds.
#
# Processing row 213...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 252
# Total estimated tokens (prompt + response): 820
# Row 213 processed in 9.40 seconds.
#
# Processing row 214...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 267
# Total estimated tokens (prompt + response): 835
# Row 214 processed in 11.61 seconds.
#
# Processing row 215...
# Estimated input tokens (prompt): 580
# Estimated output tokens (response): 280
# Total estimated tokens (prompt + response): 860
# Row 215 processed in 14.98 seconds.
#
# Processing row 216...
# Estimated input tokens (prompt): 1366
# Estimated output tokens (response): 593
# Total estimated tokens (prompt + response): 1959
# Row 216 processed in 22.25 seconds.
#
# Processing row 217...
# Estimated input tokens (prompt): 623
# Estimated output tokens (response): 313
# Total estimated tokens (prompt + response): 936
# Row 217 processed in 12.77 seconds.
#
# Processing row 218...
# Estimated input tokens (prompt): 576
# Estimated output tokens (response): 312
# Total estimated tokens (prompt + response): 888
# Row 218 processed in 12.37 seconds.
#
# Processing row 219...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 264
# Total estimated tokens (prompt + response): 832
# Row 219 processed in 11.68 seconds.
#
# Processing row 220...
# Estimated input tokens (prompt): 636
# Estimated output tokens (response): 426
# Total estimated tokens (prompt + response): 1062
# Row 220 processed in 21.05 seconds.
#
# Processing row 221...
# Estimated input tokens (prompt): 600
# Estimated output tokens (response): 290
# Total estimated tokens (prompt + response): 890
# Row 221 processed in 14.71 seconds.
#
# Processing row 222...
# Estimated input tokens (prompt): 571
# Estimated output tokens (response): 306
# Total estimated tokens (prompt + response): 877
# Row 222 processed in 15.72 seconds.
#
# Processing row 223...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 451
# Total estimated tokens (prompt + response): 1019
# Row 223 processed in 14.94 seconds.
#
# Processing row 224...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 264
# Total estimated tokens (prompt + response): 832
# Row 224 processed in 7.60 seconds.
#
# Processing row 225...
# Estimated input tokens (prompt): 717
# Estimated output tokens (response): 325
# Total estimated tokens (prompt + response): 1042
# Row 225 processed in 14.10 seconds.
#
# Processing row 226...
# Estimated input tokens (prompt): 590
# Estimated output tokens (response): 268
# Total estimated tokens (prompt + response): 858
# Row 226 processed in 10.90 seconds.
#
# Processing row 227...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 264
# Total estimated tokens (prompt + response): 832
# Row 227 processed in 10.36 seconds.
#
# Processing row 228...
# Estimated input tokens (prompt): 571
# Estimated output tokens (response): 261
# Total estimated tokens (prompt + response): 832
# Row 228 processed in 13.17 seconds.
#
# Processing row 229...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 274
# Total estimated tokens (prompt + response): 842
# Row 229 processed in 9.13 seconds.
#
# Processing row 230...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 254
# Total estimated tokens (prompt + response): 822
# Row 230 processed in 11.63 seconds.
#
# Processing row 231...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 237
# Total estimated tokens (prompt + response): 805
# Row 231 processed in 7.25 seconds.
#
# Processing row 232...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 247
# Total estimated tokens (prompt + response): 815
# Row 232 processed in 10.30 seconds.
#
# Processing row 233...
# Estimated input tokens (prompt): 590
# Estimated output tokens (response): 314
# Total estimated tokens (prompt + response): 904
# Row 233 processed in 12.65 seconds.
#
# Processing row 234...
# Estimated input tokens (prompt): 619
# Estimated output tokens (response): 292
# Total estimated tokens (prompt + response): 911
# Row 234 processed in 12.11 seconds.
#
# Processing row 235...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 256
# Total estimated tokens (prompt + response): 824
# Row 235 processed in 11.40 seconds.
#
# Processing row 236...
# Estimated input tokens (prompt): 576
# Estimated output tokens (response): 292
# Total estimated tokens (prompt + response): 868
# Row 236 processed in 15.16 seconds.
#
# Processing row 237...
# Estimated input tokens (prompt): 569
# Estimated output tokens (response): 277
# Total estimated tokens (prompt + response): 846
# Row 237 processed in 10.85 seconds.
#
# Processing row 238...
# Estimated input tokens (prompt): 602
# Estimated output tokens (response): 331
# Total estimated tokens (prompt + response): 933
# Row 238 processed in 24.29 seconds.
#
# Processing row 239...
# Estimated input tokens (prompt): 823
# Estimated output tokens (response): 681
# Total estimated tokens (prompt + response): 1504
# Row 239 processed in 24.39 seconds.
#
# Processing row 240...
# Estimated input tokens (prompt): 627
# Estimated output tokens (response): 270
# Total estimated tokens (prompt + response): 897
# Row 240 processed in 9.72 seconds.
#
# Processing row 241...
# Estimated input tokens (prompt): 665
# Estimated output tokens (response): 485
# Total estimated tokens (prompt + response): 1150
# Row 241 processed in 16.81 seconds.
#
# Processing row 242...
# Estimated input tokens (prompt): 571
# Estimated output tokens (response): 287
# Total estimated tokens (prompt + response): 858
# Row 242 processed in 9.28 seconds.
#
# Processing row 243...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 248
# Total estimated tokens (prompt + response): 816
# Row 243 processed in 11.01 seconds.
#
# Processing row 244...
# Estimated input tokens (prompt): 656
# Estimated output tokens (response): 323
# Total estimated tokens (prompt + response): 979
# Row 244 processed in 14.15 seconds.
#
# Processing row 245...
# Estimated input tokens (prompt): 577
# Estimated output tokens (response): 271
# Total estimated tokens (prompt + response): 848
# Row 245 processed in 9.11 seconds.
#
# Processing row 246...
# Estimated input tokens (prompt): 607
# Estimated output tokens (response): 454
# Total estimated tokens (prompt + response): 1061
# Row 246 processed in 18.02 seconds.
#
# Processing row 247...
# Estimated input tokens (prompt): 577
# Estimated output tokens (response): 312
# Total estimated tokens (prompt + response): 889
# Row 247 processed in 12.34 seconds.
#
# Processing row 248...
# Estimated input tokens (prompt): 570
# Estimated output tokens (response): 258
# Total estimated tokens (prompt + response): 828
# Row 248 processed in 8.87 seconds.
#
# Processing row 249...
# Estimated input tokens (prompt): 725
# Estimated output tokens (response): 270
# Total estimated tokens (prompt + response): 995
# Row 249 processed in 14.87 seconds.
#
# Processing row 250...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 276
# Total estimated tokens (prompt + response): 844
# Row 250 processed in 9.92 seconds.
#
# Processing row 251...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 265
# Total estimated tokens (prompt + response): 833
# Row 251 processed in 12.05 seconds.
#
# Processing row 252...
# Estimated input tokens (prompt): 602
# Estimated output tokens (response): 325
# Total estimated tokens (prompt + response): 927
# Row 252 processed in 15.53 seconds.
#
# Processing row 253...
# Estimated input tokens (prompt): 590
# Estimated output tokens (response): 249
# Total estimated tokens (prompt + response): 839
# Row 253 processed in 8.33 seconds.
#
# Processing row 254...
# Estimated input tokens (prompt): 620
# Estimated output tokens (response): 326
# Total estimated tokens (prompt + response): 946
# Row 254 processed in 9.67 seconds.
#
# Processing row 255...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 438
# Total estimated tokens (prompt + response): 1006
# Row 255 processed in 11.73 seconds.
#
# Processing row 256...
# Estimated input tokens (prompt): 1090
# Estimated output tokens (response): 502
# Total estimated tokens (prompt + response): 1592
# Row 256 processed in 23.26 seconds.
#
# Processing row 257...
# Estimated input tokens (prompt): 626
# Estimated output tokens (response): 370
# Total estimated tokens (prompt + response): 996
# Row 257 processed in 15.56 seconds.
#
# Processing row 258...
# Estimated input tokens (prompt): 604
# Estimated output tokens (response): 261
# Total estimated tokens (prompt + response): 865
# Row 258 processed in 10.87 seconds.
#
# Processing row 259...
# Estimated input tokens (prompt): 647
# Estimated output tokens (response): 273
# Total estimated tokens (prompt + response): 920
# Row 259 processed in 15.56 seconds.
#
# Processing row 260...
# Estimated input tokens (prompt): 591
# Estimated output tokens (response): 270
# Total estimated tokens (prompt + response): 861
# Row 260 processed in 12.86 seconds.
#
# Processing row 261...
# Estimated input tokens (prompt): 626
# Estimated output tokens (response): 254
# ...
# Estimated output tokens (response): 248
# Total estimated tokens (prompt + response): 816
# Row 440 processed in 12.37 seconds.
#
# Processing row 441...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 254
# Total estimated tokens (prompt + response): 822
# Row 441 processed in 8.35 seconds.
#
# Processing row 442...
# Estimated input tokens (prompt): 592
# Estimated output tokens (response): 301
# Total estimated tokens (prompt + response): 893
# Row 442 processed in 10.25 seconds.
#
# Processing row 443...
# Estimated input tokens (prompt): 610
# Estimated output tokens (response): 283
# Total estimated tokens (prompt + response): 893
# Row 443 processed in 11.43 seconds.
#
# Processing row 444...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 264
# Total estimated tokens (prompt + response): 832
# Row 444 processed in 12.41 seconds.
#
# Processing row 445...
# Estimated input tokens (prompt): 572
# Estimated output tokens (response): 317
# Total estimated tokens (prompt + response): 889
# Row 445 processed in 13.32 seconds.
#
# Processing row 446...
# Estimated input tokens (prompt): 602
# Estimated output tokens (response): 304
# Total estimated tokens (prompt + response): 906
# Row 446 processed in 12.09 seconds.
#
# Processing row 447...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 255
# Total estimated tokens (prompt + response): 823
# Row 447 processed in 9.30 seconds.
#
# Processing row 448...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 438
# Total estimated tokens (prompt + response): 1006
# Row 448 processed in 13.86 seconds.
#
# Processing row 449...
# Estimated input tokens (prompt): 586
# Estimated output tokens (response): 281
# Total estimated tokens (prompt + response): 867
# Row 449 processed in 13.44 seconds.
#
# Processing row 450...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 267
# Total estimated tokens (prompt + response): 835
# Row 450 processed in 10.07 seconds.
#
# Processing row 451...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 263
# Total estimated tokens (prompt + response): 831
# Row 451 processed in 8.91 seconds.
#
# Processing row 452...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 242
# Total estimated tokens (prompt + response): 810
# Row 452 processed in 10.66 seconds.
#
# Processing row 453...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 229
# Total estimated tokens (prompt + response): 797
# Row 453 processed in 8.01 seconds.
#
# Processing row 454...
# Estimated input tokens (prompt): 578
# Estimated output tokens (response): 306
# Total estimated tokens (prompt + response): 884
# Row 454 processed in 12.63 seconds.
#
# Processing row 455...
# Estimated input tokens (prompt): 589
# Estimated output tokens (response): 332
# Total estimated tokens (prompt + response): 921
# Row 455 processed in 13.79 seconds.
#
# Processing row 456...
# Estimated input tokens (prompt): 572
# Estimated output tokens (response): 288
# Total estimated tokens (prompt + response): 860
# Row 456 processed in 12.63 seconds.
#
# Processing row 457...
# Estimated input tokens (prompt): 569
# Estimated output tokens (response): 298
# Total estimated tokens (prompt + response): 867
# Row 457 processed in 11.33 seconds.
#
# Processing row 458...
# Estimated input tokens (prompt): 577
# Estimated output tokens (response): 298
# Total estimated tokens (prompt + response): 875
# Row 458 processed in 10.40 seconds.
#
# Processing row 459...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 254
# Total estimated tokens (prompt + response): 822
# Row 459 processed in 12.33 seconds.
#
# Processing row 460...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 262
# Total estimated tokens (prompt + response): 830
# Row 460 processed in 11.18 seconds.
#
# Processing row 461...
# Estimated input tokens (prompt): 569
# Estimated output tokens (response): 259
# Total estimated tokens (prompt + response): 828
# Row 461 processed in 9.72 seconds.
#
# Processing row 462...
# Estimated input tokens (prompt): 632
# Estimated output tokens (response): 330
# Total estimated tokens (prompt + response): 962
# Row 462 processed in 13.58 seconds.
#
# Processing row 463...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 256
# Total estimated tokens (prompt + response): 824
# Row 463 processed in 10.09 seconds.
#
# Processing row 464...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 255
# Total estimated tokens (prompt + response): 823
# Row 464 processed in 10.97 seconds.
#
# Processing row 465...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 243
# Total estimated tokens (prompt + response): 811
# Row 465 processed in 6.72 seconds.
#
# Processing row 466...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 253
# Total estimated tokens (prompt + response): 821
# Row 466 processed in 9.41 seconds.
#
# Processing row 467...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 232
# Total estimated tokens (prompt + response): 800
# Row 467 processed in 9.23 seconds.
#
# Processing row 468...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 292
# Total estimated tokens (prompt + response): 860
# Row 468 processed in 24.77 seconds.
#
# Processing row 469...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 259
# Total estimated tokens (prompt + response): 827
# Row 469 processed in 12.05 seconds.
#
# Processing row 470...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 254
# Total estimated tokens (prompt + response): 822
# Row 470 processed in 8.25 seconds.
#
# Processing row 471...
# Estimated input tokens (prompt): 570
# Estimated output tokens (response): 329
# Total estimated tokens (prompt + response): 899
# Row 471 processed in 11.70 seconds.
#
# Processing row 472...
# Estimated input tokens (prompt): 608
# Estimated output tokens (response): 365
# Total estimated tokens (prompt + response): 973
# Row 472 processed in 16.21 seconds.
#
# Processing row 473...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 264
# Total estimated tokens (prompt + response): 832
# Row 473 processed in 11.24 seconds.
#
# Processing row 474...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 244
# Total estimated tokens (prompt + response): 812
# Row 474 processed in 10.51 seconds.
#
# Processing row 475...
# Estimated input tokens (prompt): 575
# Estimated output tokens (response): 286
# Total estimated tokens (prompt + response): 861
# Row 475 processed in 11.38 seconds.
#
# Processing row 476...
# Estimated input tokens (prompt): 641
# Estimated output tokens (response): 318
# Total estimated tokens (prompt + response): 959
# Row 476 processed in 13.78 seconds.
#
# Processing row 477...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 266
# Total estimated tokens (prompt + response): 834
# Row 477 processed in 9.76 seconds.
#
# Processing row 478...
# Estimated input tokens (prompt): 580
# Estimated output tokens (response): 334
# Total estimated tokens (prompt + response): 914
# JSON decoding failed: Expecting property name enclosed in double quotes: line 15 column 1 (char 835)
# Raw output:
# {
#   "core_issue": "The reviewer is sarcastically complaining about the exorbitant cost of a short hospital visit.",
#   "summary": "Extremely expensive for short visit.",
#   "ward_block_room_number": "Not found in feedback",
#   "department": "Not found in feedback",
#   "hospital_condition": "Not found in feedback",
#   "doctors_mentioned": "Not found in feedback",
#   "nurses_mentioned": "Not found in feedback",
#   "support_admin_staff_mentioned": "Not found in feedback",
#   "staff_names": "Not found in feedback",
#   "treatments_procedures": "Not found in feedback",
#   "service_quality_highlighted": "The reviewer sarcastically highlights 'Excellent prices', indicating dissatisfaction with the cost ($2,500).",
#   "waiting_time": "The reviewer mentions being in the hospital for '3 hours'.",
#   "food_other_quality": "Not found in feedback",
# ovo "rude_staff": "Not found in feedback",
#   "delays_long_queues_poor_management": "The reviewer mentions a total time of '3 hours in hospital' for which they were charged $2,500.",
#   "unfair_rules_inconsistent_policies": "Not found in feedback",
#   "explicitly_negative_description": "Not found in feedback",
#   "profit_motive_unnecessary_procedures": "Yes, the sarcastic comment 'Excellent prices' juxtaposed with the high cost ($2,500 for 3 hours) strongly suggests the reviewer perceives a profit motive.",
#   "fraudulent_activity": "Not found in feedback"
# }
#
# Row 478 processed in 14.44 seconds.
#
# Processing row 479...
# Estimated input tokens (prompt): 582
# Estimated output tokens (response): 288
# Total estimated tokens (prompt + response): 870
# Row 479 processed in 13.36 seconds.
#
# Processing row 480...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 253
# Total estimated tokens (prompt + response): 821
# Row 480 processed in 8.77 seconds.
#
# Processing row 481...
# Estimated input tokens (prompt): 571
# Estimated output tokens (response): 277
# Total estimated tokens (prompt + response): 848
# Row 481 processed in 12.59 seconds.
#
# Processing row 482...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 258
# Total estimated tokens (prompt + response): 826
# Row 482 processed in 12.63 seconds.
#
# Processing row 483...
# Estimated input tokens (prompt): 575
# Estimated output tokens (response): 289
# Total estimated tokens (prompt + response): 864
# Row 483 processed in 14.94 seconds.
#
# Processing row 484...
# Estimated input tokens (prompt): 594
# Estimated output tokens (response): 335
# Total estimated tokens (prompt + response): 929
# Row 484 processed in 13.95 seconds.
#
# Processing row 485...
# Estimated input tokens (prompt): 573
# Estimated output tokens (response): 299
# Total estimated tokens (prompt + response): 872
# Row 485 processed in 10.49 seconds.
#
# Processing row 486...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 279
# Total estimated tokens (prompt + response): 847
# Row 486 processed in 12.78 seconds.
#
# Processing row 487...
# Estimated input tokens (prompt): 570
# Estimated output tokens (response): 292
# Total estimated tokens (prompt + response): 862
# Row 487 processed in 13.10 seconds.
#
# Processing row 488...
# Estimated input tokens (prompt): 599
# Estimated output tokens (response): 293
# Total estimated tokens (prompt + response): 892
# Row 488 processed in 20.12 seconds.
#
# Processing row 489...
# Estimated input tokens (prompt): 585
# Estimated output tokens (response): 302
# Total estimated tokens (prompt + response): 887
# Row 489 processed in 11.07 seconds.
#
# Processing row 490...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 261
# Total estimated tokens (prompt + response): 829
# Row 490 processed in 9.74 seconds.
#
# Processing row 491...
# Estimated input tokens (prompt): 583
# Estimated output tokens (response): 286
# Total estimated tokens (prompt + response): 869
# Row 491 processed in 27.62 seconds.
#
# Processing row 492...
# Estimated input tokens (prompt): 594
# Estimated output tokens (response): 331
# Total estimated tokens (prompt + response): 925
# Row 492 processed in 13.68 seconds.
#
# Processing row 493...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 259
# Total estimated tokens (prompt + response): 827
# Row 493 processed in 17.81 seconds.
#
# Processing row 494...
# Estimated input tokens (prompt): 578
# Estimated output tokens (response): 263
# Total estimated tokens (prompt + response): 841
# Row 494 processed in 9.45 seconds.
#
# Processing row 495...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 245
# Total estimated tokens (prompt + response): 813
# Row 495 processed in 7.62 seconds.
#
# Processing row 496...
# Estimated input tokens (prompt): 572
# Estimated output tokens (response): 274
# Total estimated tokens (prompt + response): 846
# Row 496 processed in 15.69 seconds.
#
# Processing row 497...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 264
# Total estimated tokens (prompt + response): 832
# Row 497 processed in 12.58 seconds.
#
# Processing row 498...
# Estimated input tokens (prompt): 618
# Estimated output tokens (response): 367
# Total estimated tokens (prompt + response): 985
# Row 498 processed in 10.43 seconds.
#
# Processing row 499...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 276
# Total estimated tokens (prompt + response): 844
# Row 499 processed in 24.69 seconds.
#
# Processing row 500...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 276
# Total estimated tokens (prompt + response): 844
# Row 500 processed in 11.11 seconds.
#
# Processing row 501...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 281
# Total estimated tokens (prompt + response): 849
# Row 501 processed in 12.11 seconds.
#
# Processing row 502...
# Estimated input tokens (prompt): 794
# Estimated output tokens (response): 483
# Total estimated tokens (prompt + response): 1277
# Row 502 processed in 29.04 seconds.
#
# Processing row 503...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 248
# Total estimated tokens (prompt + response): 816
# Row 503 processed in 7.38 seconds.
#
# Processing row 504...
# Estimated input tokens (prompt): 569
# Estimated output tokens (response): 258
# Total estimated tokens (prompt + response): 827
# Row 504 processed in 10.87 seconds.
#
# Processing row 505...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 256
# Total estimated tokens (prompt + response): 824
# Row 505 processed in 11.67 seconds.
#
# Processing row 506...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 241
# Total estimated tokens (prompt + response): 809
# Row 506 processed in 10.57 seconds.
#
# Processing row 507...
# Estimated input tokens (prompt): 582
# Estimated output tokens (response): 296
# Total estimated tokens (prompt + response): 878
# Row 507 processed in 11.80 seconds.
#
# Processing row 508...
# Estimated input tokens (prompt): 569
# Estimated output tokens (response): 289
# Total estimated tokens (prompt + response): 858
# Row 508 processed in 16.17 seconds.
#
# Processing row 509...
# Estimated input tokens (prompt): 569
# Estimated output tokens (response): 293
# Total estimated tokens (prompt + response): 862
# Row 509 processed in 11.02 seconds.
#
# Processing row 510...
# Estimated input tokens (prompt): 569
# Estimated output tokens (response): 284
# Total estimated tokens (prompt + response): 853
# Row 510 processed in 12.15 seconds.
#
# Processing row 511...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 260
# Total estimated tokens (prompt + response): 828
# Row 511 processed in 10.33 seconds.
#
# Processing row 512...
# Estimated input tokens (prompt): 574
# Estimated output tokens (response): 250
# Total estimated tokens (prompt + response): 824
# Row 512 processed in 9.23 seconds.
#
# Processing row 513...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 256
# Total estimated tokens (prompt + response): 824
# Row 513 processed in 10.55 seconds.
#
# Processing row 514...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 271
# Total estimated tokens (prompt + response): 839
# Row 514 processed in 13.88 seconds.
#
# Processing row 515...
# Estimated input tokens (prompt): 574
# Estimated output tokens (response): 472
# Total estimated tokens (prompt + response): 1046
# Row 515 processed in 14.91 seconds.
#
# Processing row 516...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 269
# Total estimated tokens (prompt + response): 837
# Row 516 processed in 12.73 seconds.
#
# Processing row 517...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 256
# Total estimated tokens (prompt + response): 824
# Row 517 processed in 21.66 seconds.
#
# Processing row 518...
# Estimated input tokens (prompt): 568
# Estimated output tokens (response): 260
# Total estimated tokens (prompt + response): 828
# Row 518 processed in 10.59 seconds.
