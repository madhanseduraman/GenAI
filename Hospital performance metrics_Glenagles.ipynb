# %%
#!pip install wordcloud
#!pip install textblob
#!pip install openpyxl

# %% [markdown]
# # ==============================
# # 1. Setup & Load Data
# # ==============================

# %%
# ==============================
# 1. Setup & Load Data
# ==============================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from textblob import TextBlob

# Load dataset
df = pd.read_excel("Gleneagles Hospitalv2.xlsx")

# Display basic info
print(df.shape)
df.head()
# Out:
# (442, 35)
#                                    query                 name  \
# 0  0x31da1a2024d17459:0x2559534cd241d05c  Gleneagles Hospital
# 1  0x31da1a2024d17459:0x2559534cd241d05c  Gleneagles Hospital
# 2  0x31da1a2024d17459:0x2559534cd241d05c  Gleneagles Hospital
# 3  0x31da1a2024d17459:0x2559534cd241d05c  Gleneagles Hospital
# 4  0x31da1a2024d17459:0x2559534cd241d05c  Gleneagles Hospital
#
#                                google_id                     place_id  \
# 0  0x31da1a2024d17459:0x2559534cd241d05c  ChIJWXTRJCAa2jERXNBB0kxTWSU
# 1  0x31da1a2024d17459:0x2559534cd241d05c  ChIJWXTRJCAa2jERXNBB0kxTWSU
# 2  0x31da1a2024d17459:0x2559534cd241d05c  ChIJWXTRJCAa2jERXNBB0kxTWSU
# 3  0x31da1a2024d17459:0x2559534cd241d05c  ChIJWXTRJCAa2jERXNBB0kxTWSU
# 4  0x31da1a2024d17459:0x2559534cd241d05c  ChIJWXTRJCAa2jERXNBB0kxTWSU
#
#                                        location_link  \
# 0  https://www.google.com/maps/place/Gleneagles+H...
# 1  https://www.google.com/maps/place/Gleneagles+H...
# 2  https://www.google.com/maps/place/Gleneagles+H...
# 3  https://www.google.com/maps/place/Gleneagles+H...
# 4  https://www.google.com/maps/place/Gleneagles+H...
#
#                                         reviews_link  reviews  rating  \
# 0  https://search.google.com/local/reviews?placei...      448     3.5
# 1  https://search.google.com/local/reviews?placei...      448     3.5
# 2  https://search.google.com/local/reviews?placei...      448     3.5
# 3  https://search.google.com/local/reviews?placei...      448     3.5
# 4  https://search.google.com/local/reviews?placei...      448     3.5
#
#                                            review_id  \
# 0  Ci9DQUlRQUNvZENodHljRjlvT25wRVNtWnVhbHBRZFdwdm...
# 1  Ci9DQUlRQUNvZENodHljRjlvT2pKS2NYZEZhM1psVmtaRU...
# 2  Ci9DQUlRQUNvZENodHljRjlvT25sNFYyWlFWMk5JWm5Fd0...
# 3  Ci9DQUlRQUNvZENodHljRjlvT2xSWGJHOTRXR280V2xsaG...
# 4  Ci9DQUlRQUNvZENodHljRjlvT2pCSGRGZEpWbk5KTTFKQ1...
#
#                                 review_pagination_id  ... review_rating  \
# 0  CAESY0NBRVFBUnBFUTJwRlNVRlNTWEJEWjI5QlVEY3lSMk...  ...             5
# 1  CAESYENBRVFBaHBDUTJrNFNVRlNTVzVEWjI5QlVEY3lSMk...  ...             1
# 2  CAESY0NBRVFBeHBFUTJwRlNVRlNTWEJEWjI5QlVEY3lSMl...  ...             5
# 3  CAESYENBRVFCQnBDUTJrNFNVRlNTVzVEWjI5QlVEY3lSMl...  ...             5
# 4  CAESY0NBRVFCUnBFUTJwRlNVRlNTWEJEWjI5QlVEY3lSMl...  ...             3
#
#   review_timestamp  review_datetime_utc review_likes           reviews_id  \
# 0       1755681317  08/20/2025 09:15:17          NaN  2691273841740730460
# 1       1755580500  08/19/2025 05:15:00          NaN  2691273841740730460
# 2       1755451910  08/17/2025 17:31:50          NaN  2691273841740730460
# 3       1755222088  08/15/2025 01:41:28          NaN  2691273841740730460
# 4       1754266556  08/04/2025 00:15:56          NaN  2691273841740730460
#
#    reviews_per_score_1 reviews_per_score_2 reviews_per_score_3  \
# 0                  110                  28                  40
# 1                  110                  28                  40
# 2                  110                  28                  40
# 3                  110                  28                  40
# 4                  110                  28                  40
#
#   reviews_per_score_4  reviews_per_score_5
# 0                  58                  212
# 1                  58                  212
# 2                  58                  212
# 3                  58                  212
# 4                  58                  212
#
# [5 rows x 35 columns]

# %%
df.columns
# Out:
# Index(['query', 'name', 'google_id', 'place_id', 'location_link',
#        'reviews_link', 'reviews', 'rating', 'review_id',
#        'review_pagination_id', 'author_link', 'author_title', 'author_id',
#        'author_image', 'author_reviews_count', 'author_ratings_count',
#        'review_text', 'review_img_urls', 'review_img_url', 'review_questions',
#        'review_photo_ids', 'owner_answer', 'owner_answer_timestamp',
#        'owner_answer_timestamp_datetime_utc', 'review_link', 'review_rating',
#        'review_timestamp', 'review_datetime_utc', 'review_likes', 'reviews_id',
#        'reviews_per_score_1', 'reviews_per_score_2', 'reviews_per_score_3',
#        'reviews_per_score_4', 'reviews_per_score_5'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 35 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   query                                442 non-null    object
#  1   name                                 442 non-null    object
#  2   google_id                            442 non-null    object
#  3   place_id                             442 non-null    object
#  4   location_link                        442 non-null    object
#  5   reviews_link                         442 non-null    object
#  6   reviews                              442 non-null    int64
#  7   rating                               442 non-null    float64
#  8   review_id                            442 non-null    object
#  9   review_pagination_id                 441 non-null    object
#  10  author_link                          442 non-null    object
#  11  author_title                         442 non-null    object
#  12  author_id                            442 non-null    object
#  13  author_image                         442 non-null    object
#  14  author_reviews_count                 442 non-null    int64
#  15  author_ratings_count                 442 non-null    int64
#  16  review_text                          296 non-null    object
#  17  review_img_urls                      51 non-null     object
#  18  review_img_url                       51 non-null     object
#  19  review_questions                     0 non-null      float64
#  20  review_photo_ids                     51 non-null     object
#  21  owner_answer                         182 non-null    object
#  22  owner_answer_timestamp               182 non-null    float64
#  23  owner_answer_timestamp_datetime_utc  182 non-null    object
#  24  review_link                          442 non-null    object
#  25  review_rating                        442 non-null    int64
#  26  review_timestamp                     442 non-null    int64
#  27  review_datetime_utc                  442 non-null    object
#  28  review_likes                         0 non-null      float64
#  29  reviews_id                           442 non-null    int64
#  30  reviews_per_score_1                  442 non-null    int64
#  31  reviews_per_score_2                  442 non-null    int64
#  32  reviews_per_score_3                  442 non-null    int64
#  33  reviews_per_score_4                  442 non-null    int64
#  34  reviews_per_score_5                  442 non-null    int64
# dtypes: float64(4), int64(11), object(20)
# memory usage: 121.0+ KB

# %% [markdown]
# # ==============================
# # 2. Data Cleaning
# # ==============================
# # Remove duplicates

# %%
# ==============================
# 2. Data Cleaning
# ==============================
# Remove duplicates
df = df.drop_duplicates()

# Convert datetime column
df['review_datetime_utc'] = pd.to_datetime(df['review_datetime_utc'], errors='coerce')

# Add review text length
df['review_length'] = df['review_text'].astype(str).apply(len)

# Check missing values
print(df.isna().sum())
# Out:
# query                                    0
# name                                     0
# google_id                                0
# place_id                                 0
# location_link                            0
# reviews_link                             0
# reviews                                  0
# rating                                   0
# review_id                                0
# review_pagination_id                     1
# author_link                              0
# author_title                             0
# author_id                                0
# author_image                             0
# author_reviews_count                     0
# author_ratings_count                     0
# review_text                            146
# review_img_urls                        391
# review_img_url                         391
# review_questions                       442
# review_photo_ids                       391
# owner_answer                           260
# owner_answer_timestamp                 260
# owner_answer_timestamp_datetime_utc    260
# review_link                              0
# review_rating                            0
# review_timestamp                         0
# review_datetime_utc                      0
# review_likes                           442
# reviews_id                               0
# reviews_per_score_1                      0
# reviews_per_score_2                      0
# reviews_per_score_3                      0
# reviews_per_score_4                      0
# reviews_per_score_5                      0
# review_length                            0
# dtype: int64

# %% [markdown]
# # ==============================
# # 3. Descriptive Statistics

# %%
# ==============================
# 3. Descriptive Statistics
# ==============================
print(df['review_rating'].describe())
print(df['review_length'].describe())

print("Reviewer reviews count stats:")
print(df['author_reviews_count'].describe())

print("Reviewer ratings count stats:")
print(df['author_ratings_count'].describe())

print("Owner response rate:", df['owner_answer'].notna().mean())
# Out:
# count    442.000000
# mean       3.527149
# std        1.670183
# min        1.000000
# 25%        2.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000
# Name: review_rating, dtype: float64
# count     442.000000
# mean      268.076923
# std       502.907401
# min         2.000000
# 25%         3.000000
# 50%        56.000000
# 75%       314.000000
# max      4080.000000
# Name: review_length, dtype: float64
# Reviewer reviews count stats:
# count     442.000000
# mean      115.714932
# std       352.620466
# min         0.000000
# 25%         4.000000
# 50%        19.000000
# 75%        76.500000
# max      5087.000000
# Name: author_reviews_count, dtype: float64
# Reviewer ratings count stats:
# count     442.000000
# mean       39.938914
# std       162.010171
# min         0.000000
# 25%         1.000000
# 50%         4.000000
# 75%        15.750000
# max      2356.000000
# Name: author_ratings_count, dtype: float64
# Owner response rate: 0.4117647058823529

# %% [markdown]
# # ==============================
# # 4. Univariate Analysis
# # ==============================

# %%
# ==============================
# 4. Univariate Analysis
# ==============================
sns.countplot(x='review_rating', data=df)
plt.title("Ratings Distribution")
plt.show()

sns.histplot(df['review_length'], bins=30, kde=True)
plt.title("Review Length Distribution")
plt.show()

sns.histplot(df['author_reviews_count'], bins=30)
plt.title("Reviewer Review Count Distribution")
plt.show()

# %% [markdown]
# # ==============================
# # 5. Bivariate Analysis
# # ==============================

# %%
# ==============================
# 5. Bivariate Analysis
# ==============================
sns.boxplot(x='review_rating', y='review_length', data=df)
plt.title("Review Length vs Rating")
plt.show()

sns.heatmap(df[['review_rating','review_likes','author_reviews_count','review_length']].corr(),
            annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

sns.barplot(x='review_rating', y=df['owner_answer'].notna(), data=df, estimator=np.mean)
plt.title("Owner Response Rate by Rating")
plt.show()

# %% [markdown]
# # ==============================
# # 6. Time-based Analysis
# # ==============================

# %%
# ==============================
# 6. Time-based Analysis
# ==============================
df['month'] = df['review_datetime_utc'].dt.to_period("M")

monthly = df.groupby('month').agg(
    avg_rating=('review_rating','mean'),
    review_count=('review_rating','count')
)

monthly.plot(y=['avg_rating','review_count'], subplots=True, figsize=(10,6),
             title=["Average Rating Over Time","Review Count Over Time"])
plt.show()

# %% [markdown]
# # ==============================
# # 7. Text Analysis (WordCloud + Sentiment)
# # ==============================
# # Positive reviews wordcloud

# %%
# ==============================
# 7. Text Analysis (WordCloud + Sentiment)
# ==============================
# Positive reviews wordcloud
positive_text = " ".join(df[df['review_rating'] >= 4]['review_text'].dropna())
wordcloud_pos = WordCloud(width=800, height=400, background_color='white').generate(positive_text)
plt.imshow(wordcloud_pos, interpolation='bilinear')
plt.axis("off")
plt.title("Positive Reviews WordCloud")
plt.show()

# Negative reviews wordcloud
negative_text = " ".join(df[df['review_rating'] <= 2]['review_text'].dropna())
wordcloud_neg = WordCloud(width=800, height=400, background_color='black').generate(negative_text)
plt.imshow(wordcloud_neg, interpolation='bilinear')
plt.axis("off")
plt.title("Negative Reviews WordCloud")
plt.show()

# Sentiment polarity
df['sentiment'] = df['review_text'].astype(str).apply(lambda x: TextBlob(x).sentiment.polarity)
sns.histplot(df['sentiment'], bins=30, kde=True)
plt.title("Sentiment Distribution")
plt.show()

# %% [markdown]
# # ==============================
# # 8. Reviewer Insights
# # ==============================

# %%
# ==============================
# 8. Reviewer Insights
# ==============================
top_reviewers = df.groupby('author_title').size().sort_values(ascending=False).head(10)
print("Top Reviewers:")
print(top_reviewers)

df['is_frequent'] = df['author_reviews_count'] > 5
sns.countplot(x='is_frequent', hue='review_rating', data=df)
plt.title("Frequent vs One-time Reviewers by Rating")
plt.show()
# Out:
# Top Reviewers:
# author_title
# Karuna Kwan          2
# H                    2
# wael saad            2
# A D                  1
# Robbi Imel           1
# SUPER DERP GUY       1
# SH C                 1
# Ryan Sun             1
# Roselynne Walters    1
# Ronald Yeo           1
# dtype: int64

# %%
# ==============================
# 9. Owner Response Analysis
# ==============================
neg = df[df['review_rating'] <= 2]
pos = df[df['review_rating'] >= 4]

print("Response rate for negative reviews:", neg['owner_answer'].notna().mean())
print("Response rate for positive reviews:", pos['owner_answer'].notna().mean())
# Out:
# Response rate for negative reviews: 0.6148148148148148
# Response rate for positive reviews: 0.3146067415730337

# %%
# ==============================
# 10. Aggregate Check
# ==============================
agg_counts = {
    "1_star": df['reviews_per_score_1'].iloc[0],
    "2_star": df['reviews_per_score_2'].iloc[0],
    "3_star": df['reviews_per_score_3'].iloc[0],
    "4_star": df['reviews_per_score_4'].iloc[0],
    "5_star": df['reviews_per_score_5'].iloc[0],
}
print("Aggregated counts from metadata:", agg_counts)

actual_counts = df['review_rating'].value_counts()
print("Actual counts from reviews:", actual_counts)
# Out:
# Aggregated counts from metadata: {'1_star': 110, '2_star': 28, '3_star': 40, '4_star': 58, '5_star': 212}
# Actual counts from reviews: review_rating
# 5    209
# 1    108
# 4     58
# 3     40
# 2     27
# Name: count, dtype: int64

# %% [markdown]
# #### 🏥 Google Reviews EDA + NLP Extension

# %%
# ==============================
# 11. Keyword Extraction (TF-IDF)
# ==============================
from sklearn.feature_extraction.text import TfidfVectorizer

# Use only non-null review text
texts = df['review_text'].dropna().astype(str)

# Vectorize reviews
tfidf = TfidfVectorizer(stop_words='english', max_features=20, ngram_range=(1,2))
tfidf_matrix = tfidf.fit_transform(texts)

# Top keywords
keywords = pd.DataFrame({
    "keyword": tfidf.get_feature_names_out(),
    "score": tfidf_matrix.sum(axis=0).A1
}).sort_values(by="score", ascending=False)

print("Top Keywords (TF-IDF):")
print(keywords.head(20))
# Out:
# Top Keywords (TF-IDF):
#        keyword      score
# 8     hospital  64.440167
# 15     service  34.029743
# 7         good  30.066164
# 16       staff  26.861786
# 12      nurses  24.946253
# 2       doctor  23.172710
# 5         food  19.962671
# 4   experience  19.191210
# 0         care  18.399209
# 6   gleneagles  18.125029
# 18        time  17.365027
# 17     surgery  16.820331
# 3           dr  15.431842
# 10        like  15.258620
# 14        room  14.778547
# 9         just  14.591692
# 19        ward  13.953739
# 1          day  13.783496
# 13    patients  12.894751
# 11       nurse  11.386350

# %%
# ==============================
# 12. Topic Modeling (LDA)
# ==============================
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer

# Count vectorizer for LDA
cv = CountVectorizer(stop_words='english', max_df=0.9, min_df=5)
cv_matrix = cv.fit_transform(texts)

# Fit LDA model
lda = LatentDirichletAllocation(n_components=5, random_state=42)
lda.fit(cv_matrix)

# Display top words for each topic
def display_topics(model, feature_names, no_top_words=10):
    for idx, topic in enumerate(model.components_):
        print(f"Topic {idx+1}:")
        print(" | ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))
        print("\n")

display_topics(lda, cv.get_feature_names_out())
# Out:
# Topic 1:
# hospital | care | gleneagles | treatment | medical | provided | dr | patients | money | health
#
#
# Topic 2:
# hospital | service | good | waiting | time | food | great | expensive | level | parking
#
#
# Topic 3:
# doctor | hospital | staff | just | like | test | said | asked | service | did
#
#
# Topic 4:
# time | hospital | medication | care | really | experience | didn | icu | ve | doctor
#
#
# Topic 5:
# nurses | staff | surgery | hospital | day | gleneagles | dr | ward | room | thank

# %%
# ==============================
# 13. Topic Distribution per Review
# ==============================
topic_values = lda.transform(cv_matrix)

# Create a new DataFrame with the same index as cv_matrix to ensure alignment
# This assumes cv_matrix was created from a subset of df
df_subset = df.iloc[cv_matrix.index] if hasattr(cv_matrix, 'index') else df.head(len(topic_values))

# Add dominant topic to this subset
df_subset['dominant_topic'] = topic_values.argmax(axis=1)

# Plot with the correctly aligned data
sns.countplot(x='dominant_topic', data=df_subset)
plt.title("Most Common Topics in Reviews")
plt.show()

# Alternatively, if you need to keep the original df intact:
# Create a temporary DataFrame for plotting
# temp_df = pd.DataFrame({'dominant_topic': topic_values.argmax(axis=1)})
# sns.countplot(x='dominant_topic', data=temp_df)
# Out:
# /var/tmp/ipykernel_12686/1274790882.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['dominant_topic'] = topic_values.argmax(axis=1)

# %% [markdown]
# # Assistant
# This error occurs because the length of the `topic_values` array (146) doesn't match the length of your DataFrame `df` (185). This mismatch happens when you try to assign the `dominant_topic` column to your DataFrame.
#
# The most likely cause is that your `cv_matrix` (CountVectorizer or TF-IDF matrix) was created using a subset of your data, or some rows were filtered out during preprocessing (perhaps due to empty reviews after text cleaning).
#
# Would you like me to provide the corrected code?

# %% [markdown]
# # KPI Metrics

# %%
import pandas as pd
import numpy as np
from textblob import TextBlob

# Ensure datetime and review length are present
df['review_datetime_utc'] = pd.to_datetime(df['review_datetime_utc'], errors='coerce')
df['review_length'] = df['review_text'].astype(str).apply(len)
df['sentiment'] = df['review_text'].astype(str).apply(lambda x: TextBlob(x).sentiment.polarity)

# %% [markdown]
# # ⭐ 1. Ratings-Based Metrics

# %%
# Average rating
avg_rating = df['review_rating'].mean()
median_rating = df['review_rating'].median()
rating_distribution = df['review_rating'].value_counts(normalize=True) * 100

print("Average Rating:", avg_rating)
print("Median Rating:", median_rating)
print("Rating Distribution (%):\n", rating_distribution)

# Trend over time (monthly)
df['month'] = df['review_datetime_utc'].dt.to_period("M")
rating_trend = df.groupby('month')['review_rating'].mean()
print("Monthly Rating Trend:\n", rating_trend.tail())
# Out:
# Average Rating: 3.5271493212669682
# Median Rating: 4.0
# Rating Distribution (%):
#  review_rating
# 5    47.285068
# 1    24.434389
# 4    13.122172
# 3     9.049774
# 2     6.108597
# Name: proportion, dtype: float64
# Monthly Rating Trend:
#  month
# 2025-04    4.50
# 2025-05    2.50
# 2025-06    1.00
# 2025-07    4.25
# 2025-08    3.80
# Freq: M, Name: review_rating, dtype: float64

# %% [markdown]
# # 💬 2. Sentiment Metrics

# %%
avg_sentiment = df['sentiment'].mean()
sentiment_distribution = pd.cut(df['sentiment'], bins=[-1,-0.05,0.05,1], labels=["Negative","Neutral","Positive"]).value_counts(normalize=True) * 100

print("Average Sentiment Score:", avg_sentiment)
print("Sentiment Distribution (%):\n", sentiment_distribution)

# Correlation with rating
corr_sentiment_rating = df[['review_rating','sentiment']].corr().iloc[0,1]
print("Correlation between Sentiment & Rating:", corr_sentiment_rating)
# Out:
# Average Sentiment Score: 0.1176434101524296
# Sentiment Distribution (%):
#  sentiment
# Neutral     48.181818
# Positive    40.454545
# Negative    11.363636
# Name: proportion, dtype: float64
# Correlation between Sentiment & Rating: 0.36913320354861623

# %% [markdown]
# # ✍️ 3. Review Quality & Engagement

# %%
avg_review_length = df['review_length'].mean()
avg_likes = df['review_likes'].mean(skipna=True)

print("Average Review Length:", avg_review_length)
print("Average Likes per Review:", avg_likes)

# Length vs rating
length_by_rating = df.groupby('review_rating')['review_length'].mean()
print("Review Length by Rating:\n", length_by_rating)
# Out:
# Average Review Length: 268.0769230769231
# Average Likes per Review: nan
# Review Length by Rating:
#  review_rating
# 1    557.537037
# 2    427.555556
# 3    171.125000
# 4    107.000000
# 5    161.153110
# Name: review_length, dtype: float64

# %% [markdown]
# # 👥 4. Reviewer Behavior

# %%
# One-time vs frequent
one_time_reviewers = (df['author_reviews_count'] == 1).mean() * 100
frequent_reviewers = (df['author_reviews_count'] > 5).mean() * 100

print("One-time Reviewers (%):", one_time_reviewers)
print("Frequent Reviewers (%):", frequent_reviewers)

# Reviewer bias (avg rating by reviewer type)
df['is_frequent'] = df['author_reviews_count'] > 5
bias = df.groupby('is_frequent')['review_rating'].mean()
print("Avg Rating by Reviewer Type:\n", bias)
# Out:
# One-time Reviewers (%): 7.918552036199094
# Frequent Reviewers (%): 70.81447963800905
# Avg Rating by Reviewer Type:
#  is_frequent
# False    3.720930
# True     3.447284
# Name: review_rating, dtype: float64

# %% [markdown]
# # 🔁 5. Owner Response Metrics

# %%
# Overall response rate
response_rate = df['owner_answer'].notna().mean() * 100

# Response rate by rating
response_by_rating = df.groupby('review_rating')['owner_answer'].apply(lambda x: x.notna().mean()*100)

# Response by sentiment
df['sentiment_group'] = pd.cut(df['sentiment'], bins=[-1,-0.05,0.05,1], labels=["Negative","Neutral","Positive"])
response_by_sentiment = df.groupby('sentiment_group')['owner_answer'].apply(lambda x: x.notna().mean()*100)

print("Overall Response Rate (%):", response_rate)
print("Response Rate by Rating (%):\n", response_by_rating)
print("Response Rate by Sentiment (%):\n", response_by_sentiment)
# Out:
# Overall Response Rate (%): 41.17647058823529
# Response Rate by Rating (%):
#  review_rating
# 1    66.666667
# 2    40.740741
# 3    37.500000
# 4    15.517241
# 5    35.885167
# Name: owner_answer, dtype: float64
# Response Rate by Sentiment (%):
#  sentiment_group
# Negative    58.000000
# Neutral     28.301887
# Positive    51.123596
# Name: owner_answer, dtype: float64
# /var/tmp/ipykernel_12686/4059787264.py:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   response_by_sentiment = df.groupby('sentiment_group')['owner_answer'].apply(lambda x: x.notna().mean()*100)

# %% [markdown]
# # 🔁 5. Owner Response Metrics

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# Create a copy of the dataframe with only non-NA reviews
# This ensures we work with the same subset throughout the code
df_clean = df.dropna(subset=['review_text']).copy()
texts = df_clean['review_text'].astype(str)

# ---- TF-IDF ----
tfidf = TfidfVectorizer(stop_words='english', max_features=20, ngram_range=(1,2))
tfidf_matrix = tfidf.fit_transform(texts)
keywords = pd.DataFrame({
    "keyword": tfidf.get_feature_names_out(),
    "score": tfidf_matrix.sum(axis=0).A1
}).sort_values(by="score", ascending=False)
print("Top TF-IDF Keywords:\n", keywords)

# ---- LDA Topic Modeling ----
cv = CountVectorizer(stop_words='english', max_df=0.9, min_df=5)
cv_matrix = cv.fit_transform(texts)

lda = LatentDirichletAllocation(n_components=5, random_state=42)
lda.fit(cv_matrix)

def display_topics(model, feature_names, no_top_words=10):
    topics = {}
    for idx, topic in enumerate(model.components_):
        topics[f"Topic {idx+1}"] = [feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]
    return topics

topics = display_topics(lda, cv.get_feature_names_out())
print("LDA Topics:\n", topics)

# Assign dominant topic per review
# Now we're using df_clean which has the same length as texts
topic_values = lda.transform(cv_matrix)
df_clean['dominant_topic'] = topic_values.argmax(axis=1) + 1

topic_distribution = df_clean['dominant_topic'].value_counts(normalize=True) * 100
print("Topic Distribution (%):\n", topic_distribution)
# Out:
# Top TF-IDF Keywords:
#         keyword      score
# 8     hospital  64.440167
# 15     service  34.029743
# 7         good  30.066164
# 16       staff  26.861786
# 12      nurses  24.946253
# 2       doctor  23.172710
# 5         food  19.962671
# 4   experience  19.191210
# 0         care  18.399209
# 6   gleneagles  18.125029
# 18        time  17.365027
# 17     surgery  16.820331
# 3           dr  15.431842
# 10        like  15.258620
# 14        room  14.778547
# 9         just  14.591692
# 19        ward  13.953739
# 1          day  13.783496
# 13    patients  12.894751
# 11       nurse  11.386350
# LDA Topics:
#  {'Topic 1': ['hospital', 'care', 'gleneagles', 'treatment', 'medical', 'provided', 'dr', 'patients', 'money', 'health'], 'Topic 2': ['hospital', 'service', 'good', 'waiting', 'time', 'food', 'great', 'expensive', 'level', 'parking'], 'Topic 3': ['doctor', 'hospital', 'staff', 'just', 'like', 'test', 'said', 'asked', 'service', 'did'], 'Topic 4': ['time', 'hospital', 'medication', 'care', 'really', 'experience', 'didn', 'icu', 've', 'doctor'], 'Topic 5': ['nurses', 'staff', 'surgery', 'hospital', 'day', 'gleneagles', 'dr', 'ward', 'room', 'thank']}
# Topic Distribution (%):
#  dominant_topic
# 2    32.770270
# 5    22.972973
# 1    18.918919
# 3    17.567568
# 4     7.770270
# Name: proportion, dtype: float64

# %% [markdown]
# # 🗝 6. Thematic Insights (TF-IDF & LDA)

# %%
agg_counts = {
    "1_star": df['reviews_per_score_1'].iloc[0],
    "2_star": df['reviews_per_score_2'].iloc[0],
    "3_star": df['reviews_per_score_3'].iloc[0],
    "4_star": df['reviews_per_score_4'].iloc[0],
    "5_star": df['reviews_per_score_5'].iloc[0],
}
actual_counts = df['review_rating'].value_counts()

print("Google Metadata Counts:", agg_counts)
print("Actual Extracted Counts:\n", actual_counts)
# Out:
# Google Metadata Counts: {'1_star': 110, '2_star': 28, '3_star': 40, '4_star': 58, '5_star': 212}
# Actual Extracted Counts:
#  review_rating
# 5    209
# 1    108
# 4     58
# 3     40
# 2     27
# Name: count, dtype: int64

# %%
# =============================
# 1. Setup
# =============================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from textblob import TextBlob
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

sns.set(style="whitegrid", palette="muted", font_scale=1.1)

# Load dataset
#df = pd.read_excel("Outscraper-20250823032119xs76.xlsx")
df['review_datetime_utc'] = pd.to_datetime(df['review_datetime_utc'], errors='coerce')
df['review_length'] = df['review_text'].astype(str).apply(len)
df['sentiment'] = df['review_text'].astype(str).apply(lambda x: TextBlob(x).sentiment.polarity)

# %% [markdown]
# # ⭐ 2. Ratings Overview

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="review_rating", data=df, palette="viridis")
plt.title("Ratings Distribution")
plt.show()

df.groupby(df['review_datetime_utc'].dt.to_period("M"))['review_rating'].mean().plot(figsize=(10,5), marker="o")
plt.title("Average Rating Over Time")
plt.ylabel("Avg Rating")
plt.show()
# Out:
# /var/tmp/ipykernel_12686/998790571.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="review_rating", data=df, palette="viridis")

# %% [markdown]
# # 💬 3. Sentiment Analysis

# %%
df['sentiment_group'] = pd.cut(df['sentiment'], bins=[-1,-0.05,0.05,1], labels=["Negative","Neutral","Positive"])

plt.figure(figsize=(6,4))
sns.countplot(x="sentiment_group", data=df, order=["Negative","Neutral","Positive"], palette="coolwarm")
plt.title("Sentiment Distribution")
plt.show()

sns.scatterplot(x="sentiment", y="review_rating", data=df, alpha=0.5)
plt.title("Sentiment vs Rating")
plt.show()
# Out:
# /var/tmp/ipykernel_12686/3429959399.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="sentiment_group", data=df, order=["Negative","Neutral","Positive"], palette="coolwarm")

# %% [markdown]
# # ✍️ 4. Review Length & Engagement

# %%
sns.histplot(df['review_length'], bins=50, kde=True)
plt.title("Review Length Distribution")
plt.show()

sns.boxplot(x="review_rating", y="review_length", data=df, palette="magma")
plt.title("Review Length by Rating")
plt.show()
# Out:
# /var/tmp/ipykernel_12686/2932125478.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="review_rating", y="review_length", data=df, palette="magma")

# %% [markdown]
# # 👥 5. Reviewer Behavior

# %%
sns.histplot(df['author_reviews_count'], bins=30, log_scale=True)
plt.title("Distribution of Reviewer Activity (# Reviews by Author)")
plt.show()

df['is_frequent'] = df['author_reviews_count'] > 5
sns.boxplot(x="is_frequent", y="review_rating", data=df, palette="Set2")
plt.title("Frequent vs One-Time Reviewers (Rating Bias)")
plt.xticks([0,1], ["One-time","Frequent"])
plt.show()
# Out:
# /var/tmp/ipykernel_12686/3163081248.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="is_frequent", y="review_rating", data=df, palette="Set2")

# %% [markdown]
# # 🔁 6. Owner Response Behavior

# %%
sns.barplot(x="review_rating", y=df['owner_answer'].notna(), data=df, estimator=np.mean, palette="crest")
plt.title("Response Rate by Rating")
plt.ylabel("Response Rate")
plt.show()

sns.barplot(x="sentiment_group", y=df['owner_answer'].notna(), data=df, estimator=np.mean, palette="rocket")
plt.title("Response Rate by Sentiment")
plt.ylabel("Response Rate")
plt.show()
# Out:
# /var/tmp/ipykernel_12686/3810842962.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="review_rating", y=df['owner_answer'].notna(), data=df, estimator=np.mean, palette="crest")
# /var/tmp/ipykernel_12686/3810842962.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="sentiment_group", y=df['owner_answer'].notna(), data=df, estimator=np.mean, palette="rocket")

# %% [markdown]
# # ☁️ 7. Word Cloud & Keywords

# %%
text = " ".join(df['review_text'].dropna().astype(str).values)

wc = WordCloud(width=800, height=400, background_color="white", colormap="viridis").generate(text)
plt.figure(figsize=(12,6))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.title("Most Frequent Words in Reviews")
plt.show()

# TF-IDF Keywords
tfidf = TfidfVectorizer(stop_words='english', max_features=20, ngram_range=(1,2))
tfidf_matrix = tfidf.fit_transform(df['review_text'].dropna().astype(str))
keywords = pd.DataFrame({
    "keyword": tfidf.get_feature_names_out(),
    "score": tfidf_matrix.sum(axis=0).A1
}).sort_values(by="score", ascending=False)

print("Top Keywords:\n", keywords)
# Out:
# Top Keywords:
#         keyword      score
# 8     hospital  64.440167
# 15     service  34.029743
# 7         good  30.066164
# 16       staff  26.861786
# 12      nurses  24.946253
# 2       doctor  23.172710
# 5         food  19.962671
# 4   experience  19.191210
# 0         care  18.399209
# 6   gleneagles  18.125029
# 18        time  17.365027
# 17     surgery  16.820331
# 3           dr  15.431842
# 10        like  15.258620
# 14        room  14.778547
# 9         just  14.591692
# 19        ward  13.953739
# 1          day  13.783496
# 13    patients  12.894751
# 11       nurse  11.386350

# %% [markdown]
# # 🗝 8. Topic Modeling (LDA)

# %%
cv = CountVectorizer(stop_words='english', max_df=0.9, min_df=5)
cv_matrix = cv.fit_transform(df['review_text'].dropna().astype(str))

lda = LatentDirichletAllocation(n_components=5, random_state=42)
lda.fit(cv_matrix)

def display_topics(model, feature_names, no_top_words=8):
    for idx, topic in enumerate(model.components_):
        print(f"Topic {idx+1}: ", [feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]])

display_topics(lda, cv.get_feature_names_out())
# Out:
# Topic 1:  ['hospital', 'care', 'gleneagles', 'treatment', 'medical', 'provided', 'dr', 'patients']
# Topic 2:  ['hospital', 'service', 'good', 'waiting', 'time', 'food', 'great', 'expensive']
# Topic 3:  ['doctor', 'hospital', 'staff', 'just', 'like', 'test', 'said', 'asked']
# Topic 4:  ['time', 'hospital', 'medication', 'care', 'really', 'experience', 'didn', 'icu']
# Topic 5:  ['nurses', 'staff', 'surgery', 'hospital', 'day', 'gleneagles', 'dr', 'ward']

# %% [markdown]
# # 📌 9. KPI Summary (Text Output)

# %%
summary = {
    "Average Rating": round(df['review_rating'].mean(),2),
    "Average Sentiment": round(df['sentiment'].mean(),2),
    "Response Rate (%)": round(df['owner_answer'].notna().mean()*100,2),
    "One-time Reviewer %": round((df['author_reviews_count'] == 1).mean()*100,2),
    "Frequent Reviewer %": round((df['author_reviews_count'] > 5).mean()*100,2),
    "Avg Review Length": round(df['review_length'].mean(),2),
    "Avg Likes": round(df['review_likes'].mean(skipna=True),2)
}
print("📊 KPI Dashboard:\n")
for k,v in summary.items():
    print(f"{k}: {v}")
# Out:
# 📊 KPI Dashboard:
#
# Average Rating: 3.53
# Average Sentiment: 0.12
# Response Rate (%): 41.18
# One-time Reviewer %: 7.92
# Frequent Reviewer %: 70.81
# Avg Review Length: 268.08
# Avg Likes: nan

# %%
# =============================
# 📌 9. Enhanced KPI Summary
# =============================

summary = {
    "Average Rating": round(df['review_rating'].mean(),2),
    "Average Sentiment": round(df['sentiment'].mean(),2),
    "Response Rate (%)": round(df['owner_answer'].notna().mean()*100,2),
    "One-time Reviewer %": round((df['author_reviews_count'] == 1).mean()*100,2),
    "Frequent Reviewer %": round((df['author_reviews_count'] > 5).mean()*100,2),
    "Avg Review Length": round(df['review_length'].mean(),2),
    "Avg Likes": round(df['review_likes'].mean(skipna=True),2)
}

# % Rating distribution
rating_dist = df['review_rating'].value_counts(normalize=True).sort_index() * 100
for rating, pct in rating_dist.items():
    summary[f"Rating {rating} %"] = round(pct,2)

# % Sentiment distribution
sentiment_dist = df['sentiment_group'].value_counts(normalize=True) * 100
for sentiment, pct in sentiment_dist.items():
    summary[f"{sentiment} Sentiment %"] = round(pct,2)

print("📊 KPI Dashboard:\n")
for k,v in summary.items():
    print(f"{k}: {v}")
# Out:
# 📊 KPI Dashboard:
#
# Average Rating: 3.53
# Average Sentiment: 0.12
# Response Rate (%): 41.18
# One-time Reviewer %: 7.92
# Frequent Reviewer %: 70.81
# Avg Review Length: 268.08
# Avg Likes: nan
# Rating 1 %: 24.43
# Rating 2 %: 6.11
# Rating 3 %: 9.05
# Rating 4 %: 13.12
# Rating 5 %: 47.29
# Neutral Sentiment %: 48.18
# Positive Sentiment %: 40.45
# Negative Sentiment %: 11.36

# %%
import matplotlib.pyplot as plt

# =============================
# 📊 10. KPI Visualizations
# =============================

# --- Ratings Distribution ---
rating_dist = df['review_rating'].value_counts(normalize=True).sort_index() * 100

plt.figure(figsize=(6,4))
rating_dist.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title("Ratings Distribution (%)")
plt.xlabel("Star Rating")
plt.ylabel("Percentage (%)")
plt.xticks(rotation=0)
plt.show()

# --- Sentiment Distribution ---
sentiment_dist = df['sentiment_group'].value_counts(normalize=True) * 100

plt.figure(figsize=(6,4))
sentiment_dist.plot(kind='bar', color=['red','grey','green'], edgecolor='black')
plt.title("Sentiment Distribution (%)")
plt.xlabel("Sentiment Group")
plt.ylabel("Percentage (%)")
plt.xticks(rotation=0)
plt.show()

# %%
# =============================
# 📌 11. Top Positive & Negative Reviews
# =============================

# Sort by sentiment score
top_positive = df.sort_values(by='sentiment', ascending=False).head(10)[['review_text','review_rating','sentiment']]
top_negative = df.sort_values(by='sentiment', ascending=True).head(10)[['review_text','review_rating','sentiment']]

print("🔥 Top 10 Positive Reviews (by sentiment):\n")
for i, row in top_positive.iterrows():
    print(f"⭐ Rating: {row['review_rating']} | Sentiment: {round(row['sentiment'],2)}")
    print(row['review_text'])
    print("-"*80)

print("\n⚠️ Top 10 Negative Reviews (by sentiment):\n")
for i, row in top_negative.iterrows():
    print(f"⭐ Rating: {row['review_rating']} | Sentiment: {round(row['sentiment'],2)}")
    print(row['review_text'])
    print("-"*80)
# Out:
# 🔥 Top 10 Positive Reviews (by sentiment):
#
# ⭐ Rating: 5 | Sentiment: 1.0
# Great App! Thank you
# --------------------------------------------------------------------------------
# ⭐ Rating: 1 | Sentiment: 1.0
# Best hospital
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: 1.0
# Excellent service from admission to ward to OT to discharge.
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: 1.0
# wonderful service from the staffs there!
# --------------------------------------------------------------------------------
# ⭐ Rating: 4 | Sentiment: 1.0
# One of the best and biggest Hospital in Singapore.
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: 1.0
# wonderful service
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: 1.0
# We are very happy with Gleneagles Hospital
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: 1.0
# Best hospital
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: 1.0
# Excellent experience here (Maternity ward) and A&E.
#
# The nurses seem well trained and the amenities are sufficient. the doctor you see would depend on your choice from my understanding
# --------------------------------------------------------------------------------
# ⭐ Rating: 5 | Sentiment: 1.0
# Always a wonderful and caring doctor and surgeon Dr Fong Kee siew
# --------------------------------------------------------------------------------
#
# ⚠️ Top 10 Negative Reviews (by sentiment):
#
# ⭐ Rating: 1 | Sentiment: -1.0
# Service very bad!!
# --------------------------------------------------------------------------------
# ⭐ Rating: 1 | Sentiment: -1.0
# Never stepping my foot, worst experience with Dr.Gwee Kok Ann and his unprofessional clinic.
# --------------------------------------------------------------------------------
# ⭐ Rating: 1 | Sentiment: -0.75
# So disappointed... to be treated like a dog... I should listen to my friends ...
# --------------------------------------------------------------------------------
# ⭐ Rating: 1 | Sentiment: -0.6
# Bad service, food is bad and never change worse is the arrangement of doctor.
# --------------------------------------------------------------------------------
# ⭐ Rating: 1 | Sentiment: -0.51
# Lousy and very poor attitude Cashier
# --------------------------------------------------------------------------------
# ⭐ Rating: 1 | Sentiment: -0.5
# Service not good!!!!
# --------------------------------------------------------------------------------
# ⭐ Rating: 3 | Sentiment: -0.5
# Expensive private hospital. Terribly overcrowded parking.
# --------------------------------------------------------------------------------
# ⭐ Rating: 1 | Sentiment: -0.41
# Terrible experience doing my health screening here. Long waiting times, cramped waiting area with insufficient seats, confusing building layout, nurses giving wrong instructions — misinforming me that I had another test at the radiology clinic upcoming when I had none, causing me to waste an hour waiting.
# --------------------------------------------------------------------------------
# ⭐ Rating: 1 | Sentiment: -0.4
# Worst radiology department. I was sent by my doctor for a MRI his clinic already had my CIGNA pre approval done and had faxed the form. However, the front staff had no clue insisted on getting a copy of my card and that also emailed to them. I am assuming staff is not trained to think just to be polite and follow standard process.
#
# After wasting 20 min of my time as I tried to log into my CIGNA online app to meet their demand of email of the card picture (which BTW I had also emailed in Jan when I went for another MRI) I was told since I was late for my appt by 15 min my spot has been given to next person.
#
# If I was already late then why bother wasting my time downloading the picture from my app. Also if this staff was trained and their was communication within this team she would have known that my CIGNA pre approval fax was already sent by my doctors clinic.
#
# Don’t waste your time with these $$ hungry clowns 🤡 providing worst service.
# --------------------------------------------------------------------------------
# ⭐ Rating: 1 | Sentiment: -0.38
# Very bad services from Ayu at the reception.  Yes we came late for the maternity tour, but she didn’t even bother to explain their packages since we are already here, and hinting us to leave.  Wasted our effort to come all the way here.  Do not recommend given it is a private hospital but lousy services.
# --------------------------------------------------------------------------------

# %%
rating_dist
# Out:
# review_rating
# 1    24.434389
# 2     6.108597
# 3     9.049774
# 4    13.122172
# 5    47.285068
# Name: proportion, dtype: float64

# %%
# --- Base KPI Metrics ---
kpi_data = {
    "Average Rating": round(df['review_rating'].mean(),2),
    "Average Sentiment": round(df['sentiment'].mean(),2),
    "Response Rate (%)": round(df['owner_answer'].notna().mean()*100,2),
    "One-time Reviewer %": round((df['author_reviews_count'] == 1).mean()*100,2),
    "Frequent Reviewer %": round((df['author_reviews_count'] > 5).mean()*100,2),
    "Avg Review Length": round(df['review_length'].mean(),2),
    "Avg Likes": round(df['review_likes'].mean(skipna=True),2)
}

# Rating % Distribution
rating_dist = df['review_rating'].value_counts(normalize=True).sort_index() * 100
for rating, pct in rating_dist.items():
    kpi_data[f"Rating {rating} %"] = round(pct,2)

# Sentiment % Distribution
sentiment_dist = df['sentiment_group'].value_counts(normalize=True) * 100
for sentiment, pct in sentiment_dist.items():
    kpi_data[f"{sentiment} Sentiment %"] = round(pct,2)

# --- Top Reviews Extraction ---
top_positive = df.sort_values(by='sentiment', ascending=False).head(10)[['review_text','review_rating','sentiment']]
top_negative = df.sort_values(by='sentiment', ascending=True).head(10)[['review_text','review_rating','sentiment']]

# Convert reviews into a single string (shortened for table)
pos_reviews_str = "\n\n".join([f"⭐{row['review_rating']} (sent={round(row['sentiment'],2)}): {row['review_text'][:150]}..." 
                               for _,row in top_positive.iterrows()])

neg_reviews_str = "\n\n".join([f"⭐{row['review_rating']} (sent={round(row['sentiment'],2)}): {row['review_text'][:150]}..." 
                               for _,row in top_negative.iterrows()])

# Add to KPI data
kpi_data["Top 10 Positive Reviews"] = pos_reviews_str
kpi_data["Top 10 Negative Reviews"] = neg_reviews_str

# --- Final KPI Table ---
kpi_df = pd.DataFrame(list(kpi_data.items()), columns=["Metric","Value"])

# Replace the custom module with standard pandas display
# Instead of: import caas_jupyter_tools
# Instead of: caas_jupyter_tools.display_dataframe_to_user("KPI Dashboard with Reviews", kpi_df)
display(kpi_df)  # This is the standard way to display dataframes in Jupyter notebooks
# Out:
#                      Metric                                              Value
# 0            Average Rating                                               3.53
# 1         Average Sentiment                                               0.12
# 2         Response Rate (%)                                              41.18
# 3       One-time Reviewer %                                               7.92
# 4       Frequent Reviewer %                                              70.81
# 5         Avg Review Length                                             268.08
# 6                 Avg Likes                                                NaN
# 7                Rating 1 %                                              24.43
# 8                Rating 2 %                                               6.11
# 9                Rating 3 %                                               9.05
# 10               Rating 4 %                                              13.12
# 11               Rating 5 %                                              47.29
# 12      Neutral Sentiment %                                              48.18
# 13     Positive Sentiment %                                              40.45
# 14     Negative Sentiment %                                              11.36
# 15  Top 10 Positive Reviews  ⭐5 (sent=1.0): Great App! Thank you...\n\n⭐1 (...
# 16  Top 10 Negative Reviews  ⭐1 (sent=-1.0): Service very bad!!...\n\n⭐1 (s...

# %%
weekly_ratings
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 weekly_ratings
#
# NameError: name 'weekly_ratings' is not defined

# %%
# =============================
# 📊 Weekly Ratings Trend
# =============================

# Ensure datetime is parsed
df['review_datetime_utc'] = pd.to_datetime(df['review_datetime_utc'], errors='coerce')

# Resample weekly average ratings
weekly_ratings = df.set_index('review_datetime_utc').resample('W')['review_rating'].mean()

# Plot
plt.figure(figsize=(14,6))
weekly_ratings.plot(marker='o', linewidth=1.5, alpha=0.8)
plt.title("Weekly Average Ratings Over Time")
plt.xlabel("Week")
plt.ylabel("Average Rating")
plt.grid(True, alpha=0.3)
plt.show()
